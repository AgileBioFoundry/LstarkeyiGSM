# %% [markdown]
# # Notebook to build a *Lipomyces Starkeyi* draft GSM

# %% [markdown]
# The *Lipomyces starkeyi* draft model (Lst) is built using *Rhodosporidium* IFO0880 (rto) as a scaffold. The process for building the model is as follows:
#
# * Map the genes from IFO0880 to Lst (using NCBI command line blast tool to score best matches).
# * Update the Lst model
# * Perform manual curation of simulations
# * Check performance
#
# This is the a barebones model that is used as a framework for building the complete model.

# %% [markdown]
# #### import necessary libraries

# %%
import pandas as pd
import cobra
from cobra.flux_analysis import flux_variability_analysis
from cobra.flux_analysis import gapfill

# %% [markdown]
# ## Gene Mapping
#
# Using blastp results from the Lst and IFO0880 genomes (comparing both Lst to IFO0880 and IFO0880 to Lst).
# blastp results compiled via Joonhoon and deposited into text files referenced below.
#
# ### Load blastp results

# %%
blast_header = ['qseqid','sseqid','pident','length','mismatch','gapopen',
                'qstart','qend','sstart','send','evalue','bitscore']

# %% [markdown]
# Lst to IFO0880

# %%
Lst_to_IFO0880_4 = pd.read_table('../blastp/Lipst1_1_to_IFO0880_4.txt', index_col=0, names=blast_header)
Lst_to_IFO0880_4.head()
Lst_to_IFO0880_4_full = Lst_to_IFO0880_4.copy()

# %%
# Lst_to_IFO0880_4.to_csv('lipst1_1_toIFO0880_4.csv')

# %% [markdown]
# Filter based on the 'evalue' result returned

# %%
Lst_to_IFO0880_4 = Lst_to_IFO0880_4[Lst_to_IFO0880_4['evalue'] < 1e-6]
print(len(Lst_to_IFO0880_4))
Lst_to_IFO0880_4.head()
# Out:
# 33640
#                 sseqid  pident  length  mismatch  gapopen  qstart  qend  \
# qseqid
# Lipst1_1_89131    9275  42.857     196        95        7       9   189
# Lipst1_1_89131   11708  36.019     211       122        4      12   209
# Lipst1_1_89131   11825  33.032     221       127        6      28   227
# Lipst1_1_89131   11824  35.938     192       106        7       1   181
# Lipst1_1_89131   12324  27.179     195       119        4      11   182
#
#                 sstart  send        evalue  bitscore
# qseqid
# Lipst1_1_89131      42   235  8.030000e-41     139.0
# Lipst1_1_89131      13   223  5.230000e-29     112.0
# Lipst1_1_89131     125   345  7.020000e-29     110.0
# Lipst1_1_89131      92   277  7.630000e-26     102.0
# Lipst1_1_89131      75   269  8.050000e-22      91.7

# %% [markdown]
# IFO0880 to Lst

# %%
IFO0880_4_to_Lst = pd.read_table('../blastp/IFO0880_4_to_Lipst1_1.txt', index_col=0, names=blast_header, )
IFO0880_4_to_Lst.index = IFO0880_4_to_Lst.index.astype('str')
IFO0880_4_to_Lst.head()
# Out:
#                  sseqid  pident  length  mismatch  gapopen  qstart  qend  \
# qseqid
# 10000    Lipst1_1_75163  63.294     425       149        3       1   422
# 10000    Lipst1_1_92653  40.541      37        21        1     328   364
# 10000     Lipst1_1_4357  27.049     122        71        4     242   358
# 10000   Lipst1_1_338855  32.000      50        30        1     133   178
# 10000     Lipst1_1_6497  32.432      37        25        0     136   172
#
#         sstart  send  evalue  bitscore
# qseqid
# 10000       86   506     0.0     549.0
# 10000      864   899     1.7      29.3
# 10000      115   223     4.6      27.7
# 10000       17    66     4.8      26.9
# 10000      386   422     6.6      26.9

# %% [markdown]
# Filter based on the 'evalue' result returned

# %%
IFO0880_4_to_Lst = IFO0880_4_to_Lst[IFO0880_4_to_Lst['evalue'] < 1e-6]
print(len(IFO0880_4_to_Lst))
IFO0880_4_to_Lst.head()
# Out:
# 33896
#                  sseqid  pident  length  mismatch  gapopen  qstart  qend  \
# qseqid
# 10000    Lipst1_1_75163  63.294     425       149        3       1   422
# 10001     Lipst1_1_5601  33.180     434       279        6      85   512
# 10001   Lipst1_1_319429  32.409     469       287       11      64   512
# 10001    Lipst1_1_48163  32.471     425       267        6      98   513
# 10001    Lipst1_1_72166  29.955     444       297        8      77   512
#
#         sstart  send        evalue  bitscore
# qseqid
# 10000       86   506  0.000000e+00     549.0
# 10001       12   440  1.660000e-59     201.0
# 10001       73   531  3.830000e-57     197.0
# 10001       24   437  7.140000e-56     192.0
# 10001       26   463  4.590000e-53     185.0

# %% [markdown]
# ### Map best hits
#
# ussing bitscore

# %%
IFO0880_4_to_Lst_map = dict()
for k in IFO0880_4_to_Lst.index.unique():
    temp = IFO0880_4_to_Lst.loc[[k]]
    IFO0880_4_to_Lst_map[k] = temp.loc[temp['bitscore'] > temp['bitscore'].max()*0.95,'sseqid'].tolist()

# %%
print(len(IFO0880_4_to_Lst_map.keys()))
print(len(sum([x for x in IFO0880_4_to_Lst_map.values()],[])))
print(len(set(sum([x for x in IFO0880_4_to_Lst_map.values()],[]))))
# Out:
# 4825
# 5340
# 4009

# %%
Lst_to_IFO0880_4_map = dict()
for k in Lst_to_IFO0880_4.index.unique():
    temp = Lst_to_IFO0880_4.loc[[k]]
    Lst_to_IFO0880_4_map[k] = temp.loc[temp['bitscore'] > temp['bitscore'].max()*0.95,'sseqid'].astype('str').tolist()

# %%
print(len(Lst_to_IFO0880_4_map.keys()))
print(len(sum([x for x in Lst_to_IFO0880_4_map.values()],[])))
print(len(set(sum([x for x in Lst_to_IFO0880_4_map.values()],[]))))
# Out:
# 4847
# 5296
# 3913

# %% [markdown]
# ### Map bidirectional best hits

# %%
BBH_map = dict()
for k, v in IFO0880_4_to_Lst_map.items():
    temp = set(x for x in v if x in Lst_to_IFO0880_4_map and k in Lst_to_IFO0880_4_map[x])
    if temp:
        BBH_map[k] = temp

# %%
BBH_map_strict = BBH_map.copy()

# %%
print(len(BBH_map.keys()))
print(len(sum([list(x) for x in BBH_map.values()],[])))
print(len(set(sum([list(x) for x in BBH_map.values()],[]))))
# Out:
# 3780
# 3924
# 3822

# %%
# BBH_map

# %% [markdown]
# ### Load R. toruloides model and build a draft model

# %%
rto = cobra.io.load_json_model('../models/Rt_IFO0880.json')
rto
# Out:
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# <Model Rt_IFO0880 at 0x2953f04d0>

# %%
rto.medium
# Out:
# {'EX_h_e': 1000.0,
#  'EX_h2o_e': 1000.0,
#  'EX_nh4_e': 1000.0,
#  'EX_o2_e': 1000.0,
#  'EX_pi_e': 1000.0,
#  'EX_so4_e': 1000.0,
#  'EX_glc__D_e': 1.0,
#  'EX_ca2_e': 1000.0,
#  'EX_fe2_e': 1000.0,
#  'EX_fe3_e': 1000.0,
#  'EX_k_e': 1000.0,
#  'EX_na1_e': 1000.0,
#  'EX_mg2_e': 1000.0,
#  'EX_mn2_e': 1000.0,
#  'EX_cu2_e': 1000.0,
#  'EX_zn2_e': 1000.0}

# %%
rto.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_RT = 0.07336590453116386</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>6.104E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e</td>
#       <td>3.852E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe3_e</td>
#       <td>EX_fe3_e</td>
#       <td>0.0004526</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>1</td>
#       <td>6</td>
#       <td>98.64%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e</td>
#       <td>0.04297</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e</td>
#       <td>0.004528</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_e</td>
#       <td>EX_mn2_e</td>
#       <td>4.453E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>na1_e</td>
#       <td>EX_na1_e</td>
#       <td>0.001915</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>0.4842</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>2.287</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>0.01953</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e</td>
#       <td>0.007354</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e</td>
#       <td>3.742E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>8aonn_m</td>
#       <td>SRC_8aonn_m</td>
#       <td>0.0001774</td>
#       <td>9</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>lipoate_m</td>
#       <td>SRC_lipoate_m</td>
#       <td>0.0002279</td>
#       <td>8</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>trnaala_c</td>
#       <td>SRC_trnaala_c</td>
#       <td>0.04237</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaarg_c</td>
#       <td>SRC_trnaarg_c</td>
#       <td>0.01076</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaasn_c</td>
#       <td>SRC_trnaasn_c</td>
#       <td>0.007921</td>
#       <td>10</td>
#       <td>1.30%</td>
#     </tr>
#     <tr>
#       <td>trnaasp_c</td>
#       <td>SRC_trnaasp_c</td>
#       <td>0.01447</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnacys_c</td>
#       <td>SRC_trnacys_c</td>
#       <td>0.002514</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnagln_c</td>
#       <td>SRC_trnagln_c</td>
#       <td>0.00865</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaglu_c</td>
#       <td>SRC_trnaglu_c</td>
#       <td>0.01531</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnagly_c</td>
#       <td>SRC_trnagly_c</td>
#       <td>0.03765</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnahis_c</td>
#       <td>SRC_trnahis_c</td>
#       <td>0.004488</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaile_c</td>
#       <td>SRC_trnaile_c</td>
#       <td>0.01163</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaleu_c</td>
#       <td>SRC_trnaleu_c</td>
#       <td>0.02349</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnalys_c</td>
#       <td>SRC_trnalys_c</td>
#       <td>0.01264</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnamet_c</td>
#       <td>SRC_trnamet_c</td>
#       <td>0.004186</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaphe_c</td>
#       <td>SRC_trnaphe_c</td>
#       <td>0.006982</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnapro_c</td>
#       <td>SRC_trnapro_c</td>
#       <td>0.01731</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaser_c</td>
#       <td>SRC_trnaser_c</td>
#       <td>0.02471</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnathr_c</td>
#       <td>SRC_trnathr_c</td>
#       <td>0.016</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnatrp_c</td>
#       <td>SRC_trnatrp_c</td>
#       <td>0.001711</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnatyr_c</td>
#       <td>SRC_trnatyr_c</td>
#       <td>0.004575</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaval_c</td>
#       <td>SRC_trnaval_c</td>
#       <td>0.02019</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3aap_c</td>
#       <td>DM_3aap_c</td>
#       <td>-0.05196</td>
#       <td>5</td>
#       <td>8.40%</td>
#     </tr>
#     <tr>
#       <td>4oglu_c</td>
#       <td>DM_4oglu_c</td>
#       <td>-0.0001022</td>
#       <td>5</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>amob_m</td>
#       <td>DM_amob_m</td>
#       <td>-0.0001774</td>
#       <td>15</td>
#       <td>0.09%</td>
#     </tr>
#     <tr>
#       <td>dad_5_m</td>
#       <td>DM_dad_5_m</td>
#       <td>-0.0001774</td>
#       <td>10</td>
#       <td>0.06%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-2.561</td>
#       <td>1</td>
#       <td>82.75%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e</td>
#       <td>-0.0003143</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>-4.221</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>-0.1678</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>hco3_e</td>
#       <td>EX_hco3_e</td>
#       <td>-0.001839</td>
#       <td>1</td>
#       <td>0.06%</td>
#     </tr>
#     <tr>
#       <td>zymst_e</td>
#       <td>EX_zymst_e</td>
#       <td>-0.0099</td>
#       <td>27</td>
#       <td>8.64%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### obtain list of rto reactions not mapped to a lst gene

# %%
reactions_not_mapped_rto = set()
for r in rto.reactions:
    if r.genes and not any(g.id in BBH_map for g in r.genes):
        print(r)
        reactions_not_mapped_rto.add(r.id)
# Out:
# FACOAL80p: atp_x + coa_x + octa_x --> amp_x + occoa_x + ppi_x
# URIH: h2o_c + uri_c --> rib__D_c + ura_c
# ACACT4m: accoa_m + occoa_m <-- 3odcoa_m + coa_m
# CHTNDA: chitin_c + h2o_c --> ac_c + chitos_c + h_c
# ACOAD8m: fad_m + ivcoa_m --> 3mb2coa_m + fadh2_m
# CYTD: cytd_c + h2o_c + h_c --> nh4_c + uri_c
# DPGM: 13dpg_c <=> 23dpg_c + h_c
# LEUTA: akg_c + leu__L_c <=> 4mop_c + glu__L_c
# FA140COAabcp: atp_c + 2.0 h2o_c + tdcoa_c --> adp_c + coa_c + 2.0 h_c + pi_c + ttdca_x
# MCITSm: h2o_m + oaa_m + ppcoa_m --> 2mcit_m + coa_m + h_m
# GNNUC: gsn_c + h2o_c --> gua_c + rib__D_c
# FA180COAabcp: atp_c + 2.0 h2o_c + stcoa_c --> adp_c + coa_c + 2.0 h_c + ocdca_x + pi_c
# H2Otm: h2o_c <=> h2o_m
# SACCD4m: h2o_m + nadp_m + saccrp__L_m --> L2aadp6sa_m + glu__L_m + h_m + nadph_m
# ADNUC: adn_c + h2o_c --> ade_c + rib__D_c
# FA182COAabcp: atp_c + 2.0 h2o_c + ocdycacoa_c --> adp_c + coa_c + 2.0 h_c + ocdcya_x + pi_c
# ACOAH: ac_c + coa_c + h_c <-- accoa_c + h2o_c
# NNAMrm: h2o_m + ncam_m <=> nac_m + nh4_m
# GTMLT: ala__L_c + gthrd_c --> cgly_c + gluala_c
# GMAND: gdpmann_c --> gdpddman_c + h2o_c
# NNAM: h2o_c + ncam_c --> nac_c + nh4_c
# ILETA: akg_c + ile__L_c <=> 3mop_c + glu__L_c
# DRTPPD: 25dthpp_c + h2o_c + h_c --> 5aprbu_c + nh4_c
# FACOAL100p: atp_x + coa_x + dca_x --> amp_x + dcacoa_x + ppi_x
# ACACT6m: accoa_m + ddcacoa_m <-- 3otdcoa_m + coa_m
# FA141COAabcp: atp_c + 2.0 h2o_c + tdecoa_c --> adp_c + coa_c + 2.0 h_c + pi_c + ttdcea_x
# FA161COAabcp: atp_c + 2.0 h2o_c + hdcoa_c --> adp_c + coa_c + 2.0 h_c + hdcea_x + pi_c
# ABUTt2r: 4abut_e + h_e <=> 4abut_c + h_c
# HCYSMT: amet_c + hcys__L_c --> ahcys_c + h_c + met__L_c
# HPRO_u9m: 4hpro_LT_m + q9_m --> 1p3h5c_m + h_m + q9h2_m
# 2DOXG6PP: 2doxg6p_c + h2o_c --> 2dglc_c + pi_c
# ME2: mal__L_c + nadp_c --> co2_c + nadph_c + pyr_c
# ABTA: 4abut_c + akg_c --> glu__L_c + sucsal_c
# LCYSTintv: cysi__L_v + h_v --> cysi__L_c + h_c
# MGCHrm: 3mgcoa_m + h2o_m <=> hmgcoa_m
# FA240tp: ttc_c --> ttc_x
# G3PT: glyc3p_c + h2o_c --> glyc_c + pi_c
# FA260tp: hexc_c --> hexc_x
# ASNN: asn__L_c + h2o_c --> asp__L_c + nh4_c
# DHORDfum: dhor__S_c + fum_c --> orot_c + succ_c
# FA160COAabcp: atp_c + 2.0 h2o_c + pmtcoa_c --> adp_c + coa_c + 2.0 h_c + hdca_x + pi_c
# HACD9m: 3hmbcoa_m + nad_m <=> 2maacoa_m + h_m + nadh_m
# EPGALURSe: h2o_e + pectin_e --> galur_e
# SPMDtex2: spmd_c --> spmd_e
# VALTA: akg_c + val__L_c <=> 3mob_c + glu__L_c
# ACACT7m: accoa_m + tdcoa_m <-- 3ohdcoa_m + coa_m
# DCYTD: dcyt_c + h2o_c + h_c --> duri_c + nh4_c
# OCOAT1m: acac_m + succoa_m --> aacoa_m + succ_m
# PTRCtex2: ptrc_c --> ptrc_e
# PAL: phe__L_c --> cinnm_c + nh4_c
# ASNNe: asn__L_e + h2o_e --> asp__L_e + nh4_e
# ALDD2ym: acald_m + h2o_m + nadp_m --> ac_m + 2.0 h_m + nadph_m
# ALDD2xm: acald_m + h2o_m + nad_m --> ac_m + 2.0 h_m + nadh_m
# FA181COAabcp: atp_c + 2.0 h2o_c + odecoa_c --> adp_c + coa_c + 2.0 h_c + ocdcea_x + pi_c
# PYNP2r: pi_c + uri_c <=> r1p_c + ura_c
# CHOLSH: chols_c + h2o_c --> chol_c + h_c + so4_c
# NO3t: no3_e <=> no3_c
# ORNCD: orn_c --> nh4_c + pro__L_c
# GDPTPDP: gdptp_c + h2o_c --> gtp_c + ppi_c
# VNDH: h2o_c + nad_c + vanln_c --> 2.0 h_c + nadh_c + vanlt_c
# HACD3m: 3oocoa_m + h_m + nadh_m <=> 3hocoa_m + nad_m
# NARK: no2_c <=> no2_e
# 2HESR: dtgcl_c + 2.0 gthrd_c --> gthox_c + 2.0 mercpeth_c
# NTD6: damp_c + h2o_c --> dad_2_c + pi_c
# 3AMACHYD: 3amac_c + h2o_c + h_c --> msa_c + nh4_c
# ACANTHAT: accoa_c + anth_c --> acanth_c + coa_c
# GGPTRCS: atp_c + glu__L_c + ptrc_c --> adp_c + ggptrc_c + h_c + pi_c
# INSH: h2o_c + ins_c --> hxan_c + rib__D_c
# DNAMTn2r: amet_c + dna_c <=> ahcys_c + dna5mtc_c + h_c
# PPA2: h2o_c + pppi_c --> h_c + pi_c + ppi_c
# VNDH_3: 34dhbald_c + h2o_c + nad_c --> 34dhbz_c + 2.0 h_c + nadh_c
# ACACT5m: accoa_m + dcacoa_m <-- 3oddcoa_m + coa_m
# NTD11: h2o_c + imp_c --> ins_c + pi_c
# LKDRA: lkdr_c <=> lald__L_c + pyr_c
# ACOAD5p: ddcacoa_x + fad_x --> dd2coa_x + fadh2_x
# HACD4m: 3odcoa_m + h_m + nadh_m <=> 3hdcoa_m + nad_m
# ACOAD6p: fad_x + tdcoa_x --> fadh2_x + td2coa_x
# GOFUCR: gdpofuc_c + h_c + nadph_c --> gdpfuc_c + nadp_c
# GDPDPK: atp_c + gdp_c --> amp_c + h_c + ppgpp_c
# MOCOS: 2.0 h_c + mobd_c + mptamp_c --> amp_c + cu2_c + h2o_c + moco_c
# GDMANE: gdpddman_c --> gdpofuc_c
# NTD1: dump_c + h2o_c --> duri_c + pi_c
# NTD7: amp_c + h2o_c --> adn_c + pi_c
# MN6PP: h2o_c + man6p_c --> man_c + pi_c
# CMPA: Ncbmpts_m + h2o_m + 2.0 h_m --> co2_m + nh4_m + ptrc_m
# ACOAD7p: fad_x + pmtcoa_x --> fadh2_x + hdd2coa_x
# ACOAD3p: fad_x + occoa_x --> fadh2_x + oc2coa_x
# MUCCY_kt: CCbuttc_c + h_c --> 4cml_c
# SDPDS: h2o_c + sl26da_c --> 26dap_LL_c + succ_c
# GLCATr: accoa_c + glc__D_c <=> acglc__D_c + coa_c
# 5AOPt2: 5aop_e + h_e --> 5aop_c + h_c
# COALDDH: conialdh_c + h2o_c + nad_c --> fer_c + 2.0 h_c + nadh_c
# GLUN: gln__L_c + h2o_c --> glu__L_c + nh4_c
# AMPTASEPG: h2o_c + progly_c --> gly_c + pro__L_c
# BWCOS: mptamp_c + wco_c --> amp_c + bwco_c + cu2_c
# OAADC: h_c + oaa_c --> co2_c + pyr_c
# NTRIR2x: 5.0 h_c + 3.0 nadh_c + no2_c --> 2.0 h2o_c + 3.0 nad_c + nh4_c
# CYTDH: cytd_c + h2o_c --> csn_c + rib__D_c
# SULO: h2o_c + o2_c + so3_c --> h2o2_c + so4_c
# FCLPA: fc1p_c <=> dhap_c + lald__L_c
# HXAND: h2o_c + hxan_c + nad_c --> h_c + nadh_c + xan_c
# ACPCS: amet_c --> 1acpc_c + 5mta_c + h_c
# ACACT3m: accoa_m + hxcoa_m <-- 3oocoa_m + coa_m
# ANHMK: anhm_c + atp_c + h2o_c --> acmum6p_c + adp_c + h_c
# MALTATr: accoa_c + malt_c <=> acmalt_c + coa_c
# CHLSTI_1er: zymst_r --> chlstol_r
# NITR: h_c + nadh_c + no3_c --> h2o_c + nad_c + no2_c
# ACOAD4p: dcacoa_x + fad_x --> dc2coa_x + fadh2_x
# NTD10: h2o_c + xmp_c --> pi_c + xtsn_c
# 4HBHYOXp: 4hbz_x + h_x + nadph_x + o2_x --> 34dhbz_x + h2o_x + nadp_x
# SULOm: h2o_m + o2_m + so3_m --> h2o2_m + so4_m
# HACD6m: 3otdcoa_m + h_m + nadh_m <=> 3htdcoa_m + nad_m
# ARSO4SH: arso4_c + h2o_c --> 2.0 h_c + phenol_c + so4_c
# NTD12: dimp_c + h2o_c --> din_c + pi_c
# BUPN: cala_c + h2o_c + 2.0 h_c --> ala_B_c + co2_c + nh4_c
# AFLBURPPAAMH: aflburppa_c + h2o_c + h_c --> aflbala_c + co2_c + nh4_c
# HCYSMT2: hcys__L_c + mmet_c --> h_c + 2.0 met__L_c
# BMOCOS: moco_c + mptamp_c --> amp_c + bmoco_c + cu2_c
# NTD3: dcmp_c + h2o_c --> dcyt_c + pi_c
# NTD9: gmp_c + h2o_c --> gsn_c + pi_c
# GAPP: g3p_c + h2o_c --> glyald_c + pi_c
# NTD8: dgmp_c + h2o_c --> dgsn_c + pi_c
# ACACT2m: accoa_m + btcoa_m <-- 3ohcoa_m + coa_m
# HACD7m: 3ohdcoa_m + h_m + nadh_m <=> 3hhdcoa_m + nad_m
# CATDOX: catechol_c + o2_c --> ccmuac_c + 2.0 h_c
# HCO3Em: co2_m + h2o_m <=> h_m + hco3_m
# PPGPPDP: h2o_c + ppgpp_c --> gdp_c + ppi_c
# XAND: h2o_c + nad_c + xan_c --> h_c + nadh_c + urate_c
# MTHFR2m: 2.0 h_m + mlthf_m + nadh_m --> 5mthf_m + nad_m
# NTD5: dtmp_c + h2o_c --> pi_c + thymd_c
# MTHFR3m: 2.0 h_m + mlthf_m + nadph_m --> 5mthf_m + nadp_m
# XTSNH: h2o_c + xtsn_c --> rib__D_c + xan_c
# VNDH_2: 4hbald_c + h2o_c + nad_c --> 4hbz_c + 2.0 h_c + nadh_c
# HACD2m: 3ohcoa_m + h_m + nadh_m <=> 3hhcoa_m + nad_m
# HACD5m: 3oddcoa_m + h_m + nadh_m <=> 3hddcoa_m + nad_m
# WCOS: 2.0 h_c + mptamp_c + tungs_c --> amp_c + cu2_c + h2o_c + wco_c
# GALt1r: gal_e <=> gal_c
# HMGLm: hmgcoa_m --> acac_m + accoa_m
# MANt1r: man_e <=> man_c
# GDPFUCtg: gdpfuc_c + gmp_g <=> gdpfuc_g + gmp_c
# CLPNDCPT1: clpndcoa_c + crn_c --> clpndcrn_c + coa_c
# MIP2CS326g_RT: 0.01 mipc326_RT_g + 0.01 ptd1ino_RT_g --> 0.01 12dgr_RT_g + 0.01 mip2c326_RT_g
# VLCS2p: atp_x + coa_x + dhcholestanate_x --> amp_x + dhcholestancoa_x + ppi_x
# MIP2CS324g_RT: 0.01 mipc324_RT_g + 0.01 ptd1ino_RT_g --> 0.01 12dgr_RT_g + 0.01 mip2c324_RT_g
# HPDCACRNCPT1: crn_c + hpdcacoa_c --> coa_c + hpdcacrn_c
# NMPTRCOX: nmptrc_c + o2_c --> 1mpyr_c + h2o2_c + nh4_c
# AMACR2p: dhcholestancoa_x + 0.5 o2_x --> dhcholoylcoa_x + h2o_x
# AGMTm: agm_m + h2o_m --> ptrc_m + urea_m
# XANDp: h2o_x + nad_x + xan_x --> h_x + nadh_x + urate_x
# AACTOOR: aact_c + h2o_c + o2_c --> h2o2_c + mthgxl_c + nh4_c
# AMACRr: cholcoar_r --> cholcoas_r
# MIP2CS224g_RT: 0.01 mipc224_RT_g + 0.01 ptd1ino_RT_g --> 0.01 12dgr_RT_g + 0.01 mip2c224_RT_g
# DPGase: 23dpg_c + h2o_c --> 3pg_c + pi_c
# DCSPTN1CPT1: crn_c + dcsptn1coa_c --> coa_c + dcsptn1crn_c
# GFUCS: gdpddman_c + h_c + nadph_c --> gdpfuc_c + nadp_c
# GTMLTe: ala__L_c + gthrd_c --> cgly_e + gluala_e
# ACHEe: ach_e + h2o_e --> ac_e + chol_e + h_e
# SCPx: cholcoaone_x + coa_x --> cholcoa_x + ppcoa_x
# HEXCCPT1: crn_c + hexccoa_c --> coa_c + hexccrn_c
# SCP22x: dmnoncoa_c <=> dmnoncoa_x
# XYLt: xyl__D_e <=> xyl__D_c
# MALTt1r: malt_e <=> malt_c
# PTHPS: ahdt_c --> 6pthp_c + pppi_c
# VLCSr: atp_r + coa_r + thcholstoic_r --> amp_r + cholcoar_r + ppi_r
# FRUt1r: fru_e <=> fru_c
# SACCD3m: akg_m + h_m + lys__L_m + nadph_m --> h2o_m + nadp_m + saccrp__L_m
# PTRCOX1: h2o_c + o2_c + ptrc_c --> 4abutn_c + h2o2_c + nh4_c
# ETHP: ethamp_c + h2o_c --> etha_c + pi_c
# MIP2CS126g_RT: 0.01 mipc126_RT_g + 0.01 ptd1ino_RT_g --> 0.01 12dgr_RT_g + 0.01 mip2c126_RT_g
# SCP3x: coa_x + dhcholestancoa_x + o2_x --> dcholcoa_x + h2o_x + ppcoa_x
# CHLP: cholp_c + h2o_c --> chol_c + pi_c
# SR5ARr: h_r + nadph_r + tststerone_r --> 5adtststerone_r + nadp_r
# NRVNCCPT1: crn_c + nrvnccoa_c --> coa_c + nrvnccrn_c
# LNLNCGCPT1: crn_c + lnlncgcoa_c --> coa_c + lnlncgcrn_c
# GAMt1r: gam_e <=> gam_c
# C161CPT12: crn_c + hdd2coa_c --> coa_c + hdd2crn_c
# H2O2syn: h_c + nadph_c + o2_c --> h2o2_c + nadp_c
# 13DAMPPOX: 13dampp_c + h2o_c + o2_c --> bamppald_c + h2o2_c + nh4_c
# XAOx: h2o_x + o2_x + xan_x --> h2o2_x + urate_x
# PAPStg: paps_c <=> paps_g
# P45017A1r: h_r + nadph_r + o2_r + prgnlone_r --> 17ahprgnlone_r + h2o_r + nadp_r
# PTHPSn: ahdt_n --> 6pthp_n + pppi_n
# LTC4Sr: gthrd_r + leuktrA4_r --> leuktrC4_r
# PTDCACRNCPT1: crn_c + ptdcacoa_c --> coa_c + ptdcacrn_c
# XAO2x: h2o_x + hxan_x + o2_x --> h2o2_x + xan_x
# AMACR2r: dhcholestancoa_r + 0.5 o2_r --> dhcholoylcoa_r + h2o_r
# LTA4H: h2o_c + leuktrA4_c --> leuktrB4_c
# C161CPT1: crn_c + hdcoa_c --> coa_c + hdcecrn_c
# C181CPT1: crn_c + odecoa_c --> coa_c + odecrn_c
# GLCtg: glc__D_c <=> glc__D_g
# M14NTg: n2m2masn_g + uacgam_g --> h_g + n2m2nmasn_g + udp_g
# HISTASE: h2o_c + hista_c + o2_c --> h2o2_c + im4act_c + nh4_c
# VLCSp: atp_x + coa_x + thcholstoic_x --> amp_x + cholcoar_x + ppi_x
# TETTET6CPT1: crn_c + tettet6coa_c --> coa_c + tettet6crn_c
# P45017A3r: h_r + nadph_r + o2_r + prgstrn_r --> 17ahprgstrn_r + h2o_r + nadp_r
# HMGLx: hmgcoa_x --> acac_x + accoa_x
# SCP21x: phytcoa_c <=> phytcoa_x
# MIP2CS124g_RT: 0.01 mipc124_RT_g + 0.01 ptd1ino_RT_g --> 0.01 12dgr_RT_g + 0.01 mip2c124_RT_g
# VLCS2r: atp_r + coa_r + dhcholestanate_r --> amp_r + dhcholestancoa_r + ppi_r
# CSNAT2x: crn_x + dmnoncoa_x <=> coa_x + dmnoncrn_x
# ALDD21er: h2o_r + nad_r + pristanal_r --> 2.0 h_r + nadh_r + prist_r
# ELAIDCPT1: crn_c + od2coa_c --> coa_c + elaidcrn_c
# PROD_u9m: pro__L_m + q9_m --> 1pyr5c_m + h_m + q9h2_m
# SCP2x: coa_x + dhocholoylcoa_x --> dgcholcoa_x + ppcoa_x
# TTDCPT1: crn_c + tdcoa_c --> coa_c + ttdcrn_c
# P45017A4r: 17ahprgstrn_r + h_r + nadph_r + 0.5 o2_r --> acald_r + andrstndn_r + h2o_r + nadp_r
# HACD1m: aacoa_m + h_m + nadh_m <=> 3hbcoa_m + nad_m
# MHISOR: h2o_c + mhista_c + o2_c --> 3mldz_c + h2o2_c + nh4_c
# AMACRp: cholcoar_x --> cholcoas_x
# SR5AR2r: andrstndn_r + h_r + nadph_r --> andrstandn_r + nadp_r
# TRYPTAOX: h2o_c + o2_c + trypta_c --> h2o2_c + id3acald_c + nh4_c
# C160CPT1: crn_c + pmtcoa_c --> coa_c + pmtcrn_c
# MIP2CS226g_RT: 0.01 mipc226_RT_g + 0.01 ptd1ino_RT_g --> 0.01 12dgr_RT_g + 0.01 mip2c226_RT_g
# DHAAt1r: dhdascb_e <=> dhdascb_c
# P45017A2r: 17ahprgnlone_r + h_r + nadph_r + 0.5 o2_r --> acald_r + dhea_r + h2o_r + nadp_r
# GLYCLTDyp: glx_x + h_x + nadph_x --> glyclt_x + nadp_x
# HTMLA_m: 3htmelys_m --> 4tmeabut_m + gly_m
# TMABDH1_m: 4tmeabut_m + h2o_m + nad_m --> gbbtn_m + 2.0 h_m + nadh_m
# NDPK10m: atp_m + didp_m <=> adp_m + ditp_m
# NDPK1m: atp_m + gdp_m <=> adp_m + gtp_m
# NDPK2m: atp_m + udp_m <=> adp_m + utp_m
# NDPK3m: atp_m + cdp_m <=> adp_m + ctp_m
# NDPK4m: atp_m + dtdp_m <=> adp_m + dttp_m
# NDPK5m: atp_m + dgdp_m <=> adp_m + dgtp_m
# NDPK6m: atp_m + dudp_m <=> adp_m + dutp_m
# NDPK7m: atp_m + dcdp_m <=> adp_m + dctp_m
# NDPK8m: atp_m + dadp_m <=> adp_m + datp_m
# NDPK9m: atp_m + idp_m <=> adp_m + itp_m
# DNTPPA: ahdt_c + h2o_c --> dhpmp_c + h_c + ppi_c
# ACOAD3m: fad_m + occoa_m --> fadh2_m + oc2coa_m
# ACOAD4m: dcacoa_m + fad_m --> dc2coa_m + fadh2_m
# ACOAD5m: ddcacoa_m + fad_m --> dd2coa_m + fadh2_m
# ACOAD6m: fad_m + tdcoa_m --> fadh2_m + td2coa_m
# ACOAD7m: fad_m + pmtcoa_m --> fadh2_m + hdd2coa_m
# ACOAD8p: fad_x + stcoa_x --> fadh2_x + od2coa_x
# C3STKR1er: 4mzym_int2_r + h_r + nadph_r --> 4mzym_r + nadp_r
# C3STKR2er: h_r + nadph_r + zym_int2_r --> nadp_r + zymst_r
# PI45BP5Pn_RT: h2o_n + 0.01 ptd145bp_RT_n --> pi_n + 0.01 ptd4ino_RT_n
# PMDPHT: 5aprbu_c + h2o_c --> 4r5au_c + pi_c
# GNDp: 6pgc_x + nadp_x --> co2_x + nadph_x + ru5p__D_x
# C30CPT1: crn_c + ppcoa_c <=> coa_c + pcrn_c
# PCRNtc: pcrn_x --> pcrn_c
# ACRNtp: acrn_x --> acrn_c
# FA183COAabcp: atp_c + 2.0 h2o_c + lnlncgcoa_c --> adp_c + coa_c + 2.0 h_c + lnlncg_x + pi_c
# 34HPPOR: 34hpp_c + o2_c --> co2_c + hgentis_c
# 2OBUTt: 2obut_e + h_e <=> 2obut_c + h_c
# AASAD3m: L2aadp6sa_m + h2o_m + nad_m --> L2aadp_m + 2.0 h_m + nadh_m
# UCP2ASPtm: asp__L_m + h_c + pi_c --> asp__L_c + h_m + pi_m
# UCP2MALtm: h_c + mal__L_m + pi_c --> h_m + mal__L_c + pi_m
# UCP2OAAtm: h_c + oaa_m + pi_c --> h_m + oaa_c + pi_m
# GLYtm: gly_c <=> gly_m
# ALDD16er: h2o_r + hxdcal_r + nad_r --> 2.0 h_r + hdca_r + nadh_r
# ALDD3C161er: h2o_r + hxdceal_r + nad_r --> 2.0 h_r + hdc2ea_r + nadh_r
# 4HBALDDm: 4hbald_m + h2o_m + nad_m --> 4hbz_m + 2.0 h_m + nadh_m
# QUINDH: nad_c + quin_c --> 3dhq_c + 2.0 h_c + nadh_c
# TAL: tyr__L_c --> T4hcinnm_c + nh4_c
# FA200tp: arach_c --> arach_x
# FA220tp: docosac_c --> docosac_x
# PACCOAL: atp_c + coa_c + pac_c --> amp_c + phaccoa_c + ppi_c
# COUCOAHp: coucoa_x + h2o_x --> 34hp3hpcoa_x
# 4HBZACCOARp: 34hp3hpcoa_x + nad_x --> 4hbzaccoa_x + h_x + nadh_x
# 4HBZACCOATp: 4hbzaccoa_x + coa_x --> 4hbzcoa_x + accoa_x
# T4HCINNMtp: T4hcinnm_c --> T4hcinnm_x
# PCADYOX: 34dhbz_c + o2_c --> CCbuttc_c + 2.0 h_c
# 3OADPCOATm: 3oxoadp_m + succoa_m --> oxadpcoa_m + succ_m
# 3OXCOATm: coa_m + oxadpcoa_m --> accoa_m + succoa_m
# CRNtp: crn_c <=> crn_x
# 34DHCINMtp: 34dhcinm_c --> 34dhcinm_x
# CAFFCOAHp: caffcoa_x + h2o_x --> 3dhp3hpcoa_x
# 34DHBZACCOARp: 3dhp3hpcoa_x + nad_x --> 34dhbzaccoa_x + h_x + nadh_x
# 34DHBZACCOATp: 34dhbzaccoa_x + coa_x --> 34dhbzcoa_x + accoa_x
# PSYer: 2.0 ggdp_r --> phyto_r + 2.0 ppi_r
# PDSer: 4.0 nadp_r + phyto_r --> 4.0 h_r + lycop_r + 4.0 nadph_r
# LYCOPCer: lycop_r --> gcaro_r
# GCAROCer: gcaro_r --> bcaro_r
# ACACt2: acac_e + h_e <=> acac_c + h_c
# C40CPT1: btcoa_c + crn_c --> c4crn_c + coa_c
# C60CPT1: crn_c + hxcoa_c --> c6crn_c + coa_c
# NTD2e: h2o_e + ump_e --> pi_e + uri_e
# NTD4e: cmp_e + h2o_e --> cytd_e + pi_e
# NTD7e: amp_e + h2o_e --> adn_e + pi_e
# NTD9e: gmp_e + h2o_e --> gsn_e + pi_e
# G2PPe: glyc2p_e + h2o_e --> glyc_e + pi_e
# 2PGPe: 2pg_e + h2o_e --> glyc__R_e + pi_e
# 3PGPe: 3pg_e + h2o_e --> glyc__R_e + pi_e
# PEPPe: h2o_e + pep_e --> pi_e + pyr_e
# GAM6PPe: gam6p_e + h2o_e --> gam_e + pi_e
# GNPe: 6pgc_e + h2o_e --> glcn_e + pi_e
# MAN1PPe: h2o_e + man1p_e --> man_e + pi_e
# MAN6PPe: h2o_e + man6p_e --> man_e + pi_e
# MINPP1er: h2o_r + minohp_r --> mi13456p_r + pi_r
# MINPP2er: h2o_r + mi13456p_r --> mi1456p_r + pi_r
# MINPP3er: h2o_r + mi1456p_r --> mi145p_r + pi_r
# MINPP4er: h2o_r + mi1345p_r --> mi145p_r + pi_r

# %% [markdown]
# #### build draft lst model from rto

# %%
model = cobra.Model()
for r in rto.reactions:
    if not r.genes:
        model.add_reactions([r.copy()])
    elif any(g.id in BBH_map for g in r.genes):
        r_copy = r.copy()
        temp_gpr = r.gene_reaction_rule
        for g in r.genes:
            if g.id in BBH_map:
                if len(BBH_map[g.id]) == 1:
                    temp_gpr = temp_gpr.replace(g.id, list(BBH_map[g.id])[0])
                else:
                    temp_gpr = temp_gpr.replace(g.id, '('+' or '.join(BBH_map[g.id])+')')
        r_copy.gene_reaction_rule = temp_gpr
        model.add_reactions([r_copy])

# %% [markdown]
# #### Test the draft model for growth

# %%
model.reactions.get_by_id('BIOMASS_RT').id = 'BIOMASS_Ls'
model.objective = 'BIOMASS_Ls'
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ls = 0.0</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>0.732</td>
#       <td>6</td>
#       <td>100.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ac_e</td>
#       <td>EX_ac_e</td>
#       <td>-0.732</td>
#       <td>2</td>
#       <td>33.33%</td>
#     </tr>
#     <tr>
#       <td>btd_RR_e</td>
#       <td>EX_btd_RR_e</td>
#       <td>-0.244</td>
#       <td>4</td>
#       <td>22.22%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-0.488</td>
#       <td>1</td>
#       <td>11.11%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>-0.732</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>sbt__D_e</td>
#       <td>EX_sbt__D_e</td>
#       <td>-0.244</td>
#       <td>6</td>
#       <td>33.33%</td>
#     </tr>
#   </tbody>
# </table>

# %%
model.optimize()
# Out:
# <Solution 0.000 at 0x2a188a450>

# %% [markdown]
# #### The draft model cannot simulate growth

# %%
metabolites_not_synthesized_original = set()
for m, v in model.reactions.BIOMASS_Ls.metabolites.items():
    if v < 0:
        with model:
#             for x in ['ALDD2ym','C30CPT1','C3STKR1er','C3STKR2er','DNTPPA','DRTPPD','PMDPHT']:
#                 r = rto.reactions.get_by_id(x).copy()
#                 model_rto_based_v2.add_reaction(r)
            temp = model.add_boundary(m, type='demand')
            model.objective = temp.id
            sol = model.optimize()
            if not sol.objective_value:
#                 print(m)
                metabolites_not_synthesized_original.add(m.id)
len(metabolites_not_synthesized_original)
# Out:
# 30

# %% [markdown]
# # Examining models.

# %%
model
# Out:
# <Model None at 0x296550f90>

# %%
gapfiller = cobra.flux_analysis.gapfilling.GapFiller(model, rto, demand_reactions=False, integer_threshold=1e-9)
gapfiller.model.solver.configuration.tolerances.feasibility = 1e-9
gapfiller.model.solver.configuration.tolerances.integrality = 1e-10
# gapfiller.model.solver.configuration.tolerances.optimality = 1e-9
gapfiller.fill()
# Out:
# [[<Reaction H2Otm at 0x29ee50990>,
#   <Reaction DRTPPD at 0x29eeade10>,
#   <Reaction ALDD2ym at 0x29efe1910>,
#   <Reaction DNTPPA at 0x29f171e50>,
#   <Reaction C3STKR1er at 0x29efa92d0>,
#   <Reaction C3STKR2er at 0x29f189210>,
#   <Reaction PMDPHT at 0x29f194590>,
#   <Reaction C30CPT1 at 0x29f197ed0>,
#   <Reaction ACRNtp at 0x29f1a4510>,
#   <Reaction FA183COAabcp at 0x29f1a6150>,
#   <Reaction CRNtp at 0x29f23b210>]]

# %%
growing_model = model.copy()

for i in ['H2Otm','DRTPPD','ALDD2ym','DNTPPA',
          'C3STKR1er','C3STKR2er','PMDPHT','C30CPT1',
          'ACRNtp','FA183COAabcp','CRNtp']:
    r = rto.reactions.get_by_id(i)
    growing_model.add_reactions([r.copy()])
# Out:
# Read LP format model from file /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/tmp_ihgsnrh.lp
# Reading time = 0.01 seconds
# : 1897 rows, 4208 columns, 17198 nonzeros

# %%
growing_model.optimize()
# Out:
# <Solution 0.060 at 0x2a3ba8c50>

# %% [markdown]
# ### removing Rto genes from L. starkeyi model.

# %%
model_removed = model.copy()
cobra.manipulation.remove_genes(model_removed, [g.id for g in model.genes if not g.id.startswith('Lipst1')])
# Out:
# Read LP format model from file /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/tmphmm3gh7w.lp
# Reading time = 0.01 seconds
# : 1897 rows, 4208 columns, 17198 nonzeros

# %%
model_removed.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ls = 0.0</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>0.732</td>
#       <td>6</td>
#       <td>100.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ac_e</td>
#       <td>EX_ac_e</td>
#       <td>-0.732</td>
#       <td>2</td>
#       <td>33.33%</td>
#     </tr>
#     <tr>
#       <td>btd_RR_e</td>
#       <td>EX_btd_RR_e</td>
#       <td>-0.244</td>
#       <td>4</td>
#       <td>22.22%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-0.488</td>
#       <td>1</td>
#       <td>11.11%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>-0.732</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>sbt__D_e</td>
#       <td>EX_sbt__D_e</td>
#       <td>-0.244</td>
#       <td>6</td>
#       <td>33.33%</td>
#     </tr>
#   </tbody>
# </table>

# %%
model_removed
# Out:
# <Model None at 0x2a3a6ff50>

# %% [markdown]
# Finding reactions needed for growth.

# %% [markdown]
# #### Reactions removed by removing R. toruloides genes

# %%
reactions_needing_genes = []
for r in growing_model.reactions:
    if r.id not in model_removed.reactions:
        reactions_needing_genes.append(r.id)
        print(r.id, r.gene_reaction_rule)
# Out:
# CYOR_u9m COB and Lipst1_1_72848 and Lipst1_1_112667 and Lipst1_1_38038 and Lipst1_1_47735 and Lipst1_1_3376 and Lipst1_1_42388 and 15231 and Lipst1_1_6808 and Lipst1_1_70538 and Lipst1_1_65274 and Lipst1_1_49747
# FAO141p_even (10293 and Lipst1_1_75883 and Lipst1_1_158150 and 12742 and Lipst1_1_160699 and Lipst1_1_47324) or (10293 and Lipst1_1_75883 and Lipst1_1_158150 and 12752 and Lipst1_1_160699 and Lipst1_1_47324) or (10293 and Lipst1_1_75883 and Lipst1_1_158150 and Lipst1_1_160699 and Lipst1_1_47324 and Lipst1_1_2790)
# RNDR3n (10848 and Lipst1_1_2363 and Lipst1_1_29458 and Lipst1_1_2363) or (Lipst1_1_2363 and Lipst1_1_29458 and 12730 and Lipst1_1_2363) or (Lipst1_1_2363 and Lipst1_1_29458 and 12737 and Lipst1_1_2363)
# FAO161p_odd (10293 and Lipst1_1_75883 and 12742 and Lipst1_1_47324) or (10293 and Lipst1_1_75883 and 12752 and Lipst1_1_47324) or (10293 and Lipst1_1_75883 and Lipst1_1_47324 and Lipst1_1_2790)
# FAO161p_even (10293 and Lipst1_1_75883 and Lipst1_1_158150 and 12742 and Lipst1_1_160699 and Lipst1_1_47324) or (10293 and Lipst1_1_75883 and Lipst1_1_158150 and 12752 and Lipst1_1_160699 and Lipst1_1_47324) or (10293 and Lipst1_1_75883 and Lipst1_1_158150 and Lipst1_1_160699 and Lipst1_1_47324 and Lipst1_1_2790)
# RNDR4n (10848 and Lipst1_1_2363 and Lipst1_1_29458 and Lipst1_1_2363) or (Lipst1_1_2363 and Lipst1_1_29458 and 12730 and Lipst1_1_2363) or (Lipst1_1_2363 and Lipst1_1_29458 and 12737 and Lipst1_1_2363)
# TRDRm 16019 and Lipst1_1_404
# OIVD3m (Lipst1_1_67480 and 11183 and 12566 and 15436) or (Lipst1_1_67480 and 11188 and 12566 and 15436)
# TRDR (10848 and Lipst1_1_404) or (12730 and Lipst1_1_404) or (12737 and Lipst1_1_404)
# FAO141p_odd (10293 and Lipst1_1_75883 and 12742 and Lipst1_1_47324) or (10293 and Lipst1_1_75883 and 12752 and Lipst1_1_47324) or (10293 and Lipst1_1_75883 and Lipst1_1_47324 and Lipst1_1_2790)
# SERPTer Lipst1_1_71191 and 9394 and Lipst1_1_72156
# FAO181p_even (10293 and Lipst1_1_75883 and Lipst1_1_158150 and 12742 and Lipst1_1_160699 and Lipst1_1_47324) or (10293 and Lipst1_1_75883 and Lipst1_1_158150 and 12752 and Lipst1_1_160699 and Lipst1_1_47324) or (10293 and Lipst1_1_75883 and Lipst1_1_158150 and Lipst1_1_160699 and Lipst1_1_47324 and Lipst1_1_2790)
# ATPS3m ATP6 and ATP8 and ATP9 and Lipst1_1_90916 and 9619 and Lipst1_1_25267 and Lipst1_1_101415 and Lipst1_1_72935 and Lipst1_1_32736 and Lipst1_1_71305 and Lipst1_1_72399 and Lipst1_1_52074 and 13759 and 13842 and Lipst1_1_86782 and Lipst1_1_4904 and Lipst1_1_46841 and Lipst1_1_75804 and 15880 and Lipst1_1_448
# GLYCt2 Lipst1_1_201837 and 10705
# THIORDXm (Lipst1_1_101999 or Lipst1_1_4575) and 16019
# FAO182p_odd (10293 and Lipst1_1_75883 and 12742 and Lipst1_1_160699 and Lipst1_1_47324) or (10293 and Lipst1_1_75883 and 12752 and Lipst1_1_160699 and Lipst1_1_47324) or (10293 and Lipst1_1_75883 and Lipst1_1_160699 and Lipst1_1_47324 and Lipst1_1_2790)
# FAO182p_even (10293 and Lipst1_1_75883 and Lipst1_1_158150 and 12742 and Lipst1_1_160699 and Lipst1_1_47324) or (10293 and Lipst1_1_75883 and Lipst1_1_158150 and 12752 and Lipst1_1_160699 and Lipst1_1_47324) or (10293 and Lipst1_1_75883 and Lipst1_1_158150 and Lipst1_1_160699 and Lipst1_1_47324 and Lipst1_1_2790)
# THIORDXni (10848 and Lipst1_1_44049) or (12730 and Lipst1_1_44049) or (12737 and Lipst1_1_44049)
# FAO181p_odd (10293 and Lipst1_1_75883 and 12742 and Lipst1_1_47324) or (10293 and Lipst1_1_75883 and 12752 and Lipst1_1_47324) or (10293 and Lipst1_1_75883 and Lipst1_1_47324 and Lipst1_1_2790)
# RNDR1n (10848 and Lipst1_1_2363 and Lipst1_1_29458 and Lipst1_1_2363) or (Lipst1_1_2363 and Lipst1_1_29458 and 12730 and Lipst1_1_2363) or (Lipst1_1_2363 and Lipst1_1_29458 and 12737 and Lipst1_1_2363)
# RNDR2n (10848 and Lipst1_1_2363 and Lipst1_1_29458 and Lipst1_1_2363) or (Lipst1_1_2363 and Lipst1_1_29458 and 12730 and Lipst1_1_2363) or (Lipst1_1_2363 and Lipst1_1_29458 and 12737 and Lipst1_1_2363)
# THIORDXi (10848 and Lipst1_1_74862) or (Lipst1_1_74862 and 12730) or (Lipst1_1_74862 and 12737)
# PRPPS Lipst1_1_85 and 16592
# GLCNACT 13348 and Lipst1_1_74719
# CYOO6m COX1 and COX2 and COX3 and Lipst1_1_65503 and Lipst1_1_3895 and Lipst1_1_55045 and 12506 and 11352 and 13275 and 11769 and Lipst1_1_54407 and Lipst1_1_26031 and Lipst1_1_67449 and Lipst1_1_65274
# 2OXOADOXm Lipst1_1_67480 and Lipst1_1_3320 and 9274
# NADH2_u9m2 NAD1 and NAD2 and NAD3 and NAD4 and NAD4L and NAD5 and NAD6 and Lipst1_1_49243 and Lipst1_1_68269 and Lipst1_1_94660 and Lipst1_1_3107 and Lipst1_1_75481 and 11151 and Lipst1_1_91670 and Lipst1_1_6913 and 11857 and 12482 and Lipst1_1_111403 and Lipst1_1_1786 and Lipst1_1_71618 and Lipst1_1_114537 and Lipst1_1_180820 and 13268 and Lipst1_1_7118 and 13656 and Lipst1_1_75503 and Lipst1_1_275555 and Lipst1_1_2955 and Lipst1_1_54800 and 14717 and Lipst1_1_111304 and Lipst1_1_72853 and Lipst1_1_102530 and Lipst1_1_76917 and Lipst1_1_2954 and Lipst1_1_157358 and Lipst1_1_103623 and 8446 and 8530 and Lipst1_1_105616 and 8817 and Lipst1_1_35858 and 9144 and Lipst1_1_55461
# OIVD1m (Lipst1_1_67480 and 11183 and 12566 and 15436) or (Lipst1_1_67480 and 11188 and 12566 and 15436)
# MCCCrm 12867 and 15694 and Lipst1_1_1110
# OIVD2m (Lipst1_1_67480 and 11183 and 12566 and 15436) or (Lipst1_1_67480 and 11188 and 12566 and 15436)
# L_LACDcm 9113 and Lipst1_1_65274
# OBDHm (Lipst1_1_67480 and 11183 and 12566 and 15436) or (Lipst1_1_67480 and 11188 and 12566 and 15436)
# FAOXC5C3m (12570 and Lipst1_1_58573 and 11203 and 8885) or (Lipst1_1_48542 and Lipst1_1_58573 and 11203 and 8885)
# FAOXC7C5m 12570 and Lipst1_1_58573 and 11203 and 8885
# FAOXC9C7m 12570 and Lipst1_1_58573 and 11203 and 8885
# FAOXC11C9m 12570 and Lipst1_1_58573 and 11203 and 8885
# FAOXC13C11m 12570 and Lipst1_1_58573 and 11203 and 8885
# FAOXC15C13m 12570 and Lipst1_1_58573 and 11203 and 8885
# FAOXC170150m 12570 and Lipst1_1_58573 and 11203 and 8885
# FAO183p_even (10293 and Lipst1_1_75883 and Lipst1_1_158150 and 12742 and Lipst1_1_160699 and Lipst1_1_47324) or (10293 and Lipst1_1_75883 and Lipst1_1_158150 and 12752 and Lipst1_1_160699 and Lipst1_1_47324) or (10293 and Lipst1_1_75883 and Lipst1_1_158150 and Lipst1_1_160699 and Lipst1_1_47324 and Lipst1_1_2790)
# FAO183p_odd (10293 and Lipst1_1_75883 and 12742 and Lipst1_1_160699 and Lipst1_1_47324) or (10293 and Lipst1_1_75883 and 12752 and Lipst1_1_160699 and Lipst1_1_47324) or (10293 and Lipst1_1_75883 and Lipst1_1_160699 and Lipst1_1_47324 and Lipst1_1_2790)
# T4HCINNMt Lipst1_1_201837 and 10705
# H2Otm 9014
# DRTPPD 15506
# ALDD2ym 13426
# DNTPPA 15385
# C3STKR1er 14213
# C3STKR2er 14213
# PMDPHT 11513
# C30CPT1 9315
# ACRNtp 10149
# FA183COAabcp 13167 and 9637
# CRNtp 10149

# %%
len(reactions_needing_genes)
# Out:
# 53

# %% [markdown]
# #### gap fill model with rto.

# %%
model_removed.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ls = 0.0</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>0.732</td>
#       <td>6</td>
#       <td>100.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ac_e</td>
#       <td>EX_ac_e</td>
#       <td>-0.732</td>
#       <td>2</td>
#       <td>33.33%</td>
#     </tr>
#     <tr>
#       <td>btd_RR_e</td>
#       <td>EX_btd_RR_e</td>
#       <td>-0.244</td>
#       <td>4</td>
#       <td>22.22%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-0.488</td>
#       <td>1</td>
#       <td>11.11%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>-0.732</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>sbt__D_e</td>
#       <td>EX_sbt__D_e</td>
#       <td>-0.244</td>
#       <td>6</td>
#       <td>33.33%</td>
#     </tr>
#   </tbody>
# </table>

# %%
growing_model.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ls = 0.060378943547815464</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>5.024E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e</td>
#       <td>3.17E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe3_e</td>
#       <td>EX_fe3_e</td>
#       <td>0.0003725</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>1</td>
#       <td>6</td>
#       <td>98.88%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e</td>
#       <td>0.03536</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e</td>
#       <td>0.003726</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_e</td>
#       <td>EX_mn2_e</td>
#       <td>3.665E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>na1_e</td>
#       <td>EX_na1_e</td>
#       <td>0.001576</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>0.38</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>2.35</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>0.01607</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e</td>
#       <td>0.006052</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e</td>
#       <td>3.079E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>8aonn_m</td>
#       <td>SRC_8aonn_m</td>
#       <td>0.000146</td>
#       <td>9</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>lipoate_m</td>
#       <td>SRC_lipoate_m</td>
#       <td>0.0001876</td>
#       <td>8</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>trnaala_c</td>
#       <td>SRC_trnaala_c</td>
#       <td>0.03487</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaarg_c</td>
#       <td>SRC_trnaarg_c</td>
#       <td>0.008856</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaasn_c</td>
#       <td>SRC_trnaasn_c</td>
#       <td>0.006519</td>
#       <td>10</td>
#       <td>1.07%</td>
#     </tr>
#     <tr>
#       <td>trnaasp_c</td>
#       <td>SRC_trnaasp_c</td>
#       <td>0.01191</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnacys_c</td>
#       <td>SRC_trnacys_c</td>
#       <td>0.002069</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnagln_c</td>
#       <td>SRC_trnagln_c</td>
#       <td>0.007119</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaglu_c</td>
#       <td>SRC_trnaglu_c</td>
#       <td>0.0126</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnagly_c</td>
#       <td>SRC_trnagly_c</td>
#       <td>0.03099</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnahis_c</td>
#       <td>SRC_trnahis_c</td>
#       <td>0.003693</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaile_c</td>
#       <td>SRC_trnaile_c</td>
#       <td>0.009574</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaleu_c</td>
#       <td>SRC_trnaleu_c</td>
#       <td>0.01933</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnalys_c</td>
#       <td>SRC_trnalys_c</td>
#       <td>0.01041</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnamet_c</td>
#       <td>SRC_trnamet_c</td>
#       <td>0.003445</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaphe_c</td>
#       <td>SRC_trnaphe_c</td>
#       <td>0.005746</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnapro_c</td>
#       <td>SRC_trnapro_c</td>
#       <td>0.01424</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaser_c</td>
#       <td>SRC_trnaser_c</td>
#       <td>0.02034</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnathr_c</td>
#       <td>SRC_trnathr_c</td>
#       <td>0.01317</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnatrp_c</td>
#       <td>SRC_trnatrp_c</td>
#       <td>0.001408</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnatyr_c</td>
#       <td>SRC_trnatyr_c</td>
#       <td>0.003765</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaval_c</td>
#       <td>SRC_trnaval_c</td>
#       <td>0.01661</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3aap_c</td>
#       <td>DM_3aap_c</td>
#       <td>-0.0242</td>
#       <td>5</td>
#       <td>3.35%</td>
#     </tr>
#     <tr>
#       <td>4oglu_c</td>
#       <td>DM_4oglu_c</td>
#       <td>-8.411E-05</td>
#       <td>5</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>amob_m</td>
#       <td>DM_amob_m</td>
#       <td>-0.000146</td>
#       <td>15</td>
#       <td>0.06%</td>
#     </tr>
#     <tr>
#       <td>dad_5_m</td>
#       <td>DM_dad_5_m</td>
#       <td>-0.000146</td>
#       <td>10</td>
#       <td>0.04%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-2.761</td>
#       <td>1</td>
#       <td>76.51%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e</td>
#       <td>-0.0002587</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>-4.184</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>-0.1196</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>hco3_e</td>
#       <td>EX_hco3_e</td>
#       <td>-0.001513</td>
#       <td>1</td>
#       <td>0.04%</td>
#     </tr>
#     <tr>
#       <td>zymst_e</td>
#       <td>EX_zymst_e</td>
#       <td>-0.02671</td>
#       <td>27</td>
#       <td>19.99%</td>
#     </tr>
#   </tbody>
# </table>

# %%
rto.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_RT = 0.07336590453116386</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>6.104E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e</td>
#       <td>3.852E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe3_e</td>
#       <td>EX_fe3_e</td>
#       <td>0.0004526</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>1</td>
#       <td>6</td>
#       <td>98.64%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e</td>
#       <td>0.04297</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e</td>
#       <td>0.004528</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_e</td>
#       <td>EX_mn2_e</td>
#       <td>4.453E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>na1_e</td>
#       <td>EX_na1_e</td>
#       <td>0.001915</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>0.4842</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>2.287</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>0.01953</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e</td>
#       <td>0.007354</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e</td>
#       <td>3.742E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>8aonn_m</td>
#       <td>SRC_8aonn_m</td>
#       <td>0.0001774</td>
#       <td>9</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>lipoate_m</td>
#       <td>SRC_lipoate_m</td>
#       <td>0.0002279</td>
#       <td>8</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>trnaala_c</td>
#       <td>SRC_trnaala_c</td>
#       <td>0.04237</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaarg_c</td>
#       <td>SRC_trnaarg_c</td>
#       <td>0.01076</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaasn_c</td>
#       <td>SRC_trnaasn_c</td>
#       <td>0.007921</td>
#       <td>10</td>
#       <td>1.30%</td>
#     </tr>
#     <tr>
#       <td>trnaasp_c</td>
#       <td>SRC_trnaasp_c</td>
#       <td>0.01447</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnacys_c</td>
#       <td>SRC_trnacys_c</td>
#       <td>0.002514</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnagln_c</td>
#       <td>SRC_trnagln_c</td>
#       <td>0.00865</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaglu_c</td>
#       <td>SRC_trnaglu_c</td>
#       <td>0.01531</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnagly_c</td>
#       <td>SRC_trnagly_c</td>
#       <td>0.03765</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnahis_c</td>
#       <td>SRC_trnahis_c</td>
#       <td>0.004488</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaile_c</td>
#       <td>SRC_trnaile_c</td>
#       <td>0.01163</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaleu_c</td>
#       <td>SRC_trnaleu_c</td>
#       <td>0.02349</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnalys_c</td>
#       <td>SRC_trnalys_c</td>
#       <td>0.01264</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnamet_c</td>
#       <td>SRC_trnamet_c</td>
#       <td>0.004186</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaphe_c</td>
#       <td>SRC_trnaphe_c</td>
#       <td>0.006982</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnapro_c</td>
#       <td>SRC_trnapro_c</td>
#       <td>0.01731</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaser_c</td>
#       <td>SRC_trnaser_c</td>
#       <td>0.02471</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnathr_c</td>
#       <td>SRC_trnathr_c</td>
#       <td>0.016</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnatrp_c</td>
#       <td>SRC_trnatrp_c</td>
#       <td>0.001711</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnatyr_c</td>
#       <td>SRC_trnatyr_c</td>
#       <td>0.004575</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaval_c</td>
#       <td>SRC_trnaval_c</td>
#       <td>0.02019</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3aap_c</td>
#       <td>DM_3aap_c</td>
#       <td>-0.05196</td>
#       <td>5</td>
#       <td>8.40%</td>
#     </tr>
#     <tr>
#       <td>4oglu_c</td>
#       <td>DM_4oglu_c</td>
#       <td>-0.0001022</td>
#       <td>5</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>amob_m</td>
#       <td>DM_amob_m</td>
#       <td>-0.0001774</td>
#       <td>15</td>
#       <td>0.09%</td>
#     </tr>
#     <tr>
#       <td>dad_5_m</td>
#       <td>DM_dad_5_m</td>
#       <td>-0.0001774</td>
#       <td>10</td>
#       <td>0.06%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-2.561</td>
#       <td>1</td>
#       <td>82.75%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e</td>
#       <td>-0.0003143</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>-4.221</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>-0.1678</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>hco3_e</td>
#       <td>EX_hco3_e</td>
#       <td>-0.001839</td>
#       <td>1</td>
#       <td>0.06%</td>
#     </tr>
#     <tr>
#       <td>zymst_e</td>
#       <td>EX_zymst_e</td>
#       <td>-0.0099</td>
#       <td>27</td>
#       <td>8.64%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# determine the essential reactions in model 
essential_reactions_model = cobra.flux_analysis.find_essential_reactions(growing_model)

# how many essential reactions are in the model_removed? 
for r in essential_reactions_model:
    
    # print the ones lacking
    if r.id not in model_removed.reactions:
        print(r, r.gene_reaction_rule)
# Out:
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/tmpf_f_1vcw.lp
# Reading time = 0.01 seconds
# : 1898 rows, 4230 columns, 17294 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/tmphpzmf3pn.lp
# Reading time = 0.01 seconds
# : 1898 rows, 4230 columns, 17294 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/tmpp8s2y6t4.lp
# Reading time = 0.01 seconds
# : 1898 rows, 4230 columns, 17294 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/tmp14pj_jlo.lp
# Reading time = 0.01 seconds
# : 1898 rows, 4230 columns, 17294 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/tmp99yrtw92.lp
# Reading time = 0.01 seconds
# : 1898 rows, 4230 columns, 17294 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/tmpyz32d0f9.lp
# Reading time = 0.01 seconds
# : 1898 rows, 4230 columns, 17294 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/tmplkaxueta.lp
# Reading time = 0.01 seconds
# : 1898 rows, 4230 columns, 17294 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/tmp0cnj8cd3.lp
# Reading time = 0.01 seconds
# : 1898 rows, 4230 columns, 17294 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/tmpzfwl1_9f.lp
# Reading time = 0.01 seconds
# : 1898 rows, 4230 columns, 17294 nonzeros
# ALDD2ym: acald_m + h2o_m + nadp_m --> ac_m + 2.0 h_m + nadph_m 13426
# CYOR_u9m: 2.0 ficytc_m + 2.0 h_m + q9h2_m --> 2.0 focytc_m + 4.0 h_c + q9_m COB and Lipst1_1_72848 and Lipst1_1_112667 and Lipst1_1_38038 and Lipst1_1_47735 and Lipst1_1_3376 and Lipst1_1_42388 and 15231 and Lipst1_1_6808 and Lipst1_1_70538 and Lipst1_1_65274 and Lipst1_1_49747
# C30CPT1: crn_c + ppcoa_c <=> coa_c + pcrn_c 9315
# DNTPPA: ahdt_c + h2o_c --> dhpmp_c + h_c + ppi_c 15385
# C3STKR1er: 4mzym_int2_r + h_r + nadph_r --> 4mzym_r + nadp_r 14213
# C3STKR2er: h_r + nadph_r + zym_int2_r --> nadp_r + zymst_r 14213
# SERPTer: h_r + pmtcoa_r + ser__L_r --> 3dsphgn_r + co2_r + coa_r Lipst1_1_71191 and 9394 and Lipst1_1_72156
# PMDPHT: 5aprbu_c + h2o_c --> 4r5au_c + pi_c 11513
# PRPPS: atp_c + r5p_c <=> amp_c + h_c + prpp_c Lipst1_1_85 and 16592
# ACRNtp: acrn_x --> acrn_c 10149
# TRDR: h_c + nadph_c + trdox_c --> nadp_c + trdrd_c (10848 and Lipst1_1_404) or (12730 and Lipst1_1_404) or (12737 and Lipst1_1_404)
# FA183COAabcp: atp_c + 2.0 h2o_c + lnlncgcoa_c --> adp_c + coa_c + 2.0 h_c + lnlncg_x + pi_c 13167 and 9637
# DRTPPD: 25dthpp_c + h2o_c + h_c --> 5aprbu_c + nh4_c 15506
# CRNtp: crn_c <=> crn_x 10149
# CYOO6m: 4.0 focytc_m + 8.0 h_m + o2_m --> 4.0 ficytc_m + 2.0 h2o_m + 4.0 h_c COX1 and COX2 and COX3 and Lipst1_1_65503 and Lipst1_1_3895 and Lipst1_1_55045 and 12506 and 11352 and 13275 and 11769 and Lipst1_1_54407 and Lipst1_1_26031 and Lipst1_1_67449 and Lipst1_1_65274

# %%
gapfiller = cobra.flux_analysis.gapfilling.GapFiller(model_removed, growing_model, demand_reactions=False, integer_threshold=1e-12)
gapfiller.model.solver.configuration.tolerances.feasibility = 1e-9
gapfiller.model.solver.configuration.tolerances.integrality = 1e-10
# gapfiller.model.solver.configuration.tolerances.optimality = 1e-9
gapfiller.fill()
# Out:
# [[<Reaction CYOR_u9m at 0x7f21471c4890>,
#   <Reaction TRDR at 0x7f2144eb68d0>,
#   <Reaction SERPTer at 0x7f2144ed4a50>,
#   <Reaction ATPS3m at 0x7f2144e71250>,
#   <Reaction PRPPS at 0x7f2144da4a50>,
#   <Reaction CYOO6m at 0x7f2144dc2a50>,
#   <Reaction OBDHm at 0x7f2144cc0310>,
#   <Reaction FAO183p_even at 0x7f2144cc05d0>,
#   <Reaction CRNtp at 0x7f2144bcc710>,
#   <Reaction H2Otm at 0x7f2144bcc750>,
#   <Reaction DRTPPD at 0x7f2144bcc790>,
#   <Reaction ALDD2ym at 0x7f2144bcc7d0>,
#   <Reaction DNTPPA at 0x7f2144bcc810>,
#   <Reaction C3STKR1er at 0x7f2144bcc850>,
#   <Reaction C3STKR2er at 0x7f2144bcc890>,
#   <Reaction PMDPHT at 0x7f2144bcc8d0>,
#   <Reaction C30CPT1 at 0x7f2144bcc910>,
#   <Reaction ACRNtp at 0x7f2144bcc950>,
#   <Reaction FA183COAabcp at 0x7f2144bcc990>]]

# %%
gapfiller = cobra.flux_analysis.gapfilling.GapFiller(model_removed, rto, demand_reactions=False, integer_threshold=1e-10)
gapfiller.model.solver.configuration.tolerances.feasibility = 1e-9
gapfiller.model.solver.configuration.tolerances.integrality = 1e-10
gapfiller.model.solver.configuration.tolerances.optimality = 1e-9
gapfiller.fill()
# Out:
# [[<Reaction CYOR_u9m at 0x7f21359a69d0>,
#   <Reaction H2Otm at 0x7f21359a6f90>,
#   <Reaction DRTPPD at 0x7f21336d8250>,
#   <Reaction TRDR at 0x7f21336d8d50>,
#   <Reaction SERPTer at 0x7f21336f4f90>,
#   <Reaction ATPS3m at 0x7f2133713790>,
#   <Reaction FA240tp at 0x7f213366bb10>,
#   <Reaction ALDD2ym at 0x7f2144ef62d0>,
#   <Reaction PRPPS at 0x7f2142461a10>,
#   <Reaction CYOO6m at 0x7f2158b16510>,
#   <Reaction OIVD2m at 0x7f2156755810>,
#   <Reaction DNTPPA at 0x7f215600d8d0>,
#   <Reaction C3STKR1er at 0x7f2153b97690>,
#   <Reaction C3STKR2er at 0x7f2153b978d0>,
#   <Reaction PMDPHT at 0x7f2153b97510>,
#   <Reaction C30CPT1 at 0x7f215b7894d0>,
#   <Reaction ACRNtp at 0x7f215b7891d0>,
#   <Reaction CRNtp at 0x7f215b773590>]]

# %%
rto.reactions.get_by_id('FA240tp')
# Out:
# <Reaction FA240tp at 0x2971c0d10>

# %%
rto.reactions.get_by_id('FA183COAabcp')
# Out:
# <Reaction FA183COAabcp at 0x2977bd6d0>

# %%
rto.reactions.get_by_id('FA160COAabcp')
# Out:
# <Reaction FA160COAabcp at 0x297279690>

# %% [markdown]
# Note. during original gap filling procedures, FA160COAabcp was obtained instead of FA240tp. FA160COAabcp results in a higher biomass objective (0.0613 vs 0.057).

# %%
# all three peroxisome transporters included.

reactions = ['CYOR_u9m','H2Otm','DRTPPD','TRDR','SERPTer','ATPS3m','FA240tp','FA160COAabcp','FA183COAabcp',
            'ALDD2ym','PRPPS','CYOO6m','OIVD2m','DNTPPA','C3STKR1er','C3STKR2er','PMDPHT','C30CPT1','ACRNtp','CRNtp']

# %%
model_removed_copy = model_removed.copy()
# Out:
# Read LP format model from file /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/tmp0tvt1k3c.lp
# Reading time = 0.01 seconds
# : 1897 rows, 4124 columns, 16590 nonzeros

# %%
# with model_removed_copy:
for x in reactions:

    # 'ALDD2ym','C30CPT1','C3STKR1er','C3STKR2er','DNTPPA','DRTPPD','PMDPHT',
    #   'ACRNtp','CRNtp','FA160COAabcp','H2Otm']:
    r = rto.reactions.get_by_id(x).copy()
    model_removed_copy.add_reactions([r])
sol = model_removed_copy.optimize()
if sol.status!='optimal':
    print('infeasible')
else:
    print(sol.objective_value)
# Out:
# 0.0613065722993276

# %%
model_removed_copy.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ls = 0.0613065722993276</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>5.101E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e</td>
#       <td>3.219E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe3_e</td>
#       <td>EX_fe3_e</td>
#       <td>0.0003782</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>1</td>
#       <td>6</td>
#       <td>98.86%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e</td>
#       <td>0.03591</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e</td>
#       <td>0.003784</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_e</td>
#       <td>EX_mn2_e</td>
#       <td>3.721E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>na1_e</td>
#       <td>EX_na1_e</td>
#       <td>0.0016</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>0.4046</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>2.898</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>0.01632</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e</td>
#       <td>0.006145</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e</td>
#       <td>3.127E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>8aonn_m</td>
#       <td>SRC_8aonn_m</td>
#       <td>0.0001482</td>
#       <td>9</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>lipoate_m</td>
#       <td>SRC_lipoate_m</td>
#       <td>0.0001905</td>
#       <td>8</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>trnaala_c</td>
#       <td>SRC_trnaala_c</td>
#       <td>0.03541</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaarg_c</td>
#       <td>SRC_trnaarg_c</td>
#       <td>0.008992</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaasn_c</td>
#       <td>SRC_trnaasn_c</td>
#       <td>0.006619</td>
#       <td>10</td>
#       <td>1.09%</td>
#     </tr>
#     <tr>
#       <td>trnaasp_c</td>
#       <td>SRC_trnaasp_c</td>
#       <td>0.0121</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnacys_c</td>
#       <td>SRC_trnacys_c</td>
#       <td>0.002101</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnagln_c</td>
#       <td>SRC_trnagln_c</td>
#       <td>0.007228</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaglu_c</td>
#       <td>SRC_trnaglu_c</td>
#       <td>0.01279</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnagly_c</td>
#       <td>SRC_trnagly_c</td>
#       <td>0.03146</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnahis_c</td>
#       <td>SRC_trnahis_c</td>
#       <td>0.00375</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaile_c</td>
#       <td>SRC_trnaile_c</td>
#       <td>0.009721</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaleu_c</td>
#       <td>SRC_trnaleu_c</td>
#       <td>0.01963</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnalys_c</td>
#       <td>SRC_trnalys_c</td>
#       <td>0.01057</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnamet_c</td>
#       <td>SRC_trnamet_c</td>
#       <td>0.003498</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaphe_c</td>
#       <td>SRC_trnaphe_c</td>
#       <td>0.005834</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnapro_c</td>
#       <td>SRC_trnapro_c</td>
#       <td>0.01446</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaser_c</td>
#       <td>SRC_trnaser_c</td>
#       <td>0.02065</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnathr_c</td>
#       <td>SRC_trnathr_c</td>
#       <td>0.01337</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnatrp_c</td>
#       <td>SRC_trnatrp_c</td>
#       <td>0.00143</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnatyr_c</td>
#       <td>SRC_trnatyr_c</td>
#       <td>0.003823</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaval_c</td>
#       <td>SRC_trnaval_c</td>
#       <td>0.01687</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3aap_c</td>
#       <td>DM_3aap_c</td>
#       <td>-0.04342</td>
#       <td>5</td>
#       <td>6.08%</td>
#     </tr>
#     <tr>
#       <td>4oglu_c</td>
#       <td>DM_4oglu_c</td>
#       <td>-8.54E-05</td>
#       <td>5</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>amob_m</td>
#       <td>DM_amob_m</td>
#       <td>-0.0001482</td>
#       <td>15</td>
#       <td>0.06%</td>
#     </tr>
#     <tr>
#       <td>dad_5_m</td>
#       <td>DM_dad_5_m</td>
#       <td>-0.0001482</td>
#       <td>10</td>
#       <td>0.04%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-3.126</td>
#       <td>1</td>
#       <td>87.51%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e</td>
#       <td>-0.0002626</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>-4.514</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>-0.1403</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>hco3_e</td>
#       <td>EX_hco3_e</td>
#       <td>-0.001536</td>
#       <td>1</td>
#       <td>0.04%</td>
#     </tr>
#     <tr>
#       <td>zymst_e</td>
#       <td>EX_zymst_e</td>
#       <td>-0.008273</td>
#       <td>27</td>
#       <td>6.25%</td>
#     </tr>
#   </tbody>
# </table>

# %%
model_removed.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ls = 0.0</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>0.732</td>
#       <td>6</td>
#       <td>100.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ac_e</td>
#       <td>EX_ac_e</td>
#       <td>-0.732</td>
#       <td>2</td>
#       <td>33.33%</td>
#     </tr>
#     <tr>
#       <td>btd_RR_e</td>
#       <td>EX_btd_RR_e</td>
#       <td>-0.244</td>
#       <td>4</td>
#       <td>22.22%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-0.488</td>
#       <td>1</td>
#       <td>11.11%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>-0.732</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>sbt__D_e</td>
#       <td>EX_sbt__D_e</td>
#       <td>-0.244</td>
#       <td>6</td>
#       <td>33.33%</td>
#     </tr>
#   </tbody>
# </table>

# %%
cobra.io.save_json_model(model_removed_copy,'Lst_v_0.0_removedRTOGenes_forPUB.json')
