# %% [markdown]
# # orthoMCL_GSM_geneComparisons.
#
# This notebook seeks to reconcile genes and reactions for the *Lipomyces starkeyi* GSM. Gene orthologs were obtained via orthoMCL (provided by Dr. Yichao Han for four species).
#
#
# GSMs were originally built using only bbh between the scaffold species and *L. starkeyi*. As an example: bbh was performed between *Rhodosporidium toruloides* and *L. starkeyi*. Reactions with suspected *L. starkeyi* genes were ported from the rto scaffold to the lst GSM.

# %%
import cobra
import pandas as pd
import numpy as np

# %%
# load GSMs.
rto = cobra.io.load_json_model('../models/Rt_IFO0880.json')
sce = cobra.io.load_matlab_model('../models/yeast8_modifiedwBIGGnames.mat')
ylip = cobra.io.load_matlab_model('../models/twoModels/iYLI647_corr.mat')

# lst_from_sce = cobra.io.load_matlab_model("../models/Lst_v_0.0_modelRemovedYeast8Genes.matlab")
# lst_from_ylip = cobra.io.load_json_model('../models/OLD_models_prior16Dec22/Lst_v0.1_model_yarrowiaBased.json')

# lst_from_rto = cobra.io.load_json_model("../models/Lst_v_0.1_modelRemovedGenes.json")
# Out:
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# This model seems to have confidenceScores instead of rxnConfidenceScores field. Will use confidenceScores for what rxnConfidenceScores represents.
# This model seems to have metCharge instead of metCharges field. Will use metCharge for what metCharges represents.
# No defined compartments in model model. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, m, n, r, v, x

# %%
# adjust iYLI647 parameters for consistent annotation. 
for m in ylip.metabolites:
    if ('[' in m.id):
        ylip.metabolites.get_by_id(m.id).id = m.id.replace('[','_').replace(']','')
    if ('_L_' in m.id):
        ylip.metabolites.get_by_id(m.id).id = m.id.replace('_L_','__L_')
    if ('_D_' in m.id):
        ylip.metabolites.get_by_id(m.id).id = m.id.replace('_D_','__D_')
for r in ylip.reactions:
    if ('(e)' in r.id):
        ylip.reactions.get_by_id(r.id).id = r.id.replace('(e)','_e')
    if(('_L_') in r.id):
        ylip.reactions.get_by_id(r.id).id = r.id.replace('_L_','__L_')

    if(('_D_') in r.id):
        ylip.reactions.get_by_id(r.id).id = r.id.replace('_D_','__D_')

# %% [markdown]
# load the *L. starkeyi* framework model.

# %%
## below is the original model used. 
# model = cobra.io.load_json_model("../models/Lst_v_0.1_modelRemovedGenes.json")
## this is a model to verify. 
model = cobra.io.load_json_model("../models/Lst_v_0.0_removedRTOGenes_forPUB.json")

# %% [markdown]
# ### load orthoMCL data.

# %%
orthoMCL = pd.read_csv('../orthoMCL/orthoMCL_orthologs_2023.csv')
orthoMCL.head(4)
# Out:
#                 Unnamed: 0              Lst    Rto      Sce           Yli  \
# 0  Lst|G1IA6-22289-MONOMER  Lipst1_1_113024  10878  YML069W  YALI0D25058g
# 1  Lst|G1IA6-16751-MONOMER     Lipst1_1_441  14212      NaN  YALI0F19734g
# 2  Lst|G1IA6-23047-MONOMER  Lipst1_1_175925  12668  YKL046C  YALI0D02563g
# 3  Lst|G1IA6-17901-MONOMER   Lipst1_1_91016    NaN      NaN  YALI0E00396g
#
#       s2     s3     s4
# 0  1.447  1.776  1.588
# 1  1.055    NaN  1.272
# 2  0.159  1.579  1.284
# 3    NaN    NaN  0.895

# %%
# obtain the genes present in each GSM. 

g = ylip.genes
ylip_GSM_genes = [temp.id for temp in g]

g = rto.genes
rto_GSM_genes = [temp.id for temp in g]

g = sce.genes
sce_GSM_genes = [temp.id for temp in g]

# %%
# the number of genes in the GSM that have Lst orthologs. 

# rto to Lst
print(len(set(orthoMCL.Rto.to_list()).intersection(set(rto_GSM_genes))))

# sce to Lst
print(len(set(orthoMCL.Sce.to_list()).intersection(set(sce_GSM_genes))))

# yli to Lst
print(len(set(orthoMCL.Yli.to_list()).intersection(set(ylip_GSM_genes))))
# Out:
# 810
# 790
# 512

# %%
# more genes are present in the direct bbh blasting scaffolds for GSMs. 
# print(len(lst_from_rto.genes))
# print(len(lst_from_sce.genes))
# print(len(lst_from_ylip.genes))

# %%
# create dictionary mapping the genes for each species. 
lst_rto_dict = dict(zip(orthoMCL.Rto,orthoMCL.Lst))
lst_sce_dict = dict(zip(orthoMCL.Sce,orthoMCL.Lst))
lst_ylip_dict = dict(zip(orthoMCL.Yli,orthoMCL.Lst))

# %% [markdown]
# ### next to do.
#
# comparisons between GSMs using python.

# %%
# determine reactions annotations in all three GSMs. 
# and either ylip:rto or sce:rto GSMs.

ylip_rto_overlap = []
ylip_sce_rto_overlap = []
rto_sce_overlap = []

# start with Rhodo GSM reaction names. 
for r in rto.reactions:
    
    # search for ID in yarrowia. 
    if r.id in ylip.reactions:
        
        # now search for ID in saccharomyces.
        if r.id in sce.reactions:
            ylip_sce_rto_overlap.append(r.id)
        
        # reaction not in saccharomyces. 
        # ylip and rto overlapping reactions. 
        else:
            ylip_rto_overlap.append(r.id)
    
    # reaction not in yarrowia.
    # sce and rto overlapping reactions.
    elif r.id in sce.reactions:
        rto_sce_overlap.append(r.id)

# %%
# obtain the ylip:sce reaction overlap. 
# obtain the sce and ylip only genes. 

ylip_sce_overlap = []
ylip_rxn_only = []
ylip_gene_only = []
sce_rxn_only = []
sce_gene_only = []

# now loop through the yarrowia reactions. 
for r in ylip.reactions:
    
    # check if the id is not already in one of the previously determined lists. 
    if (r.id not in ylip_sce_rto_overlap) and (r.id not in rto_sce_overlap) and (r.id not in ylip_rto_overlap):
        
        # check if the reaction is in saccharomyces. 
        if r.id in sce.reactions:
            ylip_sce_overlap.append(r.id)
        
        # reaction is only present in yarrowia. 
        else:
            ylip_genes = r.gene_reaction_rule
            
            # obtain the gpr for the reaction if it is also present in the orthoMCL groups. 
            for g in [ylip_genes]:
                if g in set(orthoMCL.Yli.to_list()).intersection(set(ylip_GSM_genes)):
                    ylip_rxn_only.append(r.id)
                    ylip_gene_only.append(g)

# now loop through saccharomyces reactions. 
for r in sce.reactions:
    
    # check if the reaction has already been inlcuded in one of the previously determined lists. 
    if (r.id not in ylip_sce_rto_overlap) and (r.id not in rto_sce_overlap) and (r.id not in ylip_rto_overlap) and (r.id not in ylip_sce_overlap):
        
        # reaction is only in saccharomyces. 
        sce_genes = r.gene_reaction_rule
        
        # obtain the gpr for the reaction if it is also present in the orthoMCL groups. 
        for g in [sce_genes]:
            if g in set(orthoMCL.Yli.to_list()).intersection(set(ylip_GSM_genes)):
                sce_rxn_only.append(r.id)
                sce_gene_only.append(g)

# %% [markdown]
# ## Grab the L. starkeyi ortholog for reactions that have genes present in the orthoMCL groups.
#
# #### note, this section does not modify the GSM. It just obtains orthologs and new GPRs.

# %% [markdown]
# compare all three sets.

# %%
# definition to compare the genes in common reactions. 
def compare_three_lists(list1, list2, list3):

    
    # Convert lists to sets.
    set1, set2, set3 = set(list1), set(list2), set(list3)
    
    # Find all intersections and differences.
    common_all = set1 & set2 & set3
    
    only_12 = (set1 & set2) - set3
    only_13 = (set1 & set3) - set2
    only_23 = (set2 & set3) - set1
    
    only_1 = set1 - set2 - set3
    only_2 = set2 - set1 - set3
    only_3 = set3 - set1 - set2
    
    all_three_diff = (set1 | set2 | set3) - common_all - only_12 - only_13 - only_23 - only_1 - only_2 - only_3
    
    # Construct verbose explanation.
    explanation = {}
    
#     explanation['common_all'] = f"Items common in all three lists: {list(common_all)}"
#     explanation['only_12'] = f"Items found only in list 1 and list 2: {list(only_12)}"
#     explanation['only_13'] = f"Items found only in list 1 and list 3: {list(only_13)}"
#     explanation['only_23'] = f"Items found only in list 2 and list 3: {list(only_23)}"
#     explanation['only_1'] = f"Items unique to list 1: {list(only_1)}"
#     explanation['only_2'] = f"Items unique to list 2: {list(only_2)}"
#     explanation['only_3'] = f"Items unique to list 3: {list(only_3)}"
#     explanation['all_three_diff'] = f"Items present in all three lists but not shared by all of them simultaneously: {list(all_three_diff)}"
    
    explanation['common_all'] = list(common_all)
    explanation['only_12'] = list(only_12)
    explanation['only_13'] = list(only_13)
    explanation['only_23'] = list(only_23)
    explanation['only_1'] = list(only_1)
    explanation['only_2'] = list(only_2)
    explanation['only_3'] = list(only_3)
    explanation['all_three_diff'] = list(all_three_diff)
    
    
    return explanation


# gene overlap in all three.

_names = []
_gpr_sce = []
_gpr_ylip = []
_gpr_rto = []

_lst_rto_gene = []
_lst_sce_gene = []
_lst_ylip_gene = []

_id = []
_stoich = []
_subsystem = []
_lst_gene = []
_ylip_gene = []


consensus = []
consensus_count = []
consensus_source = []
_output = []


_common_all = []
_only_12 = []
_only_13 = []
_only_23 = []
_only_1 = []
_only_2 = []
_only_3 = []
_all_three_diff = []

# loop through the reactions present in all three GSMs and determine the L. starkeyi ortholog. 
for rxn in ylip_sce_rto_overlap:
# test cases: 
# for rxn in ['NNDPRm','CSp','MTHFCm','PYRt2','PDE4','CSm']:
    r = rto.reactions.get_by_id(rxn)
    y = ylip.reactions.get_by_id(rxn)
    s = sce.reactions.get_by_id(rxn)
    
    _names.append(r.name)
    _gpr_rto.append(r.gene_reaction_rule)
    _gpr_sce.append(s.gene_reaction_rule)
    _gpr_ylip.append(y.gene_reaction_rule)

    _id.append(r.id)
    _stoich.append(r.reaction)
    _subsystem.append(r.subsystem)
    
    
    # rto genes.
    temp1 = []
    for g in r.genes:
        try:
            temp1.append(lst_rto_dict[g.id])
        except:
            temp1.append('NA')
            donothing=0
    _lst_rto_gene.append(temp1)
    
    # sce genes.
    temp2 = []
    for g in s.genes:
        try:
            temp2.append(lst_sce_dict[g.id])
        except:
            temp2.append('NA')
            donothing=0
    _lst_sce_gene.append(temp2)
    
    # ylip genes. 
    temp3 = []
    for g in y.genes:
        try:
            temp3.append(lst_ylip_dict[g.id])
        except:
            temp3.append('NA')
            donothing=0
    _lst_ylip_gene.append(temp3)

    

    ### comparisions below - general gene info is above.

    # remove NA for comparisions. 
    if 'NA' in temp1:
        temp1.remove('NA')
        temp1 = [e for e in temp1 if e not in ('NA')]
    if 'NA' in temp2:
        temp2.remove('NA')
        temp2 = [e for e in temp2 if e not in ('NA')]

    if 'NA' in temp3:
        temp3.remove('NA')
        temp3 = [e for e in temp3 if e not in ('NA')]
    
    result = compare_three_lists(temp1, temp2, temp3)
    _output.append(result)
    
    
    _common_all.append(result['common_all'])
    _only_12.append(result['only_12'])
    _only_13.append(result['only_13'])
    _only_23.append(result['only_23'])
    _only_1.append(result['only_1'])
    _only_2.append(result['only_2'])
    _only_3.append(result['only_3'])
    _all_three_diff.append(result['all_three_diff'])
#     for key, value in result.items():
        
#         print(f"{key}: {value}")

# %%
# df3 = pd.DataFrame([_names,_id,_stoich,_subsystem,_gpr_rto,_gpr_sce,_gpr_ylip,_lst_rto_gene,_lst_sce_gene,_lst_ylip_gene,_common_all,_only_12,_only_13,_only_23,_only_1,_only_2,_only_3,_all_three_diff]).T

# %%
# df3

# %%
# df3 = pd.DataFrame([_names,_id,_stoich,_subsystem,_gpr_rto,_gpr_sce,_gpr_ylip,_lst_rto_gene,_lst_sce_gene,_lst_ylip_gene,_common_all,_only_12,_only_13,_only_23,_only_1,_only_2,_only_3,_all_three_diff]).T
# df3.to_csv('allcomparisions_genes.csv')

# %% [markdown]
# compare the ylip:sce overlap.

# %%
# rxn overlap for ylip and sce.    
# _names = []
# _gpr_sce = []
# _gpr_ylip = []
# _gpr_rto = []

# _lst_rto_gene = []
# _lst_sce_gene = []
# _lst_ylip_gene = []

# _id = []
# _stoich = []
# _subsystem = []
# _lst_gene = []
# _ylip_gene = []

# _common_all = []
# _only_12 = []
# _only_13 = []
# _only_23 = []
# _only_1 = []
# _only_2 = []
# _only_3 = []
# _all_three_diff = []

for rxn in ylip_sce_overlap:
#     r = rto.reactions.get_by_id(rxn)
    y = ylip.reactions.get_by_id(rxn)
    s = sce.reactions.get_by_id(rxn)
    
    _names.append(s.name)
#     _gpr_rto.append(r.gene_reaction_rule)
    _gpr_rto.append('None')
    _gpr_sce.append(s.gene_reaction_rule)
    _gpr_ylip.append(y.gene_reaction_rule)

    _id.append(s.id)
    _stoich.append(s.reaction)
    _subsystem.append(s.subsystem)
    
    temp1 = []
#     for g in [r.gene_reaction_rule]:
#         try:
#             temp1.append(lst_rto_dict[g])
#         except:
    temp1.append('NA')
    _lst_rto_gene.append(temp1)
    
    temp2 = []
    for g in s.genes:
        try:
            temp2.append(lst_sce_dict[g.id])
        except:
            temp2.append('NA')
            donothing=0
    _lst_sce_gene.append(temp2)
    
    temp3 = []
    for g in y.genes:
        try:
            temp3.append(lst_ylip_dict[g.id])
        except:
            temp3.append('NA')
            donothing=0

    _lst_ylip_gene.append(temp3)
    
    # remove NA for comparisions. 
    if 'NA' in temp1:
        temp1.remove('NA')
        temp1 = [e for e in temp1 if e not in ('NA')]

    if 'NA' in temp2:
        temp2.remove('NA')
        temp2 = [e for e in temp2 if e not in ('NA')]

    if 'NA' in temp3:
        temp3.remove('NA')
        temp3 = [e for e in temp3 if e not in ('NA')]
    
    result = compare_three_lists(temp1, temp2, temp3)
    
    
    _common_all.append(result['common_all'])
    _only_12.append(result['only_12'])
    _only_13.append(result['only_13'])
    _only_23.append(result['only_23'])
    _only_1.append(result['only_1'])
    _only_2.append(result['only_2'])
    _only_3.append(result['only_3'])
    _all_three_diff.append(result['all_three_diff'])
#     for key, value in result.items():

# %%
# df3 = pd.DataFrame([_names,_id,_stoich,_subsystem,_gpr_sce,_gpr_ylip,_lst_sce_gene,_lst_ylip_gene,_common_all,_only_12,_only_13,_only_23,_only_1,_only_2,_only_3,_all_three_diff]).T

# %%
# df3.head()

# %%
# df3.to_csv('ylip_sce_rxn_overlap_genes.csv')

# %% [markdown]
# compare the ylip:rto overlap.

# %%
# overlap ylip and rto.  
# _names = []
# _gpr_sce = []
# _gpr_ylip = []
# _gpr_rto = []

# _lst_rto_gene = []
# _lst_sce_gene = []
# _lst_ylip_gene = []

# _id = []
# _stoich = []
# _subsystem = []
# _lst_gene = []
# _ylip_gene = []

# _common_all = []
# _only_12 = []
# _only_13 = []
# _only_23 = []
# _only_1 = []
# _only_2 = []
# _only_3 = []
# _all_three_diff = []

for rxn in ylip_rto_overlap:
    r = rto.reactions.get_by_id(rxn)
    y = ylip.reactions.get_by_id(rxn)
#     s = sce.reactions.get_by_id(rxn)
    
    _names.append(r.name)
    _gpr_rto.append(r.gene_reaction_rule)
#     _gpr_sce.append(s.gene_reaction_rule)
    _gpr_sce.append('None')
    
    
    _gpr_ylip.append(y.gene_reaction_rule)

    _id.append(r.id)
    _stoich.append(r.reaction)
    _subsystem.append(r.subsystem)
    
    temp1 = []
    for g in r.genes:
        try:
            temp1.append(lst_rto_dict[g.id])
        except:
            temp1.append('NA')
            donothing=0

    _lst_rto_gene.append(temp1)
    
    temp2 = []
    temp2.append('NA')
#     for g in [s.gene_reaction_rule]:
#         try:
#             temp2.append(lst_sce_dict[g])
#         except:
#             temp2.append('NA')
    _lst_sce_gene.append(temp2)
    
    temp3 = []
    for g in y.genes:
        try:
            temp3.append(lst_ylip_dict[g.id])
        except:
            temp3.append('NA')
            donothing=0

    _lst_ylip_gene.append(temp3)
      
        
    
    # remove NA for comparisions. 
    # remove NA for comparisions. 
    if 'NA' in temp1:
        temp1.remove('NA')
        temp1 = [e for e in temp1 if e not in ('NA')]
    
    if 'NA' in temp2:
        temp2.remove('NA')
        temp2 = [e for e in temp2 if e not in ('NA')]

    if 'NA' in temp3:
        temp3.remove('NA')
        temp3 = [e for e in temp3 if e not in ('NA')]
    
    result = compare_three_lists(temp1, temp2, temp3)
    
    _common_all.append(result['common_all'])
    _only_12.append(result['only_12'])
    _only_13.append(result['only_13'])
    _only_23.append(result['only_23'])
    _only_1.append(result['only_1'])
    _only_2.append(result['only_2'])
    _only_3.append(result['only_3'])
    _all_three_diff.append(result['all_three_diff'])

# %%
# df3 = pd.DataFrame([_names,_id,_stoich,_subsystem,_gpr_rto,_gpr_ylip,_lst_rto_gene,_lst_ylip_gene,_common_all,_only_12,_only_13,_only_23,_only_1,_only_2,_only_3,_all_three_diff]).T

# %%
# df3.to_csv('ylip_rto_overlap_genes.csv')

# %% [markdown]
# compare the sce:rto overlap.

# %%
# overlap sce and rto.    
# _names = []
# _gpr_sce = []
# _gpr_ylip = []
# _gpr_rto = []

# _lst_rto_gene = []
# _lst_sce_gene = []
# _lst_ylip_gene = []

# _id = []
# _stoich = []
# _subsystem = []
# _lst_gene = []
# _ylip_gene = []

# _common_all = []
# _only_12 = []
# _only_13 = []
# _only_23 = []
# _only_1 = []
# _only_2 = []
# _only_3 = []
# _all_three_diff = []

for rxn in rto_sce_overlap:
    r = rto.reactions.get_by_id(rxn)
#     y = ylip.reactions.get_by_id(rxn)
    s = sce.reactions.get_by_id(rxn)
    
    _names.append(r.name)
    _gpr_rto.append(r.gene_reaction_rule)
    _gpr_sce.append(s.gene_reaction_rule)
#     _gpr_ylip.append(y.gene_reaction_rule)
    _gpr_ylip.append('None')


    _id.append(r.id)
    _stoich.append(r.reaction)
    _subsystem.append(r.subsystem)
    
    temp1 = []
    for g in r.genes:
        try:
            temp1.append(lst_rto_dict[g.id])
            print(temp1)
        except:
            temp1.append('NA')
            donothing=0

    _lst_rto_gene.append(temp1)
    
    temp2 = []
    for g in s.genes:
        try:
            temp2.append(lst_sce_dict[g.id])
        except:
#             temp2.append('NA')
            donothing=0
            
    _lst_sce_gene.append(temp2)
    
    temp3 = []
    temp3.append('NA')
    
#     for g in [y.gene_reaction_rule]:
#         try:
#             temp.append(lst_ylip_dict[g])
#         except:
#             temp.append('NA')
    _lst_ylip_gene.append(temp3)
    
    # remove NA for comparisions. 
    if 'NA' in temp1:
        temp1.remove('NA')
        temp1 = [e for e in temp1 if e not in ('NA')]
    if 'NA' in temp2:
        temp2.remove('NA')
        temp2 = [e for e in temp2 if e not in ('NA')]

    if 'NA' in temp3:
        temp3.remove('NA')
        temp3 = [e for e in temp3 if e not in ('NA')]
        
        
    result = compare_three_lists(temp1, temp2, temp3)
    
    
    _common_all.append(result['common_all'])
    _only_12.append(result['only_12'])
    _only_13.append(result['only_13'])
    _only_23.append(result['only_23'])
    _only_1.append(result['only_1'])
    _only_2.append(result['only_2'])
    _only_3.append(result['only_3'])
    _all_three_diff.append(result['all_three_diff'])
# Out:
# ['NA', 'NA', 'NA', 'Lipst1_1_6303']
# ['NA', 'NA', 'NA', 'Lipst1_1_74900']
# ['Lipst1_1_314464']
# ['Lipst1_1_5453']
# ['Lipst1_1_265510']
# ['Lipst1_1_265510', 'Lipst1_1_127634']
# ['Lipst1_1_289621']
# ['Lipst1_1_70370']
# ['Lipst1_1_76289']
# ['Lipst1_1_105640']
# ['Lipst1_1_4472']
# ['NA', 'NA', 'NA', 'Lipst1_1_6303']
# ['Lipst1_1_102591']
# ['Lipst1_1_314768']
# ['Lipst1_1_423']
# ['Lipst1_1_1263']
# ['Lipst1_1_2889']
# ['Lipst1_1_107753']
# ['Lipst1_1_73838']
# ['Lipst1_1_3878']
# ['Lipst1_1_53536']
# ['Lipst1_1_72751']
# ['NA', 'Lipst1_1_2256']
# ['NA', 'Lipst1_1_2256', 'Lipst1_1_61026']
# ['Lipst1_1_76289']
# ['Lipst1_1_338549']
# ['Lipst1_1_48101']
# ['Lipst1_1_27755']
# ['NA', 'Lipst1_1_282']
# ['Lipst1_1_81155']
# ['Lipst1_1_46126']
# ['Lipst1_1_142956']
# ['Lipst1_1_3974']
# ['Lipst1_1_3974']
# ['Lipst1_1_246321']
# ['Lipst1_1_2195']
# ['Lipst1_1_314464']
# ['Lipst1_1_46126']
# ['Lipst1_1_3313']
# ['NA', 'Lipst1_1_102207']
# ['Lipst1_1_71146']
# ['Lipst1_1_1110']
# ['Lipst1_1_931']
# ['Lipst1_1_76359']
# ['NA', 'NA', 'Lipst1_1_69867']
# ['NA', 'NA', 'Lipst1_1_69867', 'NA', 'Lipst1_1_70253']
# ['NA', 'Lipst1_1_65274']
# ['NA', 'Lipst1_1_65274', 'Lipst1_1_261247']
# ['Lipst1_1_99746']
# ['Lipst1_1_99746', 'NA', 'Lipst1_1_2772']
# ['NA', 'Lipst1_1_2256']
# ['NA', 'Lipst1_1_2256', 'Lipst1_1_61026']
# ['Lipst1_1_70370']
# ['Lipst1_1_99746']
# ['Lipst1_1_99746', 'NA', 'Lipst1_1_2772']
# ['Lipst1_1_61657']
# ['Lipst1_1_75890']
# ['Lipst1_1_76289']
# ['Lipst1_1_314464']
# ['Lipst1_1_50618']
# ['Lipst1_1_50618', 'NA', 'NA', 'Lipst1_1_7158']
# ['NA', 'Lipst1_1_3540']
# ['NA', 'NA', 'Lipst1_1_74823']
# ['Lipst1_1_3974']
# ['Lipst1_1_75163']
# ['Lipst1_1_69028']
# ['Lipst1_1_2436']
# ['Lipst1_1_338549']
# ['Lipst1_1_3860']
# ['Lipst1_1_1263']
# ['Lipst1_1_3532']
# ['Lipst1_1_1559']
# ['Lipst1_1_75335']
# ['Lipst1_1_69288']
# ['Lipst1_1_931']
# ['Lipst1_1_423']
# ['Lipst1_1_4566']
# ['Lipst1_1_121954']
# ['Lipst1_1_121954', 'NA', 'Lipst1_1_177423']
# ['Lipst1_1_46126']
# ['Lipst1_1_5184']
# ['Lipst1_1_42480']
# ['Lipst1_1_56835']
# ['Lipst1_1_1857']
# ['NA', 'Lipst1_1_201837']
# ['Lipst1_1_99746']
# ['Lipst1_1_99746', 'NA', 'Lipst1_1_2772']
# ['Lipst1_1_6465']
# ['Lipst1_1_69288']
# ['NA', 'Lipst1_1_101999']
# ['Lipst1_1_1356']
# ['Lipst1_1_1356', 'Lipst1_1_5189']
# ['Lipst1_1_76289']
# ['Lipst1_1_972']
# ['Lipst1_1_2766']
# ['Lipst1_1_594']
# ['Lipst1_1_54959']
# ['Lipst1_1_54959', 'Lipst1_1_2352']
# ['Lipst1_1_54959', 'Lipst1_1_2352', 'NA', 'Lipst1_1_74347']
# ['Lipst1_1_46126']
# ['Lipst1_1_67618']
# ['Lipst1_1_42480']
# ['Lipst1_1_338549']
# ['Lipst1_1_70181']
# ['NA', 'Lipst1_1_76061']
# ['Lipst1_1_3974']
# ['Lipst1_1_46126']
# ['Lipst1_1_99746']
# ['Lipst1_1_99746', 'NA', 'Lipst1_1_2772']
# ['Lipst1_1_61657']
# ['Lipst1_1_3923']
# ['NA', 'NA', 'NA', 'Lipst1_1_44049']
# ['Lipst1_1_73367']
# ['Lipst1_1_5784']
# ['Lipst1_1_70370']
# ['Lipst1_1_103302']
# ['Lipst1_1_310928']
# ['Lipst1_1_870']
# ['Lipst1_1_314768']
# ['Lipst1_1_314768']
# ['Lipst1_1_265510']
# ['Lipst1_1_265510', 'Lipst1_1_127634']
# ['Lipst1_1_92025']
# ['NA', 'NA', 'NA', 'Lipst1_1_121954']
# ['NA', 'NA', 'NA', 'Lipst1_1_121954', 'Lipst1_1_6303']
# ['NA', 'NA', 'NA', 'Lipst1_1_121954', 'Lipst1_1_6303', 'NA', 'Lipst1_1_177423']
# ['Lipst1_1_67618']
# ['Lipst1_1_70370']
# ['NA', 'Lipst1_1_276115']
# ['Lipst1_1_5895']
# ['Lipst1_1_2102']
# ['Lipst1_1_284310']
# ['Lipst1_1_4155']
# ['NA', 'Lipst1_1_2256']
# ['NA', 'Lipst1_1_2256', 'Lipst1_1_61026']
# ['NA', 'Lipst1_1_67991']
# ['Lipst1_1_68284']
# ['NA', 'NA', 'NA', 'Lipst1_1_6303']
# ['Lipst1_1_3985']
# ['Lipst1_1_265510']
# ['Lipst1_1_265510', 'Lipst1_1_127634']
# ['Lipst1_1_5784']
# ['Lipst1_1_3974']
# ['Lipst1_1_33829']
# ['NA', 'Lipst1_1_3540']
# ['Lipst1_1_76289']
# ['Lipst1_1_57798']
# ['NA', 'NA', 'NA', 'Lipst1_1_74862']
# ['Lipst1_1_72834']
# ['Lipst1_1_72834', 'Lipst1_1_71351']
# ['Lipst1_1_5576']
# ['Lipst1_1_72360']
# ['Lipst1_1_70370']
# ['Lipst1_1_265510']
# ['Lipst1_1_265510', 'Lipst1_1_127634']
# ['Lipst1_1_70181']
# ['Lipst1_1_275']
# ['Lipst1_1_99746']
# ['Lipst1_1_99746', 'NA', 'Lipst1_1_2772']
# ['NA', 'Lipst1_1_3431']
# ['Lipst1_1_70253']
# ['Lipst1_1_70253', 'Lipst1_1_69038']
# ['Lipst1_1_73838']
# ['Lipst1_1_75138']
# ['Lipst1_1_1110']
# ['Lipst1_1_1110', 'Lipst1_1_72701']
# ['Lipst1_1_50618']
# ['Lipst1_1_50618', 'NA', 'NA', 'Lipst1_1_7158']
# ['Lipst1_1_176686']
# ['Lipst1_1_73351']
# ['Lipst1_1_97460']
# ['Lipst1_1_4054']
# ['Lipst1_1_49747']
# ['Lipst1_1_5472']
# ['Lipst1_1_925']
# ['Lipst1_1_76716']
# ['Lipst1_1_6779']
# ['Lipst1_1_3290']
# ['Lipst1_1_53798']
# ['Lipst1_1_4390']
# ['Lipst1_1_50110']
# ['Lipst1_1_73932']
# ['Lipst1_1_76716']
# ['Lipst1_1_3617']
# ['Lipst1_1_314464']
# ['Lipst1_1_67687']
# ['Lipst1_1_67687']
# ['Lipst1_1_72108']
# ['Lipst1_1_47259']
# ['Lipst1_1_75992']
# ['Lipst1_1_6459']
# ['Lipst1_1_1356']
# ['Lipst1_1_71319']

# %%
# df3 = pd.DataFrame([_names,_id,_stoich,_subsystem,_gpr_rto,_gpr_sce,_lst_rto_gene,_lst_sce_gene,_common_all,_only_12,_only_13,_only_23,_only_1,_only_2,_only_3,_all_three_diff]).T

# %%
# df3.to_csv('rto_sce_overlap_genes.csv')

# %%
# save output. 
# df3 = pd.DataFrame([_names,_id,_stoich,_subsystem,_gpr_rto,_gpr_sce,_gpr_ylip,_lst_rto_gene,_lst_sce_gene,_lst_ylip_gene,_common_all,_only_12,_only_13,_only_23,_only_1,_only_2,_only_3,_all_three_diff]).T
# df3.to_csv('allcomparisions_genes.csv')

# %% [markdown]
# #### next
#
# Automate the GPR for each reaction and model.

# %%
def concatenate_elements(*lists):
    # Ensure that all lists have the same length by filling shorter lists with empty strings
    labels_list = []

        
    max_len = max(len(lst) for lst in lists)
    for lst in lists:
        while len(lst) < max_len:
            lst.append([''])
    
    # Concatenate lists
    result = []
    
    

    for i in range(max_len):
        combined_string = " or ".join(
            " or; ".join(sub_item.replace("None", "").replace("NA"," ") for sub_item in lst[i]) for lst in lists 
            if len(lst) > i and lst[i]
            )
        # potential alternative.
#         combined_string = ' or '.join(item.replace("None", "").replace("NA"," ") for sublist in nested_lists for subsublist in sublist for item in subsublist)

        result.append([combined_string])
        
    
        # Generate label for this concatenated string
        if combined_string:
            current_labels = []
            for j, lst in enumerate(lists):
                if len(lst) > 0 and lst[i]:
                    if j == 0:
                        current_labels.append("rto,sce,ylip")
                    elif j == 1:
                        current_labels.append("rto,sce")
                    elif j == 2:
                        current_labels.append("rto,ylip")
                    elif j == 3:
                        current_labels.append("sce,ylip")
                    elif j == 4:
                        current_labels.append("rto")
                    elif j == 5:
                        current_labels.append("sce")
                    elif j == 6:
                        current_labels.append("ylip")
            labels_list.append(" ; ".join(current_labels))
        else:
            labels_list.append('')    
            
            
            
            
#             current_labels = [f"list_{j+1}" for j, lst in enumerate(lists) if len(lst) > i and lst[i]]
#             labels_list.append(" or ".join(current_labels))
    
    return result,labels_list

# %%
# gene annotation for each ortholog and the species source of the ortholog. 
result,result_labels = concatenate_elements(_common_all,_only_12,_only_13,_only_23,_only_1,_only_2,_only_3)

# %%
for r, label in zip(result, result_labels):
    print(f"{r[0]} (From: {label})")
# Out:
# Lipst1_1_73838 (From: rto,ylip)
# Lipst1_1_103302 (From: rto,sce)
# Lipst1_1_258919 (From: rto,sce,ylip)
# Lipst1_1_63385 (From: rto,sce,ylip)
# Lipst1_1_60832 or Lipst1_1_43727 (From: rto,sce,ylip ; rto,ylip)
# Lipst1_1_68609 or Lipst1_1_70253 (From: rto,sce,ylip ; rto,sce)
# Lipst1_1_3835 or Lipst1_1_57709 (From: sce ; ylip)
# Lipst1_1_4166 or Lipst1_1_6739 (From: rto,sce,ylip ; rto)
# Lipst1_1_47324 (From: rto,sce,ylip)
# Lipst1_1_2102 or Lipst1_1_70967 (From: rto ; sce)
# Lipst1_1_54023 (From: rto,sce,ylip)
# Lipst1_1_68065 or Lipst1_1_47067 (From: rto ; ylip)
# Lipst1_1_302882 (From: rto,sce,ylip)
# Lipst1_1_102877 (From: rto,sce,ylip)
# Lipst1_1_3600 or Lipst1_1_111440 (From: rto ; sce)
# Lipst1_1_72751 (From: rto,sce,ylip)
# Lipst1_1_102877 (From: rto,sce,ylip)
# Lipst1_1_92627 or Lipst1_1_47067 (From: rto,sce,ylip ; sce,ylip)
# Lipst1_1_4094 or Lipst1_1_2516 (From: rto,sce ; ylip)
# Lipst1_1_69224 or Lipst1_1_1857 (From: rto,sce,ylip ; ylip)
# Lipst1_1_72774 (From: rto,sce,ylip)
# Lipst1_1_73707 (From: rto,sce,ylip)
# Lipst1_1_275 (From: rto,sce,ylip)
# Lipst1_1_35483 (From: rto,sce,ylip)
# Lipst1_1_1834 (From: rto,sce,ylip)
# Lipst1_1_75883 (From: rto,sce)
# Lipst1_1_68121 (From: rto,sce,ylip)
# Lipst1_1_89607 (From: rto,sce,ylip)
# Lipst1_1_103580 or Lipst1_1_164851 (From: rto,sce,ylip ; ylip)
# Lipst1_1_70511 (From: rto,sce,ylip)
#  (From: )
# Lipst1_1_69043 (From: ylip)
# Lipst1_1_196787 or Lipst1_1_201989 (From: rto,sce,ylip ; ylip)
# Lipst1_1_47324 (From: rto,sce,ylip)
# Lipst1_1_72400 (From: rto,sce,ylip)
# Lipst1_1_72898 or Lipst1_1_4939 or; Lipst1_1_71658 (From: rto,sce,ylip ; ylip)
# Lipst1_1_241647 (From: ylip)
# Lipst1_1_241647 (From: ylip)
# Lipst1_1_157499 (From: rto,sce,ylip)
# Lipst1_1_71969 or Lipst1_1_3835 or Lipst1_1_57709 (From: rto ; sce ; ylip)
# Lipst1_1_5409 or Lipst1_1_5857 (From: rto ; ylip)
# Lipst1_1_6430 (From: rto,sce,ylip)
# Lipst1_1_76556 or Lipst1_1_73409 (From: rto,sce,ylip ; ylip)
# Lipst1_1_3600 (From: rto)
# Lipst1_1_70762 or Lipst1_1_59512 or Lipst1_1_147168 (From: rto,ylip ; sce ; ylip)
# Lipst1_1_61809 (From: rto,sce,ylip)
# Lipst1_1_70474 (From: rto,sce,ylip)
# Lipst1_1_73409 or Lipst1_1_76556 (From: rto,sce,ylip ; ylip)
# Lipst1_1_3313 (From: rto,sce,ylip)
# Lipst1_1_72902 (From: rto,sce,ylip)
# Lipst1_1_72597 or Lipst1_1_7296 or Lipst1_1_54130 or; Lipst1_1_32541 (From: rto,sce ; sce ; ylip)
# Lipst1_1_283125 (From: rto,sce,ylip)
# Lipst1_1_75567 (From: rto,sce,ylip)
# Lipst1_1_1998 (From: rto,ylip)
# Lipst1_1_72597 (From: rto,sce)
# Lipst1_1_338549 (From: rto)
# Lipst1_1_75887 (From: rto,sce,ylip)
# Lipst1_1_5880 or Lipst1_1_4996 (From: rto,sce ; ylip)
# Lipst1_1_132 (From: rto,sce,ylip)
# Lipst1_1_1228 (From: rto,ylip)
# Lipst1_1_68121 (From: rto,sce,ylip)
# Lipst1_1_73845 or Lipst1_1_75188 (From: rto,sce,ylip ; ylip)
# Lipst1_1_36529 or Lipst1_1_39586 or Lipst1_1_4390 or; Lipst1_1_48116 (From: rto,ylip ; sce ; ylip)
# Lipst1_1_75883 or Lipst1_1_58573 (From: rto,sce ; ylip)
# Lipst1_1_71969 or Lipst1_1_3835 or Lipst1_1_57709 (From: rto ; sce ; ylip)
# Lipst1_1_157098 (From: rto,ylip)
#  (From: )
# Lipst1_1_6444 (From: rto,sce,ylip)
# Lipst1_1_70877 (From: rto,sce,ylip)
# Lipst1_1_3290 (From: rto,sce,ylip)
# Lipst1_1_228 or Lipst1_1_69723 (From: rto,sce,ylip ; sce)
# Lipst1_1_2363 or; Lipst1_1_29458 (From: rto,sce,ylip)
# Lipst1_1_72093 (From: rto,sce,ylip)
# Lipst1_1_168 (From: rto,sce,ylip)
# Lipst1_1_99746 (From: rto)
# Lipst1_1_72751 (From: rto,sce,ylip)
# Lipst1_1_51135 (From: rto,sce,ylip)
# Lipst1_1_4946 (From: rto,sce)
# Lipst1_1_72563 (From: rto,sce,ylip)
# Lipst1_1_69933 or Lipst1_1_73260 (From: rto,sce,ylip ; rto,ylip)
# Lipst1_1_73737 (From: rto,sce,ylip)
# Lipst1_1_4939 or; Lipst1_1_71658 or Lipst1_1_72898 (From: rto,sce,ylip ; ylip)
# Lipst1_1_239921 (From: rto,sce,ylip)
# Lipst1_1_52642 (From: rto,sce,ylip)
# Lipst1_1_105290 (From: rto,sce,ylip)
# Lipst1_1_52812 or Lipst1_1_4095 (From: rto,sce,ylip ; ylip)
# Lipst1_1_105569 (From: rto,sce,ylip)
# Lipst1_1_3975 (From: rto,sce,ylip)
# Lipst1_1_67222 (From: rto,sce)
# Lipst1_1_1741 (From: rto,sce,ylip)
# Lipst1_1_338321 (From: rto,sce,ylip)
# Lipst1_1_67513 (From: rto,sce,ylip)
# Lipst1_1_70511 (From: rto,sce,ylip)
# Lipst1_1_60832 or Lipst1_1_43727 (From: rto,sce,ylip ; ylip)
# Lipst1_1_72751 (From: rto,sce,ylip)
# Lipst1_1_87988 (From: rto,sce,ylip)
# Lipst1_1_3313 (From: rto,sce,ylip)
# Lipst1_1_1263 (From: rto,sce,ylip)
# Lipst1_1_67949 (From: rto,sce,ylip)
# Lipst1_1_241647 (From: rto,sce,ylip)
# Lipst1_1_241647 (From: ylip)
# Lipst1_1_41207 (From: rto,sce,ylip)
# Lipst1_1_72751 (From: rto,sce,ylip)
# Lipst1_1_215 (From: rto,sce,ylip)
# Lipst1_1_404 or Lipst1_1_931 (From: rto,ylip ; sce)
# Lipst1_1_110167 (From: rto,sce,ylip)
# Lipst1_1_4054 (From: rto,sce,ylip)
# Lipst1_1_2767 (From: rto,sce,ylip)
# Lipst1_1_37388 (From: rto,sce,ylip)
# Lipst1_1_256229 (From: rto,sce)
# Lipst1_1_6367 (From: rto,sce,ylip)
# Lipst1_1_2213 (From: rto,sce,ylip)
# Lipst1_1_162168 (From: rto,sce,ylip)
# Lipst1_1_46503 or Lipst1_1_322121 or Lipst1_1_69043 (From: rto,sce,ylip ; rto ; ylip)
# Lipst1_1_51135 (From: rto,sce)
# Lipst1_1_5453 (From: sce,ylip)
# Lipst1_1_72320 or Lipst1_1_94934 (From: rto,sce,ylip ; rto,ylip)
# Lipst1_1_71964 or; Lipst1_1_69736 or; Lipst1_1_67537 (From: rto,sce,ylip)
# Lipst1_1_2516 or Lipst1_1_327549 (From: rto ; sce)
# Lipst1_1_193402 (From: rto,sce,ylip)
# Lipst1_1_1998 (From: rto,sce,ylip)
# Lipst1_1_265581 (From: rto,sce,ylip)
# Lipst1_1_3600 or Lipst1_1_111440 (From: rto ; sce)
# Lipst1_1_60832 or; Lipst1_1_43727 (From: rto,sce,ylip)
# Lipst1_1_3900 or Lipst1_1_73932 (From: rto,sce,ylip ; sce)
# Lipst1_1_74823 or Lipst1_1_5931 (From: rto ; sce)
# Lipst1_1_2955 or Lipst1_1_309296 (From: rto,sce ; rto)
# Lipst1_1_1586 or Lipst1_1_256229 (From: rto,sce,ylip ; ylip)
# Lipst1_1_2516 or Lipst1_1_327549 (From: rto,sce,ylip ; sce)
# Lipst1_1_63385 (From: rto,sce,ylip)
# Lipst1_1_74203 (From: rto,sce,ylip)
# Lipst1_1_73838 (From: rto,ylip)
# Lipst1_1_84 or Lipst1_1_90973 (From: rto,sce,ylip ; ylip)
# Lipst1_1_50182 (From: rto,sce,ylip)
# Lipst1_1_132 (From: rto,sce,ylip)
# Lipst1_1_6459 (From: rto,sce)
# Lipst1_1_119165 (From: rto,sce,ylip)
# Lipst1_1_5184 (From: rto,sce,ylip)
# Lipst1_1_338321 (From: rto,sce,ylip)
# Lipst1_1_25577 (From: rto,sce,ylip)
# Lipst1_1_6251 (From: rto,sce,ylip)
# Lipst1_1_85639 (From: rto,sce,ylip)
# Lipst1_1_3128 (From: rto,sce,ylip)
# Lipst1_1_73838 (From: rto,sce,ylip)
# Lipst1_1_182606 (From: rto,sce,ylip)
# Lipst1_1_313744 or Lipst1_1_4956 or Lipst1_1_542 (From: rto,sce,ylip ; rto ; ylip)
# Lipst1_1_3600 or Lipst1_1_111440 or; Lipst1_1_57088 (From: rto ; sce)
# Lipst1_1_168 (From: rto,sce,ylip)
# Lipst1_1_1228 (From: rto,sce,ylip)
# Lipst1_1_110210 (From: rto,sce,ylip)
# Lipst1_1_104780 (From: rto,sce,ylip)
# Lipst1_1_6459 (From: rto,sce)
# Lipst1_1_72802 or Lipst1_1_265200 or Lipst1_1_4166 (From: rto,sce,ylip ; rto,ylip ; rto)
# Lipst1_1_7017 or Lipst1_1_2089 (From: rto,sce,ylip ; ylip)
# Lipst1_1_69224 or Lipst1_1_1857 (From: rto,sce,ylip ; ylip)
# Lipst1_1_4095 or Lipst1_1_52812 (From: rto,sce,ylip ; ylip)
# Lipst1_1_241647 (From: ylip)
# Lipst1_1_4946 or Lipst1_1_1110 (From: rto,sce ; rto)
# Lipst1_1_5931 or Lipst1_1_74823 (From: sce,ylip ; rto)
# Lipst1_1_316 (From: rto,sce,ylip)
# Lipst1_1_70370 (From: rto,sce,ylip)
# Lipst1_1_258919 (From: rto,sce,ylip)
# Lipst1_1_72149 (From: rto,sce)
# Lipst1_1_3573 (From: rto,sce,ylip)
# Lipst1_1_288751 (From: rto,sce,ylip)
# Lipst1_1_75188 or Lipst1_1_73845 (From: rto,sce,ylip ; ylip)
# Lipst1_1_68590 (From: rto,ylip)
# Lipst1_1_2790 (From: rto,sce,ylip)
# Lipst1_1_925 (From: rto,sce,ylip)
# Lipst1_1_3458 (From: rto,sce,ylip)
# Lipst1_1_5229 (From: rto,sce,ylip)
# Lipst1_1_73407 or Lipst1_1_101674 (From: rto,sce,ylip ; sce,ylip)
# Lipst1_1_1896 (From: rto,sce,ylip)
# Lipst1_1_68472 (From: rto,sce,ylip)
# Lipst1_1_73737 (From: rto,sce,ylip)
# Lipst1_1_75768 (From: rto,sce,ylip)
# Lipst1_1_75883 (From: rto,sce)
# Lipst1_1_3600 or Lipst1_1_111440 (From: rto ; sce)
# Lipst1_1_102853 (From: ylip)
# Lipst1_1_238934 (From: rto,sce,ylip)
# Lipst1_1_3931 (From: rto,sce,ylip)
# Lipst1_1_6067 (From: rto,sce,ylip)
# Lipst1_1_117393 (From: rto,sce,ylip)
# Lipst1_1_7080 (From: rto,sce)
# Lipst1_1_404 or Lipst1_1_70253 (From: rto,sce,ylip ; sce)
# Lipst1_1_33932 (From: rto,sce,ylip)
# Lipst1_1_71969 or Lipst1_1_3835 or Lipst1_1_57709 (From: rto ; sce ; ylip)
# Lipst1_1_102877 (From: rto,sce,ylip)
# Lipst1_1_47324 (From: rto,sce,ylip)
# Lipst1_1_74872 (From: rto,sce,ylip)
# Lipst1_1_67613 (From: rto,sce,ylip)
# Lipst1_1_5978 (From: rto,sce,ylip)
# Lipst1_1_71443 (From: rto,sce,ylip)
# Lipst1_1_3600 or Lipst1_1_111440 (From: rto ; sce)
# Lipst1_1_76037 (From: rto,sce,ylip)
# Lipst1_1_74867 or; Lipst1_1_1724 or Lipst1_1_79742 or; Lipst1_1_67480 or; Lipst1_1_55686 (From: rto,sce,ylip ; rto,sce)
# Lipst1_1_117342 or Lipst1_1_102591 (From: rto,sce,ylip ; ylip)
# Lipst1_1_94412 (From: rto,sce,ylip)
# Lipst1_1_102287 (From: rto,sce,ylip)
# Lipst1_1_6557 (From: rto,sce,ylip)
# Lipst1_1_104780 (From: rto,sce,ylip)
# Lipst1_1_2110 (From: rto,sce,ylip)
# Lipst1_1_46980 (From: rto,sce,ylip)
# Lipst1_1_69113 (From: rto,sce,ylip)
# Lipst1_1_73341 (From: rto,sce,ylip)
# Lipst1_1_54569 or Lipst1_1_3600 or Lipst1_1_111440 (From: rto,sce,ylip ; rto ; sce)
# Lipst1_1_105712 or Lipst1_1_58334 or Lipst1_1_48449 (From: sce,ylip ; rto ; sce)
# Lipst1_1_70723 (From: rto,sce,ylip)
# Lipst1_1_3128 (From: rto,sce,ylip)
# Lipst1_1_72319 (From: rto,sce,ylip)
# Lipst1_1_7085 (From: rto,sce)
# Lipst1_1_1263 (From: rto,sce,ylip)
# Lipst1_1_3600 or Lipst1_1_111440 or Lipst1_1_54569 (From: rto ; sce ; ylip)
# Lipst1_1_75883 or Lipst1_1_58573 (From: rto,sce ; ylip)
# Lipst1_1_68186 (From: rto,sce,ylip)
# Lipst1_1_75883 (From: rto,sce)
# Lipst1_1_7391 (From: rto,sce,ylip)
# Lipst1_1_1034 (From: rto,sce,ylip)
# Lipst1_1_316583 (From: rto,sce,ylip)
# Lipst1_1_72186 (From: rto,sce,ylip)
# Lipst1_1_102585 (From: rto,sce,ylip)
# Lipst1_1_68855 or Lipst1_1_72137 or Lipst1_1_61809 (From: rto,ylip ; rto ; sce)
# Lipst1_1_3600 or Lipst1_1_111440 (From: rto ; sce)
# Lipst1_1_88614 (From: rto,sce,ylip)
# Lipst1_1_3600 or Lipst1_1_111440 (From: rto ; sce)
# Lipst1_1_4257 (From: rto,ylip)
# Lipst1_1_84 or Lipst1_1_90973 (From: rto,ylip ; sce,ylip)
# Lipst1_1_332345 (From: rto,sce,ylip)
# Lipst1_1_25577 (From: rto,sce,ylip)
# Lipst1_1_72751 (From: rto,sce,ylip)
# Lipst1_1_54569 or Lipst1_1_3600 or Lipst1_1_111440 (From: rto,sce,ylip ; rto ; sce)
# Lipst1_1_69113 (From: rto,sce,ylip)
# Lipst1_1_72935 or; Lipst1_1_4904 or; Lipst1_1_32736 or; Lipst1_1_90916 or; Lipst1_1_86782 or; Lipst1_1_75804 or; Lipst1_1_52074 or; Lipst1_1_25267 or; Lipst1_1_101415 or; Lipst1_1_448 or Lipst1_1_72399 or; Lipst1_1_46841 or; Lipst1_1_71305 or Lipst1_1_2175 (From: rto,sce ; rto ; sce)
# Lipst1_1_6444 (From: rto,sce,ylip)
#  (From: )
# Lipst1_1_55185 (From: rto,sce)
# Lipst1_1_103097 (From: rto,sce)
# Lipst1_1_51135 (From: rto,sce,ylip)
# Lipst1_1_71969 or Lipst1_1_3835 or Lipst1_1_57709 (From: rto ; sce ; ylip)
# Lipst1_1_275 (From: rto,sce,ylip)
# Lipst1_1_2223 (From: rto,ylip)
# Lipst1_1_3431 (From: rto,sce,ylip)
# Lipst1_1_72319 (From: rto,sce,ylip)
# Lipst1_1_234091 (From: rto,sce,ylip)
# Lipst1_1_156565 (From: rto,sce)
# Lipst1_1_3938 (From: rto,sce,ylip)
# Lipst1_1_241647 (From: rto,sce,ylip)
# Lipst1_1_3600 or Lipst1_1_111440 (From: rto ; sce)
# Lipst1_1_47324 (From: rto,sce,ylip)
# Lipst1_1_61809 (From: rto,sce,ylip)
# Lipst1_1_72810 or Lipst1_1_31624 (From: rto,sce,ylip ; ylip)
# Lipst1_1_870 (From: rto,sce,ylip)
# Lipst1_1_67945 or Lipst1_1_74569 or; Lipst1_1_244790 (From: sce,ylip ; rto)
# Lipst1_1_70900 or Lipst1_1_4340 (From: sce,ylip ; rto)
# Lipst1_1_72797 or Lipst1_1_47259 (From: sce,ylip ; rto)
# Lipst1_1_72215 (From: rto,sce,ylip)
# Lipst1_1_3600 or Lipst1_1_111440 (From: rto ; sce)
# Lipst1_1_104169 or Lipst1_1_4018 or Lipst1_1_255632 (From: rto,sce,ylip ; sce,ylip ; sce)
# Lipst1_1_1069 (From: rto,sce)
# Lipst1_1_72751 (From: rto,sce,ylip)
# Lipst1_1_3600 or Lipst1_1_111440 (From: rto ; sce)
# Lipst1_1_177423 or; Lipst1_1_121954 or Lipst1_1_5651 or Lipst1_1_6983 (From: rto,ylip ; sce ; ylip)
# Lipst1_1_205437 or Lipst1_1_201837 or; Lipst1_1_206087 (From: rto,sce ; ylip)
# Lipst1_1_75169 (From: rto,sce,ylip)
# Lipst1_1_1998 (From: rto,ylip)
# Lipst1_1_274 (From: rto,sce,ylip)
# Lipst1_1_62277 or Lipst1_1_244782 (From: rto,sce,ylip ; ylip)
# Lipst1_1_70723 (From: rto,sce,ylip)
# Lipst1_1_336589 (From: rto,sce,ylip)
# Lipst1_1_70305 (From: rto,sce,ylip)
# Lipst1_1_72797 or Lipst1_1_47259 (From: rto,ylip ; rto)
# Lipst1_1_105823 (From: rto,sce,ylip)
# Lipst1_1_4166 or Lipst1_1_6739 (From: rto,sce,ylip ; rto)
# Lipst1_1_870 (From: rto,sce,ylip)
# Lipst1_1_69651 (From: rto,sce)
# Lipst1_1_205437 or Lipst1_1_201837 or; Lipst1_1_206087 (From: rto,sce ; ylip)
# Lipst1_1_2363 or; Lipst1_1_29458 or Lipst1_1_70253 (From: rto,sce,ylip ; rto)
# Lipst1_1_1344 or Lipst1_1_68607 (From: rto,sce,ylip ; rto)
# Lipst1_1_7080 (From: rto,sce)
# Lipst1_1_594 (From: rto,sce,ylip)
# Lipst1_1_4490 or Lipst1_1_69192 (From: rto,sce,ylip ; rto,sce)
# Lipst1_1_155998 (From: rto,sce)
# Lipst1_1_72751 (From: rto,sce,ylip)
# Lipst1_1_72186 (From: rto,sce,ylip)
# Lipst1_1_76545 or; Lipst1_1_2524 (From: rto)
# Lipst1_1_1792 (From: rto,sce,ylip)
# Lipst1_1_102477 or; Lipst1_1_3555 (From: rto,sce,ylip)
# Lipst1_1_71543 (From: rto,sce,ylip)
# Lipst1_1_72597 (From: rto,sce)
# Lipst1_1_161705 (From: rto,sce,ylip)
# Lipst1_1_117734 or Lipst1_1_154486 (From: rto,sce,ylip ; rto)
# Lipst1_1_60832 or Lipst1_1_43727 (From: rto,sce,ylip ; ylip)
# Lipst1_1_69113 (From: rto,sce,ylip)
# Lipst1_1_101656 (From: rto,sce,ylip)
# Lipst1_1_5128 (From: rto,sce,ylip)
# Lipst1_1_75322 (From: rto,sce,ylip)
# Lipst1_1_2223 (From: rto,sce,ylip)
# Lipst1_1_194216 (From: rto,sce,ylip)
# Lipst1_1_51135 (From: rto,sce)
# Lipst1_1_1356 or Lipst1_1_71673 or Lipst1_1_6750 (From: rto ; sce ; ylip)
# Lipst1_1_68186 (From: rto,sce,ylip)
# Lipst1_1_3600 or Lipst1_1_111440 (From: rto ; sce)
# Lipst1_1_59512 (From: rto,sce,ylip)
# Lipst1_1_72215 or Lipst1_1_7298 (From: rto,sce,ylip ; ylip)
# Lipst1_1_72400 (From: rto,sce,ylip)
# Lipst1_1_5341 (From: rto,sce,ylip)
# Lipst1_1_5184 (From: rto,sce,ylip)
# Lipst1_1_59861 (From: rto,sce,ylip)
# Lipst1_1_2790 (From: rto,sce,ylip)
# Lipst1_1_324941 (From: rto,sce,ylip)
# Lipst1_1_53798 or Lipst1_1_71326 (From: rto,sce,ylip ; sce)
# Lipst1_1_139115 (From: rto,sce,ylip)
# Lipst1_1_588 (From: rto,sce,ylip)
# Lipst1_1_1741 (From: rto,ylip)
# Lipst1_1_73838 (From: rto,sce,ylip)
# Lipst1_1_51135 (From: rto,sce,ylip)
# Lipst1_1_205437 or Lipst1_1_201837 or; Lipst1_1_206087 (From: rto ; ylip)
# Lipst1_1_5235 (From: rto,sce,ylip)
# Lipst1_1_117633 (From: rto,sce,ylip)
# Lipst1_1_149190 (From: rto,ylip)
# Lipst1_1_105823 (From: rto,sce,ylip)
# Lipst1_1_69850 (From: sce,ylip)
# Lipst1_1_3267 (From: rto,sce,ylip)
# Lipst1_1_70534 or Lipst1_1_1110 (From: rto,sce,ylip ; rto)
# Lipst1_1_67294 (From: rto,sce)
# Lipst1_1_54569 or Lipst1_1_3600 or Lipst1_1_111440 (From: rto,sce,ylip ; rto ; sce)
# Lipst1_1_68607 (From: rto,sce,ylip)
# Lipst1_1_934 (From: rto,sce,ylip)
# Lipst1_1_1263 (From: rto,sce,ylip)
# Lipst1_1_4523 or Lipst1_1_73977 (From: rto,sce,ylip ; ylip)
# Lipst1_1_75883 (From: rto,sce)
# Lipst1_1_314464 (From: rto,sce,ylip)
# Lipst1_1_157098 or Lipst1_1_4003 (From: rto,ylip ; rto)
# Lipst1_1_70713 (From: rto,sce,ylip)
# Lipst1_1_47565 (From: rto,sce,ylip)
# Lipst1_1_3600 or Lipst1_1_111440 (From: rto ; sce)
# Lipst1_1_6813 (From: rto,sce,ylip)
# Lipst1_1_54569 or Lipst1_1_3600 or Lipst1_1_111440 (From: rto,sce,ylip ; rto ; sce)
# Lipst1_1_74675 (From: rto,sce,ylip)
# Lipst1_1_72751 (From: rto,sce,ylip)
# Lipst1_1_2413 (From: rto,sce,ylip)
# Lipst1_1_3313 or Lipst1_1_89420 (From: rto,sce,ylip ; sce,ylip)
# Lipst1_1_54569 or Lipst1_1_3600 or Lipst1_1_111440 (From: rto,sce,ylip ; rto ; sce)
# Lipst1_1_67972 (From: rto,sce,ylip)
# Lipst1_1_1274 (From: rto,sce,ylip)
# Lipst1_1_2436 or Lipst1_1_285732 (From: rto,ylip ; sce,ylip)
# Lipst1_1_189449 (From: rto,sce,ylip)
# Lipst1_1_47324 (From: rto,sce,ylip)
# Lipst1_1_59861 (From: rto,sce,ylip)
# Lipst1_1_54184 or Lipst1_1_3514 (From: rto,sce,ylip ; ylip)
# Lipst1_1_2790 (From: rto,sce,ylip)
# Lipst1_1_2363 or; Lipst1_1_29458 (From: rto,sce,ylip)
# Lipst1_1_72797 or Lipst1_1_47259 or Lipst1_1_72533 or; Lipst1_1_70288 or; Lipst1_1_2905 (From: sce,ylip ; rto ; ylip)
# Lipst1_1_60710 or; Lipst1_1_2214 (From: rto,sce,ylip)
# Lipst1_1_5692 (From: rto,sce,ylip)
# Lipst1_1_51135 (From: rto,sce,ylip)
# Lipst1_1_1228 (From: rto,ylip)
# Lipst1_1_4003 or Lipst1_1_157098 (From: rto,sce,ylip ; rto)
# Lipst1_1_4780 (From: sce,ylip)
# Lipst1_1_2790 (From: rto,sce,ylip)
# Lipst1_1_68107 (From: rto,sce)
# Lipst1_1_4257 (From: rto,sce,ylip)
# Lipst1_1_299000 (From: rto,sce)
# Lipst1_1_149190 (From: rto,sce,ylip)
# Lipst1_1_157098 (From: rto,sce,ylip)
# Lipst1_1_75883 or Lipst1_1_58573 (From: rto,sce ; ylip)
# Lipst1_1_147292 (From: rto,sce,ylip)
# Lipst1_1_72751 (From: rto,sce,ylip)
# Lipst1_1_74014 or Lipst1_1_239921 (From: rto ; sce)
# Lipst1_1_72319 (From: rto,sce,ylip)
# Lipst1_1_5128 (From: rto,sce,ylip)
# Lipst1_1_1741 (From: rto,ylip)
# Lipst1_1_75116 (From: rto,sce,ylip)
# Lipst1_1_58737 (From: rto,sce,ylip)
# Lipst1_1_5288 (From: rto,sce,ylip)
# Lipst1_1_67179 or Lipst1_1_76570 (From: rto,sce,ylip ; rto)
# Lipst1_1_54569 or Lipst1_1_3600 or Lipst1_1_111440 or; Lipst1_1_1540 (From: rto,sce,ylip ; rto ; sce)
# Lipst1_1_3625 or Lipst1_1_154956 (From: sce,ylip ; rto)
# Lipst1_1_70001 (From: rto,sce)
# Lipst1_1_5292 (From: rto,sce,ylip)
# Lipst1_1_6813 (From: rto,sce)
# Lipst1_1_72193 (From: rto,sce,ylip)
# Lipst1_1_2363 or; Lipst1_1_29458 or Lipst1_1_70253 (From: rto,sce,ylip ; rto)
# Lipst1_1_99817 (From: rto)
# Lipst1_1_275 or Lipst1_1_3985 (From: rto,sce,ylip ; ylip)
# Lipst1_1_48617 (From: rto,sce,ylip)
# Lipst1_1_72774 (From: rto,sce,ylip)
# Lipst1_1_2790 (From: rto,sce,ylip)
# Lipst1_1_164851 or Lipst1_1_103580 (From: rto,sce,ylip ; ylip)
# Lipst1_1_241647 (From: ylip)
# Lipst1_1_255632 or; Lipst1_1_104169 or Lipst1_1_4018 (From: rto,sce,ylip ; sce,ylip)
# Lipst1_1_1591 (From: rto,sce,ylip)
# Lipst1_1_2195 or Lipst1_1_103460 (From: rto,sce,ylip ; sce,ylip)
# Lipst1_1_209648 (From: rto,sce,ylip)
# Lipst1_1_72106 or Lipst1_1_265581 (From: rto,sce ; ylip)
# Lipst1_1_118171 (From: rto,sce,ylip)
# Lipst1_1_315712 or Lipst1_1_5184 (From: rto,ylip ; ylip)
# Lipst1_1_117734 or Lipst1_1_154486 (From: rto,ylip ; rto)
# Lipst1_1_72902 (From: rto,sce,ylip)
# Lipst1_1_67652 (From: rto,sce,ylip)
# Lipst1_1_1741 (From: rto,ylip)
# Lipst1_1_4166 or Lipst1_1_6739 (From: rto,sce,ylip ; rto)
# Lipst1_1_70496 or; Lipst1_1_4980 (From: rto,sce,ylip)
# Lipst1_1_1998 (From: rto,ylip)
# Lipst1_1_72381 or; Lipst1_1_67690 or Lipst1_1_41960 (From: rto,ylip ; sce,ylip)
# Lipst1_1_33725 or Lipst1_1_73351 (From: rto,sce,ylip ; rto,sce)
#  (From: )
# Lipst1_1_54569 or Lipst1_1_3600 or Lipst1_1_111440 (From: rto,sce,ylip ; rto ; sce)
# Lipst1_1_1064 (From: rto,sce,ylip)
# Lipst1_1_70973 or Lipst1_1_61315 or; Lipst1_1_48518 or; Lipst1_1_67480 (From: rto,sce,ylip ; rto,sce)
# Lipst1_1_206 or Lipst1_1_80397 or Lipst1_1_30795 or Lipst1_1_4715 or Lipst1_1_5784 (From: rto,sce,ylip ; rto,sce ; sce,ylip ; rto ; ylip)
# Lipst1_1_3965 (From: rto,sce,ylip)
# Lipst1_1_148853 (From: rto,sce,ylip)
# Lipst1_1_3041 or Lipst1_1_71443 or Lipst1_1_6367 (From: rto,sce,ylip ; rto,sce ; rto)
# Lipst1_1_2524 (From: rto,sce,ylip)
# Lipst1_1_3809 (From: rto,sce,ylip)
# Lipst1_1_48449 or Lipst1_1_105712 (From: rto,sce,ylip ; sce,ylip)
# Lipst1_1_2774 (From: rto,sce,ylip)
# Lipst1_1_2363 or; Lipst1_1_29458 (From: rto,sce,ylip)
# Lipst1_1_238934 or; Lipst1_1_4540 (From: rto,sce,ylip)
# Lipst1_1_50963 (From: rto)
# Lipst1_1_60832 or Lipst1_1_43727 (From: rto,sce,ylip ; ylip)
# Lipst1_1_2102 or Lipst1_1_70967 (From: rto ; sce)
# Lipst1_1_326473 (From: rto,sce,ylip)
# Lipst1_1_2791 (From: rto,sce,ylip)
# Lipst1_1_73436 (From: rto,sce,ylip)
# Lipst1_1_314464 (From: rto,sce,ylip)
# Lipst1_1_338321 (From: rto,sce,ylip)
# Lipst1_1_5558 (From: rto,sce,ylip)
# Lipst1_1_2348 (From: rto,sce,ylip)
# Lipst1_1_5675 (From: rto,sce,ylip)
# Lipst1_1_2363 or; Lipst1_1_29458 or Lipst1_1_70253 (From: rto,sce,ylip ; rto)
# Lipst1_1_103302 (From: rto,sce)
# Lipst1_1_70370 or Lipst1_1_72782 (From: rto,sce ; ylip)
# Lipst1_1_147292 (From: rto,sce,ylip)
# Lipst1_1_643 (From: rto,sce,ylip)
# Lipst1_1_314464 (From: ylip)
# Lipst1_1_60314 (From: rto,sce,ylip)
# Lipst1_1_75883 or Lipst1_1_58573 (From: rto,sce ; ylip)
# Lipst1_1_7004 (From: rto)
# Lipst1_1_72728 (From: rto,sce,ylip)
# Lipst1_1_72381 or Lipst1_1_67690 (From: rto,sce,ylip ; rto,sce)
# Lipst1_1_85 or Lipst1_1_333987 or; Lipst1_1_4296 (From: rto,sce,ylip ; sce,ylip)
# Lipst1_1_205437 or Lipst1_1_201837 or Lipst1_1_50110 or; Lipst1_1_323814 or Lipst1_1_206087 (From: rto,sce ; sce,ylip ; rto ; ylip)
# Lipst1_1_72113 or Lipst1_1_234091 (From: rto,sce,ylip ; ylip)
# Lipst1_1_3600 or Lipst1_1_111440 (From: rto ; sce)
# Lipst1_1_72320 or Lipst1_1_94934 (From: rto,sce,ylip ; rto,sce)
# Lipst1_1_47667 (From: rto,sce,ylip)
# Lipst1_1_73882 (From: rto,sce,ylip)
# Lipst1_1_67910 or Lipst1_1_70223 (From: rto,sce,ylip ; rto,ylip)
# Lipst1_1_6367 (From: rto,sce,ylip)
# Lipst1_1_314464 (From: ylip)
# Lipst1_1_69966 (From: rto,sce,ylip)
# Lipst1_1_69891 (From: rto,sce,ylip)
# Lipst1_1_260066 (From: rto,sce,ylip)
# Lipst1_1_1145 (From: rto,sce,ylip)
# Lipst1_1_74347 or Lipst1_1_70234 (From: rto,sce,ylip ; rto,ylip)
# Lipst1_1_76147 (From: rto)
# Lipst1_1_115 or; Lipst1_1_4467 (From: rto,sce,ylip)
# Lipst1_1_3355 (From: rto,sce,ylip)
# Lipst1_1_328593 or Lipst1_1_4739 (From: rto,sce,ylip ; rto)
#  (From: )
# Lipst1_1_6746 (From: rto,sce,ylip)
# Lipst1_1_4523 or Lipst1_1_73977 (From: rto,ylip ; ylip)
# Lipst1_1_6058 (From: sce)
# Lipst1_1_108550 or Lipst1_1_67513 (From: sce,ylip ; rto)
# Lipst1_1_50624 or Lipst1_1_57415 or Lipst1_1_1339 or; Lipst1_1_74374 (From: sce,ylip ; rto ; sce)
# Lipst1_1_89278 (From: sce)
# Lipst1_1_36529 or Lipst1_1_39586 or Lipst1_1_4390 or; Lipst1_1_48116 (From: rto,ylip ; sce ; ylip)
# Lipst1_1_6795 or Lipst1_1_75116 (From: sce,ylip ; rto)
# Lipst1_1_3988 (From: rto,ylip)
#  (From: )
#  (From: )
# Lipst1_1_117633 or Lipst1_1_72673 (From: rto,sce ; ylip)
#  (From: )
# Lipst1_1_72834 (From: sce)
# Lipst1_1_2357 (From: rto)
# Lipst1_1_50090 or Lipst1_1_238934 (From: sce,ylip ; rto)
#  (From: )
#  (From: )
# Lipst1_1_6058 (From: sce)
#  (From: )
# Lipst1_1_6058 (From: sce)
#  (From: )
# Lipst1_1_6058 (From: sce)
# Lipst1_1_101656 (From: rto)
# Lipst1_1_72342 (From: rto,sce)
# Lipst1_1_121954 or Lipst1_1_5651 or Lipst1_1_76630 (From: rto ; sce ; ylip)
# Lipst1_1_274802 or Lipst1_1_101656 (From: sce,ylip ; rto)
# Lipst1_1_50110 (From: rto)
# Lipst1_1_315712 or Lipst1_1_5184 (From: rto,ylip ; ylip)
# Lipst1_1_74823 or Lipst1_1_5931 or; Lipst1_1_71227 (From: rto ; sce)
# Lipst1_1_72342 (From: rto,sce)
# Lipst1_1_74591 or Lipst1_1_2633 (From: rto ; sce)
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
# Lipst1_1_156565 (From: sce)
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
# Lipst1_1_69872 (From: rto)
# Lipst1_1_73446 or; Lipst1_1_103731 (From: rto,sce)
#  (From: )
#  (From: )
#  (From: )
#  (From: )
# Lipst1_1_74247 or Lipst1_1_73414 (From: sce,ylip ; rto)
# Lipst1_1_71411 (From: sce,ylip)
#  (From: )
# Lipst1_1_72774 (From: rto)
# Lipst1_1_4390 (From: rto)
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
# Lipst1_1_69723 (From: sce)
#  (From: )
#  (From: )
#  (From: )
#  (From: )
# Lipst1_1_177423 or; Lipst1_1_121954 or; Lipst1_1_6303 or Lipst1_1_5651 or Lipst1_1_76630 (From: rto ; sce ; ylip)
#  (From: )
# Lipst1_1_6205 (From: rto)
#  (From: )
# Lipst1_1_6205 (From: rto)
# Lipst1_1_2357 or Lipst1_1_55653 (From: rto ; sce)
#  (From: )
#  (From: )
# Lipst1_1_154956 (From: rto)
#  (From: )
# Lipst1_1_205437 (From: sce)
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
# Lipst1_1_205437 (From: sce)
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
# Lipst1_1_71543 or; Lipst1_1_222534 (From: ylip)
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
# Lipst1_1_5692 (From: sce,ylip)
#  (From: )
# Lipst1_1_314464 (From: ylip)
# Lipst1_1_2955 or Lipst1_1_6225 (From: sce ; ylip)
# Lipst1_1_72571 (From: ylip)
#  (From: )
# Lipst1_1_4094 (From: sce,ylip)
#  (From: )
#  (From: )
# Lipst1_1_246003 or; Lipst1_1_3320 or Lipst1_1_67480 (From: sce,ylip ; sce)
# Lipst1_1_246003 or; Lipst1_1_3320 or; Lipst1_1_67480 (From: sce,ylip)
#  (From: )
# Lipst1_1_2594 (From: sce,ylip)
# Lipst1_1_72193 (From: ylip)
# Lipst1_1_314464 (From: ylip)
# Lipst1_1_314464 (From: ylip)
# Lipst1_1_72557 (From: sce,ylip)
#  (From: )
# Lipst1_1_107475 (From: sce,ylip)
#  (From: )
# Lipst1_1_211414 (From: sce)
#  (From: )
# Lipst1_1_85639 (From: ylip)
# Lipst1_1_182606 (From: sce,ylip)
# Lipst1_1_67262 (From: sce,ylip)
# Lipst1_1_73715 (From: sce,ylip)
# Lipst1_1_5903 (From: sce,ylip)
#  (From: )
# Lipst1_1_238934 or; Lipst1_1_4540 (From: ylip)
#  (From: )
# Lipst1_1_73737 (From: sce,ylip)
#  (From: )
#  (From: )
# Lipst1_1_72342 (From: sce,ylip)
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
# Lipst1_1_48518 or Lipst1_1_61315 or; Lipst1_1_70973 or; Lipst1_1_67480 (From: sce,ylip ; sce)
#  (From: )
# Lipst1_1_70973 or Lipst1_1_61315 or; Lipst1_1_48518 or; Lipst1_1_67480 (From: sce,ylip ; sce)
#  (From: )
#  (From: )
#  (From: )
# Lipst1_1_1740 (From: sce,ylip)
# Lipst1_1_55005 (From: ylip)
# Lipst1_1_70001 (From: sce)
#  (From: )
#  (From: )
#  (From: )
# Lipst1_1_65274 or Lipst1_1_261247 (From: sce ; ylip)
#  (From: )
#  (From: )
#  (From: )
#  (From: )
# Lipst1_1_5184 or Lipst1_1_315712 (From: sce,ylip ; ylip)
# Lipst1_1_5184 or Lipst1_1_315712 (From: sce,ylip ; ylip)
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
# Lipst1_1_2772 (From: sce,ylip)
# Lipst1_1_74886 (From: sce,ylip)
# Lipst1_1_170681 (From: sce)
#  (From: )
#  (From: )
# Lipst1_1_2633 or Lipst1_1_74591 (From: sce ; ylip)
# Lipst1_1_50182 (From: ylip)
# Lipst1_1_72144 (From: sce,ylip)
#  (From: )
#  (From: )
#  (From: )
# Lipst1_1_60314 (From: sce,ylip)
#  (From: )
#  (From: )
# Lipst1_1_5229 or; Lipst1_1_3988 (From: ylip)
# Lipst1_1_67480 or Lipst1_1_48518 or; Lipst1_1_61315 or; Lipst1_1_70973 or; Lipst1_1_246003 or; Lipst1_1_3320 (From: sce,ylip ; sce)
# Lipst1_1_48518 or Lipst1_1_61315 or; Lipst1_1_70973 or; Lipst1_1_67480 (From: sce,ylip ; sce)
# Lipst1_1_70973 or Lipst1_1_61315 or; Lipst1_1_48518 or; Lipst1_1_67480 (From: sce,ylip ; sce)
# Lipst1_1_67480 or Lipst1_1_61315 or; Lipst1_1_70973 or; Lipst1_1_48518 (From: sce,ylip ; sce)
#  (From: )
# Lipst1_1_110167 (From: ylip)
# Lipst1_1_73435 or Lipst1_1_6913 or; Lipst1_1_111304 or; Lipst1_1_114537 or; Lipst1_1_180820 or; Lipst1_1_54800 or; Lipst1_1_4310 or; Lipst1_1_2954 (From: sce ; ylip)
# Lipst1_1_50110 (From: sce)
#  (From: )
# Lipst1_1_68590 (From: sce,ylip)
#  (From: )
#  (From: )
#  (From: )
# Lipst1_1_54073 or Lipst1_1_4566 or; Lipst1_1_3884 (From: sce,ylip ; ylip)
#  (From: )
#  (From: )
# Lipst1_1_112377 or Lipst1_1_75138 (From: sce,ylip ; ylip)
#  (From: )
#  (From: )
#  (From: )
# Lipst1_1_60710 or; Lipst1_1_2214 (From: sce,ylip)
# Lipst1_1_68056 (From: sce,ylip)
#  (From: )
# Lipst1_1_72728 (From: sce,ylip)
# Lipst1_1_70762 (From: sce,ylip)
#  (From: )
# Lipst1_1_54023 (From: sce,ylip)
# Lipst1_1_54023 (From: sce,ylip)
# Lipst1_1_70234 or; Lipst1_1_73846 (From: sce)
# Lipst1_1_3931 (From: sce,ylip)
# Lipst1_1_335824 (From: sce,ylip)
#  (From: )
# Lipst1_1_3010 (From: sce)
# Lipst1_1_54023 (From: sce,ylip)
# Lipst1_1_314464 (From: ylip)
# Lipst1_1_332244 (From: sce,ylip)
# Lipst1_1_114537 or; Lipst1_1_180820 or; Lipst1_1_54800 or; Lipst1_1_6913 or; Lipst1_1_4310 or; Lipst1_1_2954 or; Lipst1_1_111304 (From: ylip)
# Lipst1_1_117393 (From: sce,ylip)
# Lipst1_1_73932 or Lipst1_1_3458 (From: sce ; ylip)
# Lipst1_1_3458 (From: ylip)
# Lipst1_1_48150 (From: sce,ylip)
# Lipst1_1_73932 or Lipst1_1_124163 or; Lipst1_1_5321 (From: sce,ylip ; sce)
# Lipst1_1_73932 (From: ylip)
# Lipst1_1_4013 (From: sce,ylip)
# Lipst1_1_976 (From: sce,ylip)
#  (From: )
# Lipst1_1_310928 (From: sce)
#  (From: )
#  (From: )
#  (From: )
# Lipst1_1_180684 (From: sce)
#  (From: )
# Lipst1_1_4188 (From: sce,ylip)
#  (From: )
#  (From: )
# Lipst1_1_310928 (From: sce,ylip)
# Lipst1_1_976 (From: sce)
# Lipst1_1_68196 (From: sce,ylip)
#  (From: )
#  (From: )
# Lipst1_1_102853 (From: ylip)
# Lipst1_1_870 (From: sce,ylip)
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
# Lipst1_1_54828 (From: sce,ylip)
# Lipst1_1_205437 (From: sce)
# Lipst1_1_147168 or; Lipst1_1_70762 (From: ylip)
# Lipst1_1_28592 or; Lipst1_1_73864 or; Lipst1_1_58405 or Lipst1_1_151 (From: sce,ylip ; ylip)
# Lipst1_1_70973 or Lipst1_1_61315 or; Lipst1_1_48518 or; Lipst1_1_67480 (From: sce,ylip ; sce)
# Lipst1_1_39586 or Lipst1_1_4390 or; Lipst1_1_36529 or; Lipst1_1_48116 (From: sce ; ylip)
#  (From: )
# Lipst1_1_73732 (From: ylip)
#  (From: )
# Lipst1_1_75768 (From: sce,ylip)
# Lipst1_1_4583 or Lipst1_1_73341 (From: sce ; ylip)
#  (From: )
# Lipst1_1_2633 (From: sce)
# Lipst1_1_46980 (From: rto,ylip)
# Lipst1_1_2790 (From: rto,ylip)
# Lipst1_1_50945 (From: ylip)
# Lipst1_1_57709 (From: rto,ylip)
# Lipst1_1_71969 or Lipst1_1_57709 (From: rto ; ylip)
#  (From: )
# Lipst1_1_275 (From: rto,ylip)
# Lipst1_1_76544 (From: rto,ylip)
#  (From: )
# Lipst1_1_47324 or; Lipst1_1_2790 or; Lipst1_1_75883 (From: rto)
#  (From: )
# Lipst1_1_3498 (From: rto,ylip)
# Lipst1_1_2790 or; Lipst1_1_75883 or; Lipst1_1_160699 or; Lipst1_1_47324 or; Lipst1_1_158150 (From: rto)
# Lipst1_1_73286 or; Lipst1_1_287747 (From: rto,ylip)
# Lipst1_1_57709 (From: rto,ylip)
# Lipst1_1_47324 or; Lipst1_1_2790 or; Lipst1_1_75883 (From: rto)
# Lipst1_1_275 (From: rto,ylip)
# Lipst1_1_73286 or; Lipst1_1_287747 (From: rto,ylip)
# Lipst1_1_2790 or; Lipst1_1_75883 or; Lipst1_1_160699 or; Lipst1_1_47324 or; Lipst1_1_158150 (From: rto)
# Lipst1_1_2363 or; Lipst1_1_29458 (From: rto,ylip)
#  (From: )
#  (From: )
# Lipst1_1_284310 (From: ylip)
# Lipst1_1_6224 or; Lipst1_1_6225 or Lipst1_1_72701 or; Lipst1_1_75352 (From: rto,ylip ; ylip)
# Lipst1_1_47324 (From: rto,ylip)
# Lipst1_1_6224 or; Lipst1_1_6225 or Lipst1_1_72701 or; Lipst1_1_75352 (From: rto,ylip ; ylip)
#  (From: )
# Lipst1_1_4956 or; Lipst1_1_313744 (From: rto)
# Lipst1_1_338549 (From: rto)
# Lipst1_1_67994 or; Lipst1_1_104545 or Lipst1_1_3871 (From: rto ; ylip)
# Lipst1_1_59861 (From: rto,ylip)
# Lipst1_1_2767 (From: rto,ylip)
# Lipst1_1_71969 (From: rto)
# Lipst1_1_4472 (From: rto,ylip)
# Lipst1_1_57709 (From: ylip)
# Lipst1_1_105970 (From: rto,ylip)
#  (From: )
# Lipst1_1_2907 or; Lipst1_1_74933 or; Lipst1_1_49131 or Lipst1_1_69250 (From: rto,ylip ; rto)
#  (From: )
# Lipst1_1_6224 or; Lipst1_1_6225 or Lipst1_1_72701 or; Lipst1_1_75352 (From: rto,ylip ; ylip)
# Lipst1_1_115 or; Lipst1_1_4467 (From: rto,ylip)
# Lipst1_1_47324 or; Lipst1_1_2790 or; Lipst1_1_75883 (From: rto)
# Lipst1_1_6750 (From: rto,ylip)
# Lipst1_1_70877 (From: rto,ylip)
# Lipst1_1_6224 or; Lipst1_1_6225 or Lipst1_1_72701 or; Lipst1_1_75352 (From: rto,ylip ; ylip)
# Lipst1_1_74417 (From: rto,ylip)
# Lipst1_1_67994 or; Lipst1_1_104545 or Lipst1_1_3871 (From: rto ; ylip)
# Lipst1_1_4883 (From: rto,ylip)
# Lipst1_1_275 (From: rto,ylip)
# Lipst1_1_2790 or; Lipst1_1_75883 or; Lipst1_1_160699 or; Lipst1_1_47324 or; Lipst1_1_158150 (From: rto)
# Lipst1_1_74417 (From: rto,ylip)
# Lipst1_1_73286 or; Lipst1_1_287747 (From: rto,ylip)
# Lipst1_1_103920 or; Lipst1_1_37982 (From: rto,ylip)
# Lipst1_1_6224 or; Lipst1_1_6225 or Lipst1_1_72701 or; Lipst1_1_75352 (From: rto,ylip ; ylip)
# Lipst1_1_275 (From: rto,ylip)
# Lipst1_1_57709 (From: rto,ylip)
# Lipst1_1_46921 (From: rto,ylip)
# Lipst1_1_275 (From: rto,ylip)
# Lipst1_1_275 (From: rto,ylip)
# Lipst1_1_57709 (From: rto,ylip)
# Lipst1_1_2363 or; Lipst1_1_29458 or Lipst1_1_70253 (From: rto,ylip ; rto)
# Lipst1_1_71400 or Lipst1_1_69441 (From: rto,ylip ; ylip)
# Lipst1_1_275 (From: rto,ylip)
#  (From: )
# Lipst1_1_57709 (From: rto,ylip)
# Lipst1_1_47324 or; Lipst1_1_2790 or; Lipst1_1_75883 (From: rto)
#  (From: )
# Lipst1_1_75883 (From: rto)
# Lipst1_1_75883 (From: rto)
# Lipst1_1_2348 (From: rto,ylip)
# Lipst1_1_53798 (From: rto,ylip)
#  (From: )
# Lipst1_1_71969 (From: rto)
# Lipst1_1_53798 (From: rto,ylip)
# Lipst1_1_70877 or Lipst1_1_74886 (From: rto ; ylip)
# Lipst1_1_6224 or; Lipst1_1_6225 or Lipst1_1_72701 or; Lipst1_1_75352 (From: rto,ylip ; ylip)
# Lipst1_1_75883 or Lipst1_1_58573 (From: rto ; ylip)
# Lipst1_1_70691 (From: rto,ylip)
# Lipst1_1_141437 (From: rto,ylip)
# Lipst1_1_57709 (From: rto,ylip)
# Lipst1_1_53798 (From: rto,ylip)
# Lipst1_1_75883 or Lipst1_1_58573 (From: rto ; ylip)
# Lipst1_1_4094 (From: rto,ylip)
# Lipst1_1_275 (From: rto,ylip)
#  (From: )
# Lipst1_1_57709 (From: rto,ylip)
# Lipst1_1_117342 (From: rto)
# Lipst1_1_117895 (From: rto)
#  (From: )
#  (From: )
#  (From: )
#  (From: )
# Lipst1_1_314464 (From: rto)
#  (From: )
# Lipst1_1_70194 (From: rto,ylip)
#  (From: )
#  (From: )
# Lipst1_1_71147 (From: rto)
#  (From: )
# Lipst1_1_5601 or; Lipst1_1_72166 (From: rto)
# Lipst1_1_6303 or Lipst1_1_4197 (From: rto ; sce)
#  (From: )
# Lipst1_1_74900 (From: rto,sce)
# Lipst1_1_314464 (From: rto)
# Lipst1_1_5453 or Lipst1_1_5116 or; Lipst1_1_6972 (From: rto ; sce)
# Lipst1_1_127634 or Lipst1_1_265510 (From: rto,sce ; rto)
# Lipst1_1_289621 or Lipst1_1_3546 (From: rto,sce ; sce)
# Lipst1_1_70370 (From: rto,sce)
# Lipst1_1_76289 (From: rto,sce)
# Lipst1_1_105640 (From: rto,sce)
# Lipst1_1_4472 (From: rto,sce)
# Lipst1_1_6303 or Lipst1_1_4197 (From: rto ; sce)
# Lipst1_1_102591 (From: rto)
# Lipst1_1_92627 (From: sce)
# Lipst1_1_314768 (From: rto,sce)
# Lipst1_1_423 (From: rto,sce)
# Lipst1_1_1263 (From: rto,sce)
# Lipst1_1_2889 (From: rto,sce)
# Lipst1_1_107753 (From: rto,sce)
# Lipst1_1_73838 (From: rto,sce)
# Lipst1_1_3878 (From: rto,sce)
# Lipst1_1_53536 (From: rto,sce)
# Lipst1_1_72751 (From: rto,sce)
# Lipst1_1_2256 or; Lipst1_1_61026 or Lipst1_1_6033 or; Lipst1_1_97209 (From: rto ; sce)
# Lipst1_1_76289 (From: rto,sce)
# Lipst1_1_338549 (From: rto)
# Lipst1_1_48101 (From: rto,sce)
# Lipst1_1_27755 (From: rto,sce)
# Lipst1_1_282 or Lipst1_1_5651 (From: rto ; sce)
# Lipst1_1_81155 (From: rto,sce)
# Lipst1_1_46126 or Lipst1_1_48239 (From: rto,sce ; sce)
# Lipst1_1_142956 (From: rto,sce)
# Lipst1_1_3974 (From: rto,sce)
# Lipst1_1_3974 (From: rto,sce)
# Lipst1_1_246321 (From: rto,sce)
# Lipst1_1_2195 (From: rto)
# Lipst1_1_314464 (From: rto)
# Lipst1_1_46126 (From: rto,sce)
# Lipst1_1_3313 (From: rto)
# Lipst1_1_102207 (From: rto,sce)
# Lipst1_1_71146 (From: rto,sce)
#  (From: )
# Lipst1_1_1110 (From: rto,sce)
# Lipst1_1_931 or Lipst1_1_6152 or; Lipst1_1_5188 (From: rto,sce ; sce)
# Lipst1_1_76359 (From: rto)
# Lipst1_1_69867 or; Lipst1_1_70253 or Lipst1_1_104402 (From: rto ; sce)
# Lipst1_1_261247 or; Lipst1_1_65274 or Lipst1_1_72041 (From: rto,sce ; sce)
#  (From: )
# Lipst1_1_2772 or Lipst1_1_99746 (From: rto,sce ; rto)
# Lipst1_1_2256 or; Lipst1_1_61026 or Lipst1_1_111440 or; Lipst1_1_6033 or; Lipst1_1_119165 or; Lipst1_1_97209 (From: rto ; sce)
# Lipst1_1_70370 (From: rto,sce)
# Lipst1_1_2772 or Lipst1_1_99746 (From: rto,sce ; rto)
# Lipst1_1_61657 (From: rto,sce)
# Lipst1_1_75890 (From: rto)
# Lipst1_1_76289 (From: rto,sce)
# Lipst1_1_314464 (From: rto)
# Lipst1_1_7158 or; Lipst1_1_50618 or Lipst1_1_6034 or; Lipst1_1_48239 (From: rto ; sce)
# Lipst1_1_3540 (From: rto,sce)
# Lipst1_1_74823 or Lipst1_1_5931 (From: rto ; sce)
# Lipst1_1_3974 (From: rto,sce)
# Lipst1_1_75163 (From: rto,sce)
# Lipst1_1_69028 (From: rto,sce)
# Lipst1_1_2436 or Lipst1_1_285732 (From: rto ; sce)
# Lipst1_1_338549 (From: rto)
# Lipst1_1_3860 (From: rto,sce)
# Lipst1_1_1263 (From: rto,sce)
#  (From: )
# Lipst1_1_3532 (From: rto)
# Lipst1_1_1559 (From: rto,sce)
# Lipst1_1_75335 (From: rto,sce)
# Lipst1_1_69288 (From: rto,sce)
# Lipst1_1_931 or Lipst1_1_5596 (From: rto,sce ; sce)
# Lipst1_1_423 (From: rto,sce)
# Lipst1_1_4566 (From: rto,sce)
# Lipst1_1_177423 or Lipst1_1_121954 (From: rto,sce ; rto)
# Lipst1_1_46126 (From: rto,sce)
# Lipst1_1_5184 (From: rto,sce)
# Lipst1_1_42480 (From: rto,sce)
# Lipst1_1_56835 (From: rto,sce)
# Lipst1_1_1857 (From: rto,sce)
# Lipst1_1_201837 or Lipst1_1_72253 (From: rto,sce ; sce)
# Lipst1_1_2772 or Lipst1_1_99746 (From: rto,sce ; rto)
# Lipst1_1_6465 or Lipst1_1_73761 or; Lipst1_1_5188 (From: rto,sce ; sce)
# Lipst1_1_69288 (From: rto,sce)
# Lipst1_1_101999 (From: rto,sce)
# Lipst1_1_5189 or Lipst1_1_1356 (From: rto,sce ; rto)
# Lipst1_1_76289 (From: rto,sce)
# Lipst1_1_972 (From: rto,sce)
# Lipst1_1_67195 (From: sce)
# Lipst1_1_2766 (From: rto,sce)
# Lipst1_1_594 (From: rto,sce)
# Lipst1_1_74347 or Lipst1_1_2352 or; Lipst1_1_54959 (From: rto,sce ; rto)
# Lipst1_1_46126 (From: rto,sce)
# Lipst1_1_67618 (From: rto,sce)
# Lipst1_1_42480 (From: rto,sce)
# Lipst1_1_338549 (From: rto)
# Lipst1_1_70181 (From: rto,sce)
# Lipst1_1_76061 (From: rto,sce)
# Lipst1_1_3974 (From: rto,sce)
# Lipst1_1_46126 (From: rto,sce)
# Lipst1_1_2772 or Lipst1_1_99746 (From: rto,sce ; rto)
# Lipst1_1_61657 (From: rto,sce)
# Lipst1_1_3923 (From: rto,sce)
# Lipst1_1_44049 or Lipst1_1_70253 (From: rto,sce ; sce)
#  (From: )
# Lipst1_1_73367 (From: rto,sce)
# Lipst1_1_5784 (From: rto,sce)
# Lipst1_1_70370 (From: rto)
# Lipst1_1_103302 (From: rto,sce)
# Lipst1_1_310928 (From: rto,sce)
# Lipst1_1_870 (From: rto,sce)
# Lipst1_1_314768 (From: rto,sce)
# Lipst1_1_314768 (From: rto,sce)
# Lipst1_1_127634 or Lipst1_1_265510 (From: rto,sce ; rto)
#  (From: )
#  (From: )
# Lipst1_1_92025 (From: rto,sce)
# Lipst1_1_177423 or; Lipst1_1_121954 or; Lipst1_1_6303 or Lipst1_1_4197 (From: rto ; sce)
# Lipst1_1_67618 (From: rto,sce)
# Lipst1_1_70370 (From: rto,sce)
# Lipst1_1_276115 or Lipst1_1_114186 (From: rto ; sce)
# Lipst1_1_5895 (From: rto,sce)
# Lipst1_1_52540 (From: sce)
# Lipst1_1_2102 or Lipst1_1_70967 (From: rto ; sce)
# Lipst1_1_284310 (From: rto,sce)
# Lipst1_1_4155 (From: rto,sce)
# Lipst1_1_2256 or; Lipst1_1_61026 or Lipst1_1_6033 or; Lipst1_1_52551 or; Lipst1_1_97209 (From: rto ; sce)
#  (From: )
#  (From: )
# Lipst1_1_67991 (From: rto,sce)
# Lipst1_1_68284 (From: rto,sce)
# Lipst1_1_6303 or Lipst1_1_4197 (From: rto ; sce)
# Lipst1_1_3985 (From: rto,sce)
# Lipst1_1_127634 or Lipst1_1_265510 (From: rto,sce ; rto)
# Lipst1_1_5784 (From: rto,sce)
# Lipst1_1_3974 (From: rto,sce)
# Lipst1_1_33829 (From: rto)
#  (From: )
# Lipst1_1_3540 (From: rto,sce)
# Lipst1_1_76289 (From: rto,sce)
# Lipst1_1_57798 (From: rto,sce)
# Lipst1_1_74862 or Lipst1_1_70253 (From: rto ; sce)
#  (From: )
# Lipst1_1_72834 or; Lipst1_1_71351 (From: rto)
# Lipst1_1_5576 (From: rto,sce)
# Lipst1_1_72360 (From: rto,sce)
# Lipst1_1_70370 (From: rto)
# Lipst1_1_127634 or Lipst1_1_265510 (From: rto,sce ; rto)
# Lipst1_1_70181 (From: rto,sce)
# Lipst1_1_275 (From: rto,sce)
# Lipst1_1_2772 or Lipst1_1_99746 (From: rto,sce ; rto)
# Lipst1_1_3431 (From: rto,sce)
# Lipst1_1_70253 or; Lipst1_1_69038 (From: rto,sce)
# Lipst1_1_73838 (From: rto)
# Lipst1_1_75138 (From: rto,sce)
# Lipst1_1_1110 or; Lipst1_1_72701 (From: rto,sce)
# Lipst1_1_7158 or; Lipst1_1_50618 or Lipst1_1_6034 or; Lipst1_1_48239 (From: rto ; sce)
# Lipst1_1_176686 (From: rto)
# Lipst1_1_73351 (From: rto,sce)
# Lipst1_1_97460 or Lipst1_1_48807 (From: rto ; sce)
# Lipst1_1_4054 or Lipst1_1_73352 (From: rto ; sce)
# Lipst1_1_49747 or Lipst1_1_71533 (From: rto,sce ; sce)
# Lipst1_1_5472 (From: rto)
# Lipst1_1_146577 (From: sce)
# Lipst1_1_925 (From: rto)
# Lipst1_1_71411 (From: sce)
# Lipst1_1_76716 or Lipst1_1_5571 (From: rto ; sce)
# Lipst1_1_6779 or Lipst1_1_73351 (From: rto ; sce)
# Lipst1_1_3290 (From: rto)
#  (From: )
# Lipst1_1_53798 (From: rto,sce)
# Lipst1_1_4390 (From: rto)
# Lipst1_1_50110 (From: rto)
# Lipst1_1_73932 or Lipst1_1_3458 (From: rto ; sce)
#  (From: )
# Lipst1_1_76716 (From: rto,sce)
# Lipst1_1_3617 (From: rto,sce)
# Lipst1_1_314464 (From: rto)
# Lipst1_1_67687 (From: rto,sce)
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
# Lipst1_1_170681 or; Lipst1_1_103302 (From: sce)
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
# Lipst1_1_67687 (From: rto,sce)
# Lipst1_1_72108 (From: rto,sce)
# Lipst1_1_6006 (From: sce)
#  (From: )
# Lipst1_1_170681 (From: sce)
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
# Lipst1_1_47259 (From: rto)
# Lipst1_1_75992 (From: rto)
#  (From: )
#  (From: )
# Lipst1_1_6459 (From: rto)
#  (From: )
#  (From: )
# Lipst1_1_1356 (From: rto)
#  (From: )
#  (From: )
# Lipst1_1_71543 (From: sce)
#  (From: )
#  (From: )
# Lipst1_1_170681 (From: sce)
#  (From: )
# Lipst1_1_170681 (From: sce)
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
#  (From: )
# Lipst1_1_71319 (From: rto,sce)
#  (From: )

# %% [markdown]
# ### Note - section above did not add to model - just obtained orthologs and new GPRs.

# %%
# save output. 
# df3 = pd.DataFrame([_names,_id,_stoich,_subsystem,_gpr_rto,_gpr_sce,_gpr_ylip,_lst_rto_gene,_lst_sce_gene,_lst_ylip_gene,_common_all,_only_12,_only_13,_only_23,_only_1,_only_2,_only_3,_all_three_diff,result,result_labels]).T
# df3.to_csv('allcomparisions_genes_withGPR_.csv')

# %%
# rxnID to new GPR.
__dict = dict(zip(_id,result))

# %%
# rxnID to organism source.
__dict2 = dict(zip(_id,result_labels))

# %% [markdown]
# verify model and add a needed reaction for growth on lipid compounds.

# %%
# reaction needed to enable growth for lipid compounds. 
model.add_reactions([rto.reactions.GAPP.copy()])

# %%
# examine the model genes for non-Lst genes.
genes = model.genes
genes = [g.id for g in genes]
wrong = [g for g in genes if 'Lipst1' not in g]
len(set(wrong))
# Out:
# 71

# %% [markdown]
# check that the genes are all associated with a reaction. remove the ones that are not.

# %%
wrong_g = []
wrong_rx = []
for g in wrong:
    reac = model.genes.get_by_id(g).reactions
    if not reac:
        print(f'{g} has no associated reaction')
        
        cobra.manipulation.delete.remove_genes(model,[g])
    for rx in reac:
        if rx:
#             print(rx,g)
            wrong_g.append(g)
            wrong_rx.append(rx)
print(len(set(wrong_g)))
print(len(set(wrong_rx)))
# Out:
# 71
# 21

# %% [markdown]
# 71 genes are associated with 21 reactions that currently do not have Lst genes.

# %%
set(wrong_rx)
# Out:
# {<Reaction ACRNtp at 0x2a1bc3a10>,
#  <Reaction ALDD2ym at 0x15b811ad0>,
#  <Reaction ATPS3m at 0x15bcd1890>,
#  <Reaction C30CPT1 at 0x2a1bc32d0>,
#  <Reaction C3STKR1er at 0x2a1bc1e10>,
#  <Reaction C3STKR2er at 0x2a17cab10>,
#  <Reaction CRNtp at 0x2a1bc8150>,
#  <Reaction CYOO6m at 0x2a18c2f10>,
#  <Reaction CYOR_u9m at 0x15b829810>,
#  <Reaction DNTPPA at 0x2a1841d90>,
#  <Reaction DRTPPD at 0x2a1b92f90>,
#  <Reaction FA160COAabcp at 0x2a1ba3990>,
#  <Reaction FA183COAabcp at 0x2a1920c90>,
#  <Reaction FA240tp at 0x2a1a134d0>,
#  <Reaction GAPP at 0x16a228f90>,
#  <Reaction H2Otm at 0x2a1782c90>,
#  <Reaction OIVD2m at 0x2a1bbb6d0>,
#  <Reaction PMDPHT at 0x2a1bc2350>,
#  <Reaction PRPPS at 0x2a1bba210>,
#  <Reaction SERPTer at 0x2a13c8f50>,
#  <Reaction TRDR at 0x2a1b93390>}

# %%
model_v01 = model.copy()
# Out:
# Read LP format model from file /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/tmp_184yos8.lp
# Reading time = 0.01 seconds
# : 1898 rows, 4166 columns, 16794 nonzeros

# %%
model.reactions.get_by_id('ICLp')
# Out:
# <Reaction ICLp at 0x2a1395150>

# %% [markdown]
# ## Cell block below replaces the Lst model reaction GPR with orthoMCL && adds reactions that were not in the model but are in rto and have orthologs.
#
# also keeps gapfilled reactions that enabled growth.
# replace genes.

# %%
len(model.reactions)
# Out:
# 2083

# %%
# model.reactions.GAPP

# %%
if 'GAPP' in list(__dict.keys()):
    print('yes')

# %%
# list(__dict.keys())

# %%
# all the reactions added below come from the rto model. The sources of the Lst genes can come from rto, sce or ylip. 

and_checks = []
maintained_v01_gpr = []
gpr_replaced = []
no_gpr_bothMethods = []
added_to_model = []
not_in_model = []
added_to_model_source = []




# iterate through dict (reaction.id:gpr)
for r in list(__dict.keys()):
    
    # if the r is included in the model. 
    if r in model.reactions:
        
        # obtain the reaction.
        model_rxn = model.reactions.get_by_id(r)
#         print(model_rxn.gene_reaction_rule)
        old_gpr = model_rxn.gene_reaction_rule

        # obtain the new gpr. 
        new_gpr = __dict[r][0]
        
        # a semi-colon represents a potential "and" reaction for further validation.
        if ';' in new_gpr:
            new_gpr = new_gpr.replace(';','')
            
            # further validation.
            and_checks.append(r)
    
    # reaction not in model.
    else:
        value = __dict[r][0]
        if (value) and (r in rto.reactions):
            copy_rxn = rto.reactions.get_by_id(r).copy()
            model.add_reactions([copy_rxn])
            
            
            if ';' in value:
                value = value.replace(';','')
                new_gpr = value
                # further validation
                and_checks.append(r)
            model.reactions.get_by_id(r).gene_reaction_rule = value
            
            
            added_to_model.append(r)
            added_to_model_source.append(__dict2[r])
        
        else:
            not_in_model.append(r)
    
#     if ("Lipst1" not in new_gpr) and (new_gpr):
#         print("new",r, new_gpr)
#     if ("Lipst1" not in old_gpr) and (old_gpr):
#         print("old", r, old_gpr)
        
    if (r=='GAPP'):
        print('new',new_gpr,'old',old_gpr)
    # if there is a gene value from orthoMCL.     
    if (old_gpr) and (new_gpr) and (r in model.reactions):
        gpr_replaced.append(r)
        model_rxn.gene_reaction_rule = new_gpr
        if ("Lipst1" not in new_gpr):
            print("new",r, new_gpr)
    elif (new_gpr) and (r in model.reactions):
        gpr_replaced.append(r)
        model_rxn.gene_reaction_rule = new_gpr
    
        if ("Lipst1" not in new_gpr):
            print("new2",r, new_gpr)

    # no new gpr -- remove reaction?
    # keep old reaction?
    elif (old_gpr) and (r in model.reactions):
        maintained_v01_gpr.append(r)
        if ("Lipst1" not in old_gpr) and (old_gpr):
            print("old", r, old_gpr)

    elif ((r in model.reactions)):
        no_gpr_bothMethods.append(r)
    else: 
        not_in_model.append(r)
        
            
#             print(f'{old_gpr} and {new_gpr}:')

        #model_rxn.gene_reaction_rule = new_gpr

#     print(r,new_gpr,model_rxn.gene_reaction_rule)
        
        # assign new gpr rule.
#         model_rxn.gene_reaction_rule = new_gpr
#         print(model_rxn.gene_reaction_rule)
    
    # if it is in the rto model (so was removed because lack of GPR)
#     elif r in rto.reactions:
# Out:
# old H2Otm 9014
# old DNTPPA 15385
# old PMDPHT 11513
# old ACRNtp 10149
# old CRNtp 10149
# old FA240tp 9912
# old FA160COAabcp 13167 and 9637
# old DRTPPD 15506

# %%
maintained_v01_gpr
# Out:
# ['H2Otm',
#  'DNTPPA',
#  'PMDPHT',
#  'ACRNtp',
#  'CRNtp',
#  'FA240tp',
#  'FA160COAabcp',
#  'DRTPPD']

# %%
genes = model.genes
genes = [g.id for g in genes]
wrong = [g for g in genes if 'Lipst1' not in g]
len(set(wrong))
# Out:
# 105

# %%
wrong_g2 = []
wrong_rx2 = []
for g in wrong:
    reac = model.genes.get_by_id(g).reactions
    if not reac:
        print(f'{g} has no associated reaction')
        
        cobra.manipulation.delete.remove_genes(model,[g])
    for rx in reac:
        if rx:
#             print(rx,g)
            wrong_g2.append(g)
            wrong_rx2.append(rx)
print(len(set(wrong_g)))
print(len(set(wrong_rx2)))
# Out:
# 12737 has no associated reaction
# 9688 has no associated reaction
# 12730 has no associated reaction
# 10848 has no associated reaction
# 9940 has no associated reaction
# 16359 has no associated reaction
# 11958 has no associated reaction
# ATP8 has no associated reaction
# 14786 has no associated reaction
# 13842 has no associated reaction
# 9619 has no associated reaction
# 13759 has no associated reaction
# 11967 has no associated reaction
# ATP9 has no associated reaction
# 15287 has no associated reaction
# 13424 has no associated reaction
# 15880 has no associated reaction
# 14912 has no associated reaction
# 13053 has no associated reaction
# ATP6 has no associated reaction
# 13252 has no associated reaction
# 15589 has no associated reaction
# 10674 has no associated reaction
# 9080 has no associated reaction
# 13426 has no associated reaction
# 11145 has no associated reaction
# 16592 has no associated reaction
# 15900 has no associated reaction
# 9910 has no associated reaction
# 14014 has no associated reaction
# 11290 has no associated reaction
# 11172 has no associated reaction
# 14237 has no associated reaction
# 16019 has no associated reaction
# 9838 has no associated reaction
# 10937 has no associated reaction
# 16648 has no associated reaction
# 10043 has no associated reaction
# 13627 has no associated reaction
# 15762 has no associated reaction
# 8454 has no associated reaction
# 14623 has no associated reaction
# 12742 has no associated reaction
# 9700 has no associated reaction
# 10293 has no associated reaction
# 13228 has no associated reaction
# 11362 has no associated reaction
# 12752 has no associated reaction
# 11907 has no associated reaction
# 13813 has no associated reaction
# 13048 has no associated reaction
# 11328 has no associated reaction
# 10704 has no associated reaction
# 10705 has no associated reaction
# 10200 has no associated reaction
# 13413 has no associated reaction
# 15037 has no associated reaction
# 14866 has no associated reaction
# 12715 has no associated reaction
# 12761 has no associated reaction
# 8434 has no associated reaction
# 71
# 17

# %%
set(wrong_rx2)
# Out:
# {<Reaction ACRNtp at 0x2a1bc3a10>,
#  <Reaction C30CPT1 at 0x2a1bc32d0>,
#  <Reaction C3STKR1er at 0x2a1bc1e10>,
#  <Reaction C3STKR2er at 0x2a17cab10>,
#  <Reaction CRNtp at 0x2a1bc8150>,
#  <Reaction CYOO6m at 0x2a18c2f10>,
#  <Reaction CYOR_u9m at 0x15b829810>,
#  <Reaction DNTPPA at 0x2a1841d90>,
#  <Reaction DRTPPD at 0x2a1b92f90>,
#  <Reaction FA160COAabcp at 0x2a1ba3990>,
#  <Reaction FA183COAabcp at 0x2a1920c90>,
#  <Reaction FA240tp at 0x2a1a134d0>,
#  <Reaction GAPP at 0x16a228f90>,
#  <Reaction H2Otm at 0x2a1782c90>,
#  <Reaction OIVD2m at 0x2a1bbb6d0>,
#  <Reaction PMDPHT at 0x2a1bc2350>,
#  <Reaction SERPTer at 0x2a13c8f50>}

# %% [markdown]
# {<Reaction ACRNtp at 0x2a19ea1d0>,
#  <Reaction C30CPT1 at 0x2a19e9a90>,
#  <Reaction C3STKR1er at 0x2a08e0a50>,
#  <Reaction C3STKR2er at 0x2a19e8b10>,
#  <Reaction CRNtp at 0x2a19ea8d0>,
#  <Reaction CYOO6m at 0x2a10856d0>,
#  <Reaction CYOR_u9m at 0x2a19bbad0>,
#  <Reaction DNTPPA at 0x2a19df810>,
#  <Reaction DRTPPD at 0x2a19c5710>,
#  <Reaction FA160COAabcp at 0x2a1092590>,
#  <Reaction FA183COAabcp at 0x2a176b410>,
#  <Reaction FA240tp at 0x2a1769c90>,
#  <Reaction GAPP at 0x2a19ead90>,
#  <Reaction H2Otm at 0x2a090d450>,
#  <Reaction OIVD2m at 0x2a19a6d90>,
#  <Reaction PMDPHT at 0x2a19e92d0>,
#  <Reaction SERPTer at 0x2a0bc76d0>}

# %%
genes = model.genes
genes = [g.id for g in genes]
wrong = [g for g in genes if 'Lipst1' not in g]
len(set(wrong))
# Out:
# 44

# %%
wrong_g2 = []
wrong_rx2 = []
for g in wrong:
    reac = model.genes.get_by_id(g).reactions
    if not reac:
        print(f'{g} has no associated reaction')
        
        cobra.manipulation.delete.remove_genes(model,[g])
    for rx in reac:
        if rx:
#             print(rx,g)
            wrong_g2.append(g)
            wrong_rx2.append(rx)
print(len(set(wrong_g)))
print(len(set(wrong_rx2)))
# Out:
# 71
# 17

# %%
len(model.reactions)-2083
# Out:
# 39

# %% [markdown]
# 39 reactions added

# %%
model.reactions.get_by_id('ICLp')
# Out:
# <Reaction ICLp at 0x2a1395150>

# %%
maintained_v01_gpr
# Out:
# ['H2Otm',
#  'DNTPPA',
#  'PMDPHT',
#  'ACRNtp',
#  'CRNtp',
#  'FA240tp',
#  'FA160COAabcp',
#  'DRTPPD']

# %%
len(added_to_model)
# Out:
# 39

# %%
model_v01.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ls = 0.06130800269480152</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>5.101E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e</td>
#       <td>3.219E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe3_e</td>
#       <td>EX_fe3_e</td>
#       <td>0.0003782</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>1</td>
#       <td>6</td>
#       <td>98.86%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e</td>
#       <td>0.03591</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e</td>
#       <td>0.003784</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_e</td>
#       <td>EX_mn2_e</td>
#       <td>3.721E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>na1_e</td>
#       <td>EX_na1_e</td>
#       <td>0.0016</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>0.4047</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>2.898</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>0.01632</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e</td>
#       <td>0.006145</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e</td>
#       <td>3.127E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>8aonn_m</td>
#       <td>SRC_8aonn_m</td>
#       <td>0.0001482</td>
#       <td>9</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>lipoate_m</td>
#       <td>SRC_lipoate_m</td>
#       <td>0.0001905</td>
#       <td>8</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>trnaala_c</td>
#       <td>SRC_trnaala_c</td>
#       <td>0.03541</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaarg_c</td>
#       <td>SRC_trnaarg_c</td>
#       <td>0.008992</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaasn_c</td>
#       <td>SRC_trnaasn_c</td>
#       <td>0.006619</td>
#       <td>10</td>
#       <td>1.09%</td>
#     </tr>
#     <tr>
#       <td>trnaasp_c</td>
#       <td>SRC_trnaasp_c</td>
#       <td>0.0121</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnacys_c</td>
#       <td>SRC_trnacys_c</td>
#       <td>0.002101</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnagln_c</td>
#       <td>SRC_trnagln_c</td>
#       <td>0.007228</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaglu_c</td>
#       <td>SRC_trnaglu_c</td>
#       <td>0.01279</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnagly_c</td>
#       <td>SRC_trnagly_c</td>
#       <td>0.03146</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnahis_c</td>
#       <td>SRC_trnahis_c</td>
#       <td>0.00375</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaile_c</td>
#       <td>SRC_trnaile_c</td>
#       <td>0.009722</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaleu_c</td>
#       <td>SRC_trnaleu_c</td>
#       <td>0.01963</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnalys_c</td>
#       <td>SRC_trnalys_c</td>
#       <td>0.01057</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnamet_c</td>
#       <td>SRC_trnamet_c</td>
#       <td>0.003498</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaphe_c</td>
#       <td>SRC_trnaphe_c</td>
#       <td>0.005834</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnapro_c</td>
#       <td>SRC_trnapro_c</td>
#       <td>0.01446</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaser_c</td>
#       <td>SRC_trnaser_c</td>
#       <td>0.02065</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnathr_c</td>
#       <td>SRC_trnathr_c</td>
#       <td>0.01337</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnatrp_c</td>
#       <td>SRC_trnatrp_c</td>
#       <td>0.00143</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnatyr_c</td>
#       <td>SRC_trnatyr_c</td>
#       <td>0.003823</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaval_c</td>
#       <td>SRC_trnaval_c</td>
#       <td>0.01687</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3aap_c</td>
#       <td>DM_3aap_c</td>
#       <td>-0.04342</td>
#       <td>5</td>
#       <td>6.08%</td>
#     </tr>
#     <tr>
#       <td>4oglu_c</td>
#       <td>DM_4oglu_c</td>
#       <td>-8.54E-05</td>
#       <td>5</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>amob_m</td>
#       <td>DM_amob_m</td>
#       <td>-0.0001482</td>
#       <td>15</td>
#       <td>0.06%</td>
#     </tr>
#     <tr>
#       <td>dad_5_m</td>
#       <td>DM_dad_5_m</td>
#       <td>-0.0001482</td>
#       <td>10</td>
#       <td>0.04%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-3.126</td>
#       <td>1</td>
#       <td>87.51%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e</td>
#       <td>-0.0002626</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>-4.514</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>-0.1403</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>hco3_e</td>
#       <td>EX_hco3_e</td>
#       <td>-0.001536</td>
#       <td>1</td>
#       <td>0.04%</td>
#     </tr>
#     <tr>
#       <td>zymst_e</td>
#       <td>EX_zymst_e</td>
#       <td>-0.008273</td>
#       <td>27</td>
#       <td>6.25%</td>
#     </tr>
#   </tbody>
# </table>

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ls = 0.06233019485004844</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>5.186E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e</td>
#       <td>3.272E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe3_e</td>
#       <td>EX_fe3_e</td>
#       <td>0.0003845</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>1</td>
#       <td>6</td>
#       <td>98.84%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e</td>
#       <td>0.03651</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e</td>
#       <td>0.003847</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_e</td>
#       <td>EX_mn2_e</td>
#       <td>3.783E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>na1_e</td>
#       <td>EX_na1_e</td>
#       <td>0.001627</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>0.4114</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>2.846</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>0.01659</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e</td>
#       <td>0.006248</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e</td>
#       <td>3.179E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>8aonn_m</td>
#       <td>SRC_8aonn_m</td>
#       <td>0.0001507</td>
#       <td>9</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>lipoate_m</td>
#       <td>SRC_lipoate_m</td>
#       <td>0.0001937</td>
#       <td>8</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>trnaala_c</td>
#       <td>SRC_trnaala_c</td>
#       <td>0.036</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaarg_c</td>
#       <td>SRC_trnaarg_c</td>
#       <td>0.009142</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaasn_c</td>
#       <td>SRC_trnaasn_c</td>
#       <td>0.00673</td>
#       <td>10</td>
#       <td>1.11%</td>
#     </tr>
#     <tr>
#       <td>trnaasp_c</td>
#       <td>SRC_trnaasp_c</td>
#       <td>0.0123</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnacys_c</td>
#       <td>SRC_trnacys_c</td>
#       <td>0.002136</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnagln_c</td>
#       <td>SRC_trnagln_c</td>
#       <td>0.007349</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaglu_c</td>
#       <td>SRC_trnaglu_c</td>
#       <td>0.01301</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnagly_c</td>
#       <td>SRC_trnagly_c</td>
#       <td>0.03199</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnahis_c</td>
#       <td>SRC_trnahis_c</td>
#       <td>0.003813</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaile_c</td>
#       <td>SRC_trnaile_c</td>
#       <td>0.009884</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaleu_c</td>
#       <td>SRC_trnaleu_c</td>
#       <td>0.01996</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnalys_c</td>
#       <td>SRC_trnalys_c</td>
#       <td>0.01074</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnamet_c</td>
#       <td>SRC_trnamet_c</td>
#       <td>0.003556</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaphe_c</td>
#       <td>SRC_trnaphe_c</td>
#       <td>0.005932</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnapro_c</td>
#       <td>SRC_trnapro_c</td>
#       <td>0.0147</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaser_c</td>
#       <td>SRC_trnaser_c</td>
#       <td>0.021</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnathr_c</td>
#       <td>SRC_trnathr_c</td>
#       <td>0.0136</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnatrp_c</td>
#       <td>SRC_trnatrp_c</td>
#       <td>0.001453</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnatyr_c</td>
#       <td>SRC_trnatyr_c</td>
#       <td>0.003887</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaval_c</td>
#       <td>SRC_trnaval_c</td>
#       <td>0.01715</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3aap_c</td>
#       <td>DM_3aap_c</td>
#       <td>-0.04415</td>
#       <td>5</td>
#       <td>6.25%</td>
#     </tr>
#     <tr>
#       <td>4oglu_c</td>
#       <td>DM_4oglu_c</td>
#       <td>-8.683E-05</td>
#       <td>5</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>amob_m</td>
#       <td>DM_amob_m</td>
#       <td>-0.0001507</td>
#       <td>15</td>
#       <td>0.06%</td>
#     </tr>
#     <tr>
#       <td>dad_5_m</td>
#       <td>DM_dad_5_m</td>
#       <td>-0.0001507</td>
#       <td>10</td>
#       <td>0.04%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-3.078</td>
#       <td>1</td>
#       <td>87.16%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e</td>
#       <td>-0.000267</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>-4.489</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>-0.1426</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>hco3_e</td>
#       <td>EX_hco3_e</td>
#       <td>-0.001562</td>
#       <td>1</td>
#       <td>0.04%</td>
#     </tr>
#     <tr>
#       <td>zymst_e</td>
#       <td>EX_zymst_e</td>
#       <td>-0.008411</td>
#       <td>27</td>
#       <td>6.43%</td>
#     </tr>
#   </tbody>
# </table>

# %%
model_remove_original_gpr = model.copy()
# Out:
# Read LP format model from file /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/tmpaoqfjyvs.lp
# Reading time = 0.01 seconds
# : 1904 rows, 4244 columns, 17194 nonzeros

# %% [markdown]
# ##### removing the maintained reactions that were gapfilled leads to no growth.

# %%
# with model_remove_original_gpr:
for r in maintained_v01_gpr:
    rxn = model_remove_original_gpr.reactions.get_by_id(r)
    model_remove_original_gpr.remove_reactions([rxn])

# %%
model_remove_original_gpr.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ls = 0.0</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>0.488</td>
#       <td>6</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>0.122</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ac_e</td>
#       <td>EX_ac_e</td>
#       <td>-0.732</td>
#       <td>2</td>
#       <td>50.00%</td>
#     </tr>
#     <tr>
#       <td>btd_RR_e</td>
#       <td>EX_btd_RR_e</td>
#       <td>-0.244</td>
#       <td>4</td>
#       <td>33.33%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-0.488</td>
#       <td>1</td>
#       <td>16.67%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>-0.244</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>-0.732</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
len(model_remove_original_gpr.reactions)
# Out:
# 2114

# %%
len(model.reactions)
# Out:
# 2122

# %%
len(model_v01.reactions)
# Out:
# 2083

# %%
len(maintained_v01_gpr)
# Out:
# 8

# %%
for r in (maintained_v01_gpr):
    print(r, model.reactions.get_by_id(r).gene_reaction_rule)
# Out:
# H2Otm 9014
# DNTPPA 15385
# PMDPHT 11513
# ACRNtp 10149
# CRNtp 10149
# FA240tp 9912
# FA160COAabcp 13167 and 9637
# DRTPPD 15506

# %% [markdown]
# summary of above findings.
#
# 8 reactions all were gap filled in order to function orginally.

# %% [markdown]
# # look for other orthologs from individual rto genes potentially left out.

# %%
# this cell block looks at the rto model and determines if there are other orthologs that can be added to the lst GSM. 
# previous code only looked at reactions that were in multiple models (i.e., in the rto and ylip model). 

# counter. 
count=0

# storage variables. 
ortholog_available = []
no_ortholog = []
no_rxn = []
genes = []


# obtain list of rto, model reactions.
rto_rxns = list(rto.reactions)
rto_rxns = [x.id for x in rto_rxns]
model_rxns = list(model.reactions)
model_rxns = [x.id for x in model_rxns]

# dictionary with keys of rto genes, values of Lst genes. 
lst_dict_keys = list(lst_rto_dict.keys())

# determine how many reactions were not added to the model. 
diff_rxns = set(rto_rxns) - set(model_rxns)
print(len(diff_rxns))

# check the gpr of the reactions. 
for r in diff_rxns:
    
    # rxn is the rto object.
    rxn = rto.reactions.get_by_id(r)

    # gpr is the rto gene reaction rule. 
    gpr = rxn.genes
    
    
    # temporary storage for new orthologs. 
    temp_gpr = []

    # tracking orthologs. 
    count_ortho=0
    
    
    # determine the number of orthologs for the GPR.
    for i in range(len(gpr)):
        
        # obtain the individual genes. 
        g=list(gpr)[i]

        # evaluate if there are any orthologs lst_orthologs. 
        if g.id in lst_dict_keys:

            # obtain the lst gene ortholog.
            value = lst_rto_dict[g.id]

            # check if the ortholog is blank. 
            if value:
                temp_gpr.append(value)
                count_ortho+=1
                    
    # if there were no orthologs. 
    if count_ortho==0:
        no_ortholog.append(r)
    
    # there was at least one ortholog for the reaction. 
    elif count_ortho>0:
        # append the reaction to this list. 
        ortholog_available.append(r)
        # append the gpr to this list. 
        genes.append(temp_gpr)
        
        # make a GPR rule for the orthologs. 
        temp = " or ".join(sub_item.replace("None", "").replace("NA"," ") for sub_item in temp_gpr)
        
#         print(temp, '\n',temp_gpr)
        
        # add the reaction and GPR to the Lst model. 
        model.add_reactions([rxn.copy()])
        model.reactions.get_by_id(r).gene_reaction_rule = temp

        # track the number of reactions added. 
        count+=1
# Out:
# 277

# %%
count
# Out:
# 26

# %%
genes = model.genes
genes = [g.id for g in genes]
wrong = [g for g in genes if 'Lipst1' not in g]
len(set(wrong))
# Out:
# 112

# %%
wrong_g2 = []
wrong_rx2 = []
for g in wrong:
    reac = model.genes.get_by_id(g).reactions
    if not reac:
        print(f'{g} has no associated reaction')
        
        cobra.manipulation.delete.remove_genes(model,[g])
    for rx in reac:
        if rx:
#             print(rx,g)
            wrong_g2.append(g)
            wrong_rx2.append(rx)
print(len(set(wrong_g)))
print(len(set(wrong_rx2)))
# Out:
# 15762 has no associated reaction
# 13348 has no associated reaction
# 14170 has no associated reaction
# 12742 has no associated reaction
# 9700 has no associated reaction
# 10293 has no associated reaction
# 13228 has no associated reaction
# 11362 has no associated reaction
# 12752 has no associated reaction
# 11907 has no associated reaction
# 13813 has no associated reaction
# 12570 has no associated reaction
# 14805 has no associated reaction
# 11203 has no associated reaction
# 8885 has no associated reaction
# 12116 has no associated reaction
# 9274 has no associated reaction
# 10704 has no associated reaction
# 10705 has no associated reaction
# 14070 has no associated reaction
# 12867 has no associated reaction
# 15694 has no associated reaction
# 16404 has no associated reaction
# 9113 has no associated reaction
# 11702 has no associated reaction
# 14078 has no associated reaction
# 10607 has no associated reaction
# 13017 has no associated reaction
# 10017 has no associated reaction
# 8446 has no associated reaction
# 8444 has no associated reaction
# NAD6 has no associated reaction
# 9144 has no associated reaction
# 15864 has no associated reaction
# 15998 has no associated reaction
# NAD2 has no associated reaction
# 10541 has no associated reaction
# 12497 has no associated reaction
# 15947 has no associated reaction
# 8817 has no associated reaction
# 8909 has no associated reaction
# NAD3 has no associated reaction
# 12653 has no associated reaction
# 14717 has no associated reaction
# 14418 has no associated reaction
# 13656 has no associated reaction
# 13411 has no associated reaction
# 8699 has no associated reaction
# 11857 has no associated reaction
# 14900 has no associated reaction
# 15973 has no associated reaction
# 12543 has no associated reaction
# 9348 has no associated reaction
# 10010 has no associated reaction
# NAD4 has no associated reaction
# 11151 has no associated reaction
# 12482 has no associated reaction
# 11411 has no associated reaction
# 14261 has no associated reaction
# NAD1 has no associated reaction
# 15179 has no associated reaction
# 13268 has no associated reaction
# 10318 has no associated reaction
# 8530 has no associated reaction
# 13925 has no associated reaction
# NAD4L has no associated reaction
# 13214 has no associated reaction
# NAD5 has no associated reaction
# 71
# 17

# %%
wrong_rx2 = [x.id for x in wrong_rx2]
(set(wrong_rx2))
# Out:
# {'ACRNtp',
#  'C30CPT1',
#  'C3STKR1er',
#  'C3STKR2er',
#  'CRNtp',
#  'CYOO6m',
#  'CYOR_u9m',
#  'DNTPPA',
#  'DRTPPD',
#  'FA160COAabcp',
#  'FA183COAabcp',
#  'FA240tp',
#  'GAPP',
#  'H2Otm',
#  'OIVD2m',
#  'PMDPHT',
#  'SERPTer'}

# %% [markdown]
# ## above cell added 26 reactions that had orthologs but were not previously included.

# %%
len(no_ortholog)
# Out:
# 251

# %%
len(ortholog_available)
# Out:
# 26

# %%
len(model.reactions)
# Out:
# 2148

# %%
len(model_v01.reactions)
# Out:
# 2083

# %%
len(model.reactions)-2083
# Out:
# 65

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ls = 0.07253593170088728</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>6.035E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e</td>
#       <td>3.808E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe3_e</td>
#       <td>EX_fe3_e</td>
#       <td>0.0004475</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>1</td>
#       <td>6</td>
#       <td>98.66%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e</td>
#       <td>0.04248</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e</td>
#       <td>0.004477</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_e</td>
#       <td>EX_mn2_e</td>
#       <td>4.403E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>na1_e</td>
#       <td>EX_na1_e</td>
#       <td>0.001893</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>0.4788</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>2.329</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>0.01931</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e</td>
#       <td>0.007271</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e</td>
#       <td>3.699E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>8aonn_m</td>
#       <td>SRC_8aonn_m</td>
#       <td>0.0001754</td>
#       <td>9</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>lipoate_m</td>
#       <td>SRC_lipoate_m</td>
#       <td>0.0002254</td>
#       <td>8</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>trnaala_c</td>
#       <td>SRC_trnaala_c</td>
#       <td>0.04189</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaarg_c</td>
#       <td>SRC_trnaarg_c</td>
#       <td>0.01064</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaasn_c</td>
#       <td>SRC_trnaasn_c</td>
#       <td>0.007832</td>
#       <td>10</td>
#       <td>1.29%</td>
#     </tr>
#     <tr>
#       <td>trnaasp_c</td>
#       <td>SRC_trnaasp_c</td>
#       <td>0.01431</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnacys_c</td>
#       <td>SRC_trnacys_c</td>
#       <td>0.002486</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnagln_c</td>
#       <td>SRC_trnagln_c</td>
#       <td>0.008552</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaglu_c</td>
#       <td>SRC_trnaglu_c</td>
#       <td>0.01514</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnagly_c</td>
#       <td>SRC_trnagly_c</td>
#       <td>0.03723</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnahis_c</td>
#       <td>SRC_trnahis_c</td>
#       <td>0.004437</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaile_c</td>
#       <td>SRC_trnaile_c</td>
#       <td>0.0115</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaleu_c</td>
#       <td>SRC_trnaleu_c</td>
#       <td>0.02323</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnalys_c</td>
#       <td>SRC_trnalys_c</td>
#       <td>0.0125</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnamet_c</td>
#       <td>SRC_trnamet_c</td>
#       <td>0.004138</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaphe_c</td>
#       <td>SRC_trnaphe_c</td>
#       <td>0.006903</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnapro_c</td>
#       <td>SRC_trnapro_c</td>
#       <td>0.01711</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaser_c</td>
#       <td>SRC_trnaser_c</td>
#       <td>0.02444</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnathr_c</td>
#       <td>SRC_trnathr_c</td>
#       <td>0.01582</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnatrp_c</td>
#       <td>SRC_trnatrp_c</td>
#       <td>0.001691</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnatyr_c</td>
#       <td>SRC_trnatyr_c</td>
#       <td>0.004524</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaval_c</td>
#       <td>SRC_trnaval_c</td>
#       <td>0.01996</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3aap_c</td>
#       <td>DM_3aap_c</td>
#       <td>-0.05137</td>
#       <td>5</td>
#       <td>8.21%</td>
#     </tr>
#     <tr>
#       <td>4oglu_c</td>
#       <td>DM_4oglu_c</td>
#       <td>-0.000101</td>
#       <td>5</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>amob_m</td>
#       <td>DM_amob_m</td>
#       <td>-0.0001754</td>
#       <td>15</td>
#       <td>0.08%</td>
#     </tr>
#     <tr>
#       <td>dad_5_m</td>
#       <td>DM_dad_5_m</td>
#       <td>-0.0001754</td>
#       <td>10</td>
#       <td>0.06%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-2.599</td>
#       <td>1</td>
#       <td>83.12%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e</td>
#       <td>-0.0003107</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>-4.242</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>-0.1659</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>hco3_e</td>
#       <td>EX_hco3_e</td>
#       <td>-0.001818</td>
#       <td>1</td>
#       <td>0.06%</td>
#     </tr>
#     <tr>
#       <td>zymst_e</td>
#       <td>EX_zymst_e</td>
#       <td>-0.009788</td>
#       <td>27</td>
#       <td>8.45%</td>
#     </tr>
#   </tbody>
# </table>

# %%
model_v01.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ls = 0.06130800269480152</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>5.101E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e</td>
#       <td>3.219E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe3_e</td>
#       <td>EX_fe3_e</td>
#       <td>0.0003782</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>1</td>
#       <td>6</td>
#       <td>98.86%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e</td>
#       <td>0.03591</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e</td>
#       <td>0.003784</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_e</td>
#       <td>EX_mn2_e</td>
#       <td>3.721E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>na1_e</td>
#       <td>EX_na1_e</td>
#       <td>0.0016</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>0.4047</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>2.898</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>0.01632</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e</td>
#       <td>0.006145</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e</td>
#       <td>3.127E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>8aonn_m</td>
#       <td>SRC_8aonn_m</td>
#       <td>0.0001482</td>
#       <td>9</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>lipoate_m</td>
#       <td>SRC_lipoate_m</td>
#       <td>0.0001905</td>
#       <td>8</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>trnaala_c</td>
#       <td>SRC_trnaala_c</td>
#       <td>0.03541</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaarg_c</td>
#       <td>SRC_trnaarg_c</td>
#       <td>0.008992</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaasn_c</td>
#       <td>SRC_trnaasn_c</td>
#       <td>0.006619</td>
#       <td>10</td>
#       <td>1.09%</td>
#     </tr>
#     <tr>
#       <td>trnaasp_c</td>
#       <td>SRC_trnaasp_c</td>
#       <td>0.0121</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnacys_c</td>
#       <td>SRC_trnacys_c</td>
#       <td>0.002101</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnagln_c</td>
#       <td>SRC_trnagln_c</td>
#       <td>0.007228</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaglu_c</td>
#       <td>SRC_trnaglu_c</td>
#       <td>0.01279</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnagly_c</td>
#       <td>SRC_trnagly_c</td>
#       <td>0.03146</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnahis_c</td>
#       <td>SRC_trnahis_c</td>
#       <td>0.00375</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaile_c</td>
#       <td>SRC_trnaile_c</td>
#       <td>0.009722</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaleu_c</td>
#       <td>SRC_trnaleu_c</td>
#       <td>0.01963</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnalys_c</td>
#       <td>SRC_trnalys_c</td>
#       <td>0.01057</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnamet_c</td>
#       <td>SRC_trnamet_c</td>
#       <td>0.003498</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaphe_c</td>
#       <td>SRC_trnaphe_c</td>
#       <td>0.005834</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnapro_c</td>
#       <td>SRC_trnapro_c</td>
#       <td>0.01446</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaser_c</td>
#       <td>SRC_trnaser_c</td>
#       <td>0.02065</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnathr_c</td>
#       <td>SRC_trnathr_c</td>
#       <td>0.01337</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnatrp_c</td>
#       <td>SRC_trnatrp_c</td>
#       <td>0.00143</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnatyr_c</td>
#       <td>SRC_trnatyr_c</td>
#       <td>0.003823</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaval_c</td>
#       <td>SRC_trnaval_c</td>
#       <td>0.01687</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3aap_c</td>
#       <td>DM_3aap_c</td>
#       <td>-0.04342</td>
#       <td>5</td>
#       <td>6.08%</td>
#     </tr>
#     <tr>
#       <td>4oglu_c</td>
#       <td>DM_4oglu_c</td>
#       <td>-8.54E-05</td>
#       <td>5</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>amob_m</td>
#       <td>DM_amob_m</td>
#       <td>-0.0001482</td>
#       <td>15</td>
#       <td>0.06%</td>
#     </tr>
#     <tr>
#       <td>dad_5_m</td>
#       <td>DM_dad_5_m</td>
#       <td>-0.0001482</td>
#       <td>10</td>
#       <td>0.04%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-3.126</td>
#       <td>1</td>
#       <td>87.51%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e</td>
#       <td>-0.0002626</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>-4.514</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>-0.1403</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>hco3_e</td>
#       <td>EX_hco3_e</td>
#       <td>-0.001536</td>
#       <td>1</td>
#       <td>0.04%</td>
#     </tr>
#     <tr>
#       <td>zymst_e</td>
#       <td>EX_zymst_e</td>
#       <td>-0.008273</td>
#       <td>27</td>
#       <td>6.25%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # look at sce and ylip to determine individual reactions that could be added.

# %% [markdown]
# following cell does not add reactions - finds sce individual reactions that have orthologs for Lst.

# %%
# this cell now looks at the sce model to find individual reactions that have an Lst gene ortholog. 
# this cell does not modify the model but rather tracks the reactions that have potential for additions. 

# track objects. 
sce_ortholog_available = []
no_ortholog = []
no_rxn = []
genes = []


# obtain list of sce and model reactions. 
sce_rxns = list(sce.reactions)
sce_rxns = [x.id for x in sce_rxns]
model_rxns = list(model.reactions)
model_rxns = [x.id for x in model_rxns]

# obtain keys of the sce:lst dictionary. Keys are the sce genes. 
sce_dict_keys = list(lst_sce_dict.keys())

# determine the reactions that have not yet been added to the model.
diff_rxns = set(sce_rxns) - set(model_rxns)

print(len(diff_rxns))

# iterate through the not added reactions.
for r in diff_rxns:
    
    # rxn is the sce reaction IDs.
    rxn = sce.reactions.get_by_id(r)

    # gpr are the sce reaction genes. 
    gpr = rxn.genes
    
    # holder for the Lst orthologs. 
    temp_gpr = []


    count_ortho=0
        
    # determine the number of orthologs for the GPR.
    for i in range(len(gpr)):
        
        # g is the individual genes in the rxns. 
        g=list(gpr)[i]

        # examine lst_orthologs. 
        if g.id in sce_dict_keys:

            # obtain the lst gene ortholog.
            value = lst_sce_dict[g.id]

            # check if the ortholog is blank. 
            if value:
                temp_gpr.append(value)
                count_ortho+=1
                    
    # if there were no orthologs. 
    if count_ortho==0:
        no_ortholog.append(r)
    
    # if one ortholog exist for a reaction, append it sce_ortholog_available list. 
    elif count_ortho>0:
        sce_ortholog_available.append(r)
        genes.append(temp_gpr)
# Out:
# 3234

# %%
len(sce_ortholog_available)
# Out:
# 1668

# %%
len(model.reactions)
# Out:
# 2148

# %%
2148-2083
# Out:
# 65

# %% [markdown]
# potential to add 1668 more reactions.

# %% [markdown]
# #### ylip orthologs.

# %% [markdown]
# following cell does not add reactions - finds ylip reactions that have orthologs to Lst.

# %%
# this cell now looks at the ylip model to find individual reactions that have an Lst gene ortholog. 
# this cell does not modify the model but rather tracks the reactions that have potential for additions. 

# track objects.
ylip_ortholog_available = []
no_ortholog = []
no_rxn = []
genes = []

# obtain the ylip and model reaction lists. 
ylip_rxns = list(ylip.reactions)
ylip_rxns = [x.id for x in ylip_rxns]
model_rxns = list(model.reactions)
model_rxns = [x.id for x in model_rxns]

# obtain keys of the ylip:lst dictionary. Keys are the ylip genes.
ylip_dict_keys = list(lst_ylip_dict.keys())

# determine the reactions that are in the ylip GSM but not in the Lst GSM model. 
diff_rxns = set(ylip_rxns) - set(model_rxns)
print(len(diff_rxns))

# iterate through the reactions not included. 
for r in diff_rxns:
    
    # rxn holds the ylip reactions. 
    rxn = ylip.reactions.get_by_id(r)
    
    # gpr holds the ylip reaction genes. 
    gpr = rxn.genes
    
    # list object to hold the Lst orthologs. 
    temp_gpr = []

    count_ortho=0
        
    # determine the number of orthologs for the GPR.
    for i in range(len(gpr)):
        
        # g is the individual ylip genes in the reaction. 
        g=list(gpr)[i]

        # examine lst_orthologs. 
        if g.id in ylip_dict_keys:

            # obtain the lst gene ortholog.
            value = lst_ylip_dict[g.id]

            # check if the ortholog is blank. 
            if value:
                temp_gpr.append(value)
                count_ortho+=1
                    
    # if there were no orthologs. 
    if count_ortho==0:
        no_ortholog.append(r)
    
    # append reactions for which there is one Lst ortholog to the ylip_ortholog_available list. 
    elif count_ortho>0:
        ylip_ortholog_available.append(r)
        genes.append(temp_gpr)
        
#         temp = " or ".join(sub_item.replace("None", "").replace("NA"," ") for sub_item in temp_gpr)
# Out:
# 633

# %%
len(model.reactions)-2083
# Out:
# 65

# %%
len(ylip_ortholog_available)
# Out:
# 260

# %%
len(sce_ortholog_available)
# Out:
# 1668

# %% [markdown]
# There are 260 potential ylip reactions that can be added.

# %% [markdown]
# ## following section seeks to determine if there are reactions in the individual sce or ylip GSMs that are in the Lst draft GSM, but may have had seperate ID conventions.
#
# i.e.
#
# - ReacR1 = a+b --> c
# - ReacR_1 = a+b --> c
#
# The two reactions are the same but would not have turned up the same in the previous iteration.
#
# Now we try to match the naming conventions instead of IDs to identify these reactions.
#
# i.e.,
# - ReacR1 = a+b --> c : name = Reaction 1
# - ReacR_1 = a+b --> c : name = Reaction 1

# %%
# This cell gathers the reactions that have orthologs from the sce model that will be used for making a dictionary. 

# list holders for reaction details. 
_names = []
_gpr = []
_id = []
_stoich = []
_subsystem = []


# gather the reaction details from the possible ortholog reactions. 
for rx in sce_ortholog_available:
    r = sce.reactions.get_by_id(rx)
    _names.append(r.name)
    _gpr.append(r.gene_reaction_rule)
    _id.append(r.id)
    _stoich.append(r.reaction)
    
# store the names here. 
sce_rxns_name = _names

# %%
# here we obtain the model reactions and names. 
model_rxns_name = model.reactions
model_rxns_id = [x.id for x in model_rxns_name]
model_rxns_name = [x.name for x in model_rxns_name]

# %% [markdown]
# now we check how many names match the sce and model reactions.

# %%
temp = []
for r in sce_rxns_name:
    if r in model_rxns_name:
        temp.append(r)
print(len(temp))
# Out:
# 12

# %%
print(temp)
# Out:
# ['C-3 sterol dehydrogenase (4-methylzymosterol)', '3-mercaptopyruvate sulfurtransferase', '3-methyl-2-oxobutanoate hydroxymethyltransferase', '2-keto-4-methylthiobutyrate transamination', 'C-14 sterol reductase', 'Phytosphingosine phosphate lyase', 'UDP-N-acetylglucosamine diphosphorylase', 'C-4 sterol methyl oxidase (4,4-dimethylzymosterol)', 'NAD kinase', 'GTP cyclohydrolase II', 'fatty-acid--CoA ligase (decanoate)', 'NAD diphosphatase']

# %% [markdown]
# ## match reaction names so we can add orthologs even if reaction IDs do not match.
#
# Many reaction names have different writing conventions (i.e., spaces, dashes, captilization). We will use the python 're' library to replace many of those names to try and match reactions.

# %%
import re

# %%
# replace the model reaction special characters and make all characters lower case. 
model_rxns_name = [x.replace(" ","").replace('-','').replace(':',"").replace(',',"").replace(')',"").replace(')',"").replace('\'',"").replace('mitochondrialmembrane',"").lower() for x in model_rxns_name]
model_rxns_name = [re.sub(r'[^a-zA-Z0-9]', '', x) for x in model_rxns_name]

# %%
len(sce_rxns_name)
# Out:
# 1668

# %%
len(sce.reactions)
# Out:
# 4131

# %%
# replace the sce reaction name special characters and make all characters lower case. 
sce_rxns_name = [re.sub(r' c$',"",x) for x in sce_rxns_name]
sce_rxns_name = [re.sub(r' v$',"",x) for x in sce_rxns_name]

sce_rxns_name = [x.replace(" ","").replace('-','').replace(':',"").replace(',',"").replace(')',"").replace(')',"").replace('\'',"").replace('+',"").replace('mitochondrialmembrane',"").lower() for x in sce_rxns_name]

sce_rxns_name = [re.sub(r'[^a-zA-Z0-9]', '', x) for x in sce_rxns_name]

# the yeast-8 scaffold model has many membrane/envelope compartments. 
# Here we will replace those names for initial matching purposes.
sce_rxns_name = [x.replace('mitochondrialmembrane',"").replace('golgimembrane',"").replace('ermembrane',"") for x in sce_rxns_name]
sce_rxns_name = [x.replace('cellenvelopecytoplasm',"").replace('vacuolarmembrane',"") for x in sce_rxns_name]
sce_rxns_name = [re.sub(r'mitochondrial$',"",x) for x in sce_rxns_name]
sce_rxns_name = [re.sub(r'mitochondria$',"",x) for x in sce_rxns_name]
sce_rxns_name = [re.sub(r'cellenvelope$',"",x) for x in sce_rxns_name]
sce_rxns_name = [re.sub(r'cytoplasm$',"",x) for x in sce_rxns_name]
sce_rxns_name = [re.sub(r'cytoplasmic$',"",x) for x in sce_rxns_name]

# %%
for r in sce_rxns_name:
    if 'mitochondria' in r:
        print(r)
# Out:
# mitochondrialalcoholdehydrogenase
# glutamyltrnaglnamidotransferasesubunitbmitochondrialgluadtsubunitbec635cytochromecoxidaseassemblyfactorpet112
# magnesiumtransportermrs2mitochondrialrnasplicingproteinmrs2
# ironsulfurclusterassemblyprotein2mitochondrialironsulfurclusterscaffoldprotein2
# putativelipoateproteinligaseaec63120alteredinheritancerateofmitochondriaprotein22

# %%
for r in sce_rxns_name:
    if 'cytoplasm' in r:
        print(r)

# %%
len(sce_rxns_name)
# Out:
# 1668

# %% [markdown]
# potentially 1386 reactions can be added from sce.

# %%
len(set(sce_rxns_name))
# Out:
# 1386

# %% [markdown]
# however, many reactions have the same name.

# %%
phrase = 'ipsphospholipasec'
try:
    position = sce_rxns_name.index(phrase)
    positions = [i for i, x in enumerate(sce_rxns_name) if x == phrase]
    if positions:
        print(f"'{phrase}' found at positions {positions} in the list.")
#     print(f"'{phrase}' found at position {position} in the list.")
except ValueError:
    print(f"'{phrase}' not found in the list.")
# Out:
# 'ipsphospholipasec' found at positions [54, 66, 84, 119, 135, 156, 166, 235, 300, 322, 325, 421, 429, 462, 534, 536, 553, 587, 593, 595, 617, 649, 682, 690, 716, 781, 815, 827, 947, 978, 980, 982, 1177, 1186, 1189, 1194, 1198, 1200, 1202, 1203, 1212, 1220, 1245, 1255, 1264, 1299, 1324, 1328, 1339, 1369, 1410, 1425, 1435, 1470, 1512, 1520, 1552, 1580, 1587, 1654] in the list.

# %% [markdown]
# ## but first, lets check how many reactions are already in the model.
#
# 88 reactions are already in model and need updated GPRs.

# %%
temp = []
for r in sce_rxns_name:
    if r in model_rxns_name:
        temp.append(r)
print(len(temp))
# Out:
# 88

# %% [markdown]
# 88 reactions are already in model and need updated GPRs for the sce genes.

# %%
## this cell removes more of the unique identifiers from the model reaction names. 
model_rxns_name = [re.sub(r' c$',"",x) for x in model_rxns_name]
model_rxns_name = [re.sub(r' v$',"",x) for x in model_rxns_name]

model_rxns_name = [x.replace(" ","").replace('-','').replace(':',"").replace(',',"").replace(')',"").replace(')',"").replace('\'',"").replace('+',"").replace('mitochondrialmembrane',"").lower() for x in model_rxns_name]

model_rxns_name = [re.sub(r'[^a-zA-Z0-9]', '', x) for x in model_rxns_name]

# model_rxns_name = [x.replace('mitochondrialmembrane',"").replace('golgimembrane',"").replace('ermembrane',"") for x in model_rxns_name]
model_rxns_name = [x.replace('vacuolar',"").replace('vacuolarmembrane',"") for x in model_rxns_name]
model_rxns_name = [re.sub(r'mitochondrial$',"",x) for x in model_rxns_name]
model_rxns_name = [re.sub(r'mitochondria$',"",x) for x in model_rxns_name]
model_rxns_name = [re.sub(r'cellenvelope$',"",x) for x in model_rxns_name]
model_rxns_name = [re.sub(r'cytoplasm$',"",x) for x in model_rxns_name]
model_rxns_name = [re.sub(r'cytoplasmic$',"",x) for x in model_rxns_name]

model_rxns_name = [re.sub(r'peroxisomal$',"",x) for x in model_rxns_name]
model_rxns_name = [re.sub(r'cytoplasmic$',"",x) for x in model_rxns_name]

# sce_rxns_name = [x.replace('mitochondrialmembrane',"").replace('golgimembrane',"").replace('ermembrane',"") for x in sce_rxns_name]

# %% [markdown]
# correction. 102 reactions need updated GPRs.

# %%
temp = []
for r in sce_rxns_name:
    if r in model_rxns_name:
        temp.append(r)
print(len(temp))
print(len(set(temp)))
# Out:
# 110
# 102

# %%
# create a dictionary of the model rxn names to the original ids. 
model_dict_sce = dict(zip(model_rxns_name,model_rxns_id))

# %%
model_dict_sce
# Out:
# {'aldehydedehydrogenase2phenylethanolnadp': 'ALCD25yi',
#  'methenyltetrahydrifikatecyclohydrolase': 'MTHFCm',
#  'ampnucleosidase': 'AMPN',
#  'diacylglycerolcholinephosphotransferaseyeastspecific': 'DAGCPTer_RT',
#  'pyruvatetransportinviaprotonsymport': 'PYRt2',
#  'nicotinatenucleotidediphosphorylasecarboxylating': 'NNDPR',
#  'hydroxymethylglutarylcoasynthase': 'HMGCOAS',
#  '35cyclicnucleotidephosphodiesterase': 'PDE3',
#  'phosphoadenylylsulfatereductasethioredoxin': 'PAPSR',
#  'acylcoaoxidasedecanoylcoa': 'ACOAO4p',
#  '3isopropylmalate3methyltransferase': '3IPM3MT',
#  'udpglucose6dehydrogenase': 'UDPGD',
#  'cytidinekinasegtp': 'CYTDK2',
#  'fattyacidcoaligasetetradecenoate': 'FACOAL141p',
#  'acetylcoaacyltransferasetetradecanoylcoa': 'ACACT7p',
#  'polyamineoxidase': 'POLYAO',
#  'mevalonatekinaseatp': 'MEVK1',
#  'datpuridine5phosphotransferase': 'DATUP',
#  'taurinedioxygenase': 'TAUDO',
#  'citratesynthase': 'CSm',
#  'phosphoserinetransaminase': 'PSERT',
#  'guanylatekinasegmpdatp': 'GK2',
#  'lcysteinereversibletransportviaprotonsymport': 'CYSt2r',
#  'hatpase': 'ATPS2v',
#  'sphinganinephosphatelyase': 'SPHPLer',
#  'phospholipasebphosphatidylcholineyeastspecificextracellular': 'PLBPCe_RT',
#  'aldehydedehydrogenasephenylacetaldehydenad': 'ALDD19xr',
#  'glutathionehydralaseperiplasmic': 'GTHRDH_syn',
#  'nucleosidediphosphatekinaseatpdcdp': 'NDPK7',
#  'propane12diolnadp1oxidoreductase': 'PPDOy',
#  'glyoxylatereductasenadp': 'GLYCLTDy',
#  'deoxyguanylatekinasedgmpatp': 'DGK1',
#  'sphingolipidlongchainbasekinasephytosphingosine': 'SLCBK2er',
#  'ceramide1synthase26cendoplasmicreticular': 'CERS126er',
#  'inositol145triphosphate6kinasenucleus': 'MI145P6Kn',
#  'adentylatekinasegtp': 'ADK3m',
#  'dimethylallyltranstransferase': 'DMATT',
#  'phosphomethylpyrimidinekinase': 'PMPK',
#  'lactoylglutathionelyase': 'LGTHL',
#  'purinenucleosidephosphorylaseguanosine': 'PUNP3',
#  'prephenatedehydratase': 'PPNDH',
#  'glycyltrnasynthetase': 'GLYTRS',
#  '3hydroxyacylcoadehydrogenase3oxodecanoylcoa': 'HACD5p',
#  'glycerol3phosphateacyltransferaseglyceronephosphateyeastspecific': 'GAT2er_RT',
#  'cdpdiacylglycerolsynthetaseyeastspecific': 'DASYNm_RT',
#  's3hydroxybutanoylcoahydrolyase': 'ECOAH1p',
#  'kynureninase': 'KYN',
#  'histidinolphosphatetransaminase': 'HSTPT',
#  'ironiitransport': 'FE2tm',
#  '3methyl2oxopentanoatedecarboxylase': '3MOPDC',
#  'peroxisomalacylcoathioesterase': 'PTE12x',
#  'glutamyltrnasynthetase': 'GLUTRSm',
#  'phosphoribosylaminoimidazolecarboxamideformyltransferase': 'AICART',
#  '42aminoethyl12benzenedioloxygenoxidoreductasedeaminatingflavincontaining': '42A12BOOX',
#  'triosephosphateisomerase': 'TPI',
#  'coatransportermitochondrialirreversible': 'COAtim',
#  'nicotinatemononucleotideadenylyltransferase': 'NADS2',
#  'acetylcoacacetyltransferaseoctanoylcoa': 'ACACT4p',
#  'histidyltrnasynthetase': 'HISTRSm',
#  'phenylalanyltrnasynthetase': 'PHETRS',
#  '2oxo4methyl3carboxypentanoatedecarboxylation': 'OMCDCm',
#  'dtmpkinase': 'DTMPK',
#  'aldehydedehydrogenaseisobutylalcoholnadp': 'ALCD23yi',
#  'fattyacidcoaligasehexadecanoate': 'FACOAL160',
#  '6phosphogluconolactonase': 'PGLp',
#  'lthreoninedeaminase': 'THRD_L',
#  'betaglucosidase': 'BG_MBDG',
#  'tryptophanyltrnasynthetase': 'TRPTRSm',
#  'sadenosyllmethioninetransportinviaprotonsymport': 'AMETt2',
#  'osuccinylhomoserinelyaselcysteine': 'SHSL1',
#  'oacetylhomoserinethiollyase': 'AHSERL2',
#  'acetatetransporter': 'ACtr',
#  'cytochromep450lanosterol14alphademethylasenad': 'LNS14DMrx',
#  '2methylacylcoadehydrogenasetrans2methylbut2enoylcoaforming': 'ACOAD10m',
#  'thymidinephosphorylase': 'TMDPP',
#  'inositoltransportinviaprotonsymport': 'INSTt2',
#  'inositolphosphorylceramideceramide224cphospholipasec': 'IPC224PLCg_RT',
#  'dctpcytidine5phosphotransferase': 'DCTCP',
#  'hexokinasedfructoseatp': 'HEX7',
#  'homoisocitratedehydrogenase': 'HICITDm',
#  'malatetransport': 'MALtm',
#  'amidase': 'AMID3',
#  'pantothenatekinase': 'PNTK',
#  'fattyacidoxidationoctanoylcoa': 'FAO80p',
#  'adenosinedeaminase': 'ADA',
#  'glutamatedehydrogenasenad': 'GLUDxi',
#  'uraciltransportinviaprotonsymport': 'URAt2',
#  'ergosterolreversibletransport': 'ERGSTt',
#  'carnitineoacetyltransferasereversedirection': 'CSNATp',
#  'udpglucose4epimerase': 'UDPG4E',
#  'shikimatedehydrogenase': 'SHK3Dr',
#  'succinatesemialdehydedehydrogenasenadp': 'SSALy',
#  'cysteinedesulfhydrase': 'CYSDS',
#  'ribokinase': 'RBK',
#  '3methyl2oxobutanoatehydroxymethyltransferase': 'MOHMT',
#  'inositolphosphorylceramideceramide324cphospholipasec': 'IPC324PLCg_RT',
#  'phosphoribosylglycinamideformyltransferase': 'GARFT',
#  'pyridoxaminekinase': 'PYDAMK',
#  '3hydroxylkynureninehydrolase': 'HKYNH',
#  'datpcytidine5phosphotransferase': 'DATCY',
#  'atpnicotinamidenucleotideadenylyltransferasenucleus': 'NNATn',
#  'methionyltrnasynthetase': 'METTRS',
#  'sformylglutathionehydralase': 'SFGTHi',
#  'inositolphosphoryceramidesynthaseceramide226cyeastspecific': 'IPCS226g_RT',
#  'acidphosphataseextracellularsecreted': 'ACP1e',
#  'formatetetrahydrofolateligase': 'FTHFLi',
#  'aspartatesemialdehydedehydrogenase': 'ASAD',
#  '3hydroxyacylcoadehydratase3hydroxyhexadecanoylcoa': 'ECOAH7p',
#  'fattyacidcoaligasetetradecanoate': 'FACOAL140',
#  'enoylcoahydratase3hydroxy2methylbutyrylcoaforming': 'ECOAH9m',
#  'hypoxanthinephosphoribosyltransferasehypoxanthine': 'HXPRT',
#  'c22steroldesaturasenad': 'C22STDSrx',
#  'nitrilase': 'NTRLASE',
#  'dihydroxyaciddehydratase23dihydroxy3methylpentanoate': 'DHAD2m',
#  'udpglucoseergosterolglucosyltransferase': 'ERGSTGLCT',
#  'fattyacidcoaligaseoctadecynoate': 'FACOAL182p',
#  'pyrroline5carboxylatereductase': 'P5CR',
#  'phytosphingosinephosphatelyase': 'PSPHPLer',
#  'myoinositol1phosphatase': 'MI1PP',
#  'sodiumprotonantiporterhnais11': 'NAt3_1g',
#  'nucleosidediphosphatekinaseatpdidp': 'NDPK10',
#  '3phospho5adenylylsulfate3phosphohydrolase': 'BPNT2',
#  'coproporphyrinogenoxidaseo2required': 'CPPPGO',
#  'putrescinetransportinviaprotonantiportirreversible': 'PTRCt3i',
#  'naprtaserev': 'NAPRT',
#  'mannoseinositolp2ceramideceramide324cphospholipasec': 'MIP2C324PLCg_RT',
#  'alcoholdehydrogenaseethanol': 'ALCD2x',
#  'nucleosidediphosphatekinaseatpcdp': 'NDPK3',
#  'lanosterolreversibletransport': 'LANOSTt',
#  'fattyacidcoaligasedodecanoate': 'FACOAL120p',
#  'enoylcoahydratasec120': 'ECOAH5m',
#  'c4sterolmethyloxidase4methylzymosterol': 'C4STMO2er',
#  'uridylatekinasedump': 'URIDK2r',
#  'nucleosidetriphosphatepyrophosphorylaseitp': 'NTPP9',
#  'ceramide2psynthase24c': 'CERS2p24er',
#  'allophanatehydrolase': 'ALPHNH',
#  'deoxyuridinephosphorylase': 'DURIPP',
#  'glutamatedehydrogenasenadp': 'GLUDy',
#  'homoserineotransacetylase': 'HSERTA',
#  'citratetransport': 'CITtcm',
#  'fmnadenylyltransferase': 'FMNATm',
#  'tyrosyltrnasynthetase': 'TYRTRSm',
#  'isoleucyltrnasynthetase': 'ILETRS',
#  'aspartatekinase': 'ASPK',
#  'diphthinesynthase': 'DIPS',
#  'udpgalactosetransportgolgiapparatus': 'UDPGALt2g',
#  'llactaldehydenadp1oxidoreductase': 'LALDO3',
#  'homoserinekinase': 'HSK',
#  'gtpgdptranslocasemitochondrialelectroneutral': 'GTPt2m',
#  'phosphopantothenoylcysteinedecarboxylase': 'PPCDC',
#  'atpadenylyltransferase': 'ATPATF3',
#  'phosphoribosylatppyrophosphatase': 'PRATPP',
#  'aspartyltrnasynthetase': 'ASPTRSm',
#  'ltyrosinetransportinviaprotonantiport': 'TYRt6',
#  'phosphatidylserinedecarboxylaseyeastspecific': 'PSERDer_RT',
#  'impcyclohydrolase': 'IMPC',
#  'dgtpuridine5phosphotransferase': 'DGTUP',
#  'nucleosidediphosphatekinaseatpidp': 'NDPK9',
#  'sucrosehydrolyzingenxymeextracellular': 'SUCRe',
#  'ltyrosinetransportoutviaprotonsymport': 'TYRt7',
#  'ribulose5phosphate3epimerase': 'RPE',
#  'hexokinasedmannoseatp': 'HEX4',
#  'lisoleucinetransportoutviaprotonsymport': 'ILEt7',
#  '3dehydroquinatedehydrataseirreversible': 'DHQTi',
#  'ornithinemitochondrialtransportviaprotonantiport': 'ORNLYStm',
#  'leucinetransaminase': 'LEUTA',
#  'enoylcoahydratasec140': 'ECOAH6m',
#  'nadhdehydrogenasecytosolic': 'NADH2_u9cm',
#  'cholinephosphatecytididyltransferase': 'CHLPCTD',
#  'nucleosidediphosphatekinaseatpudp': 'NDPK2',
#  'ceramide2psynthase26c': 'CERS2p26er',
#  'pyruvatekinase': 'PYK',
#  'fattyacylcoasynthasenc180coa': 'FAS180COA',
#  'propanoylcoaacceptor23oxidoreductase': 'PPCOAOm',
#  'glycinehydroxymethyltransferasereversible': 'GHMT2r',
#  'acetylcoacacyltransferasedecanoylcoa': 'ACACT5p',
#  'allantoateamidinohydrolasereversible': 'ALLTAHr',
#  'ceramide3synthase24c': 'CERS324er',
#  'phosphoglucosaminemutase': 'PGAMT',
#  'phosphomevalonatekinase': 'PMEVK',
#  'fattyacylcoasynthasenc80coalumpedreaction': 'FAS80COA_L',
#  'dihydrofolatesynthase': 'DHFS',
#  'acetylglutamatekinase': 'ACGKm',
#  'phosphoglyceratedehydrogenase': 'PGCD',
#  'porphobilinogensynthase': 'PPBNGS',
#  '15phosphoribosyl55phosphoribosylaminomethylideneaminoimidazole4carboxamideisomerase': 'PRMICI',
#  '4phosphopantothenatelcysteineligase': 'PPNCL3',
#  'phosphoglyceratemutase': 'PGM',
#  'cytidylatekinasedcmp': 'CYTK2',
#  'mannoseinositolp2ceramideceramide224cphospholipasec': 'MIP2C224PLCg_RT',
#  'aspartate1decarboxylase': 'ASP1DC',
#  'ethanolaminephosphotransferaseyeastspecific': 'ETHAPTer_RT',
#  'phosphoglucomutase': 'PGMT',
#  'reducedglutathioneviaabcsystem': 'GTHRDabcv',
#  'dolichylphosphatemannoseproteinmannosyltransferaseendoplasmicreticular': 'DOLPMMer',
#  'deoxyadenylatekinase': 'DADK',
#  'dttpcytidine5phosphotransferase': 'DTTGY',
#  'zymosterolreversibletransport': 'ZYMSTt',
#  'adenylatecyclase': 'ADNCYC',
#  'uridinetransportinviaprotonsymport': 'URIt2',
#  'aspartatecarbamoyltransferase': 'ASPCT',
#  'cysteinyltrnasynthetase': 'CYSTRS',
#  'larganinereversibletransportviaprotonsymport': 'ARGt2r',
#  'atpcitratelyase': 'ACITL',
#  'glycolipid12alphadmannosyltransferasegolgiapparatus': 'G12MT1g',
#  'phosphofructokinase': 'PFK',
#  'aminobutyraldehydedehydrogenase': 'ABUTD',
#  'phenethylamineoxidase': 'PEAMNO',
#  'aldehydedehydrogenaseacetaldehydenad': 'ALDD2x',
#  'inositolphosphorylceramidesynthaseceramide224cyeastspecific': 'IPCS224g_RT',
#  'alkalinephosphatase': 'ALKP',
#  '3hydroxyisobutyrylcoahydrolase': '3HBCOAHLm',
#  'lasparaginetransportinviaprotonantiport': 'ASNt6',
#  'dgtpcytidine5phosphotransferase': 'DGTCY',
#  'atpasecytosolic': 'ATPS',
#  'phosphoacetylglucosaminemutase': 'ACGAMPM',
#  'phenylalaninetransaminase': 'PHETA1',
#  'hexokinasedglucosamineatp': 'HEX10',
#  '16betaglucansynthase': '16GS',
#  'malonylcoaacptransacylase': 'MCOATAm',
#  'nadsynthasenh3nuclear': 'NADS1n',
#  'alanylaminopeptidasecysgly': 'AMPTASECG',
#  'tetrahydrofolatelglutamategammaligaseadpforming': 'THFGLUS',
#  'adenylatekinase': 'CYTK2_1',
#  'rrbutanedioldehydrogenase': 'BTDD_RR',
#  'gtpcyclohydrolasei': 'GTPCI',
#  'methylenetetrahydrofolatedehydrogenasenadp': 'MTHFD',
#  'leucyltrnasynthetase': 'LEUTRSm',
#  'phosphatidylnmethylethanolaminenmethyltransferaseyeastspecific': 'PMETMer_RT',
#  'glycerol3phosphatedehydrogenasenad': 'G3PD1ir',
#  'glycylpeptidentetradecanoyltransferase': 'GLPT',
#  'deoxyribokinase': 'DRBK',
#  'adenosinetransportinviaprotonsymport': 'ADNt2',
#  'ureareversibletransportviaprotonsymport2h': 'UREA2t2',
#  'aspartatetransaminase': 'ASPTAm',
#  'mannoseinositolphosphorylceramidesynthaseceramide326cyeastspecific': 'MIPCS326g_RT',
#  'phosphoribosylampcyclohydrolase': 'PRAMPC',
#  'adenylsuccinatelyase': 'ADSL1r',
#  'arginase': 'ARGN',
#  'isocitratedehydrogenasenadp': 'ICDHyp',
#  'transketolase': 'TKT1',
#  'sadenosylmethioninedelta24sterolcmethyltransferase': 'SAM24MTer',
#  'biotinacetylcoacarboxylaseligase': 'BACCLm',
#  'dutpuridine5phosphotransferase': 'DUTUP',
#  'glutathioneoxidoreductase': 'GTHOm',
#  'ampatptransporter': 'ATP2tp_H',
#  'glutamatedecarboxylase': 'GLUDC',
#  'lmethioninereversibletransportviaprotonsymport': 'METt2r',
#  '3hydroxybutanoylcoanadpoxidoreductase': 'HBCO_nadp',
#  'valinetransaminasemitochondiral': 'VALTAm',
#  'glutathionetransport': 'GTHRDt2',
#  'lmethioninesoxidereductase': 'METSOXR1',
#  'phospholipasedyeastspecific': 'PLDn_RT',
#  'naprtase': 'NAPRTm',
#  'fattyacidcoaligasenc260': 'FACOAL260',
#  'pyridoxinekinase': 'PYDXNK',
#  'alcoholdehydrogenaseethanolnadp': 'ALCD2y',
#  'imidazoleglycerol3phosphatesynthase': 'IG3PS',
#  '1acylglycerol3phosphateacyltransferaseyeastspecific': 'AGATer_RT',
#  'dctpdeaminase': 'DCTPD',
#  'cytidinetransportinviaprotonsymport': 'CYTDt2',
#  'uracilphosphoribosyltransferase': 'UPPRT',
#  'enoylcoahydratase3hydroxyisobutyrylcoaforming': 'ECOAH12m',
#  '3sulfoalaninecarboxylyase': 'LCYSTCBOXL',
#  'dihydroxyacetonekinase': 'DHAK',
#  'geranyltranstransferase': 'GRTT',
#  'inositolphosphorylceramidesynthaseceramide124cyeastspecific': 'IPCS124g_RT',
#  'ureacarboxylase': 'UREASE',
#  'acylcoathioesterase': 'PTE10m',
#  'tyrosinetransaminase': 'TYRTA',
#  'glycogenphosphorylase': 'GLCP',
#  'pyruvatedecarboxylase': 'PYRDC',
#  'phosphatidylinositolsynthaseyeastspecific': 'PINOSer_RT',
#  'mannoseinositolphosphorylceramideceramide124cphospholipasec': 'MIPC124PLCg_RT',
#  'phosphatetransporter': 'PIt2m',
#  'pyridoxamineoxygenoxidoreductasedeaminating': 'PYDXO_1',
#  'riboflavinsynthase': 'RBFSb',
#  'phosphomannomutase': 'PMANM',
#  'nadsynthasenh3': 'NADS1',
#  'phosphatidylserinedecarboxylaseyeastspecificgolgi': 'PSERDg_RT',
#  'hydroxyacylglutathionehydrolase': 'GLYOX',
#  'dlactatedehydrogenasecytosolic': 'D_LACDcm',
#  'acylcoaoxidasedodecanoylcoa': 'ACOAO5p',
#  '5aminolevulinatesynthase': 'ALASm',
#  'aldehydedehydrogenaseisoamylalcoholnad': 'ALCD24xi',
#  'nucleosidediphosphatasegdpgolgi': 'NDP3g',
#  'diacylglycerolpyrophosphatephosphataseyeastspecific': 'DAGPYPer_RT',
#  'spermidinetransportinviaprotonantiport': 'SPMDt3i',
#  '3methyl2oxobutanoatedecarboxylase': '3MOBDC',
#  'ctp12diacylsnglycerol3phosphotransferase': 'DAGKer_RT',
#  'malatedehydrogenase': 'MDHp',
#  'seryltrnasynthetase': 'SERTRSm',
#  'transaldolase': 'TALA',
#  'aldehydedehydrogenase2phenylethanolnad': 'ALCD25xi',
#  'glyceraldehyde3phosphatedehydrogenase': 'GAPD',
#  'atppantothenoyllcysteine4phosphotransferase': 'APCPT',
#  'ornithinecarbamoyltransferaseirreversible': 'OCBTm',
#  'c5steroldesaturase': 'C5STDSer',
#  '13betaglucansynthase': '13GS',
#  'sirohydrochlorindehydrogenasenad': 'SHCHD2',
#  'galactokinase': 'GALKr',
#  'thiaminediphosphokinase': 'TMDPK',
#  'ceramide1hydroxylase26c': 'CERH126er',
#  'citratehydrolyasecisaconitateforming': 'ACONTam',
#  'dctpuridine5phosphotransferase': 'DCTUP',
#  'mannoseinositolphosphorylceramideceramide324cphospholipasec': 'MIPC324PLCg_RT',
#  's2hydroxyacidoxidase': 'GLYCTO1p',
#  'fecosterolesterhydrolaseyeastspecific': 'FECOSTESTH_RT',
#  '3hydroxyacylcoadehydrogenase3oxohexadecanoylcoa': 'HACD7p',
#  'lthreoninereversibletransportviaprotonsymport': 'THRt2r',
#  'electrontransferflavoprotein': 'ETF',
#  'nucleotidephosphatase': 'NP1',
#  'pantetheinephosphateadenylyltransferase': 'PTPATi',
#  'indole3glycerolphosphatesynthase': 'IGPS',
#  'aldehydedehydrogenaseindole3acetaldehydenad': 'ALDD20x',
#  'llysinetransportinviaprotonantiport': 'LYSt6',
#  'methioninesynthase': 'METS',
#  'cystathionineblyase': 'CYSTL',
#  '1phosphatidylinositol35bisphosphate5phosphataseyeastspecific': 'PIN3Per_RT',
#  'nadkinase': 'NADK',
#  '5nucleotidaseump': 'NTD2',
#  'mannoseinositolphosphorylceramidesynthaseceramide226cyeastspecific': 'MIPCS226g_RT',
#  'cdpdiacylglycerolserineophosphatidyltransferaeyeastspecific': 'CDPDGPm_RT',
#  'histidinolphosphatase': 'HISTP',
#  'fattyacidcoaligasehexadecenoate': 'FACOAL161',
#  'guanylatekinasegmpatp': 'GK1',
#  'acylcoaepisterolacyltransferaseyeastspecific': 'EPISTATer_RT',
#  'isobutylacetatehydrolyzingesterase': 'ACHLE2',
#  'acetylcoacacetyltransferasedodecanoyl': 'ACACT6p',
#  'gmpsynthase': 'GMPS',
#  '4amino4deoxychorismatesynthase': 'ADCS',
#  'impdehydrogenase': 'IMPDm',
#  'tryptophantransaminase': 'TRPTA',
#  'coahydrolase': 'COAHLp',
#  'lanosterolesterhydrolaseyeastspecific': 'LANOSTESTH_RT',
#  'ornithinetransacetylaseirreversible': 'ORNTACim',
#  'lvalinereversibletransportviaprotonsymport': 'VALt2r',
#  'cs24sterolreductaseendoplamicreticular': 'C24STRer',
#  'lasparaginetransportoutviaprotonsymport': 'ASNt7',
#  'yumpsynthetase': 'YUMPS',
#  'phosphatidylcholinediacylglycerolacyltransferase': 'PCDAGATer_RT',
#  'inositolphosphorylceramideceramide226cphospholipasec': 'IPC226PLCg_RT',
#  'fattyacylcoasynthasenc140coa': 'FAS140COA',
#  'acetolactatesynthase': 'ACLSm',
#  'glucose6phosphatedehydrogenase': 'G6PDH2rp',
#  '1phosphatidylinositol3kinaseyeastspecific': 'PIN3Kn_RT',
#  'sphinganinenadphoxygenoxidoreductase4hydroxylating': 'PSPHSer',
#  'pyruvatedehydrogenase': 'PDHm',
#  'ammoniareversibletransport': 'NH4t',
#  'gammaglutamylcysteinesynthetase': 'GLUCYS',
#  'alanyltrnasynthetase': 'ALATRS',
#  'protoporphyrinogenoxidase': 'PPPGOm',
#  'dcmpdeaminase': 'DCMPDA',
#  'glutaminyltrnasynthetase': 'GLNTRS',
#  'adenosinemonophosphatedeaminase': 'AMPDA',
#  'ornithinecarbamoyltransferase': 'OCBT',
#  'acetylcoacacetyltransferase': 'ACACT1m',
#  'adeninetransportinviaprotonsymport': 'ADEt2',
#  'alphaalphatrehalase': 'TREHe',
#  'lglutamatetransportviaprotonsymportreversible': 'GLUt2r',
#  'fecosterolreversibletransport': 'FECOSTt',
#  'betafructofuranosidase': 'BFFS',
#  'triglycerolsynthesis': 'TRIGSer_RT',
#  '2deoxydarabinoheptulosonate7phosphatesynthetase': 'DDPAm',
#  '14alphaglucanbranchingenzyme': 'GBEZ',
#  'lhydroxyprolinereductasenadp': 'HPROb',
#  'thiaminephosphatediphosphorylase': 'TMPPP',
#  'fructosebisphosphatealdolase': 'FBA',
#  '34dihydroxy2butanone4phosphatesynthase': 'DB4PS',
#  'argininosuccinatesynthase': 'ARGSS',
#  '3dehydroquinatesynthase': 'DHQS',
#  'lleucinereversibletransportviaprotonsymport': 'LEUt2r',
#  '3phosphoshikimate1carboxyvinyltransferase': 'PSCVT',
#  '3hydroxyacylcoadehydratase3hydroxytetradecanoylcoa': 'ECOAH6p',
#  'ctpsynthasenh3': 'CTPS1',
#  'acylcoalanosterolacyltransferaseyeastspecific': 'LANOSTATer_RT',
#  'mannoseinositolp2ceramideceramide226cphospholipasec': 'MIP2C226PLCg_RT',
#  'nacetylglucosamine6phosphatesynthase': 'ACGAM6PS',
#  'glutathionesynthetase': 'GTHS',
#  'guanylatecyclase': 'GUACYC',
#  'glutamatetransportuniporter': 'LYSt7m',
#  'phosphoribosylaminoimidazolesuccinocarboxamidesynthase': 'PRASCSi',
#  'utpuridine5phosphotransferase': 'UTUP',
#  'prephenatedehydrogenasenadp': 'PPND2',
#  'phosphoribosylglycinamidesynthase': 'PRAGSr',
#  'fattyacylcoasynthasenc120coa': 'FAS120COA',
#  'glutamate5semialdehydedehydrogenase': 'G5SD',
#  '5methylthioribose1phosphateisomerase': 'MTRI',
#  'cysteinesynthase': 'CYSS',
#  'glycogensynthaseudpglc': 'GLCS2',
#  'lhistidinereversibletransportviaprotonsymport': 'HISt2r',
#  'lallothreoninedehydrogenase': 'ATHRDHr',
#  'dolichylphosphatedmannosyltransferase': 'DOLPMTcer',
#  'peptidealphanacetyltransferase': 'PEPAT',
#  'cysteinetransaminase': 'CYSTA',
#  'lprolinereversibletransportviaprotonsymport': 'PROt2r',
#  '2methylacylcoadehydrogenase2methylprop2enoylcoaforming': 'ACOAD9m',
#  '25diamino6ribosylamino43hpyrimidinone5phosphatereductasenadh': 'DROPPRx',
#  'pyridoxine5phosphatephosphatase': 'PDXPP',
#  'inorganicdiphosphatase': 'PPA',
#  'phosphoribosylaminoimidazolecarboxylase': 'AIRCr',
#  'glycerolkinase': 'GLYKm',
#  'carnitineoaceyltransferase': 'CSNAT3x',
#  'nucleosidetriphosphatepyrophosphorylaseditp': 'NTPP10',
#  'purinenucleosidephosphorylasedeoxyadenosine': 'PUNP2',
#  'hemeosynthase': 'HEMEOSm',
#  'phosphatidylinositol4kinasenuclearyeastspecifc': 'PIN4Kn_RT',
#  'adenylosuccinatelyase': 'ADSL2r',
#  'nucleosidediphosphatekinaseatpdgdp': 'NDPK5',
#  'lalaninereversibletransportviaprotonsymport': 'ALAt2r',
#  'cytosinetransportinviaprotonsymport': 'CSNt2',
#  'glyceroldehydrogenasenadpdependent': 'GLYCDy',
#  'lglutaminetransportinviaprotonantiport': 'GLNt6',
#  'dihydroxyaciddehydratase23dihydroxy3methylbutanoate': 'DHAD1m',
#  'hco3equilibrationreaction': 'HCO3E',
#  'nformyllkynurenineamidohydrolase': 'FKYNH',
#  'umpkinasenuclear': 'UMPKn',
#  'inositol1345triphosphate6kinasenucleus': 'MI1345PKn',
#  'purinenucleosidephosphorylaseinosine': 'PUNP5',
#  'arginyltrnasynthetase': 'ARGTRSm',
#  'homoserinedehydrogenasenadhirreversible': 'HSDxi',
#  'tyrosinetransaminaseirreversible': 'TYRTAip',
#  'glycogenstarchsynthase': 'GLYGS',
#  'dfructose1phosphatedglyceraldehyde3phosphatelyase': 'FBA2',
#  'asparaginyltrnasynthetasemiotchondrial': 'ASNTRSm',
#  'h2otransportviadiffusion': 'H2Ot',
#  'laspartatetransportoutviaprotonsymport': 'ASPt7',
#  'adpribosediphosphatase': 'ADPRDP',
#  'phosphoribosylformylglycinamidinesynthase': 'PRFGS',
#  'adenosylmethionine8amino7oxononanoatetransaminase': 'AMAOTrm',
#  'isoleucinetransaminase': 'ILETA',
#  'phosphatidylserinesynthaseyeastspecific': 'PSERSm_RT',
#  'lphenylalaninereversibletransportviaprotonsymport': 'PHEt2r',
#  'udpnacetylglucosaminediphosphorylase': 'UDPACGLP',
#  'acetylcoaacyltransferasetetracosanoylcoa': 'ACACT9p',
#  'mannoseinositolphosphorylceramidesynthaseceramide324cyeastspecific': 'MIPCS324g_RT',
#  'asparaginesynthaseglutaminehydrolysing': 'ASNS1',
#  'episterolesterhydrolaseyeastspecific': 'EPISTESTH_RT',
#  '510methylenetetrahydrofolatereductasenadh': 'MTHFR2',
#  'alanineglyoxylateaminotransferaseirreversible': 'AGTi',
#  'sphinganinenadp3oxidoreductase': '3DSPHRer',
#  'phosphatidylinositol4kinaseyeastspecific': 'PIN4Ker_RT',
#  'pyridoxineoxidase': 'PYDXNO',
#  'farnesyltranstransferase': 'FRTT',
#  'pantothenatereversibletransportviaprotonsymport': 'PNTOt2',
#  '2dehydropantoate2reductase': 'DPR',
#  'dsorbitoldehydrogenasedfructoseproducing': 'SBTD_D2',
#  'lserinedeaminase': 'SERD_L',
#  'formaldehydedehydrogenase': 'FALDH2',
#  'llysinereversibletransportviaprotonsymport': 'LYSt2r',
#  'trehalosephosphatase': 'TRE6PP',
#  'adenosylmethioninedecarboxylase': 'ADMDC',
#  'nucleosidediphosphatekinaseatpdadp': 'NDPK8',
#  'ltyrosinereversibletransportviaprotonsymport': 'TYRt2r',
#  'alcoholdehydrogenaseglycerolnadp': 'ALCD19y',
#  'mannoseinositolphosphorylceramideceramide226cphospholipasec': 'MIPC226PLCg_RT',
#  'dfructosetransportinviaprotonsymport': 'FRUt2',
#  'aldehydedehydrogenase2methylbutanolnad': 'ALCD22xi',
#  'adenylosuccinatesynthase': 'ADSS',
#  'darabinono14lactoneoxidase': 'ARAB14LO',
#  'phosphatidylethanolaminenmethyltransferaseyeastspecific': 'PETOHMer_RT',
#  'glutathioneperidoxase': 'GTHPi',
#  'thiaminetransportinviaprotonsymport': 'THMt2',
#  'uroporphyrinogenmethyltransferase': 'UPP3MT',
#  'ribose5phosphateisomerase': 'RPI',
#  'mannoseinositolp2ceramideceramide126cphospholipasec': 'MIP2C126PLCg_RT',
#  'lserinedehydrogenase': 'LSERDHr',
#  'hydroxyethylthiazolekinase': 'HETZK',
#  'uroporphyrinogeniiisynthase': 'UPP3S',
#  'glucan14alphaglucosidase': 'GLCGSD',
#  'thymidylatesynthase': 'TMDS',
#  'xylitoldehydrogenasedxyuloseforming': 'XYLTD_D',
#  'valyltrnasynthetase': 'VALTRSm',
#  'uridinekinaseatpuridine': 'URIK1',
#  'acylcoaergosterolacyltransferaseyeastspecific': 'ERGSTATer_RT',
#  'pyridoxamine5phosphateoxidase': 'PYAM5PO',
#  'nadhdehydrogenase': 'NADH2_u9m2',
#  '3isopropylmalatedehydrogenase': 'IPMD',
#  'inositolphosphorylceramideceramide326cphospholipasec': 'IPC326PLCg_RT',
#  'chitinsynthase': 'CHTNS',
#  'mannoseinositolphosphorylceramidesynthaseceramide224cyeastspecific': 'MIPCS224g_RT',
#  'dmannosetransportinviaprotonsymport': 'MANt2',
#  'ribonucleosidediphosphatereductaseadp': 'RNDR1',
#  'acetylcoacacyltransferase': 'ACACT10m',
#  'sulfateadenylyltransferase': 'SADT',
#  '5nucleotidasecmp': 'NTD4',
#  'lipidphosphatephosphataseyeastspecific': 'LPPer_RT',
#  '5methylthio5deoxydribulose1phosphatedehydratase': 'MDRPD',
#  'cardiolipinsynthaseyeastspecific': 'CLPNSm_RT',
#  'threoninealdolase': 'THRA',
#  'fattyacylcoasynthasenc160coa': 'FAS160COA',
#  'laminoadipatesemialdehydedehydrogenasenadph': 'AASAD1',
#  'homoacontinatehydratase': 'HACONTbm',
#  'utpcytidine5phosphotransferase': 'UTCY',
#  '4aminobenzoatesynthase': 'ADCL',
#  'methylmalonatesemialdehydedehydrogenaseacylating': 'MMSAD3m',
#  'gluconokinase': 'GNK',
#  'lallothreoninealdolase': 'THRA2',
#  'squaleneepoxidaseendoplasmicreticularnad': 'SQLErx',
#  'nucleosidediphosphatekinaseatpdtdp': 'NDPK4',
#  'phosphoribosylaminoimidazolesynthase': 'PRAIS',
#  'acetylcoasynthetase': 'ACS',
#  'phosphogluconatedehydrogenase': 'GND',
#  'sulfitereductasenadph2': 'SULR',
#  'cholinetransportviaprotonsymport': 'CHLt2',
#  'ceramide3synthase26c': 'CERS326er',
#  'purinenucleosidephosphorylaseadenosine': 'PUNP1',
#  'fattyacidcoaligaseoctadecenoate': 'FACOAL181p',
#  'methionyltrnaformyltransferase': 'FMETTRSm',
#  'catalasea': 'CATp',
#  'lleucinetransportinviaprotonantiport': 'LEUt6',
#  '1dmyoinositol4phosphatephosphohydrolase': 'MI4PP',
#  'fadfmnantiport': 'FADFMNtm',
#  'sphingoidbasephosphatephosphatasesphinganine1phosphataseendoplasmicreticulum': 'SBPP1er',
#  'ethylacetatehydrolyzingesterase': 'ACHLE3',
#  'guaninereversibletransportviaprotonsymport': 'GUAt2r',
#  'lglutamatetransportoutviaprotonsymport': 'GLUt7',
#  'episterolreversibletransport': 'EPISTt',
#  'saccharopinedehydrogenasenadplglutamateforming': 'SACCD1',
#  '2isopropylmalatehydratase': 'IPPMIb',
#  'c8sterolisomerase': 'C8STIer',
#  'inositolphosphorylceramideceramide126cphospholipasec': 'IPC126PLCg_RT',
#  'phospholipasebphosphatidylinositolyeastspecificextracellular': 'PLBP1Ie_RT',
#  'atppantetheine4phosphotransferase': 'APNPT',
#  'phosphoglyceratekinase': 'PGK',
#  'ctpcmpantiport': 'CTPtm2',
#  'lornithine2oxoacidaminotransferase': 'ORNTArm',
#  'purinenucleosidephosphorylasexanthosine': 'PUNP7',
#  'adenosinekinase': 'ADNK1',
#  'cytidylatekinasecmp': 'CYTK1',
#  'ribonucleosidediphosphatereductaseudp': 'RNDR4',
#  'alphaglucosidase': 'MALT',
#  'acetylcoasynthasepropionate': 'ACS2',
#  'ctpsynthaseglutamine': 'CTPS2',
#  'orntithinereversibletransportinviaprotonsymport': 'ORNt2r',
#  'isocitratehydrolyasecisaconitateforming': 'ACONTbm',
#  'cystathionineglyase': 'CYSTGL',
#  'enoylcoahydratasec100': 'ECOAH4m',
#  '5oxoprolineamidohydrolaseatphydrolysingir': 'OPAH',
#  'phospholipasebphosphatidylcholineyeastspecific': 'PLBPC_RT',
#  'lleucinetransportoutviaprotonsymport': 'LEUt7',
#  'acyldihydroxyacetonephosphatereductaseyeastspecific': 'ADHAPRer_RT',
#  'c22steroldesaturasenadp': 'C22STDSer',
#  'saccharopinedehydrogenasenadllysineforming': 'SACCD2',
#  'phosphofructokinases7p': 'PFK_3',
#  'lisoleucinetransportinviaprotonantiport': 'ILEt6',
#  'prolyltrnasynthetase': 'PROTRS',
#  'acylcoaoxidaseoctadecanoylcoa': 'ACOAO8p',
#  'fructosebisphosphatase': 'FBP',
#  'nicotinamidenucleotideadenylyltransferase': 'NMNATn',
#  'ltryptophanoxygen23oxidoreductasedecyclizing': 'TRPO2',
#  '35bisphosphatenucleotidase': 'BPNT',
#  'inositolphosphorylceramidesynthaseceramide126cyeastspecific': 'IPCS126g_RT',
#  'aldehydedehydrogenasetryptopholnad': 'ALCD26xi',
#  'sirohydrochlorinferrochelatase': 'SHCHF',
#  'purinenucleosidephosphorylasedeoxyguanosine': 'PUNP4',
#  'methenyltetrahydrofolatecyclohydrolase': 'MTHFCx',
#  'phosphatidylinositol4phosphate5kinaseyeastspecfic': 'PI4P5Kn_RT',
#  'uridylatekinasedumpnuclear': 'URIDK2rn',
#  'dgalactosetransportinviaprotonsymport': 'GALt2',
#  '2keto4methylthiobutyratetransamination': 'UNK3',
#  'ornithinedecarboxylase': 'ORNDC',
#  'cholinekinase': 'CHOLK',
#  'mannoseinositolphosphorylceramideceramide126cphospholipasec': 'MIPC126PLCg_RT',
#  '2isopropylmalatesynthase': 'IPPS',
#  'allantoinase': 'ALLTN',
#  'nucleosidetriphosphatepyrophosphorylasextp': 'NTPP11',
#  'pyridoxal5phosphatephosphatase': 'PYDXPP',
#  'succinatefumaratetransport': 'SUCFUMtm',
#  'methylenetetrahydrofolatedehydrogenasenad': 'MTHFD2i',
#  'glycero3phospho1inositoltransportextracellulartocytosol': 'G3PIt',
#  'phenylpyruvatedecarboxylase': 'PPYRDC',
#  'aldosereductasemethylglyoxal': 'ALR2',
#  'pyruvatecarboxylase': 'PC',
#  'dlactatetransportviaprotonsymport': 'D_LACt2',
#  'glyceroltransportviachannel': 'GLYCt',
#  'glycinereversibletransportviaprotonsymport': 'GLYt2r',
#  'adenylylsulfatekinase': 'ADSK',
#  'phosphoenolpyruvatecarboxykinase': 'PPCK',
#  'taurcholateviaabcsystem': 'TCHOLAabcv',
#  'shikimatekinase': 'SHKK',
#  'lysyltrnasynthetase': 'LYSTRSm',
#  'triacylglycerollipaseyeastspecific': 'TAGL_RT',
#  'fumaratereductasecytosolic': 'FRDcm',
#  '3hydroxyacylcoadehydrogenase3oxotetradecanoylcoa': 'HACD6p',
#  'l4hydroxyglutamatesemialdehydedehydrogenase': '4HGLSDm',
#  'methylenefattyacylphospholipidsynthaseyeastspecific': 'MFAPSer_RT',
#  'aldehydedehydrogenaseindole3acetaldehydenadp': 'ALDD20y',
#  'pyridoxine5phosphateoxidase': 'PDX5POi',
#  'guaninephosphoribosyltransferase': 'GUAPRT',
#  'glutamate5kinase': 'GLU5K',
#  'mannoseinositolphosphorylceramideceramide224cphospholipasec': 'MIPC224PLCg_RT',
#  'chorismatemutase': 'CHORM',
#  'fattyacidcoaligaseoctanoate': 'FACOAL80p',
#  'lcysteine2oxoglutarateaminotransferase': 'CYSTAm',
#  'lisoleucinereversibletransportviaprotonsymport': 'ILEt2r',
#  'udpglucosehexose1phosphateuridylyltransferase': 'UGLT',
#  'itpcytidine5phosphotransferase': 'ITCY',
#  'lglutaminereversibletransportviaprotonsymport': 'GLNt2r',
#  'adeninedeaminase': 'ADD',
#  'glutaminefructose6phosphatetransaminase': 'GF6PTA',
#  'deoxyadenosinedeaminase': 'DADA',
#  'nucleosidediphosphatekinaseatpgdp': 'NDPK1',
#  'mannoseinositolphosphorylceramideceramide326cphospholipasec': 'MIPC326PLCg_RT',
#  'ceramide2synthase24cendoplasmicreticular': 'CERS224er',
#  'mannoseinositolp2ceramideceramide124cphospholipasec': 'MIP2C124PLCg_RT',
#  'enolase': 'ENO',
#  'transaconitate3methyltransferase': 'ACON3MT',
#  '3hydroxyacylcoadehydrogenase3oxooctadecanoylcoa': 'HACD8p',
#  'hexokinasedglucoseatp': 'HEX1',
#  '3mercaptopyruvatesulfurtransferase': 'MCPST',
#  'lasparaginereversibletransportviaprotonsymport': 'ASNt2r',
#  'adenosylhomocysteinase': 'ADSHm',
#  'adeninephosphoribosyltransferase': 'ADPT',
#  'acteylornithinetransaminaseirreversible': 'ACOTAim',
#  'inositolphosphorylceramidesynthaseceramide324cyeastspecific': 'IPCS324g_RT',
#  'nicotinamidenmethyltransferase': 'NNMT',
#  '3hydroxyacylcoadehydrogenase3oxohexacosylcoa': 'HACD10p',
#  'dihydroorotase': 'DHORTS',
#  'acetylcoaacyltransferasehexadecanoylcoa': 'ACACT8p',
#  'mannose1phosphateguanylyltransferase': 'MAN1PT',
#  'inositolphosphorylceramideceramide124cphospholipasec': 'IPC124PLCg_RT',
#  'peroxidasemultiplesubstrates': 'PRDX',
#  'acylcpaoxidasetetradecanoylcoa': 'ACOAO6p',
#  'acetohydroxyacidisomeroreductase': 'KARA1im',
#  'lsorbitoldehydrogenaselsorboseproducing': 'SBTD_L',
#  'aldehydedehydrogenase2methylbutanolnadp': 'ALCD22yi',
#  'deaminonadnucleotidohydrolase': 'DNADDP',
#  'succinatecoaligaseadpforming': 'SUCOASm',
#  'threoninesynthase': 'THRS',
#  'sphingoidbasephosphatephosphatasephytosphingosine1phosphateendoplasmicreticulum': 'SBPP2er',
#  'umpkinase': 'UMPK',
#  'pyridoxalkinase': 'PYDXK',
#  'dihydroneopterinmonophosphatedephosphorylase': 'DNMPPA',
#  'mannoseinositolp2ceramideceramide326cphospholipasec': 'MIP2C326PLCg_RT',
#  'acylcoaoxidasehexadecanoylcoa': 'ACOAO7p',
#  'acylcoafecosterolacyltransferaseyeastspecific': 'FECOSTATer_RT',
#  'acetaldehydecondensation': 'ACALDCD',
#  'sadenosyllmethioninereversibletransport': 'AMETt2m',
#  'ceramide1hydroxylase24c': 'CERH124er',
#  'orotidine5phosphatedecarboxylase': 'OMPDC',
#  'lysophosphatidylcholineacyltransferaseacyltransferaseyeastspecific': 'LPCATer_RT',
#  'inositol1456tetrakisphosphate3kinasenucleus': 'MI1456PKn',
#  'inositolphosphorylceramidesynthaseceramide326cyeastspecific': 'IPCS326g_RT',
#  'xanthinephosphoribosyltransferase': 'XPPT',
#  '3hydroxyacylcoadehydratase3hydroxydecanoylcoa': 'ECOAH4p',
#  'riboflavinkinase': 'RBFK',
#  'nucleosidediphosphatekinaseatpdudp': 'NDPK6',
#  'isocitratelyase': 'ICLp',
#  'nicotinicacidtransport': 'NACt',
#  'imidazoleacetaldeydedehydrogenase': 'IMACTD',
#  '3hydroxybutanoylcoahydrolyase': 'ECOAH1m',
#  'sedoheptulose17bisphosphatedglyceraldehyde3phosphatelyase': 'FBA3',
#  '3isopropylmalatedehydratase': 'IPPMIa',
#  'ribosylnicotinamidekinase': 'RNMK',
#  'sulfateadenylyltransferaseadp': 'SLFAT',
#  'glycerol3phosphateacyltransferaseglycerol3phosphateyeastspecific': 'GAT1er_RT',
#  'threonyltrnasynthetase': 'THRTRSm',
#  'hydroxypyruvatereductasenadp': 'HPYRRy',
#  '3hydroxyanthranilate34dioxygenase': '3HAO',
#  'mannoseinositiolphophorylceramidesynthaseceramide124cyeastspecific': 'MIPCS124g_RT',
#  'nicotinatenucleotideadenylyltransferase': 'NNATm',
#  'tryptophansynthaseindoleglycerolphosphate': 'TRPS1',
#  '1phosphatidylinositol45bisphosphatephosphodiesteraseyeastspecific': 'PI45BPPn_RT',
#  'cytosinedeaminase': 'CSND',
#  'lserinereversibletransportviaprotonsymport': 'SERt2r',
#  'maltosetransportinviaprotonsymport': 'MALTt2',
#  'dephosphocoakinase': 'DPCOAK',
#  'isopentenyldiphosphatedisomerase': 'IPDDI',
#  'phosphatidylinositol3phosphate5kinaseyeastspecfic': 'PI3P5Kn_RT',
#  'galactose1phosphateuridylyltransferase': 'GALT',
#  'poylamineoxidase': 'POLYAO2',
#  'dutpcytidine5phosphotransferase': 'DUTCP',
#  'lalaninetransaminase': 'ALATA_Lm',
#  'c3steroldehydrogenasezymosterol': 'C3STDH2er',
#  'acetylcoahydrolasemitochondrialirreversible': 'ACOAHim',
#  'gdpmannoseantiport': 'GDPMANNtg',
#  'ribonucleosidediphosphatereductasecdp': 'RNDR3',
#  'sperminetransportviaprotonantiportirreversible': 'SPRMt2i',
#  'hypotheticalenyme': 'HYPOE',
#  'atpcytidine5phosphotransferase': 'CYTDK1',
#  'imidazoleglycerolphosphatedehydratase': 'IGPDH',
#  'hydroxymethylpyrimidinekinaseatp': 'HMPK1',
#  'fattyacidcoaligasenc240': 'FACOAL240p',
#  'acylcoaoxidasehexacanoylcoa': 'ACOAO9p',
#  'sulfitetransporteffluxcytosoltoextracellular': 'SO3ti',
#  'alphaalphatrehalosephosphatesynthaseudpforming': 'TRE6PS',
#  'utpglucose1phosphateuridylyltransferaseirreversible': 'GALUi',
#  'diphosphomevalonatedecarboxylase': 'DPMVD',
#  'carbamoylphosphatesynthaseglutaminehydrolysing': 'CBPS',
#  'dttpuridine5phosphotransferase': 'DTTUP',
#  'fattyacidcoaligasedecanoate': 'FACOAL100p',
#  'glutarylcoadehydrogenase': 'GLUTCOADHm',
#  'zymosterolesterhydrolaseyeastspecific': 'ZYMSTESTH_RT',
#  'kynurenine3monooxygenase': 'KYN3OX',
#  'uridinekinaseitpuridine': 'URIK3',
#  'cystathioninebetasynthase': 'CYSTS',
#  'methylamineoxygenoxidoreductasedeaminatingcoppercontaining': 'MAOX',
#  'aldehydedehydrogenaseisoamylalcoholnadp': 'ALCD24yi',
#  'formatedehydrogenase': 'FDH',
#  'nicotinatedribonucleotidesynthaseatp': 'NICRNS',
#  '5methylthioadenosinephosphorylase': 'MTAP',
#  'catalase': 'CATm',
#  'succinatetransport': 'SUCCtm',
#  'orotatephosphoribosyltransferase': 'ORPT',
#  'ceramide2synthase26cendoplasmicreticular': 'CERS226er',
#  'uridinekinasegtpuridine': 'URIK2',
#  'isocitratedehydrogenasenad': 'ICDHxm',
#  'lhydroxyprolinereductasenad': 'HPROa',
#  'allantoinirreversibleuniport': 'ALLTNti',
#  'sphingolipidlongchainbasekinasesphinganine': 'SLCBK1er',
#  '6phosphofructo2kinase': 'PFK26',
#  'dutpdiphosphatase': 'DUTPDPm',
#  'fattyacylcoasynthasenc100coa': 'FAS100COA',
#  '3hydroxyacylcoadehydratase3hydroxyoctadecanoylcoa': 'ECOAH8p',
#  'glycero3phosphocholinetransportextracellulartocytosol': 'G3PCt',
#  'lglutaminetransportoutviaprotonsymport': 'GLNt7',
#  'laspartatereversibletransportviaprotonsymport': 'ASPt2r',
#  'glucose6phosphateisomerase': 'PGI',
#  'glycinecleavagesystem': 'GLYCLm',
#  'phosphatereversibletransportviasymport': 'PIt2r',
#  'chorismatesynthase': 'CHORS',
#  'anthranilatephosphoribosyltransferase': 'ANPRT',
#  'glycerophosphodiesterphosphodiesteraseglycerophosphocholine': 'GPDDA1',
#  'nacteylglutamatesynthase': 'ACGSm',
#  'glutamatesynthasenadh2': 'GLUSx',
#  '3deoxydarabinoheptulosonate7phosphatesynthetase': 'DDPA',
#  'mannose6phosphateisomerase': 'MAN6PI',
#  's3hydroxybutanoylcoanadoxidoreductase': 'HACD1p',
#  'isoamylacetatehydrolyzingesterase': 'ACHLE1',
#  'hemeomonooxygenase': 'HEMEASm',
#  'aconitase': 'ACONT3m',
#  'anthranilatesynthase': 'ANS',
#  'allantoateirreversibleuniport': 'ALLTTti',
#  'hnrnpargininenmethyltransferase': 'ARMT',
#  'gtpcyclohydrolaseii': 'GTPCII',
#  '3hydroxypropionylcoahydrolyase': 'PRPNCOAHYDm',
#  'succinatedehydrogenaseubiquinone6': 'SUCD2_u9m',
#  'glutaminephosphoribosyldiphosphateamidotransferase': 'GLUPRT',
#  'malatesynthase': 'MALSp',
#  'aldehydedehydrogenaseacetaldehydenadp': 'ALDD2y',
#  'histidinoldehydrogenase': 'HISTD',
#  'pyridoxal5phosphatesynthase': 'PYDXS',
#  'ketolacidreductoisomerase2aceto2hydroxybutanoate': 'KARA2im',
#  'hydroxymethylglutarylcoareductase': 'HMGCOAR',
#  'inositol145trisphosphate3kinasenucleus': 'MI145PKn',
#  'gammalinolenicacidcoaligaseampforming': 'FACOAL1831p',
#  'ap4ahydrolase': 'AP4AH',
#  'ribonucleosidediphosphatereductasegdp': 'RNDR2',
#  'llactatereversibletransportviaprotonsymport': 'L_LACt2r',
#  'guaninedeaminase': 'GUAD',
#  'indole3pyruvatedecarboxylase': 'INDPYRD',
#  '4methyl2oxopentanoatedecarboxylase': '4MOPDC',
#  'lanosterolsynthase': 'LNSTLSr',
#  '1phosphatidylinositol45bisphosphate5phosphataseyeastspecific': 'PIN3Pn_RT',
#  'aspartateaminotransferasecysteateforming': 'LCYSTATm',
#  'argininosuccinatelyase': 'ARGSL',
#  'acylcoazymosterolacyltransferaseyeastspecific': 'ZYMSTATer_RT',
#  'fumarase': 'FUMm',
#  'mannoseinositolphosphorylceramidesynthaseceramide126cyeastspecific': 'MIPCS126g_RT',
#  'ceramide1synthase24cendoplasmicreticular': 'CERS124er',
#  'utpumpantiport': 'UTPtm2',
#  'purinenucleosidephosphorylase': 'PNP',
#  '3hydroxyacylcoadehydratase3hydroxydodecanoylcoa': 'ECOAH5p',
#  'homogentisateoxygen12oxidoreductasedecyclizing': 'HGNTOR',
#  'aldehydedehydrogenaseisobutylalcoholnad': 'ALCD23xi',
#  'lglutamate5semialdehydenadoxidoreductasearginineandprolinemetabolismec15112': 'G5SADm',
#  'malicenzymenad': 'ME1m',
#  'fructose26bisphosphate2phosphatase': 'FBP26',
#  '1dmyoinositol3phosphatephosphohydrolase': 'MI3PP',
#  'homoserinedehydrogenasenadph': 'HSDy',
#  '3hydroxyacylcoadehydratase3hydroxyhexacosylcoa': 'ECOAH11p',
#  'glucosetransportuniport': 'GLCt1',
#  'enoylcoahydratasec160': 'ECOAH7m',
#  'asparaginyltrnasynthetase': 'ASNTRS',
#  'adentylatekinaseitp': 'ADK4m',
#  'ltryptophanreversibletransportviaprotonsymport': 'TRPt2r',
#  'phosphopentomutase': 'PPM',
#  'ergosterolesterhydrolaseyeastspecific': 'ERGSTESTH_RT',
#  'hydrogenperoxidereductasethioredoxin': 'THIORDXi',
#  '510methylenetetrahydrofolatereductasenadph': 'MTHFR3',
#  'peptidetransportinviaprotonsymport': 'PEPDt3',
#  'ornithinetransaminase': 'ORNTA',
#  'purinenucleosidephosphorylasedeoxyinosine': 'PUNP6',
#  'sulfateirreversibleuniport': 'SO4ti',
#  'nacetylgglutamylphosphatereductaseirreversible': 'AGPRim',
#  '3mercaptopyruvatecyanidesulfurtransferase': 'HMR_6515',
#  'glutaminesynthetase': 'GLNS',
#  'uroporphyrinogendecarboxylaseuroporphyrinogeniii': 'UPPDC1',
#  'formatetetrahydrofolateligasemitochondrialirreversible': 'FTHFLmi',
#  'methylisocitratelyase': 'MCITL2m',
#  'pantothenatesynthase': 'PANTS',
#  'fattyacidcoaligaseoctadecanoate': 'FACOAL180p',
#  'hydroxymethylbilanesynthase': 'HMBS',
#  'acetylcoacarboxylase': 'ACCOAC',
#  'squaleneepoxidaseendoplasmicreticularnadp': 'SQLEr',
#  'lhistidinetransportinviaprotonantiport': 'HISt6',
#  'fumarylacetoacetase': 'FUMAC',
#  '2aceto2hydroxybutanoatesynthase': 'ACHBSm',
#  'atpphosphoribosyltransferase': 'ATPPRT',
#  'methionineadenosyltransferase': 'METAT',
#  'mannosyloligosaccharide12alphamannosidaseasnglcnacglcnacmanmanmanmanmanmanmanman': 'MM3',
#  'linoleoylcoahydrolase1829z12z': 'FACOAE1829Z12Z',
#  'lmethioninersulfoxidereductase': 'METSOXR2',
#  'fattyacidcoathioesterasedecanoate': 'FACOAE100',
#  'isc4fe4stransfer': 'I4FE4STm',
#  'udpnacetyldmannosamineoxidoreductase': 'UACMAMO',
#  'fattyacidcoathioesterasetetradecanoate': 'FACOAE140',
#  'succinyldiaminopimelatetransaminase': 'SDPTA',
#  'dfructose6phosphatephosphatase': 'F6PP',
#  'dolichylphosphatebetaglucosyltransferase': 'UDPDOLPT',
#  'trans2enoylcoareductasenadphc120': 'ACOAR5m',
#  'xylulokinase': 'XYLK',
#  'alphaamylase': 'AAMYLASE',
#  'adenosine35phosphate5nucleotidohydrolasenucleus': 'APNn',
#  'udpglucuronatec4decarboxylase': 'UDPGDC',
#  'lipoyloctanoyltransferase': 'LIPOCTm',
#  'nucleobasetransportthioguanineextracellular': 'TGUAt',
#  'alpha12mannosyltransferasedoldpglcnacglcnacmanmanmanmanmanmanman': 'G12MT3',
#  'glucose6phosphatephosphatase': 'G6PP',
#  'nadhxdehydratase': 'NADHXD2',
#  'voltagesensitivenachannel': 'NA1tm',
#  '2oalphamannosyl6phosphatedglyceratehydrolase': 'MANPGH',
#  'udplara4nformyltransferase': 'ULA4NFT',
#  'betainelipidsynthase3amino3carboxypropyltransferase1819z1819z': 'ACPT1819Z1819Z',
#  'butanolsynthase': 'BTS',
#  'equilibrativenucleosidetransporter': 'ADNtm',
#  'malonicsemialdehydereductase': 'MSAR',
#  'malonylcoamethyltransferase': 'MALCOAMT',
#  'aldehydedehydrogenasepropanalnadp': 'ALDD3y',
#  'phosphogluconatephosphatase': 'GNP',
#  'maltodextrinphosphorylasemaltohexaose': 'MLTP2',
#  'spermidineprotonantiporterreversible': 'SPMDtmr',
#  'cyanidesulfurtransferase': 'CYANST',
#  'nucleosidetriphosphatepyrophosphorylasedgtp': 'NTPP1',
#  '3phosphohydroxypyruvatephosphatase': 'HPYRP',
#  'acetatekinase': 'ACKr',
#  'fattyacidcoathioesteraseoctadecanoate': 'FACOAE180',
#  'bis5adenosyltriphosphatase': 'BTP',
#  'betaalaninedipeptidase': 'BADP',
#  '7hydroxysteroiddehydrogenase': 'CHOLID',
#  'pyridoxinenadp4oxidoreductase': 'PYDXOR',
#  'ureidoglycolatehydrolase': 'UGLYCH',
#  '56dihydro5fluorouracilamidohydrolase': '56DH5FLURAAMH',
#  'isc2fe2ssynthesisii': 'I2FE2SS2m',
#  '25diketodgluconatereductase': 'DKGLCNR1',
#  '34dihydroxyphenylacetateametomethyltransferase': '34DHPHAMT',
#  'aminophospholipidtranslocasepgp1819z160extracellular': 'PGP1819Z160t',
#  'exo13betaglucanglucohydrase': '13BGHe',
#  'lacaldehydereductasespropane12diolforming': 'LCARSyi',
#  'trehalose6phosphatehydrolase': 'TRE6PH',
#  'acetylcoaacetylcoacacetyltransferase': 'ACACT1p',
#  '3hydroxycinnamatehydroxylase': '3HCINNMH',
#  'isc2fe2ssynthesis': 'I2FE2SSm',
#  'dihydropteroatesynthase': 'DHPS2',
#  'uroporphyrinogendecarboxylaseuroporphyrinogeni': 'UPPDC2',
#  'nadphdependentdihydrocurcuminreductase': 'DHCURR',
#  'fattyacidcoathioesterasehexadecenoate': 'FACOAE161',
#  'hemecligase': 'HEMELm',
#  'formamidase': 'FORA',
#  'uratepermease': 'URATEt_1',
#  'glyceratekinase': 'GLYCK',
#  'lipoyladenylateproteinligase': 'LIPAMPLm',
#  'udpglcnacdolichylphosphatenacetylglucosaminephosphotransferase': 'GLCNACPT',
#  'thiaminphosphataseextracellular': 'THMPe',
#  'cuexportingatpase': 'Cu1ATPase',
#  'formyltetrahydrofolatedeformylase': 'FTHFD',
#  'gammalinolenoylcoahydrolase1836z9z12z': 'FACOAE1836Z9Z12Z',
#  'glutaredoxinreductase': 'GRXRm',
#  'dtdp4dehydrorhamnosereductase': 'TDPDRR',
#  'glucan13alphaglucosidaseasnglcnacglcnacmanmanmanmanmanmanmanmanmanglca': 'MG3A',
#  'glycerophosphodiesterphosphodiesteraseglycerophosphoethanolamine': 'GPDDA2',
#  'nucleosidetriphosphatepyrophosphorylasegtp': 'NTPP2',
#  'acetylcoaoxalatecoatransferase': 'ACOXT',
#  'aminophospholipidtranslocasepe1819z1819zextracellular': 'PE1819Z1819Zt',
#  'aminophospholipidtranslocasepail1819z160extracellular': 'PAIL1819Z160t',
#  'phenylhydantoinase': 'PHDA',
#  'betainelipidsynthasetrimethylase1601819z': 'TM1601819Z',
#  'purinenucleosidephorphoramidase': 'PNSPA',
#  'acetamidase': 'AMID_1',
#  'trans2enoylcoareductasenadphc140': 'ACOAR6m',
#  'adenosine5phosphosulfatereductase': 'APSR',
#  '6mercaptopurinephosphoribosyltransferase': '6MPURPRT',
#  'ethanolaminekinase': 'ETHAK',
#  'nadhhydratase': 'NADHHR',
#  'chitobiosyldiphosphodolicholbetamannosyltransferase': 'BDMT',
#  '5dehydrodgluconatereductase': '5DGLCNR',
#  'acylcoadehydrogenasehexanoylcoa': 'ACOAD2p',
#  'mannosyloligosaccharide12alphamannosidaseasnglcnacglcnacmanmanmanmanman': 'MM1',
#  'fattyacidcoathioesteraseoctanoate': 'FACOAE80',
#  'fattyacidcoathioesteraseoctadecenoate': 'FACOAE181',
#  'isccysteinedesulfuration': 'ICYSDSm',
#  'isc2fe2sregeneration': 'I2FE2SRm',
#  'enoylcoahydratasec60': 'ECOAH2m',
#  '1acylglycerolacylhydrolase160': 'MAGAH160',
#  'aminophospholipidtranslocasepg1819z160extracellular': 'PG1819Z160t',
#  '6thioinosine5monophosphatenadoxidoreductase': '6TINS5MPOR',
#  '3hydroxybutanoatenadoxidoreductase': 'BDHm',
#  'acylcoadehydrogenasebutanoylcoa': 'ACOAD1m',
#  'cyanateaminohydrolase': 'CYNTAH',
#  'trans2enoylcoareductasenadphc100': 'ACOAR4m',
#  'arabinose5phosphateisomerase': 'A5PISO',
#  'nucleobasetransportfluorouracilextracellular': '5FLURAt',
#  'glyoxylatereductasenad': 'GLYCLTDxm',
#  'glycerophosphodiesterphosphodiesteraseglycerophosphoserine': 'GPDDA3',
#  'ribose5phosphatephosphatase': 'R5PP',
#  'shydroxyoctanoylcoanadoxidoreductase': 'HACD3p',
#  'alphaalphatrehalaseglca': 'AATHA',
#  'dolichylphosphatebetadmannosyltransferase': 'DOLPMT',
#  'betainelipidsynthase3amino3carboxypropyltransferase1601819z': 'ACPT1601819Z',
#  'folatereductase': 'FOLR2_1',
#  'spermidineacetyltransferase': 'SPMDAT1',
#  'glycinecacetyltransferase': 'GLYATm',
#  'dihydrofolatereductase': 'DHFRim',
#  'carboxylicaciddissociation': 'H2CO3D',
#  'sulfatetransportinviaprotonsymport': 'SO4t2',
#  'ornithinetransacetylase': 'ORNTAC',
#  'phosphoribosylanthranilateisomeraseirreversible': 'PRAIi',
#  'lipoateatpadenylatetransferase': 'LIPATPTm',
#  'glycerol3phosphatedehydrogenasefad': 'G3PD_u9cm',
#  'udpdgalactosenad6oxidoreductase': 'UDPGALOR',
#  'glucose1phosphatase': 'G1PP',
#  'dserinedehydrogenase': 'DSERDHr',
#  'hydroxypyruvatereductasenad': 'HPYRRx',
#  'transtranscisgeranylgeranyldiphosphatesynthase': 'FT',
#  'hydrogencarbonatelglutamineamidoligase': 'CBPSm',
#  'trans2enoylcoareductasenadphc160': 'ACOAR7m',
#  'glucan13alphaglucosidaseasnglcnacglcnacmanmanmanmanmanmanmanmanmanglcb': 'MG3B',
#  'nacetylglutamatesynthase': 'ACGS',
#  'aldose1epimerase': 'A1E',
#  'nadhxepimerase': 'NADHXE',
#  'formamidaseglyoxysomal': 'FORAMDx',
#  'mannosyloligosaccharide1316alphamannosidaseasnglcnacglcnacmanmanman': 'MM2',
#  'mannosyloligosaccharideglucosidaseasnglcnacglcnacmanmanmanmanmanmanmanmanmanglcglcglcb': 'MG1B',
#  'betainelipidsynthasetrimethylase1819z1819z': 'TM1819Z1819Z',
#  'nadphdependentcurcuminreductase': 'CURR',
#  'erythrose4phosphatephosphatase': 'E4PP',
#  'gudbutnah': 'GUDBUTNAH',
#  '1acylglycerolacylhydrolase180': 'MAGAH180',
#  'nucleobasetransport6mercaptopurineextracellular': '6MPURt',
#  'ribulose5phosphatephosphatase': 'RU5PP',
#  'ralphahydroxyglutaratedehydrogenase': 'GHBTRHDm',
#  'inositol13456pentakisphosphate2kinasenuclear': 'MI13456PKn',
#  'phosphatetransportnuclear': 'PItn',
#  '3oxoadipateenollactonehydrolase': 'OXOAEL',
#  '5ketodgluconate5reductase': '5DKGR',
#  'fattyacidcoathioesterasehexanoate': 'FACOAE60',
#  'nicotinicacidmononucleotidepyrophosphorylase': 'NAMNPP',
#  'glycerophosphodiesterphosphodiesteraseglycerophosphoglycerol': 'GPDDA4',
#  'shydroxyhexanoylcoahydrolyase': 'ECOAH2p',
#  'tryptophansynthaseindole': 'TRPS2',
#  'maltodextrinphosphorylasemaltopentaose': 'MLTP1',
#  'urateoxidase': 'URO',
#  'serinedecarboxylase': 'SERDC',
#  'ferrousironuptakegtpdependentplasmamembrane': 'FE2GTPabc',
#  'dolichyldiphosphooligosaccharideproteinglycotransferase': 'DOLASNT',
#  '10formyltetrahydrofolatelglutamateligaseadpforming': '10FTHFGLULLm',
#  'ferricironuptakeplasmamembrane': 'FE3t',
#  'udplarabinose4epimerase': 'UA4E',
#  '1acylglycerolacylhydrolase1819z': 'MAGAH1819Z',
#  'aminophospholipidtranslocasepe1801829z12zextracellular': 'PE1801829Z12Zt',
#  'lipoatesynthase': 'LIPOSm',
#  'nadphxdehydratase': 'NADPHXD2',
#  'alpha12mannosyltransferasedoldpglcnacglcnacmanmanmanmanmanmanmanmanman': 'G12MT4',
#  'h2otransport': 'H2Otm',
#  'dihydooroticacidubiquinone6irreversible': 'DHORD_u9m',
#  '6thioxanthine5monophosphatelglutamineamidoligase': '6TXAN5MPAML',
#  'nacetylgglutamylphosphatereductase': 'AGPR',
#  'alpha16mannosyltransferasedoldpglcnacglcnacmanmanman': 'G16MT',
#  'shydroxyhexanoylcoanadoxidoreductase': 'HACD2p',
#  'thioguaninephosphoribosyltransferase': 'TGUAPRT',
#  'fattyacidcoathioesterasedodecanoate': 'FACOAE120',
#  'fattyacidcoathioesterasehexadecanoate': 'FACOAE160',
#  'acireductonedioxygenase': 'ACDO',
#  'isc4fe4sreduction': 'I4FE4SRm',
#  'trans2enoylcoareductasenadphc60': 'ACOAR2m',
#  'dfructose1phosphatephosphatase': 'F1PP',
#  'cholinedehydrogenase': 'CHOLD',
#  'superoxidedismutase': 'SPODMm',
#  'ammoniaperoxisomaltransport': 'NH4tp',
#  'aminophospholipidtranslocasepe1819z1829z12zextracellular': 'PE1819Z1829Z12Zt',
#  'acylcarrierproteinsynthase': 'ACPS1',
#  'enoylcoahydratasec80': 'ECOAH3m',
#  'glycinetrnaligase': 'GLYTLm',
#  '5diphosphoinositol12346pentakisphosphatesynthase': 'PMI12346PSn',
#  'mannosyloligosaccharideglucosidaseasnglcnacglcnacmanmanmanmanmanmanmanmanmanglcglcglca': 'MG1A',
#  'lseryladenylatesynthase': 'SERASr',
#  'spermidineacetyltransferasen8': 'SPMDAT2',
#  'aminophospholipidtranslocasepe1801819zextracellular': 'PE1801819Zt',
#  'nucleobasetransporttegafurextracellular': 'TEGAt',
#  'nucleosidetriphosphatepyrophosphorylasedttp': 'NTPP7',
#  'hexanoylcoaacetylcoacacyltransferase': 'ACACT3p',
#  'alpha12mannosyltransferasedoldpglcnacglcnacmanmanmanmanman': 'G12MT2',
#  'octanoatenonlipoylatedapodomainligase': 'OCTNLLm',
#  'glucan13alphaglucosidaseasnglcnacglcnacmanmanmanmanmanmanmanmanmanglcglcb': 'MG2B',
#  'nadphxepimerase': 'NADPHXE',
#  'glycerol2phosphatephosphatase': 'G2PP',
#  'alcoholdehydrogenaseglycerol': 'ALCD19',
#  'biotinsynthase': 'BTS5m',
#  'butanolsynthasenadph': 'BTS_nadph',
#  ...}

# %%
# here we create two lists that have the model IDs from the sce scaffold and the modified reaction names. 

# holders for the names and IDs.
temp = []
temp2 = []
model_temp_id_sce = []

# iterate through the sce modified reaction names. 
for i,r in enumerate(sce_rxns_name):
    
    # check if the modified sce modified reaction name matches the model modified reaction name. 
    if r in model_rxns_name:
        
        # append the modified reaction name to temp.
        temp.append(r)
        
        # append the reaction _id to temp 2. 
        temp2.append(_id[i])
        
        # append the Lst model reaction ID that corresponds to the reaction name
        model_temp_id_sce.append(model_dict_sce[r])

# output should be 110 and 102. 
print(len(temp),len(temp2))
print(len(set(temp)))
# Out:
# 110 110
# 102

# %%
# create a dictionary of the modified reaction names to the model reaction IDs.

# dictionary of modified reaction names to the model reaction ID. 
sce_additional_rxns_toModel = dict(zip(temp,model_temp_id_sce))

# dictionary of modified reaction names to the sce GSM reaction ID. 
sce_additional_rxns = dict(zip(temp,temp2))

# %% [markdown]
# ### Repeat this process for *Y. lipolytica* GSM.
#
# Determine reactins in ylip that share names with the model reactions, but have diferent IDs.

# %%
# output the ortholog from Ylip to csv to validate reactions
_names = []
_gpr = []
_id = []
_stoich = []
_subsystem = []

# gather the reaction details from the possible ortholog reactions. 
for rx in ylip_ortholog_available:
    r = ylip.reactions.get_by_id(rx)
    _names.append(r.name)
    _gpr.append(r.gene_reaction_rule)
    _id.append(r.id)
    _stoich.append(r.reaction)

# store the ylip GSM names here. 
ylip_rxns_name = _names

# %%
# gather the reaction names in the model.
# note - this variable name is re-used from the sce section and will be overwritten by running this cell. 
model_rxns_name = model.reactions
model_rxns_name = [x.name for x in model_rxns_name]

# %%
# replace naming conventions that can be 'messy'. 
model_rxns_name = [re.sub(r' c$',"",x) for x in model_rxns_name]
model_rxns_name = [re.sub(r' v$',"",x) for x in model_rxns_name]
model_rxns_name = [x.replace(" ","").replace('-','').replace(':',"").replace(',',"").replace(')',"").replace(')',"").replace('\'',"").replace('+',"").replace('mitochondrialmembrane',"").lower() for x in model_rxns_name]

model_rxns_name = [re.sub(r'[^a-zA-Z0-9]', '', x) for x in model_rxns_name]

model_rxns_name = [x.replace('vacuolar',"").replace('vacuolarmembrane',"") for x in model_rxns_name]
model_rxns_name = [re.sub(r'mitochondrial$',"",x) for x in model_rxns_name]
model_rxns_name = [re.sub(r'mitochondria$',"",x) for x in model_rxns_name]
model_rxns_name = [re.sub(r'cellenvelope$',"",x) for x in model_rxns_name]
model_rxns_name = [re.sub(r'cytoplasm$',"",x) for x in model_rxns_name]
model_rxns_name = [re.sub(r'cytoplasmic$',"",x) for x in model_rxns_name]

model_rxns_name = [re.sub(r'peroxisomal$',"",x) for x in model_rxns_name]
model_rxns_name = [re.sub(r'cytoplasmic$',"",x) for x in model_rxns_name]

# sce_rxns_name = [x.replace('mitochondrialmembrane',"").replace('golgimembrane',"").replace('ermembrane',"") for x in sce_rxns_name]

# %% [markdown]
# replace the ylip naming conventions that can be 'messy'.

# %%
ylip_rxns_name = [re.sub(r' c$',"",x) for x in ylip_rxns_name]
ylip_rxns_name = [re.sub(r' v$',"",x) for x in ylip_rxns_name]

ylip_rxns_name = [x.replace(" ","").replace('-','').replace(':',"").replace(',',"").replace(')',"").replace(')',"").replace('\'',"").replace('+',"").replace('mitochondrialmembrane',"").lower() for x in ylip_rxns_name]

ylip_rxns_name = [re.sub(r'[^a-zA-Z0-9]', '', x) for x in ylip_rxns_name]

ylip_rxns_name = [x.replace('mitochondrialmembrane',"").replace('golgimembrane',"").replace('ermembrane',"") for x in ylip_rxns_name]
ylip_rxns_name = [x.replace('cellenvelopecytoplasm',"").replace('vacuolarmembrane',"") for x in ylip_rxns_name]
ylip_rxns_name = [re.sub(r'mitochondrial$',"",x) for x in ylip_rxns_name]
ylip_rxns_name = [re.sub(r'mitochondria$',"",x) for x in ylip_rxns_name]
ylip_rxns_name = [re.sub(r'cellenvelope$',"",x) for x in ylip_rxns_name]
ylip_rxns_name = [re.sub(r'cytoplasm$',"",x) for x in ylip_rxns_name]
ylip_rxns_name = [re.sub(r'cytoplasmic$',"",x) for x in ylip_rxns_name]

# sce_rxns_name = [x.replace('mitochondrialmembrane',"").replace('golgimembrane',"").replace('ermembrane',"") for x in sce_rxns_name]

# %% [markdown]
# 260 reactions have orthologs in the ylip model.

# %%
# length of reactions with orthologs only in the ylip model.
len(ylip_rxns_name)
# Out:
# 260

# %%
# create dictionary of the replaced model reaction names to the reaction IDs. 
model_dict = dict(zip(model_rxns_name,model_rxns_id))

# %%
# here we create two lists that have the model IDs from the sce scaffold and the modified reaction names. 

# holders for the names and IDs.
temp = []
temp2 = []
model_temp_id = []

# iterate through the ylip modified reaction names. 
for i,r in enumerate(ylip_rxns_name):

    # check if the modified sce modified reaction name matches the model modified reaction name. 
    if r in model_rxns_name:

        # append the reaction _id to temp 2. 
        temp.append(r)
        
        # append the reaction _id to temp 2. 
        temp2.append(_id[i])
        
        # append the Lst model reaction ID that corresponds to the reaction name
        model_temp_id.append(model_dict[r])

print(len(temp),len(temp2))
print(len(set(temp)))
# Out:
# 108 108
# 101

# %%
# create a dictionary of the modified reaction names to the model reaction IDs. 

# dictionary of modified reaction names to the model reaction ID. 
ylip_additional_rxns_toModel = dict(zip(temp,model_temp_id))

# dictionary of modified reaction names to the sce GSM reaction ID. 
ylip_additional_rxns = dict(zip(temp,temp2))

# %%
# create a dictionary of the modified reaction names to the ylip GSM reaction IDs. 

ylip_additional_rxns = dict(zip(temp,temp2))

# %%
ylip_additional_rxns['isocitratelyase']
# Out:
# 'ICL'

# %%
# this cell contains a modified function that was previously used to compare three lists. 
# this cell instead will take two lists of genes and determine if any of the genes overlap or are unique.
# the function returns the unique genes. 

# definition to compare the genes in common reactions. 
def compare_two_lists(list1, list2):

    # Convert lists to sets.
    set1, set2 = set(list1), set(list2)
    
    # Find all intersections and differences.
    common_all = set1 & set2
        
    only_1 = set1 - set2
    only_2 = set2 - set1
    
    all_diff = (set1 | set2 ) - common_all - only_1 - only_2
    
    # Construct verbose explanation.
    explanation = {}

    
    explanation['common_all'] = list(common_all)

    explanation['only_1'] = list(only_1)
    explanation['only_2'] = list(only_2)
    explanation['all_diff'] = list(all_diff)
    
    
    return explanation

# %% [markdown]
# ## This section uses the collected reaction names and modifies the Lst model GPR as needed.
# following cell updates the model GPR for overlapping reactions in ylip.

# %%
# this cell updates the model GPR with the overlapping ylip reactions. 

# storage lists. 
# gene overlap in the ylip orthologs and the model genes for each reaction. 
_names = []
_gpr_sce = []
_gpr_ylip = []
_gpr_model = []

_lst_model_gene = []
_lst_sce_gene = []
_lst_ylip_gene = []

_id = []
_stoich = []
_subsystem = []
_lst_gene = []
_ylip_gene = []


consensus = []
consensus_count = []
consensus_source = []
_output = []


_common_all = []
_only_1 = []
_only_2 = []
_all_diff = []

# iterate through the modified reaction names that are in ylip and the Lst model. 
for rx in list(ylip_additional_rxns.keys()):
    
    # get actual GSM IDs.
    model_rx = ylip_additional_rxns_toModel[rx]
    ylip_rx = ylip_additional_rxns[rx]
    
    # obtain the reaction objects.
    m = model.reactions.get_by_id(model_rx)
    y = ylip.reactions.get_by_id(ylip_rx)
    
    # obtain the reaction GPRs.
    _gpr_model = (m.gene_reaction_rule)
    _gpr_ylip = (y.gene_reaction_rule)
    
#     # check. 
#     if y.id == 'ICL':
#         print(_gpr_ylip,_gpr_model)

    # obtain the reaction meta data.
    _names.append(m.name)
    _id.append(m.id)
    _stoich.append(m.reaction)
    _subsystem.append(m.subsystem)
    
    ## to do - insert check to make sure not adding multiple GPRs. 
    
    # Lst model current GPR.
    temp1 = []
    for g in m.genes:
        temp1.append(g.id)
    _lst_model_gene.append(temp1)
    if y.id == 'ICL':
        print(temp1)

    
    # ylip genes. 
    temp3 = []
    gpr = y.genes
    
    # iterate over each individual gene. 
    for i in range(len(gpr)):
        g=list(gpr)[i]

        # examine lst_orthologs. 
        if g.id in ylip_dict_keys:

            # obtain the lst gene ortholog.
            value = lst_ylip_dict[g.id]

            # check if the ortholog is blank. 
            if value:
                temp3.append(value)
#                 count_ortho+=1

    if y.id == 'ICL':
        print(temp3)
    _lst_ylip_gene.append(temp3)
    
    # call the function to compare the genes in each GSM reaction, which are stored as list temp1 and temp3. 
    result = compare_two_lists(temp1, temp3)
    
    if y.id == 'ICL':
        print(result)

    # assign the results here. 
    _common_all = (result['common_all'])
    _only_1 = (result['only_1'])
    _only_2 = (result['only_2'])
    _all_three_diff = (result['all_diff'])
    
    # append them into a single list.
    trifecta = []
    trifecta.append(_common_all)
    trifecta.append(_only_1)
    trifecta.append(_only_2)
    
    if y.id =='ICL':
        print(trifecta)   

    # if there is a new gene that needs to be added. 
    if result['only_2']:
        
        
        max_len = max(len(lst) for lst in trifecta)
        
        # join them as 'or' gpr rules. 
        for i in range(max_len):
            temp_gpr = ' or '.join(item for sublist in trifecta for item in sublist)
    
    # else keep the original gene reaction rule. 
    else:
        temp_gpr = m.gene_reaction_rule

    if y.id == 'ICL':
        print(temp_gpr)
        print(y.gene_reaction_rule)

    # assign new GPR. 
    m.gene_reaction_rule = temp_gpr
# Out:
# ['Lipst1_1_112377']
# ['Lipst1_1_112377', 'Lipst1_1_75138']
# {'common_all': ['Lipst1_1_112377'], 'only_1': [], 'only_2': ['Lipst1_1_75138'], 'all_diff': []}
# [['Lipst1_1_112377'], [], ['Lipst1_1_75138']]
# Lipst1_1_112377 or Lipst1_1_75138
# YALI0C16885g or YALI0F31999g

# %%
ylip
# Out:
# <Model model at 0x15a49dd50>

# %%
model.reactions.get_by_id('ICLp')
# Out:
# <Reaction ICLp at 0x2a1395150>

# %%
len(model.reactions)-2083
# Out:
# 65

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ls = 0.07253593170088728</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>6.035E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e</td>
#       <td>3.808E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe3_e</td>
#       <td>EX_fe3_e</td>
#       <td>0.0004475</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>1</td>
#       <td>6</td>
#       <td>98.66%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e</td>
#       <td>0.04248</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e</td>
#       <td>0.004477</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_e</td>
#       <td>EX_mn2_e</td>
#       <td>4.403E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>na1_e</td>
#       <td>EX_na1_e</td>
#       <td>0.001893</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>0.4788</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>2.329</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>0.01931</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e</td>
#       <td>0.007271</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e</td>
#       <td>3.699E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>8aonn_m</td>
#       <td>SRC_8aonn_m</td>
#       <td>0.0001754</td>
#       <td>9</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>lipoate_m</td>
#       <td>SRC_lipoate_m</td>
#       <td>0.0002254</td>
#       <td>8</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>trnaala_c</td>
#       <td>SRC_trnaala_c</td>
#       <td>0.04189</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaarg_c</td>
#       <td>SRC_trnaarg_c</td>
#       <td>0.01064</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaasn_c</td>
#       <td>SRC_trnaasn_c</td>
#       <td>0.007832</td>
#       <td>10</td>
#       <td>1.29%</td>
#     </tr>
#     <tr>
#       <td>trnaasp_c</td>
#       <td>SRC_trnaasp_c</td>
#       <td>0.01431</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnacys_c</td>
#       <td>SRC_trnacys_c</td>
#       <td>0.002486</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnagln_c</td>
#       <td>SRC_trnagln_c</td>
#       <td>0.008552</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaglu_c</td>
#       <td>SRC_trnaglu_c</td>
#       <td>0.01514</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnagly_c</td>
#       <td>SRC_trnagly_c</td>
#       <td>0.03723</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnahis_c</td>
#       <td>SRC_trnahis_c</td>
#       <td>0.004437</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaile_c</td>
#       <td>SRC_trnaile_c</td>
#       <td>0.0115</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaleu_c</td>
#       <td>SRC_trnaleu_c</td>
#       <td>0.02323</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnalys_c</td>
#       <td>SRC_trnalys_c</td>
#       <td>0.0125</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnamet_c</td>
#       <td>SRC_trnamet_c</td>
#       <td>0.004138</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaphe_c</td>
#       <td>SRC_trnaphe_c</td>
#       <td>0.006903</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnapro_c</td>
#       <td>SRC_trnapro_c</td>
#       <td>0.01711</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaser_c</td>
#       <td>SRC_trnaser_c</td>
#       <td>0.02444</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnathr_c</td>
#       <td>SRC_trnathr_c</td>
#       <td>0.01582</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnatrp_c</td>
#       <td>SRC_trnatrp_c</td>
#       <td>0.001691</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnatyr_c</td>
#       <td>SRC_trnatyr_c</td>
#       <td>0.004524</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaval_c</td>
#       <td>SRC_trnaval_c</td>
#       <td>0.01996</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3aap_c</td>
#       <td>DM_3aap_c</td>
#       <td>-0.05137</td>
#       <td>5</td>
#       <td>8.21%</td>
#     </tr>
#     <tr>
#       <td>4oglu_c</td>
#       <td>DM_4oglu_c</td>
#       <td>-0.000101</td>
#       <td>5</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>amob_m</td>
#       <td>DM_amob_m</td>
#       <td>-0.0001754</td>
#       <td>15</td>
#       <td>0.08%</td>
#     </tr>
#     <tr>
#       <td>dad_5_m</td>
#       <td>DM_dad_5_m</td>
#       <td>-0.0001754</td>
#       <td>10</td>
#       <td>0.06%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-2.599</td>
#       <td>1</td>
#       <td>83.12%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e</td>
#       <td>-0.0003107</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>-4.242</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>-0.1659</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>hco3_e</td>
#       <td>EX_hco3_e</td>
#       <td>-0.001818</td>
#       <td>1</td>
#       <td>0.06%</td>
#     </tr>
#     <tr>
#       <td>zymst_e</td>
#       <td>EX_zymst_e</td>
#       <td>-0.009788</td>
#       <td>27</td>
#       <td>8.45%</td>
#     </tr>
#   </tbody>
# </table>

# %%
genes = model.genes
genes = [g.id for g in genes]
wrong = [g for g in genes if 'Lipst1' not in g]
len(set(wrong))
# Out:
# 44

# %%
wrong_g2 = []
wrong_rx2 = []
for g in wrong:
    reac = model.genes.get_by_id(g).reactions
    if not reac:
        print(f'{g} has no associated reaction')
        
        cobra.manipulation.delete.remove_genes(model,[g])
    for rx in reac:
        if rx:
#             print(rx,g)
            wrong_g2.append(g)
            wrong_rx2.append(rx)
print(len(set(wrong_g2)))
print(len(set(wrong_rx2)))
# Out:
# 44
# 17

# %%
genes = model.genes
genes = [g.id for g in genes]
wrong = [g for g in genes if 'Lipst1' not in g]
len(set(wrong))
# Out:
# 44

# %% [markdown]
# ## This section uses the collected reaction names and modifies the Lst model GPR as needed.
# following cell updates the model GPR for overlapping reactions in sce.
# #### sce

# %% [markdown]
# following cell updates gpr from SCE reactions that have naming overlaps.

# %%
# this cell updates the model GPR with the overlapping ylip reactions. 

# storage lists. 
# gene overlap in the sce orthologs and the model genes for each reaction. 
_names = []
_gpr_sce = []
_gpr_ylip = []
_gpr_model = []

_lst_model_gene = []
_lst_sce_gene = []
_lst_ylip_gene = []

_id = []
_stoich = []
_subsystem = []
_lst_gene = []
_ylip_gene = []


consensus = []
consensus_count = []
consensus_source = []
_output = []


_common_all = []

_only_1 = []
_only_2 = []
_all_diff = []

# iterate through the sce reactions that have orthologs and are also in the model reactions (based on name matching).
for rx in list(sce_additional_rxns.keys()):
    
    # get actual GSM IDs.
    model_rx = sce_additional_rxns_toModel[rx]
    sce_rx = sce_additional_rxns[rx]
    
    # obtain the reaction objects.
    m = model.reactions.get_by_id(model_rx)
    s = sce.reactions.get_by_id(sce_rx)
    
    # obtain the reaction GPRs.
    _gpr_model.append(m.gene_reaction_rule)
    _gpr_sce.append(s.gene_reaction_rule)

    # obtain the reaction meta data.
    _names.append(m.name)
    _id.append(m.id)
    _stoich.append(m.reaction)
    _subsystem.append(m.subsystem)
    
    ## to do - insert check to make sure not adding multiple GPRs. 
    
    # model current GPR.
    temp1 = []
    for g in m.genes:
        temp1.append(g.id)
    _lst_model_gene.append(temp1)
    

    # sce genes. 
    temp3 = []
    gpr = s.genes
    
    # iterate through the genes in the sce GSM. 
    for i in range(len(gpr)):
        g=list(gpr)[i]

        # examine lst_orthologs. 
        if g.id in sce_dict_keys:

            # obtain the lst gene ortholog.
            value = lst_sce_dict[g.id]

            # check if the ortholog is blank. 
            if value:
                temp3.append(value)
#                 count_ortho+=1

    _lst_sce_gene.append(temp3)
    

    # call comparing function for two lists. 
    result = compare_two_lists(temp1, temp3)

    # assign the results. 
    _common_all = (result['common_all'])
    _only_1 = (result['only_1'])
    _only_2 = (result['only_2'])
    _all_three_diff = (result['all_diff'])
    
    # concate into a single list. 
    trifecta = []
    trifecta.append(_common_all)
    trifecta.append(_only_1)
    trifecta.append(_only_2)
    
    # check. 
    if s.id == 'ICL':
        print("list:",_common_all,_only_2,_only_1)
        print("trifecta",trifecta)
    
    # if there is a new gene to add. 
    if result['only_2']:
        max_len = max(len(lst) for lst in trifecta)
        
        # concate to new gpr with 'or' gene reaction rules. 
        for i in range(max_len):
            temp_gpr = ' or '.join(item for sublist in trifecta for item in sublist)
                
    # no new genes - keep original reaction gene reaction rule. 
    else:
        temp_gpr = m.gene_reaction_rule

    # check. 
    if s.id =='ICL':
        print(temp_gpr)

    # assign new GPR. 
    m.gene_reaction_rule = temp_gpr
# Out:
# list: ['Lipst1_1_112377'] [] ['Lipst1_1_75138']
# trifecta [['Lipst1_1_112377'], ['Lipst1_1_75138'], []]
# Lipst1_1_112377 or Lipst1_1_75138

# %%
len(model.reactions)
# Out:
# 2148

# %%
2148-2083
# Out:
# 65

# %%
genes = model.genes
genes = [g.id for g in genes]
wrong = [g for g in genes if 'Lipst1' not in g]
print(len(set(wrong)))
wrong_g2 = []
wrong_rx2 = []
for g in wrong:
    reac = model.genes.get_by_id(g).reactions
    if not reac:
        print(f'{g} has no associated reaction')
        
        cobra.manipulation.delete.remove_genes(model,[g])
    for rx in reac:
        if rx:
#             print(rx,g)
            wrong_g2.append(g)
            wrong_rx2.append(rx)
print(len(set(wrong_g2)))
print(len(set(wrong_rx2)))
# Out:
# 44
# 44
# 17

# %% [markdown]
# ## Progess status.
#
# We:
# - created a scaffold GSM originally built from rto bidirectional best hits.
# - compiled orthologs using orthoMCL.
#
# then we:
# - obtained reactions in multiple GSMs.
# - concated GPRs using the unique genes in the overlapping reaction IDs.
# - updated the Lst bbh model with the multi-species GPRs.
# - added rto reactions to the Lst model that were only in rto AND had orthologs.
# - matched ylip and sce reaction names to find other overlapping reactions (multi-species).
# - modifed Lst model with multi-species GPRs.
#
# Next we will:
# - deterimine ylip/sce reactions that have Lst orthologs that ARE not in the GSM (i.e., genes not already in the model).
# - identify reactions that include metabolites already in the Lst GSM (such that we do not add orphan metabolites).
# - screen reactions to make sure that there are not comparable reactions in the Lst GSM.
# - update GPR with multi-species GPRs or add reactions as necessary.

# %% [markdown]
# ## section peruses the ylip GSM reactions and identifies ones with orthologs to Lst that are not included in the Lst model already.
# ylip - individual reactions

# %% [markdown]
# the following cell blocks find reactions from ylip that have orthologs not yet added to the model. we create a dataframe with these reactions. then, we determine if the metabolites in the reactions were in the model before adding.

# %%
# first, obtain the Lst genes included in the Lst model.
model_genes = model.genes
model_genes = [x.id for x in model_genes]

# %%
# this code finds reactions from ylip to the model that may have potential orthologs that have not been included yet. 

# list storage. 
_gpr = []
_id = []
_stoich = []
_subsystem = []
gpr_holder = []

# obtain list of reactions that had orthologs but were not added.
# (the ylip_ortholog_available was obtained from the ortholog section looking at individual models above).
# (the ylip_additional_rxns was obtained by through matching of the reaction names to Lst model).
new_ylip_only_reactions = set(ylip_ortholog_available)-set(list(ylip_additional_rxns.values()))

# iterate through reactions with Lst ortholog gene candidates. 
for rx in new_ylip_only_reactions:
    
    # obtain reaction in ylip GSM.
    r = ylip.reactions.get_by_id(rx)
    
 
    
    # counters and list tracker for new GPR. 
    count_ortho = 0
    temp_gpr = []
    
    # iterate through the genes in the ylip reaction.
    for i in range(len(r.genes)):
        
        # obtain a list of the ylip genes. 
        g=list(r.genes)[i]
        g = g.id
        
        # check if the particular gene has an Lst ortholog. 
        try:
            value = lst_ylip_dict[g]
            
            # if there is an ortholog &
            # the gene is not in the Lst model &
            # the reaction is in the list (assured based on iteration)
            if (value) and (value not in model_genes) and (rx in list(new_ylip_only_reactions)):
                
                # count how many of the genes have orthologs.
                count_ortho+=1
        
        # there is no ortholog. 
        except:
            continue
#             donothing=0
    
    # there is an ortholog for at least one gene associated with the reaction. 
    if count_ortho>0:
        # obtain reaction metadata.
        _names.append(r.name)
        _id.append(r.id)  
        _gpr.append(r.gene_reaction_rule)
        _stoich.append(r.reaction)
        
#         temp = " or ".join(sub_item.replace("None", "").replace("NA"," ") for sub_item in temp_gpr)
#         gpr_holder.append(temp)       


# this next section now looks at the reactions that had an ortholog. 
new_ylip_only_reactions2 = set(_id)-set(list(ylip_additional_rxns.values()))                             
                             
print(len(new_ylip_only_reactions2))

# re-initailize metadata storing lists. 
_names = []
_gpr = []
_id = []
_stoich = []
_subsystem = []
gpr_holder = []

# iterate through the reactions that have orthologs. 
for rx in new_ylip_only_reactions2:
    # obtain reaction. 
    r = ylip.reactions.get_by_id(rx)

    # store reaction metadata. 
    _gpr.append(r.gene_reaction_rule)
    _stoich.append(r.reaction)
    _names.append(r.name)
    _id.append(r.id)
    
    # objects for tracking and storing progress.
    count_ortho = 0
    temp_gpr = []
    
    # iterate through reaction genes. 
    for i in range(len(r.genes)):

        # obtain the individual genes. 
        g=list(r.genes)[i]
        g = g.id

        # obtain the ortholog.
        try:
            value = lst_ylip_dict[g]
            if (value):
                count_ortho+=1
        except:
            continue
            
    # this implies that at least one gene has been found that was not included in the reaction. re-run section to catpure all geens in teh reaction.
    if count_ortho>0:
        
        # iterate through genes again for each reaction.
        for i in range(len(r.genes)):
            
            # obtain the indivdual gene. 
            g=list(r.genes)[i]
            g = g.id
            
            # obtain the new GPR as a list. 
            try:
                value = lst_ylip_dict[g]
                if (value):
                    temp_gpr.append(value)
            except:
                continue
                
        # create a new GPR rule. 
        temp = " or ".join(sub_item.replace("None", "").replace("NA"," ") for sub_item in temp_gpr)
        gpr_holder.append(temp)

# create a dataframe with the candidate reactions. 
ylip_added_orthologs_orhpans = pd.DataFrame([_id,_names,_stoich,_gpr,gpr_holder]).T
# Out:
# 24

# %%
ylip_added_orthologs_orhpans
# Out:
#               0                                                  1  \
# 0         PSP_L                 phosphoserine phosphatase L serine
# 1    FAS160ACPm    fatty acyl ACP synthase n C160ACP mitochondrial
# 2        ATPS3g                       ATP synthase Golgi Apparatus
# 3          DOLK                                    Dolichol kinase
# 4        PETHCT             phosphoethanolamine cytidyltransferase
# 5    FAS161ACPm    fatty acyl ACP synthase n C161ACP mitochondrial
# 6   FAS80ACPm_L  fatty acyl ACP synthase n C80ACP mitochondrial...
# 7    FAS140ACPm    fatty acyl ACP synthase n C140ACP mitochondrial
# 8         ACt2r    acetate reversible transport via proton symport
# 9       HBZOPT6              Hydroxybenzoate octaprenyltransferase
# 10   FAS180ACPm    fatty acyl ACP synthase n C180ACP mitochondrial
# 11   FAS141ACPm    fatty acyl ACP synthase n C141ACP mitochondrial
# 12       FA60tp                fatty acid peroxisomal transport YL
# 13       FA40tp                fatty acid peroxisomal transport YL
# 14        CYOOm                 cytochrome c oxidase mitochondrial
# 15   FAS181ACPm    fatty acyl ACP synthase n C181ACP mitochondrial
# 16          TGL                                                TGL
# 17        exlip                           extracelular lipases TAG
# 18   FAS100ACPm    fatty acyl ACP synthase n C100ACP mitochondrial
# 19      OHPHM6n     2 octaprenyl 6 hydroxyphenol methylase nuclear
# 20   FAS120ACPm    fatty acyl ACP synthase n C120ACP mitochondrial
# 21       SPRMti                      spermine irreversible uniport
# 22   FAS182ACPm    fatty acyl ACP synthase n C182ACP mitochondrial
# 23      ATPCitL                               ATP Citrate Lyase YL
#
#                                                     2  \
# 0               h2o_c + pser__L_c --> pi_c + ser__L_c
# 1   3.0 h_m + malACP_m + myrsACP_m + 2.0 nadph_m -...
# 2   adp_g + 3.0 h_c + pi_g --> atp_g + h2o_g + 2.0...
# 3         ctp_c + dolichol_c --> cdp_c + dolp_c + h_c
# 4          ctp_c + ethamp_c + h_c --> cdpea_c + ppi_c
# 5   4.0 h_m + malACP_m + myrsACP_m + 3.0 nadph_m +...
# 6   acACP_m + 9.0 h_m + 3.0 malACP_m + 6.0 nadph_m...
# 7   ddcaACP_m + 3.0 h_m + malACP_m + 2.0 nadph_m -...
# 8                           ac_e + h_e <=> ac_c + h_c
# 9            4hbz_c + octdp_5_c --> 3ophb_5_c + ppi_c
# 10  3.0 h_m + malACP_m + 2.0 nadph_m + palmACP_m -...
# 11  ddcaACP_m + 4.0 h_m + malACP_m + 3.0 nadph_m +...
# 12                                    hca_c --> hca_x
# 13                                  buca_c --> buca_x
# 14  4.0 focytc_m + 6.0 h_m + o2_m --> 4.0 ficytc_m...
# 15  4.0 h_m + malACP_m + 3.0 nadph_m + o2_m + palm...
# 16  h2o_c + 0.01 triglyc_SC_c --> 0.01 12dgr_SC_c ...
# 17  triglyc_SC_e --> 0.02 dca_e + 0.06 ddca_e + 0....
# 18  3.0 h_m + malACP_m + 2.0 nadph_m + ocACP_m -->...
# 19   2ohph_5_n + amet_n --> 2omph_5_n + ahcys_n + h_n
# 20  dcaACP_m + 3.0 h_m + malACP_m + 2.0 nadph_m --...
# 21                                  sprm_e --> sprm_c
# 22  5.0 h_m + malACP_m + 4.0 nadph_m + 2.0 o2_m + ...
# 23  atp_c + cit_c + coa_c --> accoa_c + adp_c + oa...
#
#                                                     3  \
# 0                                        YALI0B20438g
# 1   YALI0D14850g and YALI0D24629g and YALI0F30679g...
# 2   YALI0A09900g and YALI0A11143g and YALI0B03982g...
# 3                                        YALI0E18942g
# 4                                        YALI0C06303g
# 5   YALI0D14850g and YALI0D24629g and YALI0F30679g...
# 6   YALI0D14850g and YALI0D24629g and YALI0F30679g...
# 7   YALI0D14850g and YALI0D24629g and YALI0F30679g...
# 8                                        YALI0E04312g
# 9   (YALI0E09276g and YALI0B16126g) or (YALI0E1366...
# 10  YALI0D14850g and YALI0D24629g and YALI0F30679g...
# 11  YALI0D14850g and YALI0D24629g and YALI0F30679g...
# 12                                       YALI0E16775g
# 13                                       YALI0E16775g
# 14  YALI0E10144g and YALI0E12628g and YALI0E16709g...
# 15  YALI0D14850g and YALI0D24629g and YALI0F30679g...
# 16                       YALI0D17534g or YALI0F10010g
# 17                                       YALI0A20350g
# 18  YALI0D14850g and YALI0D24629g and YALI0F30679g...
# 19                                       YALI0E00770g
# 20  YALI0D14850g and YALI0D24629g and YALI0F30679g...
# 21  YALI0A07447g or YALI0F03751g or YALI0C04477g o...
# 22  YALI0D14850g and YALI0D24629g and YALI0F30679g...
# 23                      YALI0E34793g and YALI0D24431g
#
#                                                     4
# 0                                       Lipst1_1_1740
# 1   Lipst1_1_3273 or Lipst1_1_2955 or Lipst1_1_106903
# 2   Lipst1_1_149291 or Lipst1_1_69438 or Lipst1_1_...
# 3                                      Lipst1_1_55005
# 4                                       Lipst1_1_4188
# 5   Lipst1_1_3273 or Lipst1_1_2955 or Lipst1_1_106903
# 6   Lipst1_1_3273 or Lipst1_1_2955 or Lipst1_1_106903
# 7   Lipst1_1_3273 or Lipst1_1_2955 or Lipst1_1_106903
# 8                                       Lipst1_1_7130
# 9   Lipst1_1_302018 or Lipst1_1_114557 or Lipst1_1...
# 10  Lipst1_1_3273 or Lipst1_1_2955 or Lipst1_1_106903
# 11  Lipst1_1_3273 or Lipst1_1_2955 or Lipst1_1_106903
# 12                                      Lipst1_1_5415
# 13                                      Lipst1_1_5415
# 14  Lipst1_1_5671 or Lipst1_1_55045 or Lipst1_1_38...
# 15  Lipst1_1_3273 or Lipst1_1_2955 or Lipst1_1_106903
# 16                 Lipst1_1_161356 or Lipst1_1_253586
# 17                                     Lipst1_1_70518
# 18  Lipst1_1_3273 or Lipst1_1_2955 or Lipst1_1_106903
# 19                                     Lipst1_1_68931
# 20  Lipst1_1_3273 or Lipst1_1_2955 or Lipst1_1_106903
# 21                    Lipst1_1_61594 or Lipst1_1_6033
# 22  Lipst1_1_3273 or Lipst1_1_2955 or Lipst1_1_106903
# 23                     Lipst1_1_5446 or Lipst1_1_5447

# %%
# check one of the gene dictionaries: for PETHCT.
lst_ylip_dict['YALI0C06303g']
# Out:
# 'Lipst1_1_4188'

# %% [markdown]
# #### metabolite determination. This section verifies that the reaction candidates only have metabolites that are already included in the GSM.
# metabolite section.

# %%
# obtain the metabolites in the Lst model. 
mets = model.metabolites
mets = [x.id for x in mets]

# %%
# this cell checks the metabolites in the reactions and ensures that they are all in the GSM. 

# reaction names.
react = ylip_added_orthologs_orhpans[0].to_list()
# new GPR.
gpr = ylip_added_orthologs_orhpans[4].to_list()

# list for tracking. 
orphan_ylip_reactions_actually_added = []

# iterate through the reactions.
for u,rx in enumerate(react):
    
    # obtain the ylip GSM reaction. 
    y = ylip.reactions.get_by_id(rx)
    
    # obtain a list of the metabolites. 
    gsm_mets = list(y.metabolites.keys())
    gsm_mets = [x.id for x in gsm_mets]
    
    # counter. 
    j=0
    
    # iterate through the metabolites.
    for i in range(len(gsm_mets)):
        
        # check if metabolite is in model.
        if gsm_mets[i] in mets:
            j+=1
        else:
#             print(gsm_mets[i])
            continue
    
    # check if all the reaction metabolites were in the model. 
    if j==len(gsm_mets):
        
        print('yes - ', rx)
#         r = y.copy()
#         r.gene_reaction_rule = gpr[u]

        # add to model. 
#         model.add_reactions([r])

        # store the reactions. 
        orphan_ylip_reactions_actually_added.append(r)
# Out:
# yes -  PSP_L
# yes -  ACt2r
# yes -  CYOOm
# yes -  SPRMti
# yes -  ATPCitL

# %%
for x in orphan_ylip_reactions_actually_added:
    print(x.id, x.name, x.reaction)
# Out:
# ATPCitL ATP Citrate Lyase YL atp_c + cit_c + coa_c --> accoa_c + adp_c + oaa_c + pi_c
# ATPCitL ATP Citrate Lyase YL atp_c + cit_c + coa_c --> accoa_c + adp_c + oaa_c + pi_c
# ATPCitL ATP Citrate Lyase YL atp_c + cit_c + coa_c --> accoa_c + adp_c + oaa_c + pi_c
# ATPCitL ATP Citrate Lyase YL atp_c + cit_c + coa_c --> accoa_c + adp_c + oaa_c + pi_c
# ATPCitL ATP Citrate Lyase YL atp_c + cit_c + coa_c --> accoa_c + adp_c + oaa_c + pi_c

# %% [markdown]
# #### here we validate and potentially add reactions to the Lst model.

# %% [markdown]
# metabolic reaction #1.
# - ACt2r acetate reversible transport via proton symport ac_e + h_e <=> ac_c + h_c
# - CYOOm cytochrome c oxidase mitochondrial 4.0 focytc_m + 6.0 h_m + o2_m --> 4.0 ficytc_m + 2.0 h2o_m + 6.0 h_c
# - PSP_L phosphoserine phosphatase L serine h2o_c + pser__L_c --> pi_c + ser__L_c
# - ATPCitL ATP Citrate Lyase YL atp_c + cit_c + coa_c --> accoa_c + adp_c + oaa_c + pi_c
# - SPRMti spermine irreversible uniport sprm_e --> sprm_c

# %%
ylip.reactions.ACt2r
# Out:
# <Reaction ACt2r at 0x17feef1d0>

# %%
for r in model.metabolites.ac_e.reactions:
    print(r, r.name)
# Out:
# EX_ac_e: ac_e -->  Acetate exchange
# ACtr: ac_e <=> ac_c Acetate transporter

# %%
model.reactions.ACtr
# Out:
# <Reaction ACtr at 0x15b813dd0>

# %% [markdown]
# two potential orthologs for acetate transporter. One is specified as a proton symport. Both will be included in the GSM.

# %%
r_copy = ylip.reactions.ACt2r.copy()
x = ylip_added_orthologs_orhpans.loc[ylip_added_orthologs_orhpans[0]=='ACt2r'][4]

# %%
x.values
# Out:
# array(['Lipst1_1_7130'], dtype=object)

# %%
model.add_reactions([r_copy])
model.reactions.ACt2r.gene_reaction_rule = 'Lipst1_1_7130'

# %% [markdown]
# reaction #2.
# - CYOOm cytochrome c oxidase mitochondrial 4.0 focytc_m + 6.0 h_m + o2_m --> 4.0 ficytc_m + 2.0 h2o_m + 6.0 h_c

# %%
ylip.reactions.CYOOm
# Out:
# <Reaction CYOOm at 0x2a09cdc10>

# %%
ylip.reactions.CYOOm.check_mass_balance()
# Out:
# {}

# %%
for r in model.metabolites.focytc_m.reactions:
    print(r, r.name)
# Out:
# CYOR_u9m: 2.0 ficytc_m + 2.0 h_m + q9h2_m --> 2.0 focytc_m + 4.0 h_c + q9_m Ubiquinol 6 cytochrome c reductase
# CCP2_m: 2.0 focytc_m + h2o2_m + 2.0 h_m --> 2.0 ficytc_m + 2.0 h2o_m Cytochrome c peroxidase, mitochondrial
# CYOO6m: 4.0 focytc_m + 8.0 h_m + o2_m --> 4.0 ficytc_m + 2.0 h2o_m + 4.0 h_c Cytochrome c oxidase Complex IV
# D_LACDcm: 2.0 ficytc_m + lac__D_c --> 2.0 focytc_m + 2.0 h_c + pyr_c D lactate dehydrogenase  cytosolicmitochondrial
# L_LACDcm: 2.0 ficytc_m + lac__L_c --> 2.0 focytc_m + 2.0 h_c + pyr_c L-Lactate dehydrogenase, cytosolic/mitochondrial

# %% [markdown]
# one potential reaction already in Lst GSM.

# %%
# model.reactions.CCP2_m

# %%
model.reactions.CYOO6m
# Out:
# <Reaction CYOO6m at 0x2a18c2f10>

# %%
model.reactions.CYOO6m.check_mass_balance()
# Out:
# {}

# %% [markdown]
# these two reactions are encoding the same reaction, but with slightly different mass balances in terms of protons moved. will keep the original reaction stoichiometry but add the new GPR.

# %% [markdown]
# two potential orthologs for acetate transporter. One is specified as a proton symport. Both will be included in the GSM.

# %%
# r_copy = ylip.reactions.CYOOm.copy()
x = ylip_added_orthologs_orhpans.loc[ylip_added_orthologs_orhpans[0]=='CYOOm'][4]

# %%
x.values
# Out:
# array(['Lipst1_1_5671 or Lipst1_1_55045 or Lipst1_1_3895 or Lipst1_1_54407 or Lipst1_1_65503 or Lipst1_1_67449'],
#       dtype=object)

# %%
model.reactions.CYOO6m.gene_reaction_rule = 'Lipst1_1_54407 or Lipst1_1_65503 or Lipst1_1_67449 or Lipst1_1_3895 or Lipst1_1_55045 or Lipst1_1_5671'

# %% [markdown]
# reaction #3.
# - PSP_L phosphoserine phosphatase L serine h2o_c + pser__L_c --> pi_c + ser__L_c

# %%
ylip.reactions.PSP_L
# Out:
# <Reaction PSP_L at 0x16a7ad610>

# %%
for r in model.metabolites.pser__L_c.reactions:
    print(r, r.name)
# Out:
# PSERT: 3php_c + glu__L_c --> akg_c + pser__L_c Phosphoserine transaminase
# PSERtr: pser__L_c <=> pser__L_e Transport of O-Phospho-L-Serine, Diffusion

# %%
r_copy = ylip.reactions.PSP_L.copy()
x = ylip_added_orthologs_orhpans.loc[ylip_added_orthologs_orhpans[0]=='PSP_L'][4]

# %%
x.values
# Out:
# array(['Lipst1_1_1740'], dtype=object)

# %%
model.add_reactions([r_copy])
model.reactions.PSP_L.gene_reaction_rule = 'Lipst1_1_1740'

# %% [markdown]
# reaction #4.
# - ATPCitL ATP Citrate Lyase YL atp_c + cit_c + coa_c --> accoa_c + adp_c + oaa_c + pi_c?

# %%
ylip.reactions.ATPCitL
# Out:
# <Reaction ATPCitL at 0x16a4b3ed0>

# %%
for r in model.metabolites.cit_c.reactions:
    print(r, r.name)
# Out:
# ACITL: atp_c + cit_c + coa_c --> accoa_c + adp_c + oaa_c + pi_c ATP-Citrate lyase
# CITtam: cit_c + mal__L_m <=> cit_m + mal__L_c Citrate transport  mitochondrial
# AKGCITtm: akg_c + cit_m --> akg_m + cit_c Dicarboxylate/tricarboxylate carrier (akg:cit), mitochondrial
# CITtcm: cit_c + icit_m <=> cit_m + icit_c Citrate transport  mitochondrial

# %% [markdown]
# one reaction already included for ATP citrate lyase.

# %%
model.reactions.ACITL
# Out:
# <Reaction ACITL at 0x15b8b9510>

# %%
x = ylip_added_orthologs_orhpans.loc[ylip_added_orthologs_orhpans[0]=='ATPCitL'][4]

# %%
x.values
# Out:
# array(['Lipst1_1_5446 or Lipst1_1_5447'], dtype=object)

# %% [markdown]
# update the ATPcitrate lyase model GPR.

# %%
model.reactions.ACITL.gene_reaction_rule = 'Lipst1_1_5446 or Lipst1_1_5447'

# %% [markdown]
# reaction #5.
# - SPRMti spermine irreversible uniport sprm_e --> sprm_c

# %%
ylip.reactions.SPRMti
# Out:
# <Reaction SPRMti at 0x15bbc4510>

# %%
for r in model.metabolites.sprm_e.reactions:
    print(r, r.name)
# Out:
# SPRMt2i: h_c + sprm_e --> h_e + sprm_c Spermine transport via proton antiport irreversible
# EX_sprm_e: sprm_e -->  Spermine C10H30N4 exchange

# %%
x = ylip_added_orthologs_orhpans.loc[ylip_added_orthologs_orhpans[0]=='SPRMti'][4]

# %%
x.values
# Out:
# array(['Lipst1_1_61594 or Lipst1_1_6033'], dtype=object)

# %%
model.reactions.get_by_id('SPRMt2i')
# Out:
# <Reaction SPRMt2i at 0x2a13cbd90>

# %% [markdown]
# one additional gene not included in the transporter.

# %% [markdown]
# will modify the existing genes to include the not added gene.

# %%
model.reactions.get_by_id('SPRMt2i').gene_reaction_rule = 'Lipst1_1_2256 or Lipst1_1_61026 or Lipst1_1_6033 or Lipst1_1_97209 or Lipst1_1_52551 or Lipst1_1_61594'

# %%
len(model.reactions)
# Out:
# 2150

# %%
2153-2083
# Out:
# 70

# %% [markdown]
# 5 additional reactions added from ylip.

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ls = 0.07800483549348808</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>6.49E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e</td>
#       <td>4.095E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe3_e</td>
#       <td>EX_fe3_e</td>
#       <td>0.0004812</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>1</td>
#       <td>6</td>
#       <td>98.56%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e</td>
#       <td>0.04569</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e</td>
#       <td>0.004814</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_e</td>
#       <td>EX_mn2_e</td>
#       <td>4.735E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>na1_e</td>
#       <td>EX_na1_e</td>
#       <td>0.002036</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>0.4596</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>2.356</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>0.02077</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e</td>
#       <td>0.007819</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e</td>
#       <td>3.978E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>8aonn_m</td>
#       <td>SRC_8aonn_m</td>
#       <td>0.0001886</td>
#       <td>9</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>lipoate_m</td>
#       <td>SRC_lipoate_m</td>
#       <td>0.0002424</td>
#       <td>8</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>trnaala_c</td>
#       <td>SRC_trnaala_c</td>
#       <td>0.04505</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaarg_c</td>
#       <td>SRC_trnaarg_c</td>
#       <td>0.01144</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaasn_c</td>
#       <td>SRC_trnaasn_c</td>
#       <td>0.008422</td>
#       <td>10</td>
#       <td>1.38%</td>
#     </tr>
#     <tr>
#       <td>trnaasp_c</td>
#       <td>SRC_trnaasp_c</td>
#       <td>0.01539</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnacys_c</td>
#       <td>SRC_trnacys_c</td>
#       <td>0.002673</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnagln_c</td>
#       <td>SRC_trnagln_c</td>
#       <td>0.009197</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaglu_c</td>
#       <td>SRC_trnaglu_c</td>
#       <td>0.01628</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnagly_c</td>
#       <td>SRC_trnagly_c</td>
#       <td>0.04003</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnahis_c</td>
#       <td>SRC_trnahis_c</td>
#       <td>0.004771</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaile_c</td>
#       <td>SRC_trnaile_c</td>
#       <td>0.01237</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaleu_c</td>
#       <td>SRC_trnaleu_c</td>
#       <td>0.02498</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnalys_c</td>
#       <td>SRC_trnalys_c</td>
#       <td>0.01344</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnamet_c</td>
#       <td>SRC_trnamet_c</td>
#       <td>0.00445</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaphe_c</td>
#       <td>SRC_trnaphe_c</td>
#       <td>0.007423</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnapro_c</td>
#       <td>SRC_trnapro_c</td>
#       <td>0.0184</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaser_c</td>
#       <td>SRC_trnaser_c</td>
#       <td>0.02628</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnathr_c</td>
#       <td>SRC_trnathr_c</td>
#       <td>0.01702</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnatrp_c</td>
#       <td>SRC_trnatrp_c</td>
#       <td>0.001819</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnatyr_c</td>
#       <td>SRC_trnatyr_c</td>
#       <td>0.004865</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaval_c</td>
#       <td>SRC_trnaval_c</td>
#       <td>0.02146</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>4oglu_c</td>
#       <td>DM_4oglu_c</td>
#       <td>-0.0001087</td>
#       <td>5</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>amob_m</td>
#       <td>DM_amob_m</td>
#       <td>-0.0001886</td>
#       <td>15</td>
#       <td>0.10%</td>
#     </tr>
#     <tr>
#       <td>dad_5_m</td>
#       <td>DM_dad_5_m</td>
#       <td>-0.0001886</td>
#       <td>10</td>
#       <td>0.06%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-2.619</td>
#       <td>1</td>
#       <td>89.99%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e</td>
#       <td>-0.0003342</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>-4.275</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>-0.1232</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>hco3_e</td>
#       <td>EX_hco3_e</td>
#       <td>-0.001955</td>
#       <td>1</td>
#       <td>0.07%</td>
#     </tr>
#     <tr>
#       <td>zymst_e</td>
#       <td>EX_zymst_e</td>
#       <td>-0.01053</td>
#       <td>27</td>
#       <td>9.76%</td>
#     </tr>
#   </tbody>
# </table>

# %%
genes = model.genes
genes = [g.id for g in genes]
wrong = [g for g in genes if 'Lipst1' not in g]
len(set(wrong))
wrong_g2 = []
wrong_rx2 = []
for g in wrong:
    reac = model.genes.get_by_id(g).reactions
    if not reac:
        print(f'{g} has no associated reaction')
        
        cobra.manipulation.delete.remove_genes(model,[g])
    for rx in reac:
        if rx:
#             print(rx,g)
            wrong_g2.append(g)
            wrong_rx2.append(rx)
print(len(set(wrong_g2)))
print(len(set(wrong_rx2)))
# Out:
# 11317 has no associated reaction
# 11352 has no associated reaction
# 9165 has no associated reaction
# 13628 has no associated reaction
# COX3 has no associated reaction
# COX2 has no associated reaction
# 12506 has no associated reaction
# COX1 has no associated reaction
# 11769 has no associated reaction
# 13275 has no associated reaction
# 13007 has no associated reaction
# 10685 has no associated reaction
# 12210 has no associated reaction
# YALI0E04312g has no associated reaction
# YALI0B20438g has no associated reaction
# 31
# 16

# %%
wrong_rx2 = [x.id for x in wrong_rx2]
set(wrong_rx2)
# Out:
# {'ACRNtp',
#  'C30CPT1',
#  'C3STKR1er',
#  'C3STKR2er',
#  'CRNtp',
#  'CYOR_u9m',
#  'DNTPPA',
#  'DRTPPD',
#  'FA160COAabcp',
#  'FA183COAabcp',
#  'FA240tp',
#  'GAPP',
#  'H2Otm',
#  'OIVD2m',
#  'PMDPHT',
#  'SERPTer'}

# %% [markdown]
# ## This section repeats the process for sce. The code takes the sce reactions that have orthologs and checks that the reaction contains metabolites in the Lst GSM.

# %%
# this code finds reactions from sce to the model that may have potential orthologs that have been missed. 

# list objects for storing information. 
_gpr = []
_id = []
_stoich = []
_subsystem = []
gpr_holder = []


# obtain reactions that have orthologs but have not already been added the GSM. 
# (sce_ortholog_available) is the complete list of sce reactions that have orthologs that arent in rto or ylip.
# (sce_additional_rxns) is the list of sce reactions that had no ID match but were able to match rxn names. 
new_sce_only_reactions = set(sce_ortholog_available)-set(list(sce_additional_rxns.values()))

# iterate through the reactions. 
for rx in new_sce_only_reactions:
    
    # obtain the sce reaction object.
    r = sce.reactions.get_by_id(rx)
    
    
    # objects for tracking. 
    count_ortho = 0
    temp_gpr = []
    
    # iterate over the sce reaction genes. 
    for i in range(len(r.genes)):
        
        
        g=list(r.genes)[i]
        g = g.id
        
        # find the ortholog.
        try:
            
            # find the ortholog.
            value = lst_sce_dict[g]
            
            # verify that the ortholog exists & 
            # is not in the model genes &
            # is in the ortholog reactions (guaranteed based on cell logic and for loops)
            if (value) and (value not in model_genes) and (rx in list(new_sce_only_reactions)):

                count_ortho+=1
        except:
            continue
    
    # if the reaction had at least one gene ortholog in Lst. 
    if count_ortho>0:
        # append reaction metadata. 
        _gpr.append(r.gene_reaction_rule)
        _stoich.append(r.reaction)        
        _names.append(r.name)
        _id.append(r.id)  
        
# obtain the sce reactions that have orthologs.      
new_sce_only_reactions2 = set(_id)-set(list(sce_additional_rxns.values()))                             
                             
print(len(new_sce_only_reactions2))


# reset the information holding lists. 
_names = []
_gpr = []
_id = []
_stoich = []
_subsystem = []
gpr_holder = []

# iterate over the reactions. 
for rx in new_sce_only_reactions2:
    
    # obtain the sce reaction object. 
    r = sce.reactions.get_by_id(rx)
    
    # store reaction metadata. 
    _gpr.append(r.gene_reaction_rule)
    _stoich.append(r.reaction)
    _names.append(r.name)
    _id.append(r.id)
    
    # objects for tracking during loop. 
    count_ortho =0
    temp_gpr = []
    
    # iterate over the sce reaction genes. 
    for i in range(len(r.genes)):

        g=list(r.genes)[i]
        g = g.id

        try:
            
            # obtain the Lst ortholog. 
            value = lst_sce_dict[g]
            
            if (value):
                count_ortho+=1
        except:
            continue

    # this implies that at least one gene has been found that was not included in the reaction.
    if count_ortho>0:
        
        # re-run the gene iteration to capture all orthologs. 
        for i in range(len(r.genes)):
            
            g=list(r.genes)[i]
            g = g.id
            
            try:
                # obtain the Lst ortholog. 
                value = lst_sce_dict[g]
                if (value):
                    temp_gpr.append(value)
            except:
                continue
        
        # join multiple genes for a single reaction together using 'or' rules. 
        temp = " or ".join(sub_item.replace("None", "").replace("NA"," ") for sub_item in temp_gpr)
        gpr_holder.append(temp)

# pd.DataFrame() for storing the reactions.         
sce_added_orthologs_orhpans = pd.DataFrame([_id,_names,_stoich,_gpr,gpr_holder]).T
# Out:
# 457

# %% [markdown]
# potentially 457 sce genes to add.

# %% [markdown]
# ## check candidate reactions to ensure that they included metabolites already in the GSM.
# metabolite checking section.

# %%
# this cell checks the metabolites in the reactions and ensures that they are all in the GSM. 

# reaction names.
react = sce_added_orthologs_orhpans[0].to_list()

# gene reaction rules.
gpr = sce_added_orthologs_orhpans[4].to_list()

# list for storing reactions. 
orphan_sce_reactions_actually_added = []

# iterate over the reactions. 
for u,rx in enumerate(react):
    
    # grab the sce GSM reaction object.
    s = sce.reactions.get_by_id(rx)
    
    # grab the metabolites in the reaction.
    gsm_mets = list(s.metabolites.keys())
    gsm_mets = [x.id for x in gsm_mets]
    
    j=0
    
    # iterate over the number of metabolits in the reaction. 
    for i in range(len(gsm_mets)):
        
        # if metabolite is in model already.
        if gsm_mets[i] in mets:
            j+=1
#         else:
#             print(gsm_mets[i])

    # store reactions that have every metabolite in the Lst model.
    if j==len(gsm_mets):
#         print('yes - ', gsm_mets[i])
        r = s.copy()
        r.gene_reaction_rule = gpr[u]
#         print(r,r.gene_reaction_rule,'\n',s.gene_reaction_rule)

        # add to model. 
#         model.add_reactions([r])
        orphan_sce_reactions_actually_added.append(s)

# %%
len(orphan_sce_reactions_actually_added)
# Out:
# 29

# %%
for x in orphan_sce_reactions_actually_added:
    print(x.id, x.name, x.reaction)
# Out:
# r2073_1 Zn(2+) transport h_e + zn2_e <=> h_c + zn2_c
# r_4162 Probable vacuolar amino acid transporter YPQ3 (PQ-loop repeat-containing protein 3) (Protein RTC2) (Restriction of telomere capping protein 2) his__L_v <=> his__L_c
# r_4331 [1,4-(N-Acetyl-beta-D-glucosaminyl)]n glycanohydrolase chtn_c + h2o_c <=> acgam_c
# GTHDH glutathione:dehydroascorbate oxidoreductase dhdascb_c + 2.0 gthrd_c <=> ascb__L_c + gthox_c
# r_1837 L-histidine transport, mitochondrial his__L_c --> his__L_m
# NTP3 nucleoside triphosphatase gtp_c + h2o_c --> gdp_c + h_c + pi_c
# MNt2 Mn(2+) transport h_e + mn2_e <=> h_c + mn2_c
# ARGt2m arginine transport arg__L_c + h_c --> arg__L_m + h_m
# r_4592 Mg(2+) transport h_e + mg2_e <=> h_c + mg2_c
# r_0438 ferrocytochrome-c:oxygen oxidoreductase focytc_m + 1.266 h_m + 0.25 o2_m --> ficytc_m + 0.5 h2o_m + 0.633 h_c
# PSP_L phosphoserine phosphatase (L-serine) h2o_c + pser__L_c --> pi_c + ser__L_c
# r_1202 L-isoleucine transport ile__L_v <=> ile__L_c
# r_4163 Probable vacuolar amino acid transporter YPQ3 (PQ-loop repeat-containing protein 3) (Protein RTC2) (Restriction of telomere capping protein 2) lys__L_v <=> lys__L_c
# GLYOX3 (R)-lactate hydro-lyase h_c + lac__D_c <=> h2o_c + mthgxl_c
# SERAT serine O-acetyltransferase accoa_c + ser__L_c --> acser_c + coa_c
# r_4275 Fe(II):NADP+ oxidoreductase 2.0 fe3_e + nadph_c <=> 2.0 fe2_c + h_c + nadp_c
# r_4589 Cu2(+) transport cu2_e + h_e <=> cu2_c + h_c
# CHOLtu Protein PNS1 (pH nine-sensitive protein 1) chol_c <=> chol_e
# r_1086 V-ATPase, vacuole atp_c + h2o_c + h_c --> adp_c + 2.0 h_v + pi_c
# r_4587 Ca(2+) transport ca2_e + h_e <=> ca2_c + h_c
# r_1919 lysine transport lys__L_c --> lys__L_m
# r_4312 S-adenosyl-L-methionine:carnosine N-methyltransferase amet_c + carn_c <=> ahcys_c + ans_c + h_c
# r_1220 L-tyrosine transport tyr__L_v <=> tyr__L_c
# Clt chloride transport cl_e <=> cl_c
# SERD_D D-serine ammonia-lyase ser__D_c --> nh4_c + pyr_c
# GGCLUT2 Glutathione-specific gamma-glutamylcyclotransferase (Gamma-GCG) (EC 4.3.2.-) gthrd_c --> 5oxpro_c + cgly_c
# r_1085 V-ATPase, Golgi atp_c + h2o_c + h_c --> adp_c + 2.0 h_g + pi_c
# r_1208 L-leucine transport, vacuoluar leu__L_v <=> leu__L_c
# r_4403 Triphosphate phosphohydrolase h2o_c + pppi_c --> pi_c + ppi_c

# %%
len(model.reactions)-2083
# Out:
# 67

# %% [markdown]
# 28 addition reactions added from sce

# %% [markdown]
# ## a reaction leads to more hco3 output rather than co2. lets find which added reactions does so.

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ls = 0.07800483549348808</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>6.49E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e</td>
#       <td>4.095E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe3_e</td>
#       <td>EX_fe3_e</td>
#       <td>0.0004812</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>1</td>
#       <td>6</td>
#       <td>98.56%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e</td>
#       <td>0.04569</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e</td>
#       <td>0.004814</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_e</td>
#       <td>EX_mn2_e</td>
#       <td>4.735E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>na1_e</td>
#       <td>EX_na1_e</td>
#       <td>0.002036</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>0.4596</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>2.356</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>0.02077</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e</td>
#       <td>0.007819</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e</td>
#       <td>3.978E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>8aonn_m</td>
#       <td>SRC_8aonn_m</td>
#       <td>0.0001886</td>
#       <td>9</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>lipoate_m</td>
#       <td>SRC_lipoate_m</td>
#       <td>0.0002424</td>
#       <td>8</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>trnaala_c</td>
#       <td>SRC_trnaala_c</td>
#       <td>0.04505</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaarg_c</td>
#       <td>SRC_trnaarg_c</td>
#       <td>0.01144</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaasn_c</td>
#       <td>SRC_trnaasn_c</td>
#       <td>0.008422</td>
#       <td>10</td>
#       <td>1.38%</td>
#     </tr>
#     <tr>
#       <td>trnaasp_c</td>
#       <td>SRC_trnaasp_c</td>
#       <td>0.01539</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnacys_c</td>
#       <td>SRC_trnacys_c</td>
#       <td>0.002673</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnagln_c</td>
#       <td>SRC_trnagln_c</td>
#       <td>0.009197</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaglu_c</td>
#       <td>SRC_trnaglu_c</td>
#       <td>0.01628</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnagly_c</td>
#       <td>SRC_trnagly_c</td>
#       <td>0.04003</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnahis_c</td>
#       <td>SRC_trnahis_c</td>
#       <td>0.004771</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaile_c</td>
#       <td>SRC_trnaile_c</td>
#       <td>0.01237</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaleu_c</td>
#       <td>SRC_trnaleu_c</td>
#       <td>0.02498</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnalys_c</td>
#       <td>SRC_trnalys_c</td>
#       <td>0.01344</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnamet_c</td>
#       <td>SRC_trnamet_c</td>
#       <td>0.00445</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaphe_c</td>
#       <td>SRC_trnaphe_c</td>
#       <td>0.007423</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnapro_c</td>
#       <td>SRC_trnapro_c</td>
#       <td>0.0184</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaser_c</td>
#       <td>SRC_trnaser_c</td>
#       <td>0.02628</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnathr_c</td>
#       <td>SRC_trnathr_c</td>
#       <td>0.01702</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnatrp_c</td>
#       <td>SRC_trnatrp_c</td>
#       <td>0.001819</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnatyr_c</td>
#       <td>SRC_trnatyr_c</td>
#       <td>0.004865</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaval_c</td>
#       <td>SRC_trnaval_c</td>
#       <td>0.02146</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>4oglu_c</td>
#       <td>DM_4oglu_c</td>
#       <td>-0.0001087</td>
#       <td>5</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>amob_m</td>
#       <td>DM_amob_m</td>
#       <td>-0.0001886</td>
#       <td>15</td>
#       <td>0.10%</td>
#     </tr>
#     <tr>
#       <td>dad_5_m</td>
#       <td>DM_dad_5_m</td>
#       <td>-0.0001886</td>
#       <td>10</td>
#       <td>0.06%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-2.619</td>
#       <td>1</td>
#       <td>89.99%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e</td>
#       <td>-0.0003342</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>-4.275</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>-0.1232</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>hco3_e</td>
#       <td>EX_hco3_e</td>
#       <td>-0.001955</td>
#       <td>1</td>
#       <td>0.07%</td>
#     </tr>
#     <tr>
#       <td>zymst_e</td>
#       <td>EX_zymst_e</td>
#       <td>-0.01053</td>
#       <td>27</td>
#       <td>9.76%</td>
#     </tr>
#   </tbody>
# </table>

# %%
temp_model = model.copy()
# Out:
# Read LP format model from file /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/tmpgmjymr5r.lp
# Reading time = 0.01 seconds
# : 1905 rows, 4300 columns, 17560 nonzeros

# %%
sol = model.optimize()
print(sol.fluxes['EX_zymst_e'],sol.fluxes['EX_hco3_e'],sol.fluxes['EX_co2_e'],sol.objective_value)
for x in orphan_sce_reactions_actually_added:
    print(x.id, x.name, x.reaction)

    with temp_model:
        temp_model.add_reactions([x])
        sol = temp_model.optimize()
        print(sol.fluxes['EX_zymst_e'],sol.fluxes['EX_hco3_e'],sol.fluxes['EX_co2_e'],sol.objective_value)
# Out:
# 0.010526362525668749 0.0 2.6212240608171524 0.07800483549348808
# r2073_1 Zn(2+) transport h_e + zn2_e <=> h_c + zn2_c
# 0.010526362525668768 0.0 2.6212240608171564 0.07800483549348822
# r_4162 Probable vacuolar amino acid transporter YPQ3 (PQ-loop repeat-containing protein 3) (Protein RTC2) (Restriction of telomere capping protein 2) his__L_v <=> his__L_c
# 0.010526362525668721 0.0 2.6212240608171467 0.0780048354934879
# r_4331 [1,4-(N-Acetyl-beta-D-glucosaminyl)]n glycanohydrolase chtn_c + h2o_c <=> acgam_c
# 0.010526362525668754 0.0 2.6212240608171533 0.0780048354934881
# GTHDH glutathione:dehydroascorbate oxidoreductase dhdascb_c + 2.0 gthrd_c <=> ascb__L_c + gthox_c
# 0.010526362525668775 0.0019547621750490725 2.619269298642111 0.07800483549348829
# r_1837 L-histidine transport, mitochondrial his__L_c --> his__L_m
# 0.010526362525668746 0.00781904870019627 2.6134050121169596 0.07800483549348809
# NTP3 nucleoside triphosphatase gtp_c + h2o_c --> gdp_c + h_c + pi_c
# 0.010526362525668796 0.0019547621750490595 2.6192692986421156 0.07800483549348844
# MNt2 Mn(2+) transport h_e + mn2_e <=> h_c + mn2_c
# 0.01052636252566875 0.0019547621750490678 2.619269298642105 0.07800483549348809
# ARGt2m arginine transport arg__L_c + h_c --> arg__L_m + h_m
# 0.01052636252566871 0.0 2.6212240608171444 0.07800483549348779
# r_4592 Mg(2+) transport h_e + mg2_e <=> h_c + mg2_c
# 0.010526362525668699 0.0 2.6212240608171418 0.07800483549348769
# r_0438 ferrocytochrome-c:oxygen oxidoreductase focytc_m + 1.266 h_m + 0.25 o2_m --> ficytc_m + 0.5 h2o_m + 0.633 h_c
# 0.010526362525668822 0.0019547621750490803 2.6192692986421204 0.0780048354934886
# Ignoring reaction 'PSP_L' since it already exists.
# PSP_L phosphoserine phosphatase (L-serine) h2o_c + pser__L_c --> pi_c + ser__L_c
# 0.010526362525668829 0.001954762175049065 2.6192692986421227 0.0780048354934887
# r_1202 L-isoleucine transport ile__L_v <=> ile__L_c
# 0.010526362525668706 0.001954762175049053 2.6192692986420947 0.07800483549348776
# r_4163 Probable vacuolar amino acid transporter YPQ3 (PQ-loop repeat-containing protein 3) (Protein RTC2) (Restriction of telomere capping protein 2) lys__L_v <=> lys__L_c
# 0.010526362525668704 0.0 2.621224060817142 0.07800483549348775
# GLYOX3 (R)-lactate hydro-lyase h_c + lac__D_c <=> h2o_c + mthgxl_c
# 0.01052636252566875 0.0 2.6212240608171533 0.07800483549348809
# SERAT serine O-acetyltransferase accoa_c + ser__L_c --> acser_c + coa_c
# 0.010526362525668744 0.0 2.6212240608171524 0.07800483549348805
# r_4275 Fe(II):NADP+ oxidoreductase 2.0 fe3_e + nadph_c <=> 2.0 fe2_c + h_c + nadp_c
# 0.018071505434529594 0.0 0.19936681848978102 0.13391756222557039
# r_4589 Cu2(+) transport cu2_e + h_e <=> cu2_c + h_c
# 0.010526362525668768 0.0 2.6212240608171564 0.07800483549348822
# CHOLtu Protein PNS1 (pH nine-sensitive protein 1) chol_c <=> chol_e
# 0.010526362525668721 0.0 2.6212240608171467 0.0780048354934879
# r_1086 V-ATPase, vacuole atp_c + h2o_c + h_c --> adp_c + 2.0 h_v + pi_c
# 0.010526362525668744 0.0019547621750490496 2.619269298642104 0.07800483549348806
# r_4587 Ca(2+) transport ca2_e + h_e <=> ca2_c + h_c
# 0.01052636252566872 0.0019547621750490548 2.6192692986420965 0.07800483549348786
# r_1919 lysine transport lys__L_c --> lys__L_m
# 0.01052636252566876 0.003909524350098138 2.617314536467057 0.07800483549348816
# r_4312 S-adenosyl-L-methionine:carnosine N-methyltransferase amet_c + carn_c <=> ahcys_c + ans_c + h_c
# 0.010526362525668752 0.003909524350098137 2.617314536467057 0.07800483549348812
# r_1220 L-tyrosine transport tyr__L_v <=> tyr__L_c
# 0.010526362525668752 0.0 2.621224060817153 0.0780048354934881
# Clt chloride transport cl_e <=> cl_c
# 0.010526362525668869 0.0 2.6212240608171813 0.07800483549348897
# SERD_D D-serine ammonia-lyase ser__D_c --> nh4_c + pyr_c
# 0.01052636252566879 0.0 2.6212240608171626 0.07800483549348838
# GGCLUT2 Glutathione-specific gamma-glutamylcyclotransferase (Gamma-GCG) (EC 4.3.2.-) gthrd_c --> 5oxpro_c + cgly_c
# 0.010526362525668808 0.0 2.621224060817166 0.07800483549348851
# r_1085 V-ATPase, Golgi atp_c + h2o_c + h_c --> adp_c + 2.0 h_g + pi_c
# 0.010526362525668742 0.001954762175049066 2.6192692986421027 0.07800483549348802
# r_1208 L-leucine transport, vacuoluar leu__L_v <=> leu__L_c
# 0.010526362525668739 0.0019547621750490656 2.6192692986421022 0.078004835493488
# r_4403 Triphosphate phosphohydrolase h2o_c + pppi_c --> pi_c + ppi_c
# 0.010526362525668782 0.0 2.6212240608171617 0.07800483549348833

# %% [markdown]
# r_4275 Fe(II):NADP+ oxidoreductase 2.0 fe3_e + nadph_c <=> 2.0 fe2_c + h_c + nadp_c
#
# This reaction leads to no co2 outlux and to more relative outflux from zymst

# %% [markdown]
# lets see if we can figure out what is going on by adding that reaction. We will create an output flux file for visualization on escher.io.

# %%
for x in orphan_sce_reactions_actually_added:
    print(x)
# Out:
# r2073_1: h_e + zn2_e <=> h_c + zn2_c
# r_4162: his__L_v <=> his__L_c
# r_4331: chtn_c + h2o_c <=> acgam_c
# GTHDH: dhdascb_c + 2.0 gthrd_c <=> ascb__L_c + gthox_c
# r_1837: his__L_c --> his__L_m
# NTP3: gtp_c + h2o_c --> gdp_c + h_c + pi_c
# MNt2: h_e + mn2_e <=> h_c + mn2_c
# ARGt2m: arg__L_c + h_c --> arg__L_m + h_m
# r_4592: h_e + mg2_e <=> h_c + mg2_c
# r_0438: focytc_m + 1.266 h_m + 0.25 o2_m --> ficytc_m + 0.5 h2o_m + 0.633 h_c
# PSP_L: h2o_c + pser__L_c --> pi_c + ser__L_c
# r_1202: ile__L_v <=> ile__L_c
# r_4163: lys__L_v <=> lys__L_c
# GLYOX3: h_c + lac__D_c <=> h2o_c + mthgxl_c
# SERAT: accoa_c + ser__L_c --> acser_c + coa_c
# r_4275: 2.0 fe3_e + nadph_c <=> 2.0 fe2_c + h_c + nadp_c
# r_4589: cu2_e + h_e <=> cu2_c + h_c
# CHOLtu: chol_c <=> chol_e
# r_1086: atp_c + h2o_c + h_c --> adp_c + 2.0 h_v + pi_c
# r_4587: ca2_e + h_e <=> ca2_c + h_c
# r_1919: lys__L_c --> lys__L_m
# r_4312: amet_c + carn_c <=> ahcys_c + ans_c + h_c
# r_1220: tyr__L_v <=> tyr__L_c
# Clt: cl_e <=> cl_c
# SERD_D: ser__D_c --> nh4_c + pyr_c
# GGCLUT2: gthrd_c --> 5oxpro_c + cgly_c
# r_1085: atp_c + h2o_c + h_c --> adp_c + 2.0 h_g + pi_c
# r_1208: leu__L_v <=> leu__L_c
# r_4403: h2o_c + pppi_c --> pi_c + ppi_c

# %% [markdown]
# we can separate the above reactions that need to be added into a few categories:
#
# transport (vacuole to cytoplasm) 5 rxns:
# - r_4162: his__L_v <=> his__L_c
# - r_1220: tyr__L_v <=> tyr__L_c
# - r_4163: lys__L_v <=> lys__L_c
# - r_1208: leu__L_v <=> leu__L_c
# - r_1202: ile__L_v <=> ile__L_c
#
# transport (mitochondria to cytoplasm) 3 rxns:
# - r_1919: lys__L_c --> lys__L_m
# - ARGt2m: arg__L_c + h_c --> arg__L_m + h_m
# - r_1837: his__L_c --> his__L_m
#
# transport (extracellular to cytoplasm) 8 rxns:
# - r_4587: ca2_e + h_e <=> ca2_c + h_c
# - r2073_1: h_e + zn2_e <=> h_c + zn2_c
# - MNt2: h_e + mn2_e <=> h_c + mn2_c
# - Clt: cl_e <=> cl_c
# - CHOLtu: chol_c <=> chol_e
# - r_4589: cu2_e + h_e <=> cu2_c + h_c
# - r_4592: h_e + mg2_e <=> h_c + mg2_c
# - r_4275: 2.0 fe3_e + nadph_c <=> 2.0 fe2_c + h_c + nadp_c
#
# metabolic reactions 13 rxns:
# - r_4331: chtn_c + h2o_c <=> acgam_c -- verfied, consolidated into CHTNASE.
# - r_4312: amet_c + carn_c <=> ahcys_c + ans_c + h_c
# - GGCLUT2: gthrd_c --> 5oxpro_c + cgly_c
# - NTP3: gtp_c + h2o_c --> gdp_c + h_c + pi_c
# - r_4403: h2o_c + pppi_c --> pi_c + ppi_c
# - GLYOX3: h_c + lac__D_c <=> h2o_c + mthgxl_c
# - GTHDH: dhdascb_c + 2.0 gthrd_c <=> ascb__L_c + gthox_c verfied, consolidated into DHAOX_c.
# - SERD_D: ser__D_c --> nh4_c + pyr_c
# - r_0438: focytc_m + 1.266 h_m + 0.25 o2_m --> ficytc_m + 0.5 h2o_m + 0.633 h_c
# - SERAT: accoa_c + ser__L_c --> acser_c + coa_c
# - r_1086: atp_c + h2o_c + h_c --> adp_c + 2.0 h_v + pi_c
# - r_1085: atp_c + h2o_c + h_c --> adp_c + 2.0 h_g + pi_c (not added to model, same genes as vacuole ATPase).
# - PSP_L: h2o_c + pser__L_c --> pi_c + ser__L_c

# %%
sce.reactions.r_4331
# Out:
# <Reaction r_4331 at 0x16aa2e990>

# %%
for m in model.metabolites.acgam_c.reactions:
    print(m)
# Out:
# ENGASE: h2o_c + s2l2n2m2m_c --> acgam_c + s2l2n2m2mn_c
# CHTNASE: chtn_c + 2.0 h2o_c --> 3.0 acgam_c
# ENGASE2: h2o_c + n2m2nm_c --> acgam_c + n2m2nmn_c

# %%
model.reactions.CHTNASE
# Out:
# <Reaction CHTNASE at 0x2a184bc90>

# %%
model.reactions.CHTNASE.check_mass_balance()
# Out:
# {}

# %%
sce.reactions.r_4331.check_mass_balance()
# Out:
# {'C': -16.0, 'H': -28.0, 'N': -2.0, 'O': -11.0}

# %%
sce.reactions.r_4331
# Out:
# <Reaction r_4331 at 0x16aa2e990>

# %% [markdown]
# sce reaction r_4331 has a different formula for chtn (c8) versus model chtn (c24). Add genes to CHTNASE in the model.

# %%
sce_added_orthologs_orhpans.loc[sce_added_orthologs_orhpans[0]=='r_4331']
# Out:
#          0                                                  1  \
# 50  r_4331  [1,4-(N-Acetyl-beta-D-glucosaminyl)]n glycanoh...
#
#                              2                   3  \
# 50  chtn_c + h2o_c <=> acgam_c  YDR371W or YLR286C
#
#                                     4
# 50  Lipst1_1_102785 or Lipst1_1_42376

# %% [markdown]
# gene Lipst1_1_42376 is not yet in the model.

# %%
model.reactions.CHTNASE.gene_reaction_rule = 'Lipst1_1_149679 or Lipst1_1_102785 or Lipst1_1_42376'

# %% [markdown]
# second metabolic reaction.
# - r_4312 amet_c + carn_c <=> ahcys_c + ans_c + h_c

# %%
sce.reactions.r_4312
# Out:
# <Reaction r_4312 at 0x16aa26ed0>

# %%
for r in model.metabolites.ahcys_c.reactions:
    print(r, r.name)
# Out:
# NNMT: amet_c + ncam_c --> 1mncam_c + ahcys_c Nicotinamide N methyltransferase
# SALMCOM2: adrnl_c + amet_c --> ahcys_c + h_c + mepi_c S-Adenosyl-L-methionine:catechol O-methyltransferase
# SALMCOM: amet_c + nrpphr_c --> ahcys_c + h_c + normete__L_c S-Adenosyl-L-methionine:catechol O-methyltransferase
# TM1819Z1819Z: 3.0 amet_c + dghs1819Z1819Z_c --> 3.0 ahcys_c + dgts1819Z1819Z_c + 3.0 h_c Betaine lipid synthase (trimethylase) (18:1(9Z)/18:1(9Z))
# DIPS: amet_c + caphis_c --> ahcys_c + cmaphis_c + h_c Diphthine synthase
# TM1601819Z: 3.0 amet_c + dghs1601819Z_c --> 3.0 ahcys_c + dgts1601819Z_c + 3.0 h_c Betaine lipid synthase (trimethylase) (16:0/18:1(9Z))
# AHCYStr: ahcys_c <=> ahcys_r S-Adenosyl-L-homocysteine intracellular diffusion
# MALCOAMT: amet_c + malcoa_c --> ahcys_c + malcoame_c Malonyl-CoA methyltransferase
# CCOAOMT: amet_c + caffcoa_c <=> ahcys_c + ferulcoa_c + h_c Caffeoyl-CoA O-methyltransferase
# UPP3MT: 2.0 amet_c + uppg3_c --> 2.0 ahcys_c + dscl_c + h_c Uroporphyrinogen methyltransferase
# AHCi: ahcys_c + h2o_c --> adn_c + hcys__L_c Adenosylhomocysteinase
# ACON3MT: acon_T_c + amet_c --> acon5m_c + ahcys_c Trans aconitate 3 methyltransferase
# 3IPM3MT: 3c2hmp_c + amet_c --> 3ipmmest_c + ahcys_c 3 Isopropylmalate 3 methyltransferase
# ARMT: amet_c + his__L_c --> NPmehis_c + ahcys_c + h_c HnRNP arginine N methyltransferase
# 34DHPHAMT: 34dhpha_c + amet_c --> ahcys_c + h_c + homoval_c 3,4-Dihydroxyphenylacetate:amet O-methyltransferase
# AMETt2m: ahcys_m + amet_c <=> ahcys_c + amet_m S-Adenosyl-L-methionine reversible transport, mitochondrial

# %% [markdown]
# reaction not in model. add.

# %%
r_copy = sce.reactions.r_4312.copy()

# %%
sce_added_orthologs_orhpans.loc[sce_added_orthologs_orhpans[0]=='r_4312']
# Out:
#           0                                                  1  \
# 361  r_4312  S-adenosyl-L-methionine:carnosine N-methyltran...
#
#                                              2        3               4
# 361  amet_c + carn_c <=> ahcys_c + ans_c + h_c  YNL092W  Lipst1_1_71580

# %%
model.add_reactions([r_copy])
model.reactions.r_4312.gene_reaction_rule = 'Lipst1_1_71580'

# %% [markdown]
# metabolic reaction #3
# - GGCLUT2: gthrd_c --> 5oxpro_c + cgly_c

# %%
sce.reactions.GGCLUT2
# Out:
# <Reaction GGCLUT2 at 0x16a9ec410>

# %%
for r in model.metabolites.cgly_c.reactions:
    print(r, r.name)
# Out:
# CGLYt3_2: cgly_e + 2.0 h_e --> cgly_c + 2.0 h_c Cys-Gly transport in via proton symport
# GTHRDH_syn: gthrd_c + h2o_c --> cgly_c + glu__L_c Glutathione hydralase (periplasmic)
# GTMLT: ala__L_c + gthrd_c --> cgly_c + gluala_c G glutamyltransferase
# AMPTASECG: cgly_c + h2o_c --> cys__L_c + gly_c Alanyl aminopeptidase (cys-gly)

# %%
for r in model.metabolites.get_by_id('5oxpro_c').reactions:
    print(r, r.name)
# Out:
# OPAH: 5oxpro_c + atp_c + 2.0 h2o_c --> adp_c + glu__L_c + h_c + pi_c 5-Oxoproline amidohydrolase (ATP-hydrolysing) (ir)

# %%
r_copy = sce.reactions.GGCLUT2.copy()
sce_added_orthologs_orhpans.loc[sce_added_orthologs_orhpans[0]=='GGCLUT2']
# Out:
#            0                                                  1  \
# 412  GGCLUT2  Glutathione-specific gamma-glutamylcyclotransf...
#
#                                  2        3               4
# 412  gthrd_c --> 5oxpro_c + cgly_c  YER163C  Lipst1_1_47595

# %%
model.add_reactions([r_copy])
model.reactions.GGCLUT2.gene_reaction_rule = 'Lipst1_1_47595'

# %% [markdown]
# metabolic reaction #4.
# - NTP3: gtp_c + h2o_c --> gdp_c + h_c + pi_c

# %%
sce.reactions.NTP3
# Out:
# <Reaction NTP3 at 0x16a550810>

# %%
for r in model.metabolites.gdp_c.reactions:
    print(r, r.name)
# Out:
# DOLPMTcer: dolp_c + gdpmann_c --> dolmanp_r + gdp_c Dolichyl phosphate D mannosyltransferase
# GK2: datp_c + gmp_c <=> dadp_c + gdp_c Guanylate kinase  GMPdATP
# G16MT: doldpglcnacglcnacmanman_c + gdpmann_c --> doldpglcnacglcnacman_man_man_c + gdp_c + h_c Alpha-1,6-mannosyltransferase (doldpglcnacglcnacman(man)man)
# NDPK1: atp_c + gdp_c <=> adp_c + gtp_c Nucleoside-diphosphate kinase (ATP:GDP)
# DOLPMT: dolp_c + gdpmann_c --> dolmanp_c + gdp_c Dolichyl-phosphate beta-D-mannosyltransferase
# UMPK4: gtp_c + ump_c <=> gdp_c + udp_c UMP kinase (GTP)
# GK1: atp_c + gmp_c <=> adp_c + gdp_c Guanylate kinase (GMP:ATP)
# CYTDK2: cytd_c + gtp_c --> cmp_c + gdp_c + h_c Cytidine kinase (GTP)
# G13MT_U: gdpmann_c + 0.1 mpdol_U_c --> gdp_c + h_c + 0.1 m1mpdol_U_c Glycolipid 1,3-alpha-D-mannosyltransferase (uterus)
# ATPATF3: gdp_c + gtp_c + h_c --> gp4g_c + pi_c ATP adenylyltransferase
# GTPt2m: gdp_m + gtp_c + h_c --> gdp_c + gtp_m + h_m GTPGDP translocase  mitochondrial  electroneutral
# G12MT1: doldpglcnacglcnacman_man_man_c + gdpmann_c --> doldpglcnacglcnacman_man_manman_c + gdp_c + h_c Alpha-1,2-mannosyltransferase (doldpglcnacglcnacman(man)manman)
# BDMT_U: 0.1 chito2pdol_U_c + gdpmann_c --> gdp_c + h_c + 0.1 mpdol_U_c GDPmannose:chitobiosyldiphosphodolichol beta-D-mannosyltransferase (uterus)
# RNDR2: gdp_c + trdrd_c --> dgdp_c + h2o_c + trdox_c Ribonucleoside-diphosphate reductase (GDP)
# BDMT_L: 0.1 chito2pdol__L_c + gdpmann_c --> gdp_c + h_c + 0.1 mpdol__L_c GDPmannose:chitobiosyldiphosphodolichol beta-D-mannosyltransferase (liver)
# URIK2: gtp_c + uri_c --> gdp_c + h_c + ump_c Uridine kinase (GTP:Uridine)
# FE2GTPabc: fe2_e + gtp_c + h2o_c --> fe2_c + gdp_c + h_c + pi_c Ferrous iron uptake (GTP-dependent), plasma membrane
# BDMT: doldpglcnacglcnac_c + gdpmann_c --> doldpglcnacglcnacman_c + gdp_c + h_c Chitobiosyldiphosphodolichol beta-mannosyltransferase
# ADSS: asp__L_c + gtp_c + imp_c --> dcamp_c + gdp_c + 2.0 h_c + pi_c Adenylosuccinate synthase
# G12MT2: doldpglcnacglcnacman_man_manman_c + gdpmann_c --> doldpglcnacglcnacman_man_manmanman_c + gdp_c + h_c Alpha-1,2-mannosyltransferase (doldpglcnacglcnacman(man)manmanman)
# G13MT: doldpglcnacglcnacman_c + gdpmann_c --> doldpglcnacglcnacmanman_c + gdp_c + h_c Alpha-1,3-mannosyltransferase (doldpglcnacglcnacmanman)
# G13MT_L: gdpmann_c + 0.1 mpdol__L_c --> gdp_c + h_c + 0.1 m1mpdol__L_c Glycolipid 1,3-alpha-D-mannosyltransferase (liver)

# %%
r_copy = sce.reactions.NTP3.copy()
x = sce_added_orthologs_orhpans.loc[sce_added_orthologs_orhpans[0]=='NTP3'][4]

# %%
x.values
# Out:
# array(['Lipst1_1_124163 or Lipst1_1_73932 or Lipst1_1_5321'], dtype=object)

# %%
model.add_reactions([r_copy])
model.reactions.NTP3.gene_reaction_rule = 'Lipst1_1_73932 or Lipst1_1_124163 or Lipst1_1_5321'

# %% [markdown]
# metabolic reaction #5

# %%
sce.reactions.r_4403
# Out:
# <Reaction r_4403 at 0x16a8efa50>

# %%
for r in model.metabolites.pppi_c.reactions:
    print(r, r.name)
# Out:
# PPPIt2r: h_e + pppi_e <=> h_c + pppi_c Triphosphate reversible transport via symport

# %%
r_copy = sce.reactions.r_4403.copy()
x = sce_added_orthologs_orhpans.loc[sce_added_orthologs_orhpans[0]=='r_4403'][4]

# %%
x.values
# Out:
# array(['Lipst1_1_72748'], dtype=object)

# %%
model.add_reactions([r_copy])
model.reactions.r_4403.gene_reaction_rule = 'Lipst1_1_72748'

# %% [markdown]
# metabolic reaction #6.
# - GLYOX3: h_c + lac__D_c <=> h2o_c + mthgxl_c

# %%
sce.reactions.GLYOX3
# Out:
# <Reaction GLYOX3 at 0x16a709e90>

# %%
for r in model.metabolites.mthgxl_c.reactions:
    print(r, r.name)
# Out:
# ALR2: h_c + mthgxl_c + nadph_c --> acetol_c + nadp_c Aldose reductase (methylglyoxal)
# LGTHL: gthrd_c + mthgxl_c --> lgt__S_c Lactoylglutathione lyase
# LALDO3: h_c + mthgxl_c + nadph_c --> lald__L_c + nadp_c L-Lactaldehyde:NADP+ 1-oxidoreductase
# LALDO2: h_c + mthgxl_c + nadph_c --> lald__D_c + nadp_c D-Lactaldehyde:NADP+ 1-oxidoreductase

# %%
r_copy = sce.reactions.GLYOX3.copy()
x = sce_added_orthologs_orhpans.loc[sce_added_orthologs_orhpans[0]=='GLYOX3'][4]

# %%
x.values
# Out:
# array(['Lipst1_1_3208'], dtype=object)

# %%
model.add_reactions([r_copy])
model.reactions.GLYOX3.gene_reaction_rule = 'Lipst1_1_3208'

# %% [markdown]
# metabolic reaction #7.
# - GTHDH: dhdascb_c + 2.0 gthrd_c <=> ascb__L_c + gthox_c

# %%
sce.reactions.GTHDH
# Out:
# <Reaction GTHDH at 0x16a9f88d0>

# %%
for r in model.metabolites.gthox_c.reactions:
    print(r, r.name)
# Out:
# GRXR: grxox_c + 2.0 gthrd_c --> grxrd_c + gthox_c Glutaredoxin reductase
# GTHOr: gthox_c + h_c + nadph_c <=> 2.0 gthrd_c + nadp_c Glutathione oxidoreductase
# GTHPi: 2.0 gthrd_c + h2o2_c --> gthox_c + 2.0 h2o_c Glutathione peridoxase
# DHAOX_c: dhdascb_c + 2.0 gthrd_c --> ascb__L_c + gthox_c + h_c Dehydroascorbate oxidoreductase

# %%
model.reactions.DHAOX_c
# Out:
# <Reaction DHAOX_c at 0x2a191b950>

# %%
# r_copy = sce.reactions.GTHDH.copy()
x = sce_added_orthologs_orhpans.loc[sce_added_orthologs_orhpans[0]=='GTHDH'][4]

# %%
x.values
# Out:
# array(['Lipst1_1_308673'], dtype=object)

# %%
model.reactions.DHAOX_c.check_mass_balance()
# Out:
# {}

# %%
sce.reactions.GTHDH.check_mass_balance()
# Out:
# {'charge': -1.0, 'H': -1.0}

# %% [markdown]
# add reaction gene rule to model. it is the same reaction as DHAOX_c

# %%
model.reactions.DHAOX_c.gene_reaction_rule = 'Lipst1_1_5188 or Lipst1_1_308673'

# %% [markdown]
# metabolic reaction #8.
# - SERD_D: ser__D_c --> nh4_c + pyr_c

# %%
sce.reactions.SERD_D
# Out:
# <Reaction SERD_D at 0x16aa0c290>

# %%
for r in model.metabolites.ser__D_c.reactions:
    print(r, r.name)
# Out:
# DSERDHr: nadp_c + ser__D_c <=> 2amsa_c + h_c + nadph_c D-serine dehydrogenase
# SER_Dt: ser__D_e --> ser__D_c D-serine transport

# %%
r_copy = sce.reactions.SERD_D.copy()
x = sce_added_orthologs_orhpans.loc[sce_added_orthologs_orhpans[0]=='SERD_D'][4]

# %%
x.values
# Out:
# array(['Lipst1_1_1096'], dtype=object)

# %%
model.add_reactions([r_copy])
model.reactions.SERD_D.gene_reaction_rule = 'Lipst1_1_1096'

# %% [markdown]
# metabolic reaction #9.
# - r_0438: focytc_m + 1.266 h_m + 0.25 o2_m --> ficytc_m + 0.5 h2o_m + 0.633 h_c

# %%
sce.reactions.r_0438
# Out:
# <Reaction r_0438 at 0x15b04a550>

# %%
for r in model.metabolites.focytc_m.reactions:
    print(r, r.name)
# Out:
# CYOR_u9m: 2.0 ficytc_m + 2.0 h_m + q9h2_m --> 2.0 focytc_m + 4.0 h_c + q9_m Ubiquinol 6 cytochrome c reductase
# CCP2_m: 2.0 focytc_m + h2o2_m + 2.0 h_m --> 2.0 ficytc_m + 2.0 h2o_m Cytochrome c peroxidase, mitochondrial
# CYOO6m: 4.0 focytc_m + 8.0 h_m + o2_m --> 4.0 ficytc_m + 2.0 h2o_m + 4.0 h_c Cytochrome c oxidase Complex IV
# D_LACDcm: 2.0 ficytc_m + lac__D_c --> 2.0 focytc_m + 2.0 h_c + pyr_c D lactate dehydrogenase  cytosolicmitochondrial
# L_LACDcm: 2.0 ficytc_m + lac__L_c --> 2.0 focytc_m + 2.0 h_c + pyr_c L-Lactate dehydrogenase, cytosolic/mitochondrial

# %%
model.reactions.CYOO6m.check_mass_balance()
# Out:
# {}

# %%
sce.reactions.r_0438.check_mass_balance()
# Out:
# {'charge': 0.367, 'H': 0.367}

# %%
# r_copy = sce.reactions.SERD_D.copy()
x = sce_added_orthologs_orhpans.loc[sce_added_orthologs_orhpans[0]=='r_0438'][4]

# %%
x.values
# Out:
# array(['Lipst1_1_3895 or Lipst1_1_65274 or Lipst1_1_65503 or Lipst1_1_54407 or Lipst1_1_25868 or Lipst1_1_4546 or Lipst1_1_67449 or Lipst1_1_55045 or Lipst1_1_3870 or Lipst1_1_41423 or Lipst1_1_106947'],
#       dtype=object)

# %%
temp = x.values
temp = [t.split(' or ') for t in temp]

# %%
temp2 = []
for g in model.reactions.CYOO6m.genes:
    temp2.append(g.id)

# %%
temp=temp[0]

# %%
set(temp)-set(temp2)
# Out:
# {'Lipst1_1_106947',
#  'Lipst1_1_25868',
#  'Lipst1_1_3870',
#  'Lipst1_1_41423',
#  'Lipst1_1_4546',
#  'Lipst1_1_65274'}

# %%
set(temp2)-set(temp)
# Out:
# {'Lipst1_1_5671'}

# %%
model.reactions.CYOO6m.gene_reaction_rule
# Out:
# 'Lipst1_1_54407 or Lipst1_1_65503 or Lipst1_1_67449 or Lipst1_1_3895 or Lipst1_1_55045 or Lipst1_1_5671'

# %% [markdown]
# These reactions above need consolidation.

# %%
# model.add_reactions([r_copy])
model.reactions.CYOO6m.gene_reaction_rule = 'Lipst1_1_3870 or Lipst1_1_54407 or Lipst1_1_65503 or Lipst1_1_25868 or Lipst1_1_4546 or Lipst1_1_55045 or Lipst1_1_106947 or Lipst1_1_3895 or Lipst1_1_41423 or Lipst1_1_65274 or Lipst1_1_67449 or Lipst1_1_5671'

# %% [markdown]
# metabolic reaction #9.
# - SERAT: accoa_c + ser__L_c --> acser_c + coa_c

# %%
sce.reactions.SERAT
# Out:
# <Reaction SERAT at 0x16a57a6d0>

# %%
for r in model.metabolites.acser_c.reactions:
    print(r, r.name)
# Out:
# CYSS: acser_c + h2s_c --> ac_c + cys__L_c + h_c Cysteine synthase

# %%
r_copy = sce.reactions.SERAT.copy()
x = sce_added_orthologs_orhpans.loc[sce_added_orthologs_orhpans[0]=='SERAT'][4]

# %%
x.values
# Out:
# array(['Lipst1_1_4043 or Lipst1_1_164418'], dtype=object)

# %%
model.add_reactions([r_copy])
model.reactions.SERAT.gene_reaction_rule = 'Lipst1_1_164418 or Lipst1_1_4043'

# %% [markdown]
# metabolic reaction #10.
# - r_1086: atp_c + h2o_c + h_c --> adp_c + 2.0 h_v + pi_c
# - r_1085: atp_c + h2o_c + h_c --> adp_c + 2.0 h_g + pi_c

# %%
sce.reactions.r_1086
# Out:
# <Reaction r_1086 at 0x16a593c50>

# %%
for r in model.metabolites.h_v.reactions:
    print(r, r.name)
# Out:
# GLUt7: glu__L_v + h_v --> glu__L_c + h_c L glutamate transport out via proton symport  vacuolar
# PSERDv_RT: h_v + 0.01 ps_RT_v --> co2_v + 0.01 pe_RT_v Phosphatidylserine decarboxylase  yeast specific  vacuolar
# TYRt6: h_v + tyr__L_c --> h_c + tyr__L_v L tyrosine transport in via proton antiport  vacuolar
# TYRt7: h_v + tyr__L_v --> h_c + tyr__L_c L tyrosine transport out via proton symport  vacuolar
# ATPS2v: atp_c + h2o_c + h_c --> adp_c + 2.0 h_v + pi_c Vacuolar H+-ATPase
# ILEt7: h_v + ile__L_v --> h_c + ile__L_c L isoleucine transport out via proton symport  vacuolar
# LEUt7: h_v + leu__L_v --> h_c + leu__L_c L leucine transport out via proton symport  vacuolar
# LYSt6: h_v + lys__L_c --> h_c + lys__L_v L lysine transport in via proton antiport  vacuolar
# GLNt6: gln__L_c + h_v --> gln__L_v + h_c L glutamine transport in via proton antiport  vacuolar
# ASPt7: asp__L_v + h_v --> asp__L_c + h_c L aspartate transport out via proton symport  vacuolar
# GTHRDabcv: atp_v + gthrd_c + h2o_v --> adp_v + gthrd_v + h_v + pi_v Reduced glutathione via ABC system  vacuolar
# GLNt7: gln__L_v + h_v --> gln__L_c + h_c L glutamine transport out via proton symport  vacuolar
# ASNt7: asn__L_v + h_v --> asn__L_c + h_c L asparagine transport out via proton symport  vacuolar
# TCHOLAabcv: atp_v + h2o_v + tchola_c --> adp_v + h_v + pi_v + tchola_v Taurcholate via ABC system  vacuolar
# HISt6: h_v + his__L_c --> h_c + his__L_v L histidine transport in via proton antiport  vacuolar
# ASNt6: asn__L_c + h_v --> asn__L_v + h_c L asparagine transport in via proton antiport  vacuolar
# LEUt6: h_v + leu__L_c --> h_c + leu__L_v L leucine transport in via proton antiport  vacuolar
# ILEt6: h_v + ile__L_c --> h_c + ile__L_v L isoleucine transport in via proton antiport  vacuolar

# %%
model.reactions.ATPS2v.gene_reaction_rule
# Out:
# 'Lipst1_1_27636 and Lipst1_1_4281 and Lipst1_1_103286 and Lipst1_1_4502 and Lipst1_1_72599 and Lipst1_1_71403 and Lipst1_1_149291 and Lipst1_1_67780 and Lipst1_1_4471 and Lipst1_1_2781 and Lipst1_1_60868 and Lipst1_1_69438 and Lipst1_1_102936 and Lipst1_1_64406'

# %%
r_copy = sce.reactions.r_1086.copy()
x = sce_added_orthologs_orhpans.loc[sce_added_orthologs_orhpans[0]=='r_1086'][4]

# %%
x.values
# Out:
# array(['Lipst1_1_2781 or Lipst1_1_102936 or Lipst1_1_60868 or Lipst1_1_71403 or Lipst1_1_69438 or Lipst1_1_4502 or Lipst1_1_149291 or Lipst1_1_72599 or Lipst1_1_103286 or Lipst1_1_4471 or Lipst1_1_67780 or Lipst1_1_4281 or Lipst1_1_27636 or Lipst1_1_64406 or Lipst1_1_51333'],
#       dtype=object)

# %%
temp = x.values
temp = [t.split(' or ') for t in temp]

# %%
temp
# Out:
# [['Lipst1_1_2781',
#   'Lipst1_1_102936',
#   'Lipst1_1_60868',
#   'Lipst1_1_71403',
#   'Lipst1_1_69438',
#   'Lipst1_1_4502',
#   'Lipst1_1_149291',
#   'Lipst1_1_72599',
#   'Lipst1_1_103286',
#   'Lipst1_1_4471',
#   'Lipst1_1_67780',
#   'Lipst1_1_4281',
#   'Lipst1_1_27636',
#   'Lipst1_1_64406',
#   'Lipst1_1_51333']]

# %%
temp = set(temp[0])
temp
# Out:
# {'Lipst1_1_102936',
#  'Lipst1_1_103286',
#  'Lipst1_1_149291',
#  'Lipst1_1_27636',
#  'Lipst1_1_2781',
#  'Lipst1_1_4281',
#  'Lipst1_1_4471',
#  'Lipst1_1_4502',
#  'Lipst1_1_51333',
#  'Lipst1_1_60868',
#  'Lipst1_1_64406',
#  'Lipst1_1_67780',
#  'Lipst1_1_69438',
#  'Lipst1_1_71403',
#  'Lipst1_1_72599'}

# %%
temp2 = []
for g in model.reactions.ATPS2v.genes:
    temp2.append(g.id)

# %%
temp-set(temp2)
# Out:
# {'Lipst1_1_51333'}

# %%
set(temp2)-temp
# Out:
# set()

# %% [markdown]
# one extra gene was not included in the model. will add

# %%
# model.add_reactions([r_copy])
model.reactions.ATPS2v.gene_reaction_rule = 'Lipst1_1_71403 or Lipst1_1_51333 or Lipst1_1_103286 or Lipst1_1_27636 or Lipst1_1_149291 or Lipst1_1_72599 or Lipst1_1_2781 or Lipst1_1_4471 or Lipst1_1_67780 or Lipst1_1_4502 or Lipst1_1_102936 or Lipst1_1_69438 or Lipst1_1_4281 or Lipst1_1_60868 or Lipst1_1_64406'

# %% [markdown]
# metabolic reaction #10.
# - r_1086: atp_c + h2o_c + h_c --> adp_c + 2.0 h_v + pi_c
# - r_1085: atp_c + h2o_c + h_c --> adp_c + 2.0 h_g + pi_c

# %%
sce.reactions.r_1085
# Out:
# <Reaction r_1085 at 0x16a57b850>

# %%
for r in model.metabolites.h_g.reactions:
    print(r, r.name)
# Out:
# CERGT18g: cer6_18_g + udpg_g --> glccer_18_g + h_g + udp_g Ceramide glucosyltransferase  18C
# MIPCS326g_RT: gdpmann_g + 0.01 ipc326_RT_g --> gdp_g + h_g + 0.01 mipc326_RT_g Mannose inositol phosphorylceramide synthase  ceramide 3  26C   yeast specific
# NAt3_1g: h_g + na1_c <=> h_c + na1_g Sodium proton antiporter (H:NA is 1:1)
# PSERDg_RT: h_g + 0.01 ps_RT_g --> co2_g + 0.01 pe_RT_g Phosphatidylserine decarboxylase  yeast specific  Golgi
# MIPCS324g_RT: gdpmann_g + 0.01 ipc324_RT_g --> gdp_g + h_g + 0.01 mipc324_RT_g Mannose inositol phosphorylceramide synthase  ceramide 3  24C   yeast specific
# IPC324PLCg_RT: h2o_g + 0.01 ipc324_RT_g --> cer3_24_g + h_g + mi1p__D_g Inositol phosphorylceramide  ceramide 3  24C  phospholipase C
# MIPCS126g_RT: gdpmann_g + 0.01 ipc126_RT_g --> gdp_g + h_g + 0.01 mipc126_RT_g Mannose inositol phosphorylceramide synthase  ceramide 1  26C   yeast specific
# UDPGLDCg: h_g + udpglcur_g --> co2_g + udpxyl_g UDP-D-glucuronate decarboxylase, Golgi apparatus
# MIPC124PLCg_RT: h2o_g + 0.01 mipc124_RT_g --> cer1_24_g + h_g + manmi1p__D_g Mannose inositol phosphorylceramide  ceramide 1  24C  phospholipase C
# MIP2C126PLCg_RT: h2o_g + 0.01 mip2c126_RT_g --> cer1_26_g + h_g + man2mi1p__D_g Mannose  inositol P 2 ceramide  ceramide 1  26C  phospholipase C
# MIP2C324PLCg_RT: h2o_g + 0.01 mip2c324_RT_g --> cer3_24_g + h_g + man2mi1p__D_g Mannose  inositol P 2 ceramide  ceramide 3  24C  phospholipase C
# MIP2C226PLCg_RT: h2o_g + 0.01 mip2c226_RT_g --> cer2_26_g + h_g + man2mi1p__D_g Mannose  inositol P 2 ceramide  ceramide 2  26C  phospholipase C
# MIPC226PLCg_RT: h2o_g + 0.01 mipc226_RT_g --> cer2_26_g + h_g + manmi1p__D_g Mannose inositol phosphorylceramide  ceramide 2  26C  phospholipase C
# IPC224PLCg_RT: h2o_g + 0.01 ipc224_RT_g --> cer2_24_g + h_g + mi1p__D_g Inositol phosphorylceramide  ceramide 2  24C  phospholipase C
# NDP3g: gdp_g + h2o_g --> gmp_g + h_g + pi_g Nucleoside diphosphatase  GDP   Golgi
# MIP2C224PLCg_RT: h2o_g + 0.01 mip2c224_RT_g --> cer2_24_g + h_g + man2mi1p__D_g Mannose  inositol P 2 ceramide  ceramide 2  24C  phospholipase C
# IPC326PLCg_RT: h2o_g + 0.01 ipc326_RT_g --> cer3_26_g + h_g + mi1p__D_g Inositol phosphorylceramide  ceramide 3  26C  phospholipase C
# MIPC224PLCg_RT: h2o_g + 0.01 mipc224_RT_g --> cer2_24_g + h_g + manmi1p__D_g Mannose inositol phosphorylceramide  ceramide 2  24C  phospholipase C
# IPC124PLCg_RT: h2o_g + 0.01 ipc124_RT_g --> cer1_24_g + h_g + mi1p__D_g Inositol phosphorylceramide  ceramide 1  24C  phospholipase C
# NDP7g: h2o_g + udp_g --> h_g + pi_g + ump_g Nucleoside-diphosphatase (UDP), Golgi apparatus
# IPC226PLCg_RT: h2o_g + 0.01 ipc226_RT_g --> cer2_26_g + h_g + mi1p__D_g Inositol phosphorylceramide  ceramide 2  26C  phospholipase C
# MIPCS226g_RT: gdpmann_g + 0.01 ipc226_RT_g --> gdp_g + h_g + 0.01 mipc226_RT_g Mannose inositol phosphorylceramide synthase  ceramide 2  26C   yeast specific
# MIPC326PLCg_RT: h2o_g + 0.01 mipc326_RT_g --> cer3_26_g + h_g + manmi1p__D_g Mannose inositol phosphorylceramide  ceramide 3  26C  phospholipase C
# MIPCS124g_RT: gdpmann_g + 0.01 ipc124_RT_g --> gdp_g + h_g + 0.01 mipc124_RT_g Mannose inositiol phophorylceramide synthase  ceramide 1  24C   yeast specific
# MIPC324PLCg_RT: h2o_g + 0.01 mipc324_RT_g --> cer3_24_g + h_g + manmi1p__D_g Mannose inositol phosphorylceramide  ceramide 3  24C  phospholipase C
# MIP2C326PLCg_RT: h2o_g + 0.01 mip2c326_RT_g --> cer3_26_g + h_g + man2mi1p__D_g Mannose  inositol P 2 ceramide  ceramide 3  26C  phospholipase C
# G12MT2g: gdpmann_g + m3macchitppdol_g --> gdp_g + h_g + m4macchitppdol_g Glycolipid 1 2 alpha D mannosyltransferase  Golgi apparatus
# G12MT1g: gdpmann_g + m2macchitppdol_g --> gdp_g + h_g + m3macchitppdol_g Glycolipid 1 2 alpha D mannosyltransferase  Golgi apparatus
# MIPCS224g_RT: gdpmann_g + 0.01 ipc224_RT_g --> gdp_g + h_g + 0.01 mipc224_RT_g Mannose inositol phosphorylceramide synthase  ceramide 2  24C   yeast specific
# MIPC126PLCg_RT: h2o_g + 0.01 mipc126_RT_g --> cer1_26_g + h_g + manmi1p__D_g Mannose inositol phosphorylceramide  ceramide 1  26C  phospholipase C
# MIP2C124PLCg_RT: h2o_g + 0.01 mip2c124_RT_g --> cer1_24_g + h_g + man2mi1p__D_g Mannose  inositol P 2 ceramide  ceramide 1  24C  phospholipase C
# IPC126PLCg_RT: h2o_g + 0.01 ipc126_RT_g --> cer1_26_g + h_g + mi1p__D_g Inositol phosphorylceramide  ceramide 1  26C  phospholipase C
# Kt3g: h_g + k_c <=> h_c + k_g Potassium transport  via proton antiport

# %% [markdown]
# no atpase reaction in golgi

# %%
r_copy = sce.reactions.r_1085.copy()
x = sce_added_orthologs_orhpans.loc[sce_added_orthologs_orhpans[0]=='r_1085'][4]

# %%
x.values
# Out:
# array(['Lipst1_1_2781 or Lipst1_1_102936 or Lipst1_1_60868 or Lipst1_1_71403 or Lipst1_1_69438 or Lipst1_1_4502 or Lipst1_1_149291 or Lipst1_1_72599 or Lipst1_1_103286 or Lipst1_1_4471 or Lipst1_1_4281 or Lipst1_1_27636 or Lipst1_1_64406 or Lipst1_1_51333'],
#       dtype=object)

# %%
temp = x.values
temp = [t.split(' or ') for t in temp]

# %%
temp
# Out:
# [['Lipst1_1_2781',
#   'Lipst1_1_102936',
#   'Lipst1_1_60868',
#   'Lipst1_1_71403',
#   'Lipst1_1_69438',
#   'Lipst1_1_4502',
#   'Lipst1_1_149291',
#   'Lipst1_1_72599',
#   'Lipst1_1_103286',
#   'Lipst1_1_4471',
#   'Lipst1_1_4281',
#   'Lipst1_1_27636',
#   'Lipst1_1_64406',
#   'Lipst1_1_51333']]

# %%
temp = set(temp[0])
temp
# Out:
# {'Lipst1_1_102936',
#  'Lipst1_1_103286',
#  'Lipst1_1_149291',
#  'Lipst1_1_27636',
#  'Lipst1_1_2781',
#  'Lipst1_1_4281',
#  'Lipst1_1_4471',
#  'Lipst1_1_4502',
#  'Lipst1_1_51333',
#  'Lipst1_1_60868',
#  'Lipst1_1_64406',
#  'Lipst1_1_69438',
#  'Lipst1_1_71403',
#  'Lipst1_1_72599'}

# %%
temp2 = []
for g in model.reactions.ATPS2v.genes:
    temp2.append(g.id)

# %%
temp-set(temp2)
# Out:
# set()

# %% [markdown]
# no differences from the vacuoloe ATPASE. not added to model.

# %%
model.reactions.ATPS
# Out:
# <Reaction ATPS at 0x15b7fdb10>

# %%
rto.reactions.ATPS
# Out:
# <Reaction ATPS at 0x15a0ef290>

# %% [markdown]
# cytosolic ATPase may needed looking at for the GPR.

# %%
# model.add_reactions([r_copy])
# model.reactions.ATPS2v.gene_reaction_rule = 'Lipst1_1_71403 or Lipst1_1_51333 or Lipst1_1_103286 or Lipst1_1_27636 or Lipst1_1_149291 or Lipst1_1_72599 or Lipst1_1_2781 or Lipst1_1_4471 or Lipst1_1_67780 or Lipst1_1_4502 or Lipst1_1_102936 or Lipst1_1_69438 or Lipst1_1_4281 or Lipst1_1_60868 or Lipst1_1_64406'

# %% [markdown]
# reaction 13.
# - PSP_L: h2o_c + pser__L_c --> pi_c + ser__L_c

# %%
sce.reactions.PSP_L
# Out:
# <Reaction PSP_L at 0x16a4fe890>

# %%
model.reactions.PSP_L
# Out:
# <Reaction PSP_L at 0x2a6985910>

# %%
r_copy = sce.reactions.PSP_L.copy()
x = sce_added_orthologs_orhpans.loc[sce_added_orthologs_orhpans[0]=='PSP_L'][4]

# %%
x.values
# Out:
# array(['Lipst1_1_1740'], dtype=object)

# %%
# model.add_reactions([r_copy])
# model.reactions.PSP_L.gene_reaction_rule = 'Lipst1_1_1740'

# %%
model.reactions.PSP_L
# Out:
# <Reaction PSP_L at 0x2a6985910>

# %%
genes = model.genes
genes = [g.id for g in genes]
wrong = [g for g in genes if 'Lipst1' not in g]
len(set(wrong))
wrong_g2 = []
wrong_rx2 = []
for g in wrong:
    reac = model.genes.get_by_id(g).reactions
    if not reac:
        print(f'{g} has no associated reaction')
        
        cobra.manipulation.delete.remove_genes(model,[g])
    for rx in reac:
        if rx:
#             print(rx,g)
            wrong_g2.append(g)
            wrong_rx2.append(rx)
print(len(set(wrong_g2)))
print(len(set(wrong_rx2)))
# Out:
# YNL092W has no associated reaction
# YER163C has no associated reaction
# YAL035W has no associated reaction
# YER005W has no associated reaction
# YLL001W has no associated reaction
# YHR201C has no associated reaction
# YDR452W has no associated reaction
# YOR391C has no associated reaction
# YDR533C has no associated reaction
# YMR322C has no associated reaction
# YPL280W has no associated reaction
# YGL196W has no associated reaction
# YHR013C has no associated reaction
# YDL040C has no associated reaction
# YOR253W has no associated reaction
# 31
# 16

# %%
len(set(wrong_rx2))
# Out:
# 16

# %%
wrong_rx2 = [x.id for x in wrong_rx2]
set(wrong_rx2)
# Out:
# {'ACRNtp',
#  'C30CPT1',
#  'C3STKR1er',
#  'C3STKR2er',
#  'CRNtp',
#  'CYOR_u9m',
#  'DNTPPA',
#  'DRTPPD',
#  'FA160COAabcp',
#  'FA183COAabcp',
#  'FA240tp',
#  'GAPP',
#  'H2Otm',
#  'OIVD2m',
#  'PMDPHT',
#  'SERPTer'}

# %%
maintained_v01_gpr
# Out:
# ['H2Otm',
#  'DNTPPA',
#  'PMDPHT',
#  'ACRNtp',
#  'CRNtp',
#  'FA240tp',
#  'FA160COAabcp',
#  'DRTPPD']

# %% [markdown]
# ## here we will try to adjust the 16 reactions to look for Lst GPRs.

# %%
# obtain reactions to iterate over.
iterate_rxns = set(wrong_rx2)

# reset the information holding lists. 
_names = []
_gpr = []
_id = []
_stoich = []
_subsystem = []
gpr_holder = []

# iterate through the reactions. 
for rx in iterate_rxns:
    
    # obtain the rto reaction object.
    r = rto.reactions.get_by_id(rx)
    
    
    # objects for tracking. 
    count_ortho = 0
    temp_gpr = []
    
    # iterate over the rto reaction genes. 
    for i in range(len(r.genes)):
        
        
        g=list(r.genes)[i]
        g = g.id
        
        # find the ortholog.
        try:
            
            # find the ortholog.
            value = lst_rto_dict[g]
            
            # verify that the ortholog exists & 
            # is not in the model genes &
            if (value):

                count_ortho+=1
        except:
            continue
    
    # if the reaction had at least one gene ortholog in Lst. 
    if count_ortho>0:
        # append reaction metadata. 
        _gpr.append(r.gene_reaction_rule)
        _stoich.append(r.reaction)        
        _names.append(r.name)
        _id.append(r.id)  
        
# obtain the sce reactions that have orthologs.      
new_iterate_rxns = set(_id)                            
                             
print(len(new_iterate_rxns))


# reset the information holding lists. 
_names = []
_gpr = []
_id = []
_stoich = []
_subsystem = []
gpr_holder = []

# iterate over the reactions. 
for rx in new_iterate_rxns:
    
    # obtain the rto reaction object. 
    r = rto.reactions.get_by_id(rx)
    
    # store reaction metadata. 
    _gpr.append(r.gene_reaction_rule)
    _stoich.append(r.reaction)
    _names.append(r.name)
    _id.append(r.id)
    
    # objects for tracking during loop. 
    count_ortho =0
    temp_gpr = []
    
    # iterate over the sce reaction genes. 
    for i in range(len(r.genes)):

        g=list(r.genes)[i]
        g = g.id

        try:
            
            # obtain the Lst ortholog. 
            value = lst_rto_dict[g]
            
            if (value):
                count_ortho+=1
        except:
            continue

    # this implies that at least one gene has been found that was not included in the reaction.
    if count_ortho>0:
        
        # re-run the gene iteration to capture all orthologs. 
        for i in range(len(r.genes)):
            
            g=list(r.genes)[i]
            g = g.id
            
            try:
                # obtain the Lst ortholog. 
                value = lst_rto_dict[g]
                if (value):
                    temp_gpr.append(value)
            except:
                continue
        
        # join multiple genes for a single reaction together using 'or' rules. 
        temp = " or ".join(sub_item.replace("None", "").replace("NA"," ") for sub_item in temp_gpr)
        gpr_holder.append(temp)

# pd.DataFrame() for storing the reactions.         
rto_added_orthologs_orhpans = pd.DataFrame([_id,_names,_stoich,_gpr,gpr_holder]).T
# Out:
# 3

# %%
rto_added_orthologs_orhpans
# Out:
#           0                                                  1  \
# 0   SERPTer  Palmitoyl-CoA:L-serine C-palmitoyltransferase ...
# 1  CYOR_u9m                 Ubiquinol 6 cytochrome c reductase
# 2    OIVD2m  2-oxoisovalerate dehydrogenase (acylating; 3-m...
#
#                                                    2  \
# 0  h_r + pmtcoa_r + ser__L_r --> 3dsphgn_r + co2_...
# 1  2.0 ficytc_m + 2.0 h_m + q9h2_m --> 2.0 focytc...
# 2  3mob_m + coa_m + nad_m --> co2_m + ibcoa_m + n...
#
#                                                    3  \
# 0                            10303 and 9394 and 9425
# 1  COB and 9705 and 9198 and 11618 and 15758 and ...
# 2  (10040 and 11183 and 12566 and 15436) or (1004...
#
#                                                    4
# 0                   Lipst1_1_72156 or Lipst1_1_71191
# 1  Lipst1_1_70538 or Lipst1_1_112667 or Lipst1_1_...
# 2                                     Lipst1_1_67480

# %%
for r in iterate_rxns:
    print(r, model.reactions.get_by_id(r).gene_reaction_rule)
# Out:
# DNTPPA 15385
# ACRNtp 10149
# CRNtp 10149
# FA240tp 9912
# H2Otm 9014 or Lipst1_1_156565
# SERPTer 10303 and 9394 and 9425
# CYOR_u9m 15681 or 15758 or 13608 or 13614 or 15231 or COB or 9830 or 9705 or 8802 or 11618 or 12966 or 9198 or Lipst1_1_6808 or Lipst1_1_38038 or Lipst1_1_3376 or Lipst1_1_70538 or Lipst1_1_42388 or Lipst1_1_112667
# PMDPHT 11513
# C3STKR2er 14213 or Lipst1_1_50180
# C30CPT1 9315
# GAPP 8460
# FA160COAabcp 13167 and 9637
# C3STKR1er 14213 or Lipst1_1_50180
# DRTPPD 15506
# OIVD2m (10040 and 11183 and 12566 and 15436) or (10040 and 11188 and 12566 and 15436)
# FA183COAabcp 13167 and 9637

# %%
model.reactions.H2Otm.gene_reaction_rule = 'Lipst1_1_156565'
model.reactions.C3STKR2er.gene_reaction_rule = 'Lipst1_1_50180'
model.reactions.C3STKR1er.gene_reaction_rule = 'Lipst1_1_50180'

# %%
model.reactions.SERPTer.gene_reaction_rule = 'Lipst1_1_71191 or Lipst1_1_72156'
model.reactions.OIVD2m.gene_reaction_rule = 'Lipst1_1_67480'
# model.reactions.C3STKR1er.gene_reaction_rule = 'Lipst1_1_50180'

# %%
x = rto_added_orthologs_orhpans[rto_added_orthologs_orhpans[0]=='CYOR_u9m'][4].values

# %% [markdown]
# 15681 or 15758 or 13608 or 12966 or 15231 or 9198 or 9830 or 9705 or 11618 or COB or 8802 or 13614 or Lipst1_1_3376 or Lipst1_1_38038 or Lipst1_1_42388 or Lipst1_1_70538 or Lipst1_1_6808 or Lipst1_1_112667

# %%
x
# Out:
# array(['Lipst1_1_70538 or Lipst1_1_112667 or Lipst1_1_49747 or Lipst1_1_72848 or Lipst1_1_3376 or Lipst1_1_65274 or Lipst1_1_42388 or Lipst1_1_6808 or Lipst1_1_38038 or Lipst1_1_47735'],
#       dtype=object)

# %%
temp = x
temp = [t.split(' or ') for t in temp]

# %%
temp2 = []
for g in model.reactions.CYOR_u9m.genes:
    temp2.append(g.id)

# %%
temp=temp[0]

# %%
set(temp)-set(temp2)
# Out:
# {'Lipst1_1_47735', 'Lipst1_1_49747', 'Lipst1_1_65274', 'Lipst1_1_72848'}

# %%
set(temp2)-set(temp)
# Out:
# {'11618',
#  '12966',
#  '13608',
#  '13614',
#  '15231',
#  '15681',
#  '15758',
#  '8802',
#  '9198',
#  '9705',
#  '9830',
#  'COB'}

# %%
model.reactions.CYOR_u9m.gene_reaction_rule = 'Lipst1_1_49747 or Lipst1_1_112667 or Lipst1_1_70538 or Lipst1_1_42388 or Lipst1_1_65274 or Lipst1_1_6808 or Lipst1_1_38038 or Lipst1_1_72848 or Lipst1_1_3376 or Lipst1_1_47735'

# %%
genes = model.genes
genes = [g.id for g in genes]
wrong = [g for g in genes if 'Lipst1' not in g]
len(set(wrong))
wrong_g2 = []
wrong_rx2 = []
for g in wrong:
    reac = model.genes.get_by_id(g).reactions
    if not reac:
        print(f'{g} has no associated reaction')
        
        cobra.manipulation.delete.remove_genes(model,[g])
    for rx in reac:
        if rx:
#             print(rx,g)
            wrong_g2.append(g)
            wrong_rx2.append(rx)
print(len(set(wrong_g2)))
print(len(set(wrong_rx2)))
# Out:
# 15231 has no associated reaction
# 15681 has no associated reaction
# 15758 has no associated reaction
# 8802 has no associated reaction
# 9198 has no associated reaction
# 9705 has no associated reaction
# 9830 has no associated reaction
# 13608 has no associated reaction
# 11618 has no associated reaction
# COB has no associated reaction
# 12966 has no associated reaction
# 13614 has no associated reaction
# 9014 has no associated reaction
# 9394 has no associated reaction
# 10303 has no associated reaction
# 9425 has no associated reaction
# 11183 has no associated reaction
# 11188 has no associated reaction
# 15436 has no associated reaction
# 12566 has no associated reaction
# 10040 has no associated reaction
# 14213 has no associated reaction
# 9
# 10

# %%
wrong_rx2 = [x.id for x in wrong_rx2]
set(wrong_rx2)
# Out:
# {'ACRNtp',
#  'C30CPT1',
#  'CRNtp',
#  'DNTPPA',
#  'DRTPPD',
#  'FA160COAabcp',
#  'FA183COAabcp',
#  'FA240tp',
#  'GAPP',
#  'PMDPHT'}

# %%
# lst_rto_dict['9705']

# %%
# set(wrong_rx2)-set(maintained_v01_gpr)

# %%
temp = set(wrong_rx2)
for x in temp:
    r = model.reactions.get_by_id(x)
    print(r.id)
    print(r.name)
    print(r.gene_reaction_rule)
    print('\n')
# Out:
# DNTPPA
# Dihydroneopterin triphosphate pyrophosphatase
# 15385
#
#
# ACRNtp
# Acetylcarnitine transport out of peroxisome
# 10149
#
#
# FA240tp
# Fatty acid peroxisomal transport
# 9912
#
#
# PMDPHT
# Pyrimidine phosphatase
# 11513
#
#
# C30CPT1
# Production of propionylcarnitine
# 9315
#
#
# GAPP
# Glyceraldehyde-3-phosphate phosphatase
# 8460
#
#
# FA160COAabcp
# Fatty acyl CoA peroxisomal transport via ABC system
# 13167 and 9637
#
#
# DRTPPD
# 2 5 diamino 6 ribitylamino 4 3H  pyrimidinone 5  phosphate deaminase
# 15506
#
#
# CRNtp
# Carnitine transport into peroxsiome
# 10149
#
#
# FA183COAabcp
# Fatty acid peroxisomal transport via ABC system
# 13167 and 9637

# %%
ylip_added_orthologs_orhpans
# Out:
#               0                                                  1  \
# 0         PSP_L                 phosphoserine phosphatase L serine
# 1    FAS160ACPm    fatty acyl ACP synthase n C160ACP mitochondrial
# 2        ATPS3g                       ATP synthase Golgi Apparatus
# 3          DOLK                                    Dolichol kinase
# 4        PETHCT             phosphoethanolamine cytidyltransferase
# 5    FAS161ACPm    fatty acyl ACP synthase n C161ACP mitochondrial
# 6   FAS80ACPm_L  fatty acyl ACP synthase n C80ACP mitochondrial...
# 7    FAS140ACPm    fatty acyl ACP synthase n C140ACP mitochondrial
# 8         ACt2r    acetate reversible transport via proton symport
# 9       HBZOPT6              Hydroxybenzoate octaprenyltransferase
# 10   FAS180ACPm    fatty acyl ACP synthase n C180ACP mitochondrial
# 11   FAS141ACPm    fatty acyl ACP synthase n C141ACP mitochondrial
# 12       FA60tp                fatty acid peroxisomal transport YL
# 13       FA40tp                fatty acid peroxisomal transport YL
# 14        CYOOm                 cytochrome c oxidase mitochondrial
# 15   FAS181ACPm    fatty acyl ACP synthase n C181ACP mitochondrial
# 16          TGL                                                TGL
# 17        exlip                           extracelular lipases TAG
# 18   FAS100ACPm    fatty acyl ACP synthase n C100ACP mitochondrial
# 19      OHPHM6n     2 octaprenyl 6 hydroxyphenol methylase nuclear
# 20   FAS120ACPm    fatty acyl ACP synthase n C120ACP mitochondrial
# 21       SPRMti                      spermine irreversible uniport
# 22   FAS182ACPm    fatty acyl ACP synthase n C182ACP mitochondrial
# 23      ATPCitL                               ATP Citrate Lyase YL
#
#                                                     2  \
# 0               h2o_c + pser__L_c --> pi_c + ser__L_c
# 1   3.0 h_m + malACP_m + myrsACP_m + 2.0 nadph_m -...
# 2   adp_g + 3.0 h_c + pi_g --> atp_g + h2o_g + 2.0...
# 3         ctp_c + dolichol_c --> cdp_c + dolp_c + h_c
# 4          ctp_c + ethamp_c + h_c --> cdpea_c + ppi_c
# 5   4.0 h_m + malACP_m + myrsACP_m + 3.0 nadph_m +...
# 6   acACP_m + 9.0 h_m + 3.0 malACP_m + 6.0 nadph_m...
# 7   ddcaACP_m + 3.0 h_m + malACP_m + 2.0 nadph_m -...
# 8                           ac_e + h_e <=> ac_c + h_c
# 9            4hbz_c + octdp_5_c --> 3ophb_5_c + ppi_c
# 10  3.0 h_m + malACP_m + 2.0 nadph_m + palmACP_m -...
# 11  ddcaACP_m + 4.0 h_m + malACP_m + 3.0 nadph_m +...
# 12                                    hca_c --> hca_x
# 13                                  buca_c --> buca_x
# 14  4.0 focytc_m + 6.0 h_m + o2_m --> 4.0 ficytc_m...
# 15  4.0 h_m + malACP_m + 3.0 nadph_m + o2_m + palm...
# 16  h2o_c + 0.01 triglyc_SC_c --> 0.01 12dgr_SC_c ...
# 17  triglyc_SC_e --> 0.02 dca_e + 0.06 ddca_e + 0....
# 18  3.0 h_m + malACP_m + 2.0 nadph_m + ocACP_m -->...
# 19   2ohph_5_n + amet_n --> 2omph_5_n + ahcys_n + h_n
# 20  dcaACP_m + 3.0 h_m + malACP_m + 2.0 nadph_m --...
# 21                                  sprm_e --> sprm_c
# 22  5.0 h_m + malACP_m + 4.0 nadph_m + 2.0 o2_m + ...
# 23  atp_c + cit_c + coa_c --> accoa_c + adp_c + oa...
#
#                                                     3  \
# 0                                        YALI0B20438g
# 1   YALI0D14850g and YALI0D24629g and YALI0F30679g...
# 2   YALI0A09900g and YALI0A11143g and YALI0B03982g...
# 3                                        YALI0E18942g
# 4                                        YALI0C06303g
# 5   YALI0D14850g and YALI0D24629g and YALI0F30679g...
# 6   YALI0D14850g and YALI0D24629g and YALI0F30679g...
# 7   YALI0D14850g and YALI0D24629g and YALI0F30679g...
# 8                                        YALI0E04312g
# 9   (YALI0E09276g and YALI0B16126g) or (YALI0E1366...
# 10  YALI0D14850g and YALI0D24629g and YALI0F30679g...
# 11  YALI0D14850g and YALI0D24629g and YALI0F30679g...
# 12                                       YALI0E16775g
# 13                                       YALI0E16775g
# 14  YALI0E10144g and YALI0E12628g and YALI0E16709g...
# 15  YALI0D14850g and YALI0D24629g and YALI0F30679g...
# 16                       YALI0D17534g or YALI0F10010g
# 17                                       YALI0A20350g
# 18  YALI0D14850g and YALI0D24629g and YALI0F30679g...
# 19                                       YALI0E00770g
# 20  YALI0D14850g and YALI0D24629g and YALI0F30679g...
# 21  YALI0A07447g or YALI0F03751g or YALI0C04477g o...
# 22  YALI0D14850g and YALI0D24629g and YALI0F30679g...
# 23                      YALI0E34793g and YALI0D24431g
#
#                                                     4
# 0                                       Lipst1_1_1740
# 1   Lipst1_1_3273 or Lipst1_1_2955 or Lipst1_1_106903
# 2   Lipst1_1_149291 or Lipst1_1_69438 or Lipst1_1_...
# 3                                      Lipst1_1_55005
# 4                                       Lipst1_1_4188
# 5   Lipst1_1_3273 or Lipst1_1_2955 or Lipst1_1_106903
# 6   Lipst1_1_3273 or Lipst1_1_2955 or Lipst1_1_106903
# 7   Lipst1_1_3273 or Lipst1_1_2955 or Lipst1_1_106903
# 8                                       Lipst1_1_7130
# 9   Lipst1_1_302018 or Lipst1_1_114557 or Lipst1_1...
# 10  Lipst1_1_3273 or Lipst1_1_2955 or Lipst1_1_106903
# 11  Lipst1_1_3273 or Lipst1_1_2955 or Lipst1_1_106903
# 12                                      Lipst1_1_5415
# 13                                      Lipst1_1_5415
# 14  Lipst1_1_5671 or Lipst1_1_55045 or Lipst1_1_38...
# 15  Lipst1_1_3273 or Lipst1_1_2955 or Lipst1_1_106903
# 16                 Lipst1_1_161356 or Lipst1_1_253586
# 17                                     Lipst1_1_70518
# 18  Lipst1_1_3273 or Lipst1_1_2955 or Lipst1_1_106903
# 19                                     Lipst1_1_68931
# 20  Lipst1_1_3273 or Lipst1_1_2955 or Lipst1_1_106903
# 21                    Lipst1_1_61594 or Lipst1_1_6033
# 22  Lipst1_1_3273 or Lipst1_1_2955 or Lipst1_1_106903
# 23                     Lipst1_1_5446 or Lipst1_1_5447

# %%
# sce_added_orthologs_orhpans
pd.set_option('display.max_rows', None)
sce_added_orthologs_orhpans
# Out:
#                 0                                                  1  \
# 0          r_2594  CL (1-18:0, 2-16:1, 3-16:0, 4-18:1) phospholip...
# 1          r_2852  phosphatidylinositol 3-kinase (1-16:0, 2-16:1)...
# 2          r_2586  CL (1-16:0, 2-16:1, 3-18:0, 4-16:1) phospholip...
# 3          r_2719  MLCL (1-16:0, 2-16:1, 4-16:1):PC (1-18:1, 2-16...
# 4          r_2731  MLCL (1-16:0, 2-16:1, 4-18:1):PC (1-18:1, 2-18...
# 5          r_2632  MLCL (2-16:1, 3-16:1, 4-16:1):PC (1-16:0, 2-18...
# 6          r_3266  TAG lipase (1-16:0, 2-16:1, 3-18:0), lipid par...
# 7          r_2764  MLCL (1-18:1, 2-16:1, 4-16:1):PC (1-16:0, 2-16...
# 8          r_3293  TAG lipase (1-18:1, 2-18:1, 3-16:1), lipid par...
# 9          r_2328         acyl dhap reductase (16:0), lipid particle
# 10         r_4194                              Zinc transporter YKE4
# 11         r_4200  Glutathione S-transferase 1 (EC 2.5.1.18) (GST-I)
# 12         r_2327            acyl dhap reductase (18:1), ER membrane
# 13         r_3279  TAG lipase (1-18:1, 2-16:1, 3-18:1), lipid par...
# 14        r2073_1                                   Zn(2+) transport
# 15         r_3281  TAG lipase (1-16:0, 2-18:1, 3-16:1), lipid par...
# 16         r_2703  MLCL (2-18:1, 3-16:0, 4-18:1):PC (1-18:1, 2-16...
# 17         r_2675  MLCL (2-18:1, 3-16:0, 4-16:1):PC (1-18:1, 2-18...
# 18         r_3286  TAG lipase (1-16:1, 2-18:1, 3-18:0), lipid par...
# 19         r_2745  MLCL (1-16:1, 2-16:1, 4-18:1):PC (1-16:1, 2-18...
# 20         r_2712  MLCL (2-18:1, 3-16:1, 4-18:1):PC (1-16:0, 2-18...
# 21         r_2678  MLCL (2-18:1, 3-16:1, 4-16:1):PC (1-18:0, 2-16...
# 22         r_4162  Probable vacuolar amino acid transporter YPQ3 ...
# 23         r_4174                    Probable ATP-dependent permease
# 24         r_3252  ergosteryl ester hydrolase (16:1), lipid particle
# 25         r_2859  phosphatidylinositol 3-kinase (1-18:1, 2-18:1)...
# 26         r_2647  MLCL (2-16:1, 3-18:1, 4-16:1):PC (1-18:1, 2-16...
# 27         BZALDH                 Benzyl alcohol:NAD+ oxidoreductase
# 28         r_2324            acyl dhap reductase (16:0), ER membrane
# 29         r_3264  TAG lipase (1-16:0, 2-16:1, 3-16:0), lipid par...
# 30         r_2600  CL (1-16:0, 2-18:1, 3-16:0, 4-18:1) phospholip...
# 31         r_2750  MLCL (1-18:0, 2-16:1, 4-16:1):PC (1-18:0, 2-16...
# 32         r_2715  MLCL (2-18:1, 3-16:1, 4-18:1):PC (1-18:1, 2-18...
# 33         r_4219  D-aminoacyl-tRNA deacylase (DTD) (EC 3.1.1.96)...
# 34         r_2736  MLCL (1-16:1, 2-16:1, 4-16:1):PC (1-16:0, 2-18...
# 35         r_2608  CL (1-18:0, 2-16:1, 3-16:0, 4-16:1) phospholip...
# 36         r_3300        DAG lipase (1-16:0, 2-18:1), lipid particle
# 37         r_2699  MLCL (2-18:1, 3-18:1, 4-16:1):PC (1-18:1, 2-18...
# 38         r_3291  TAG lipase (1-18:0, 2-18:1, 3-18:1), lipid par...
# 39         r_2645  MLCL (2-16:1, 3-18:1, 4-16:1):PC (1-16:1, 2-16...
# 40         r_0044  3-hexaprenyl-4-hydroxy-5-methoxybenzoate decar...
# 41         r_2796  MLCL (1-16:1, 2-18:1, 4-16:1):PC (1-16:0, 2-16...
# 42         r_2656  MLCL (2-16:1, 3-16:0, 4-18:1):PC (1-16:0, 2-18...
# 43         r_0963                             quinone oxidoreductase
# 44         r_2590  CL (1-18:0, 2-16:1, 3-16:0, 4-16:1) phospholip...
# 45         r_2633  MLCL (2-16:1, 3-16:1, 4-16:1):PC (1-16:1, 2-18...
# 46         r_4333                     Polyphosphate phosphohydrolase
# 47         r_3215  PI 4,5-P2 phosphatase (1-18:1, 2-18:1), ER mem...
# 48         r_2698  MLCL (2-18:1, 3-18:1, 4-16:1):PC (1-18:0, 2-18...
# 49         r_3817  phosphatidyl-L-serine (1-16:0, 2-18:1) transpo...
# 50         r_4331  [1,4-(N-Acetyl-beta-D-glucosaminyl)]n glycanoh...
# 51          FMNRx                                      FMN reductase
# 52         r_2694  MLCL (2-18:1, 3-18:1, 4-16:1):PC (1-18:0, 2-16...
# 53         G6PI_1        alpha-D-Glucose 6-phosphate ketol-isomerase
# 54         r_2622  MLCL (2-16:1, 3-16:0, 4-16:1):PC (1-18:0, 2-16...
# 55         r_4242  Initiation-specific alpha-1,6-mannosyltransfer...
# 56         r_2720  MLCL (1-16:0, 2-16:1, 4-16:1):PC (1-16:0, 2-18...
# 57         r_2757  MLCL (1-18:0, 2-16:1, 4-18:1):PC (1-16:1, 2-16...
# 58         r_2643  MLCL (2-16:1, 3-18:0, 4-16:1):PC (1-18:1, 2-18...
# 59         r_4199  Glutathione S-transferase 1 (EC 2.5.1.18) (GST-I)
# 60         FMNRx2                                      FMN reductase
# 61          GTHDH        glutathione:dehydroascorbate oxidoreductase
# 62         r_4159  UDP-N-acetylglucosamine transferase subunit AL...
# 63         r_0993                          serine palmitotransferase
# 64        CYANSTm               thiosulfate:cyanide sulfurtranserase
# 65         r_4176  Putative aryl-alcohol dehydrogenase AAD3 (EC 1...
# 66         r_2772  MLCL (1-18:1, 2-16:1, 4-18:1):PC (1-16:0, 2-16...
# 67         r_2748  MLCL (1-18:0, 2-16:1, 4-16:1):PC (1-16:0, 2-16...
# 68         r_2646  MLCL (2-16:1, 3-18:1, 4-16:1):PC (1-18:0, 2-16...
# 69         r_1837               L-histidine transport, mitochondrial
# 70           NTP3                          nucleoside triphosphatase
# 71         r_2692  MLCL (2-18:1, 3-18:1, 4-16:1):PC (1-16:0, 2-16...
# 72         r_2727  MLCL (1-16:0, 2-16:1, 4-18:1):PC (1-18:1, 2-16...
# 73         r_2840  phosphatidylinositol 4-kinase (1-16:0, 2-18:1)...
# 74         r_2673  MLCL (2-18:1, 3-16:0, 4-16:1):PC (1-16:1, 2-18...
# 75         r_2855  phosphatidylinositol 3-kinase (1-18:1, 2-16:1)...
# 76         r_2741  MLCL (1-16:1, 2-16:1, 4-18:1):PC (1-16:1, 2-16...
# 77         r_0192                      alpha 1,2-mannosyltransferase
# 78         r_2701  MLCL (2-18:1, 3-16:0, 4-18:1):PC (1-16:1, 2-16...
# 79         r_2771  MLCL (1-18:1, 2-16:1, 4-16:1):PC (1-18:1, 2-18...
# 80         r_2662  MLCL (2-16:1, 3-16:1, 4-18:1):PC (1-18:0, 2-16...
# 81         r_2682  MLCL (2-18:1, 3-16:1, 4-16:1):PC (1-18:0, 2-18...
# 82         r_2691  MLCL (2-18:1, 3-18:0, 4-16:1):PC (1-18:1, 2-18...
# 83         r_2615  CL (1-16:0, 2-18:1, 3-18:0, 4-16:1) phospholip...
# 84         r_2751  MLCL (1-18:0, 2-16:1, 4-16:1):PC (1-18:1, 2-16...
# 85         r_2659  MLCL (2-16:1, 3-16:0, 4-18:1):PC (1-18:1, 2-18...
# 86         r_2790  MLCL (1-16:0, 2-18:1, 4-18:1):PC (1-18:0, 2-16...
# 87         r_3815  phosphatidyl-L-serine (1-18:0, 2-16:1) transpo...
# 88         r_2810  MLCL (1-16:1, 2-18:1, 4-18:1):PC (1-18:0, 2-18...
# 89         r_3220  PI 3,5-P2 phosphatase (1-16:0, 2-18:1), vacuol...
# 90         r_4250              Dolichyl-diphosphate phosphohydrolase
# 91           MNt2                                   Mn(2+) transport
# 92         r_2326            acyl dhap reductase (18:0), ER membrane
# 93         ARGt2m                                 arginine transport
# 94         r_3313  lysoPE (1-16:1) oleoyl-CoA acyltransferase, li...
# 95         r_2854  phosphatidylinositol 3-kinase (1-18:0, 2-16:1)...
# 96         r_2584  CL (1-16:0, 2-16:1, 3-16:0, 4-16:1) phospholip...
# 97         r_3217  PI 3,5-P2 phosphatase (1-16:1, 2-16:1), vacuol...
# 98         r_3222  PI 3,5-P2 phosphatase (1-18:0, 2-18:1), vacuol...
# 99         r_2809  MLCL (1-16:1, 2-18:1, 4-18:1):PC (1-16:1, 2-18...
# 100        r_2733  MLCL (1-16:1, 2-16:1, 4-16:1):PC (1-16:1, 2-16...
# 101        r_2711  MLCL (2-18:1, 3-16:1, 4-18:1):PC (1-18:1, 2-16...
# 102        r_4161  Probable vacuolar amino acid transporter YPQ3 ...
# 103        r_0089         5PP-IP5 pyrophosphorylation to 5,6-PP2-IP4
# 104        r_2668  MLCL (2-18:1, 3-16:0, 4-16:1):PC (1-16:0, 2-16...
# 105        r_3296        DAG lipase (1-16:0, 2-16:1), lipid particle
# 106        r_2621  MLCL (2-16:1, 3-16:0, 4-16:1):PC (1-16:1, 2-16...
# 107        r_2794  MLCL (1-16:0, 2-18:1, 4-18:1):PC (1-18:0, 2-18...
# 108        r_2680  MLCL (2-18:1, 3-16:1, 4-16:1):PC (1-16:0, 2-18...
# 109        r_2747  MLCL (1-16:1, 2-16:1, 4-18:1):PC (1-18:1, 2-18...
# 110        r_2679  MLCL (2-18:1, 3-16:1, 4-16:1):PC (1-18:1, 2-16...
# 111        r_2763  MLCL (1-18:0, 2-16:1, 4-18:1):PC (1-18:1, 2-18...
# 112        r_2585  CL (1-16:0, 2-16:1, 3-16:1, 4-16:1) phospholip...
# 113        r_0520                        GPI-anchor assembly, step 6
# 114        r_2592  CL (1-18:0, 2-16:1, 3-18:0, 4-16:1) phospholip...
# 115        r_2755  MLCL (1-18:0, 2-16:1, 4-16:1):PC (1-18:1, 2-18...
# 116        r_3298        DAG lipase (1-18:0, 2-16:1), lipid particle
# 117        r_2726  MLCL (1-16:0, 2-16:1, 4-18:1):PC (1-18:0, 2-16...
# 118        r_0249                           CAAX farnesyltransferase
# 119        r_2754  MLCL (1-18:0, 2-16:1, 4-16:1):PC (1-18:0, 2-18...
# 120        r_2787  MLCL (1-16:0, 2-18:1, 4-16:1):PC (1-18:1, 2-18...
# 121        r_2702  MLCL (2-18:1, 3-16:0, 4-18:1):PC (1-18:0, 2-16...
# 122        r_2774  MLCL (1-18:1, 2-16:1, 4-18:1):PC (1-18:0, 2-16...
# 123        r_3292  TAG lipase (1-18:1, 2-18:1, 3-16:0), lipid par...
# 124        r_3894  phosphatidyl-L-serine (1-16:1, 2-16:1) transpo...
# 125        r_2671  MLCL (2-18:1, 3-16:0, 4-16:1):PC (1-18:1, 2-16...
# 126        r_2710  MLCL (2-18:1, 3-16:1, 4-18:1):PC (1-18:0, 2-16...
# 127        r_3287  TAG lipase (1-16:1, 2-18:1, 3-18:1), lipid par...
# 128        r_3900  phosphatidyl-L-serine (1-18:1, 2-18:1) transpo...
# 129        r_2672  MLCL (2-18:1, 3-16:0, 4-16:1):PC (1-16:0, 2-18...
# 130        r_2778  MLCL (1-18:1, 2-16:1, 4-18:1):PC (1-18:0, 2-18...
# 131        r_2800  MLCL (1-16:1, 2-18:1, 4-16:1):PC (1-16:0, 2-18...
# 132        r_4204  Vacuolar aminopeptidase 1 (EC 3.4.11.22) (Amin...
# 133        r_3214  PI 4,5-P2 phosphatase (1-18:0, 2-18:1), ER mem...
# 134        r_2612  CL (1-18:1, 2-16:1, 3-18:0, 4-16:1) phospholip...
# 135        r_3295  TAG lipase (1-18:1, 2-18:1, 3-18:1), lipid par...
# 136        r_4704                          alkanesulfonate transport
# 137        PETHCT             phosphoethanolamine cytidyltransferase
# 138        r_0518                        GPI-anchor assembly, step 2
# 139        r_2690  MLCL (2-18:1, 3-18:0, 4-16:1):PC (1-18:0, 2-18...
# 140        r_2661  MLCL (2-16:1, 3-16:1, 4-18:1):PC (1-16:1, 2-16...
# 141      3OAS40_m          B-ketoacyl-ACP synthase (acetoacetyl-ACP)
# 142        r_2144       B-ketoacyl-ACP synthase (3-oxo-octanoyl-ACP)
# 143        r_2331         acyl dhap reductase (18:1), lipid particle
# 144        r_2602  CL (1-16:0, 2-16:1, 3-16:0, 4-16:1) phospholip...
# 145        r_2792  MLCL (1-16:0, 2-18:1, 4-18:1):PC (1-16:0, 2-18...
# 146        r_2729  MLCL (1-16:0, 2-16:1, 4-18:1):PC (1-16:1, 2-18...
# 147        r_2760  MLCL (1-18:0, 2-16:1, 4-18:1):PC (1-16:0, 2-18...
# 148        r_2713  MLCL (2-18:1, 3-16:1, 4-18:1):PC (1-16:1, 2-18...
# 149        r_3209  PI 4,5-P2 phosphatase (1-16:1, 2-16:1), ER mem...
# 150        r_2836  phosphatidylinositol 4-kinase (1-16:0, 2-16:1)...
# 151        r_2738  MLCL (1-16:1, 2-16:1, 4-16:1):PC (1-18:0, 2-18...
# 152        r_2588  CL (1-16:0, 2-16:1, 3-16:0, 4-18:1) phospholip...
# 153        r_2740  MLCL (1-16:1, 2-16:1, 4-18:1):PC (1-16:0, 2-16...
# 154        r_0767                           NAD nucleosidase nuclear
# 155        r_2700  MLCL (2-18:1, 3-16:0, 4-18:1):PC (1-16:0, 2-16...
# 156        r_3267  TAG lipase (1-16:0, 2-16:1, 3-18:1), lipid par...
# 157        r_4592                                   Mg(2+) transport
# 158        r_4218  D-aminoacyl-tRNA deacylase (DTD) (EC 3.1.1.96)...
# 159        r_3897  phosphatidyl-L-serine (1-16:0, 2-18:1) transpo...
# 160        r_2786  MLCL (1-16:0, 2-18:1, 4-16:1):PC (1-18:0, 2-18...
# 161        r_2665  MLCL (2-16:1, 3-16:1, 4-18:1):PC (1-16:1, 2-18...
# 162        r_4308  Probable phospholipid-transporting ATPase DNF3...
# 163        r_2784  MLCL (1-16:0, 2-18:1, 4-16:1):PC (1-16:0, 2-18...
# 164        r_4751                D-phenylalanine N-acetyltransferase
# 165        r_2717  MLCL (1-16:0, 2-16:1, 4-16:1):PC (1-16:1, 2-16...
# 166        r_2782  MLCL (1-16:0, 2-18:1, 4-16:1):PC (1-18:0, 2-16...
# 167        r_2143       B-ketoacyl-ACP synthase (3-oxo-hexanoyl-ACP)
# 168       23CAPPD            ADP-ribose 2,3-cyclic phosphodiesterase
# 169        r_2752  MLCL (1-18:0, 2-16:1, 4-16:1):PC (1-16:0, 2-18...
# 170        r_2627  MLCL (2-16:1, 3-16:0, 4-16:1):PC (1-18:1, 2-18...
# 171        r_2707  MLCL (2-18:1, 3-16:0, 4-18:1):PC (1-18:1, 2-18...
# 172        r_3211  PI 4,5-P2 phosphatase (1-18:1, 2-16:1), ER mem...
# 173        r_2808  MLCL (1-16:1, 2-18:1, 4-18:1):PC (1-16:0, 2-18...
# 174        r_4155  Glutamyl-tRNA(Gln) amidotransferase subunit B,...
# 175        r_2596  CL (1-16:0, 2-18:1, 3-16:0, 4-16:1) phospholip...
# 176        r_2604  CL (1-16:0, 2-16:1, 3-16:0, 4-18:1) phospholip...
# 177        r_3818  phosphatidyl-L-serine (1-16:1, 2-18:1) transpo...
# 178        r_2618  CL (1-16:1, 2-18:1, 3-18:0, 4-16:1) phospholip...
# 179        r_0438            ferrocytochrome-c:oxygen oxidoreductase
# 180        r_2785  MLCL (1-16:0, 2-18:1, 4-16:1):PC (1-16:1, 2-18...
# 181        r_4217  Fe(II):oxygen oxidoreductase; Fe2+:oxygen oxid...
# 182        r_2811  MLCL (1-16:1, 2-18:1, 4-18:1):PC (1-18:1, 2-18...
# 183        r_2610  CL (1-18:0, 2-16:1, 3-16:0, 4-18:1) phospholip...
# 184        r_2620  MLCL (2-16:1, 3-16:0, 4-16:1):PC (1-16:0, 2-16...
# 185        r_4181       Manganese-transporting ATPase 1 (EC 3.6.3.-)
# 186        r_2634  MLCL (2-16:1, 3-16:1, 4-16:1):PC (1-18:0, 2-18...
# 187        r_3284  TAG lipase (1-16:1, 2-18:1, 3-16:0), lipid par...
# 188        r_2773  MLCL (1-18:1, 2-16:1, 4-18:1):PC (1-16:1, 2-16...
# 189         PSP_L               phosphoserine phosphatase (L-serine)
# 190        r_2797  MLCL (1-16:1, 2-18:1, 4-16:1):PC (1-16:1, 2-16...
# 191      4MBZALDH  Putative aryl-alcohol dehydrogenase AAD3 (EC 1...
# 192        r_4313  Alpha-1,2-mannosyltransferase ALG9 (EC 2.4.1.2...
# 193        r_2841  phosphatidylinositol 4-kinase (1-16:1, 2-18:1)...
# 194        r_2637  MLCL (2-16:1, 3-18:0, 4-16:1):PC (1-16:1, 2-16...
# 195        r_2663  MLCL (2-16:1, 3-16:1, 4-18:1):PC (1-18:1, 2-16...
# 196        r_2597  CL (1-16:0, 2-18:1, 3-16:1, 4-16:1) phospholip...
# 197        r_2599  CL (1-16:0, 2-18:1, 3-18:1, 4-16:1) phospholip...
# 198        r_2709  MLCL (2-18:1, 3-16:1, 4-18:1):PC (1-16:1, 2-16...
# 199        r_2657  MLCL (2-16:1, 3-16:0, 4-18:1):PC (1-16:1, 2-18...
# 200        r_2329         acyl dhap reductase (16:1), lipid particle
# 201        r_3312  lysoPE (1-16:0) oleoyl-CoA acyltransferase, li...
# 202        r_3269  TAG lipase (1-16:1, 2-16:1, 3-16:1), lipid par...
# 203        r_2807  MLCL (1-16:1, 2-18:1, 4-18:1):PC (1-18:1, 2-16...
# 204        r_3276  TAG lipase (1-18:1, 2-16:1, 3-16:0), lipid par...
# 205        r_2706  MLCL (2-18:1, 3-16:0, 4-18:1):PC (1-18:0, 2-18...
# 206        r_2687  MLCL (2-18:1, 3-18:0, 4-16:1):PC (1-18:1, 2-16...
# 207        r_1202                             L-isoleucine transport
# 208        r_3218  PI 3,5-P2 phosphatase (1-18:0, 2-16:1), vacuol...
# 209        r_0073               4PP-IP5 depyrophosphorylation to IP6
# 210        r_3896  phosphatidyl-L-serine (1-18:1, 2-16:1) transpo...
# 211        r_0523                        GPI-anchor assembly, step 9
# 212        r_2652  MLCL (2-16:1, 3-16:0, 4-18:1):PC (1-16:0, 2-16...
# 213        r_3208  PI 4,5-P2 phosphatase (1-16:0, 2-16:1), ER mem...
# 214        r_4723                  polyphosphate phosphohydrolase, v
# 215        r_2648  MLCL (2-16:1, 3-18:1, 4-16:1):PC (1-16:0, 2-18...
# 216        r_2639  MLCL (2-16:1, 3-18:0, 4-16:1):PC (1-18:1, 2-16...
# 217        r_4167  Vacuolar cation-chloride cotransporter 1 (Vacu...
# 218        r_2744  MLCL (1-16:1, 2-16:1, 4-18:1):PC (1-16:0, 2-18...
# 219        r_2654  MLCL (2-16:1, 3-16:0, 4-18:1):PC (1-18:0, 2-16...
# 220        r_4156  Methionine aminopeptidase 2 (MAP 2) (MetAP 2) ...
# 221        r_2641  MLCL (2-16:1, 3-18:0, 4-16:1):PC (1-16:1, 2-18...
# 222        r_2616  CL (1-16:0, 2-18:1, 3-16:0, 4-18:1) phospholip...
# 223        r_2843  phosphatidylinositol 4-kinase (1-18:1, 2-18:1)...
# 224        r_3271  TAG lipase (1-16:1, 2-16:1, 3-18:1), lipid par...
# 225        r_3210  PI 4,5-P2 phosphatase (1-18:0, 2-16:1), ER mem...
# 226        r_2688  MLCL (2-18:1, 3-18:0, 4-16:1):PC (1-16:0, 2-18...
# 227        r_3213  PI 4,5-P2 phosphatase (1-16:1, 2-18:1), ER mem...
# 228        r_2685  MLCL (2-18:1, 3-18:0, 4-16:1):PC (1-16:1, 2-16...
# 229        r_2677  MLCL (2-18:1, 3-16:1, 4-16:1):PC (1-16:1, 2-16...
# 230        r_2684  MLCL (2-18:1, 3-18:0, 4-16:1):PC (1-16:0, 2-16...
# 231        r_2759  MLCL (1-18:0, 2-16:1, 4-18:1):PC (1-18:1, 2-16...
# 232        r_2617  CL (1-16:1, 2-18:1, 3-16:0, 4-16:1) phospholip...
# 233        r_4163  Probable vacuolar amino acid transporter YPQ3 ...
# 234        r_2593  CL (1-18:0, 2-16:1, 3-18:1, 4-16:1) phospholip...
# 235        r_2670  MLCL (2-18:1, 3-16:0, 4-16:1):PC (1-18:0, 2-16...
# 236        r_2636  MLCL (2-16:1, 3-18:0, 4-16:1):PC (1-16:0, 2-16...
# 237        GLYOX3                            (R)-lactate hydro-lyase
# 238        r_2669  MLCL (2-18:1, 3-16:0, 4-16:1):PC (1-16:1, 2-16...
# 239        r_3303        DAG lipase (1-18:1, 2-18:1), lipid particle
# 240        r_2716  MLCL (1-16:0, 2-16:1, 4-16:1):PC (1-16:0, 2-16...
# 241        r_2624  MLCL (2-16:1, 3-16:0, 4-16:1):PC (1-16:0, 2-18...
# 242        r_2765  MLCL (1-18:1, 2-16:1, 4-16:1):PC (1-16:1, 2-16...
# 243        r_2742  MLCL (1-16:1, 2-16:1, 4-18:1):PC (1-18:0, 2-16...
# 244        r_2611  CL (1-18:1, 2-16:1, 3-16:0, 4-16:1) phospholip...
# 245        r_2607  CL (1-16:1, 2-16:1, 3-16:0, 4-18:1) phospholip...
# 246        r_2676  MLCL (2-18:1, 3-16:1, 4-16:1):PC (1-16:0, 2-16...
# 247        r_4327  Magnesium transporter MRS2, mitochondrial (RNA...
# 248        r_2783  MLCL (1-16:0, 2-18:1, 4-16:1):PC (1-18:1, 2-16...
# 249        r_2649  MLCL (2-16:1, 3-18:1, 4-16:1):PC (1-16:1, 2-18...
# 250        r_2725  MLCL (1-16:0, 2-16:1, 4-18:1):PC (1-16:1, 2-16...
# 251        r_0357  diphosphoinositol-1,3,4,6-tetrakisphosphate di...
# 252        r_2793  MLCL (1-16:0, 2-18:1, 4-18:1):PC (1-16:1, 2-18...
# 253        r_2704  MLCL (2-18:1, 3-16:0, 4-18:1):PC (1-16:0, 2-18...
# 254        r_2718  MLCL (1-16:0, 2-16:1, 4-16:1):PC (1-18:0, 2-16...
# 255        r_2858  phosphatidylinositol 3-kinase (1-18:0, 2-18:1)...
# 256        r_2777  MLCL (1-18:1, 2-16:1, 4-18:1):PC (1-16:1, 2-18...
# 257        r_2462  lysoPI acyltransferase (1-18:0, 2-16:1), ER me...
# 258        r_4178  Putative aryl-alcohol dehydrogenase AAD3 (EC 1...
# 259        r_4239     L-arginyl-tRNA(Arg):protein arginyltransferase
# 260        r_2801  MLCL (1-16:1, 2-18:1, 4-16:1):PC (1-16:1, 2-18...
# 261        r_2325            acyl dhap reductase (16:1), ER membrane
# 262        r_3302        DAG lipase (1-18:0, 2-18:1), lipid particle
# 263        r_4388                           cyclic phosphodiesterase
# 264      THMPPt2m                     thiamine diphosphate transport
# 265        r_4158                      NADPH2:quinone oxidoreductase
# 266        r_0532      hexaprenyldihydroxybenzoate methyltransferase
# 267        r_2625  MLCL (2-16:1, 3-16:0, 4-16:1):PC (1-16:1, 2-18...
# 268        r_2664  MLCL (2-16:1, 3-16:1, 4-18:1):PC (1-16:0, 2-18...
# 269        r_2589  CL (1-16:0, 2-16:1, 3-16:1, 4-18:1) phospholip...
# 270        r_2776  MLCL (1-18:1, 2-16:1, 4-18:1):PC (1-16:0, 2-18...
# 271        r_2799  MLCL (1-16:1, 2-18:1, 4-16:1):PC (1-18:1, 2-16...
# 272         SERAT                         serine O-acetyltransferase
# 273        r_2804  MLCL (1-16:1, 2-18:1, 4-18:1):PC (1-16:0, 2-16...
# 274        r_2756  MLCL (1-18:0, 2-16:1, 4-18:1):PC (1-16:0, 2-16...
# 275        r_2761  MLCL (1-18:0, 2-16:1, 4-18:1):PC (1-16:1, 2-18...
# 276        r_4722                        polyphosphate polymerase, c
# 277        r_2601  CL (1-16:0, 2-18:1, 3-16:1, 4-18:1) phospholip...
# 278        r_2838  phosphatidylinositol 4-kinase (1-18:0, 2-16:1)...
# 279        r_0082  5-diphosphoinositol-1,2,3,4,6-pentakisphosphat...
# 280        r_2693  MLCL (2-18:1, 3-18:1, 4-16:1):PC (1-16:1, 2-16...
# 281        r_3819  phosphatidyl-L-serine (1-18:0, 2-18:1) transpo...
# 282        r_2330         acyl dhap reductase (18:0), lipid particle
# 283        r_3820  phosphatidyl-L-serine (1-18:1, 2-18:1) transpo...
# 284        r_2638  MLCL (2-16:1, 3-18:0, 4-16:1):PC (1-18:0, 2-16...
# 285        r_0521                        GPI-anchor assembly, step 7
# 286        r_2708  MLCL (2-18:1, 3-16:1, 4-18:1):PC (1-16:0, 2-16...
# 287        r_2714  MLCL (2-18:1, 3-16:1, 4-18:1):PC (1-18:0, 2-18...
# 288     2HP6MPMOm         2-hexaprenyl-6-methoxyphenol monooxygenase
# 289        r_3277  TAG lipase (1-18:1, 2-16:1, 3-16:1), lipid par...
# 290        r_2642  MLCL (2-16:1, 3-18:0, 4-16:1):PC (1-18:0, 2-18...
# 291        r_2721  MLCL (1-16:0, 2-16:1, 4-16:1):PC (1-16:1, 2-18...
# 292        r_3219  PI 3,5-P2 phosphatase (1-18:1, 2-16:1), vacuol...
# 293        r_2681  MLCL (2-18:1, 3-16:1, 4-16:1):PC (1-16:1, 2-18...
# 294        r_3275  TAG lipase (1-18:0, 2-16:1, 3-18:1), lipid par...
# 295        r_2722  MLCL (1-16:0, 2-16:1, 4-16:1):PC (1-18:0, 2-18...
# 296         PAPtm             adenosine 3',5'-bisphosphate transport
# 297        r_2609  CL (1-18:0, 2-16:1, 3-18:0, 4-16:1) phospholip...
# 298        r_4275                        Fe(II):NADP+ oxidoreductase
# 299        r_4589                                   Cu2(+) transport
# 300        r_3301        DAG lipase (1-16:1, 2-18:1), lipid particle
# 301        r_2644  MLCL (2-16:1, 3-18:1, 4-16:1):PC (1-16:0, 2-16...
# 302        r_2629  MLCL (2-16:1, 3-16:1, 4-16:1):PC (1-16:1, 2-16...
# 303      3MBZALDH  Putative aryl-alcohol dehydrogenase AAD3 (EC 1...
# 304        r_3289  TAG lipase (1-18:0, 2-18:1, 3-16:1), lipid par...
# 305        r_2767  MLCL (1-18:1, 2-16:1, 4-16:1):PC (1-18:1, 2-16...
# 306        r_3273  TAG lipase (1-18:0, 2-16:1, 3-16:1), lipid par...
# 307        r_3813  phosphatidyl-L-serine (1-16:0, 2-16:1) transpo...
# 308        r_2803  MLCL (1-16:1, 2-18:1, 4-16:1):PC (1-18:1, 2-18...
# 309        r_2779  MLCL (1-18:1, 2-16:1, 4-18:1):PC (1-18:1, 2-18...
# 310        r_2628  MLCL (2-16:1, 3-16:1, 4-16:1):PC (1-16:0, 2-16...
# 311        r_0088         5PP-IP5 pyrophosphorylation to 4,5-PP2-IP4
# 312        r_3280  TAG lipase (1-16:0, 2-18:1, 3-16:0), lipid par...
# 313        r_0340                                  dihydroceramidase
# 314        r_2739  MLCL (1-16:1, 2-16:1, 4-16:1):PC (1-18:1, 2-18...
# 315        r_2689  MLCL (2-18:1, 3-18:0, 4-16:1):PC (1-16:1, 2-18...
# 316        r_3315  lysoPE (1-18:1) oleoyl-CoA acyltransferase, li...
# 317        r_0013  2,3-diketo-5-methylthio-1-phosphopentane degra...
# 318        r_4263  Anion/proton exchange transporter GEF1 (CLC pr...
# 319        r_2735  MLCL (1-16:1, 2-16:1, 4-16:1):PC (1-18:1, 2-16...
# 320        r_3893  phosphatidyl-L-serine (1-16:0, 2-16:1) transpo...
# 321    3DH5HPBMTm  S-adenosyl-L-methionine:3-hexaprenyl-4,5-dihyd...
# 322        r_0137  acylation of GPI inositol at 2 position, GPI-a...
# 323        r_2746  MLCL (1-16:1, 2-16:1, 4-18:1):PC (1-18:0, 2-18...
# 324        r_3274  TAG lipase (1-18:0, 2-16:1, 3-18:0), lipid par...
# 325        r_2839  phosphatidylinositol 4-kinase (1-18:1, 2-16:1)...
# 326        r_2768  MLCL (1-18:1, 2-16:1, 4-16:1):PC (1-16:0, 2-18...
# 327        r_3272  TAG lipase (1-18:0, 2-16:1, 3-16:0), lipid par...
# 328        CHOLtu         Protein PNS1 (pH nine-sensitive protein 1)
# 329        r_2770  MLCL (1-18:1, 2-16:1, 4-16:1):PC (1-18:0, 2-18...
# 330        r_2613  CL (1-18:1, 2-16:1, 3-16:0, 4-18:1) phospholip...
# 331        r_2603  CL (1-16:0, 2-16:1, 3-18:0, 4-16:1) phospholip...
# 332        r_2651  MLCL (2-16:1, 3-18:1, 4-16:1):PC (1-18:1, 2-18...
# 333        r_1086                                  V-ATPase, vacuole
# 334        r_2697  MLCL (2-18:1, 3-18:1, 4-16:1):PC (1-16:1, 2-18...
# 335        r_2791  MLCL (1-16:0, 2-18:1, 4-18:1):PC (1-18:1, 2-16...
# 336        r_4700                         hydrogen sulfide transport
# 337        r_3212  PI 4,5-P2 phosphatase (1-16:0, 2-18:1), ER mem...
# 338        r_2650  MLCL (2-16:1, 3-18:1, 4-16:1):PC (1-18:0, 2-18...
# 339        r_2769  MLCL (1-18:1, 2-16:1, 4-16:1):PC (1-16:1, 2-18...
# 340        r_3288  TAG lipase (1-18:0, 2-18:1, 3-16:0), lipid par...
# 341        r_3899  phosphatidyl-L-serine (1-18:0, 2-18:1) transpo...
# 342        r_2853  phosphatidylinositol 3-kinase (1-16:1, 2-16:1)...
# 343        r_2802  MLCL (1-16:1, 2-18:1, 4-16:1):PC (1-18:0, 2-18...
# 344        r_3895  phosphatidyl-L-serine (1-18:0, 2-16:1) transpo...
# 345        r_2788  MLCL (1-16:0, 2-18:1, 4-18:1):PC (1-16:0, 2-16...
# 346        r_4754                           flavin prenyltransferase
# 347        r_2626  MLCL (2-16:1, 3-16:0, 4-16:1):PC (1-18:0, 2-18...
# 348        r_4587                                   Ca(2+) transport
# 349        r_3816  phosphatidyl-L-serine (1-18:1, 2-16:1) transpo...
# 350        r_4314  Alpha-1,2-mannosyltransferase ALG9 (EC 2.4.1.2...
# 351        r_2631  MLCL (2-16:1, 3-16:1, 4-16:1):PC (1-18:1, 2-16...
# 352        r_2619  CL (1-16:1, 2-18:1, 3-16:0, 4-18:1) phospholip...
# 353        r_0341                                  dihydroceramidase
# 354        r_2695  MLCL (2-18:1, 3-18:1, 4-16:1):PC (1-18:1, 2-16...
# 355        r_2640  MLCL (2-16:1, 3-18:0, 4-16:1):PC (1-16:0, 2-18...
# 356        r_4705                             taurocholate transport
# 357        r_1919                                   lysine transport
# 358        r_2595  CL (1-18:0, 2-16:1, 3-16:1, 4-18:1) phospholip...
# 359        r_3898  phosphatidyl-L-serine (1-16:1, 2-18:1) transpo...
# 360        r_2762  MLCL (1-18:0, 2-16:1, 4-18:1):PC (1-18:0, 2-18...
# 361        r_4312  S-adenosyl-L-methionine:carnosine N-methyltran...
# 362        r_2728  MLCL (1-16:0, 2-16:1, 4-18:1):PC (1-16:0, 2-18...
# 363        r_2630  MLCL (2-16:1, 3-16:1, 4-16:1):PC (1-18:0, 2-16...
# 364        r_1220                               L-tyrosine transport
# 365        r_2795  MLCL (1-16:0, 2-18:1, 4-18:1):PC (1-18:1, 2-18...
# 366        r_4372                           cyclic phosphodiesterase
# 367        r_2635  MLCL (2-16:1, 3-16:1, 4-16:1):PC (1-18:1, 2-18...
# 368        r_2730  MLCL (1-16:0, 2-16:1, 4-18:1):PC (1-18:0, 2-18...
# 369        r_2734  MLCL (1-16:1, 2-16:1, 4-16:1):PC (1-18:0, 2-16...
# 370        r_2686  MLCL (2-18:1, 3-18:0, 4-16:1):PC (1-18:0, 2-16...
# 371        r_4234  Phosphatidylinositol N-acetylglucosaminyltrans...
# 372        r_0343                                  dihydroceramidase
# 373        r_2749  MLCL (1-18:0, 2-16:1, 4-16:1):PC (1-16:1, 2-16...
# 374        r_2737  MLCL (1-16:1, 2-16:1, 4-16:1):PC (1-16:1, 2-18...
# 375           Clt                                 chloride transport
# 376        r_4193  S-Adenosyl-L-methionine:histone-L-lysine N6-me...
# 377        r_2705  MLCL (2-18:1, 3-16:0, 4-18:1):PC (1-16:1, 2-18...
# 378        SERD_D                             D-serine ammonia-lyase
# 379        r_2623  MLCL (2-16:1, 3-16:0, 4-16:1):PC (1-18:1, 2-16...
# 380        r_3270  TAG lipase (1-16:1, 2-16:1, 3-18:0), lipid par...
# 381        r_3216  PI 3,5-P2 phosphatase (1-16:0, 2-16:1), vacuol...
# 382        r_4322  GPI mannosyltransferase 4 (EC 2.4.1.-) (GPI ma...
# 383        r_2606  CL (1-16:1, 2-16:1, 3-18:0, 4-16:1) phospholip...
# 384        r_2723  MLCL (1-16:0, 2-16:1, 4-16:1):PC (1-18:1, 2-18...
# 385        r_3299        DAG lipase (1-18:1, 2-16:1), lipid particle
# 386        r_2766  MLCL (1-18:1, 2-16:1, 4-16:1):PC (1-18:0, 2-16...
# 387        r_4175  Putative aryl-alcohol dehydrogenase AAD3 (EC 1...
# 388        r_4210               urea hydro-lyase (cyanamide-forming)
# 389        r_4225  Broad-range acid phosphatase DET1 (EC 3.1.3.-)...
# 390        r_3223  PI 3,5-P2 phosphatase (1-18:1, 2-18:1), vacuol...
# 391        r_2857  phosphatidylinositol 3-kinase (1-16:1, 2-18:1)...
# 392        r_4337  Iron-sulfur clusters transporter ATM1, mitocho...
# 393        r_3265  TAG lipase (1-16:0, 2-16:1, 3-16:1), lipid par...
# 394       CD2abc1  P-type cation-transporting ATPase (EC 3.6.3.3)...
# 395        r_2724  MLCL (1-16:0, 2-16:1, 4-18:1):PC (1-16:0, 2-16...
# 396        r_2856  phosphatidylinositol 3-kinase (1-16:0, 2-18:1)...
# 397        r_2667  MLCL (2-16:1, 3-16:1, 4-18:1):PC (1-18:1, 2-18...
# 398        r_3282  TAG lipase (1-16:0, 2-18:1, 3-18:0), lipid par...
# 399        r_2658  MLCL (2-16:1, 3-16:0, 4-18:1):PC (1-18:0, 2-18...
# 400        r_3814  phosphatidyl-L-serine (1-16:1, 2-16:1) transpo...
# 401        r_2789  MLCL (1-16:0, 2-18:1, 4-18:1):PC (1-16:1, 2-16...
# 402        r_0331    deoxyhypusine synthase, cytosolic/mitochondrial
# 403        r_4724                  polyphosphate phosphohydrolase, m
# 404        r_4412                           cyclic phosphodiesterase
# 405        r_2674  MLCL (2-18:1, 3-16:0, 4-16:1):PC (1-18:0, 2-18...
# 406        r_2696  MLCL (2-18:1, 3-18:1, 4-16:1):PC (1-16:0, 2-18...
# 407        r_2842  phosphatidylinositol 4-kinase (1-18:0, 2-18:1)...
# 408        r_2758  MLCL (1-18:0, 2-16:1, 4-18:1):PC (1-18:0, 2-16...
# 409        r_2666  MLCL (2-16:1, 3-16:1, 4-18:1):PC (1-18:0, 2-18...
# 410        r_3278  TAG lipase (1-18:1, 2-16:1, 3-18:0), lipid par...
# 411  FCYTOB5OXR_m  NADH-cytochrome b5 reductase 1 (EC 1.6.2.2) (M...
# 412       GGCLUT2  Glutathione-specific gamma-glutamylcyclotransf...
# 413        r_2732  MLCL (1-16:1, 2-16:1, 4-16:1):PC (1-16:0, 2-16...
# 414        r_2655  MLCL (2-16:1, 3-16:0, 4-18:1):PC (1-18:1, 2-16...
# 415        r_2660  MLCL (2-16:1, 3-16:1, 4-18:1):PC (1-16:0, 2-16...
# 416        r_4203  Vacuolar aminopeptidase 1 (EC 3.4.11.22) (Amin...
# 417        r_2837  phosphatidylinositol 4-kinase (1-16:1, 2-16:1)...
# 418        r_2753  MLCL (1-18:0, 2-16:1, 4-16:1):PC (1-16:1, 2-18...
# 419        r_1085                                    V-ATPase, Golgi
# 420        r_2463  lysoPI acyltransferase (1-18:0, 2-18:1), ER me...
# 421        r_2798  MLCL (1-16:1, 2-18:1, 4-16:1):PC (1-18:0, 2-16...
# 422        r_2781  MLCL (1-16:0, 2-18:1, 4-16:1):PC (1-16:1, 2-16...
# 423        r_2587  CL (1-16:0, 2-16:1, 3-18:1, 4-16:1) phospholip...
# 424        r_0522                        GPI-anchor assembly, step 8
# 425        r_3297        DAG lipase (1-16:1, 2-16:1), lipid particle
# 426        r_2653  MLCL (2-16:1, 3-16:0, 4-18:1):PC (1-16:1, 2-16...
# 427        r_2683  MLCL (2-18:1, 3-16:1, 4-16:1):PC (1-18:1, 2-18...
# 428        r_1208                     L-leucine transport, vacuoluar
# 429        r_0092               6PP-IP5 depyrophosphorylation to IP6
# 430        r_1684                                  choline transport
# 431        r_3314  lysoPE (1-18:0) oleoyl-CoA acyltransferase, li...
# 432        r_4725                  polyphosphate phosphohydrolase, n
# 433        r_2780  MLCL (1-16:0, 2-18:1, 4-16:1):PC (1-16:0, 2-16...
# 434        r_3294  TAG lipase (1-18:1, 2-18:1, 3-18:0), lipid par...
# 435        r_2598  CL (1-16:0, 2-18:1, 3-18:0, 4-16:1) phospholip...
# 436        r_2805  MLCL (1-16:1, 2-18:1, 4-18:1):PC (1-16:1, 2-16...
# 437        r_4403                      Triphosphate phosphohydrolase
# 438        r_3283  TAG lipase (1-16:0, 2-18:1, 3-18:1), lipid par...
# 439        r_2614  CL (1-16:0, 2-18:1, 3-16:0, 4-16:1) phospholip...
# 440        r_4247     ATP:L-threonyl,bicarbonate adenylyltransferase
# 441        r_4339           UDP-N-acetylglucosamine transporter YEA4
# 442        r_4233  S-Adenosyl-L-methionine:protein-C-terminal-S-f...
# 443     2HPMBQMTm  2-hexaprenyl-6-methoxy-1,4-benzoquinone methyl...
# 444        r_3285  TAG lipase (1-16:1, 2-18:1, 3-16:1), lipid par...
# 445        r_2806  MLCL (1-16:1, 2-18:1, 4-18:1):PC (1-18:0, 2-16...
# 446        r_4278             diphthine:ammonia ligase (AMP-forming)
# 447        r_2775  MLCL (1-18:1, 2-16:1, 4-18:1):PC (1-18:1, 2-16...
# 448        r_2743  MLCL (1-16:1, 2-16:1, 4-18:1):PC (1-18:1, 2-16...
# 449        r_0342                                  dihydroceramidase
# 450        r_3268  TAG lipase (1-16:1, 2-16:1, 3-16:0), lipid par...
# 451        r_4195                              Zinc transporter YKE4
# 452        r_2591  CL (1-18:0, 2-16:1, 3-16:1, 4-16:1) phospholip...
# 453        r_3221  PI 3,5-P2 phosphatase (1-16:1, 2-18:1), vacuol...
# 454        r_3253  ergosteryl ester hydrolase (18:1), lipid particle
# 455        r_2605  CL (1-16:1, 2-16:1, 3-16:0, 4-16:1) phospholip...
# 456        r_3290  TAG lipase (1-18:0, 2-18:1, 3-18:0), lipid par...
#
#                                                      2  \
# 0         h2o_mm + s_3250 --> h_mm + ocdca_mm + s_3275
# 1           atp_vm + h_vm + s_3340 --> adp_vm + s_3392
# 2          h2o_mm + s_3236 --> h_mm + hdca_mm + s_3273
# 3             s_3284 + s_3302 <=> 1agpc181_mm + s_3235
# 4             s_3285 + s_3307 <=> 1agpc181_mm + s_3314
# 5             s_3272 + s_3304 <=> 1agpc160_mm + s_3253
# 6         h2o_lp + s_3067 --> h_lp + ocdca_lp + s_3043
# 7             s_3290 + s_3296 <=> 1agpc160_mm + s_3253
# 8    h2o_lp + s_3066 --> 12dgr181_lp + h_lp + hdcea_lp
# 9    h_lp + nadph_lp + s_2948 --> 1hdecg3p_lp + nad...
# 10                                    zn2_c <=> zn2_er
# 11                gthrd_c + s_3834 <=> s_3835 + s_3836
# 12    h_erm + nadph_erm + s_2943 --> nadp_erm + s_2938
# 13   h2o_lp + tag1819Z1619Z1819Z_lp --> h_lp + ocdc...
# 14                         h_e + zn2_e <=> h_c + zn2_c
# 15        h2o_lp + s_3060 --> h_lp + hdcea_lp + s_3045
# 16            s_3282 + s_3302 <=> 1agpc181_mm + s_3268
# 17            s_3278 + s_3307 <=> 1agpc181_mm + s_3308
# 18        h2o_lp + s_3070 --> h_lp + ocdca_lp + s_3049
# 19            s_3287 + s_3305 <=> 1agpc161_mm + s_3315
# 20            s_3283 + s_3304 <=> 1agpc160_mm + s_3313
# 21            s_3279 + s_3300 <=> 1agpc180_mm + s_3265
# 22                               his__L_v <=> his__L_c
# 23                        chsterol_er <=> chsterol_erm
# 24      h2o_lp + s_3656 --> ergst_lp + h_lp + hdcea_lp
# 25          atp_vm + h_vm + s_3356 --> adp_vm + s_3399
# 26            s_3274 + s_3302 <=> 1agpc181_mm + s_3243
# 27           bzalc_c + nad_c <=> bzal_c + h_c + nadh_c
# 28   h_erm + nadph_erm + s_2940 --> 1hdecg3p_erm + ...
# 29         h2o_lp + s_3044 --> h_lp + hdca_lp + s_3043
# 30         h2o_mm + s_3262 --> h_mm + hdca_mm + s_3282
# 31            s_3288 + s_3300 <=> 1agpc180_mm + s_3247
# 32            s_3283 + s_3307 <=> 1agpc181_mm + s_3313
# 33         h2o_c + s_3857 <=> h_c + s_3858 + trnatyr_c
# 34            s_3286 + s_3304 <=> 1agpc160_mm + s_3243
# 35         h2o_mm + s_3246 --> h_mm + hdca_mm + s_3288
# 36    h2o_lp + s_3045 --> h_lp + mag160_lp + ocdcea_lp
# 37            s_3281 + s_3307 <=> 1agpc181_mm + s_3311
# 38       h2o_lp + s_3080 --> h_lp + ocdcea_lp + s_3053
# 39          pc161_mm + s_3274 <=> 1agpc161_mm + s_3243
# 40                3hph5mb_m + h_m --> 2hp6mp_m + co2_m
# 41            s_3294 + s_3296 <=> 1agpc160_mm + s_3265
# 42            s_3275 + s_3304 <=> 1agpc160_mm + s_3256
# 43   2hpmmbq_m + h_m + nadh_m + o2_m --> 2hpmhmbq_m...
# 44        h2o_mm + s_3246 --> h_mm + ocdca_mm + s_3270
# 45            s_3272 + s_3305 <=> 1agpc161_mm + s_3253
# 46                   h2o_c + s_4018 <=> h_c + 2.0 pi_c
# 47    h2o_erm + s_3615 --> 2.0 h_erm + pi_erm + s_3591
# 48            s_3281 + s_3306 <=> 1agpc180_mm + s_3311
# 49                                   s_3113 <=> s_3155
# 50                          chtn_c + h2o_c <=> acgam_c
# 51        fmn_c + 2.0 h_c + nadh_c --> fmnh2_c + nad_c
# 52            s_3281 + s_3300 <=> 1agpc180_mm + s_3267
# 53                                 g6p_A_c <=> g6p_B_c
# 54            s_3270 + s_3300 <=> 1agpc180_mm + s_3240
# 55      gdpmann_er + s_3891 <=> gdp_er + h_er + s_3893
# 56            s_3284 + s_3304 <=> 1agpc160_mm + s_3237
# 57          pc161_mm + s_3289 <=> 1agpc161_mm + s_3251
# 58            s_3273 + s_3307 <=> 1agpc181_mm + s_3254
# 59               gthrd_er + s_3830 <=> s_3832 + s_3833
# 60      fmn_c + 2.0 h_c + nadph_c --> fmnh2_c + nadp_c
# 61     dhdascb_c + 2.0 gthrd_c <=> ascb__L_c + gthox_c
# 62   naglc2p_er + uacgam_er <=> h_er + s_3767 + udp_er
# 63   h_er + pmtcoa_er + ser__L_er --> 3dsphgn_er + ...
# 64       cyan_m + tsul_m <=> 2.0 h_m + so3_m + tcynt_m
# 65            nad_c + s_3791 <=> h_c + nadh_c + s_3792
# 66            s_3291 + s_3296 <=> 1agpc160_mm + s_3257
# 67            s_3288 + s_3296 <=> 1agpc160_mm + s_3247
# 68            s_3274 + s_3300 <=> 1agpc180_mm + s_3243
# 69                               his__L_c --> his__L_m
# 70                gtp_c + h2o_c --> gdp_c + h_c + pi_c
# 71            s_3281 + s_3296 <=> 1agpc160_mm + s_3267
# 72            s_3285 + s_3302 <=> 1agpc181_mm + s_3239
# 73          atp_gm + h_gm + s_3368 --> adp_gm + s_3369
# 74            s_3278 + s_3305 <=> 1agpc161_mm + s_3308
# 75          atp_vm + h_vm + s_3348 --> adp_vm + s_3395
# 76          pc161_mm + s_3287 <=> 1agpc161_mm + s_3245
# 77        gdpmann_g + h_g + mpdol_g --> gdp_g + s_0414
# 78          pc161_mm + s_3282 <=> 1agpc161_mm + s_3268
# 79            s_3290 + s_3307 <=> 1agpc181_mm + s_3255
# 80            s_3276 + s_3300 <=> 1agpc180_mm + s_3245
# 81            s_3279 + s_3306 <=> 1agpc180_mm + s_3309
# 82            s_3280 + s_3307 <=> 1agpc181_mm + s_3310
# 83        h2o_mm + s_3260 --> h_mm + ocdca_mm + s_3292
# 84            s_3288 + s_3302 <=> 1agpc181_mm + s_3247
# 85            s_3275 + s_3307 <=> 1agpc181_mm + s_3256
# 86            s_3293 + s_3300 <=> 1agpc180_mm + s_3263
# 87                                   s_3111 <=> s_3151
# 88            s_3295 + s_3306 <=> 1agpc180_mm + s_3319
# 89       h2o_vm + s_3420 --> 2.0 h_vm + pi_vm + s_3396
# 90          h2o_er + h_er + s_3888 <=> dolp_er + pi_er
# 91                         h_e + mn2_e <=> h_c + mn2_c
# 92   h_erm + nadph_erm + s_2942 --> 1odecg3p_erm + ...
# 93                   arg__L_c + h_c --> arg__L_m + h_m
# 94      1agpe161_lp + ocdce9coa_lp --> coa_lp + s_3688
# 95          atp_vm + h_vm + s_3346 --> adp_vm + s_3394
# 96         h2o_mm + s_3234 --> h_mm + hdca_mm + s_3270
# 97   h2o_vm + s_3417 --> 2.0 h_vm + pail3p161_vm + ...
# 98       h2o_vm + s_3422 --> 2.0 h_vm + pi_vm + s_3398
# 99            s_3295 + s_3305 <=> 1agpc161_mm + s_3319
# 100     pc161_mm + s_3286 <=> 1agpc161_mm + clpn161_mm
# 101           s_3283 + s_3302 <=> 1agpc181_mm + s_3269
# 102                              arg__L_v <=> arg__L_c
# 103   2.0 h_c + pi_c + ppmi12346p_c <=> h2o_c + s_0309
# 104           s_3278 + s_3296 <=> 1agpc160_mm + s_3264
# 105    h2o_lp + s_3043 --> h_lp + hdcea_lp + mag160_lp
# 106         pc161_mm + s_3270 <=> 1agpc161_mm + s_3240
# 107           s_3293 + s_3306 <=> 1agpc180_mm + s_3318
# 108           s_3279 + s_3304 <=> 1agpc160_mm + s_3309
# 109           s_3287 + s_3307 <=> 1agpc181_mm + s_3315
# 110           s_3279 + s_3302 <=> 1agpc181_mm + s_3265
# 111           s_3289 + s_3307 <=> 1agpc181_mm + s_3316
# 112        h2o_mm + s_3235 --> h_mm + hdca_mm + s_3272
# 113                       pe_hs_er + s_0334 <=> s_0337
# 114       h2o_mm + s_3248 --> h_mm + ocdca_mm + s_3273
# 115           s_3288 + s_3307 <=> 1agpc181_mm + s_3249
# 116    h2o_lp + s_3051 --> h_lp + hdcea_lp + mag180_lp
# 117           s_3285 + s_3300 <=> 1agpc180_mm + s_3239
# 118                 4hbz_c + s_1231 --> ppi_c + s_1230
# 119           s_3288 + s_3306 <=> 1agpc180_mm + s_3249
# 120           s_3292 + s_3307 <=> 1agpc181_mm + s_3261
# 121           s_3282 + s_3300 <=> 1agpc180_mm + s_3268
# 122           s_3291 + s_3300 <=> 1agpc180_mm + s_3257
# 123   h2o_lp + s_3058 --> 12dgr181_lp + h_lp + hdca_lp
# 124                                  s_3110 <=> s_3480
# 125           s_3278 + s_3302 <=> 1agpc181_mm + s_3264
# 126           s_3283 + s_3300 <=> 1agpc180_mm + s_3269
# 127      h2o_lp + s_3078 --> h_lp + ocdcea_lp + s_3049
# 128                                  s_3116 <=> s_3489
# 129           s_3278 + s_3304 <=> 1agpc160_mm + s_3308
# 130           s_3291 + s_3306 <=> 1agpc180_mm + s_3317
# 131           s_3294 + s_3304 <=> 1agpc160_mm + s_3267
# 132     ala_L_ile__L_v + h2o_v <=> ala__L_v + leu__L_v
# 133   h2o_erm + s_3614 --> 2.0 h_erm + pi_erm + s_3590
# 134       h2o_mm + s_3254 --> h_mm + ocdca_mm + s_3290
# 135  h2o_lp + s_3082 --> 12dgr181_lp + h_lp + ocdce...
# 136                                  s_4266 --> s_4265
# 137         ctp_c + ethamp_c + h_c --> cdpea_c + ppi_c
# 138  acgpail_hs_er + h2o_er <=> ac_er + gpail_hs_er...
# 139           s_3280 + s_3306 <=> 1agpc180_mm + s_3310
# 140         pc161_mm + s_3276 <=> 1agpc161_mm + s_3245
# 141  acACP_m + h_m + malACP_m --> ACP_m + actACP_m ...
# 142  h_m + malACP_m + s_2773 --> 3ooctACP_m + ACP_m...
# 143      h_lp + nadph_lp + s_2951 --> nadp_lp + s_2947
# 144        h2o_mm + s_3234 --> h_mm + hdca_mm + s_3284
# 145           s_3293 + s_3304 <=> 1agpc160_mm + s_3318
# 146           s_3285 + s_3305 <=> 1agpc161_mm + s_3314
# 147           s_3289 + s_3304 <=> 1agpc160_mm + s_3316
# 148           s_3283 + s_3305 <=> 1agpc161_mm + s_3313
# 149  h2o_erm + s_3609 --> 2.0 h_erm + pail4p161_erm...
# 150         atp_gm + h_gm + s_3358 --> adp_gm + s_3361
# 151           s_3286 + s_3306 <=> 1agpc180_mm + s_3243
# 152        h2o_mm + s_3238 --> h_mm + hdca_mm + s_3275
# 153           s_3287 + s_3296 <=> 1agpc160_mm + s_3245
# 154          h2o_n + nad_n --> adprib_n + h_n + ncam_n
# 155           s_3282 + s_3296 <=> 1agpc160_mm + s_3268
# 156      h2o_lp + s_3075 --> h_lp + ocdcea_lp + s_3043
# 157                        h_e + mg2_e <=> h_c + mg2_c
# 158         h2o_c + s_3856 <=> gly_c + h_c + trnaala_c
# 159                                  s_3113 <=> s_3486
# 160           s_3292 + s_3306 <=> 1agpc180_mm + s_3261
# 161           s_3276 + s_3305 <=> 1agpc161_mm + s_3257
# 162  atp_erm + h2o_erm + s_3985 --> adp_erm + h_erm...
# 163           s_3292 + s_3304 <=> 1agpc160_mm + s_3261
# 164                accoa_c + s_4296 --> coa_c + s_4297
# 165         pc161_mm + s_3284 <=> 1agpc161_mm + s_3235
# 166           s_3292 + s_3300 <=> 1agpc180_mm + s_3259
# 167  h_m + malACP_m + s_2771 --> 3ohexACP_m + ACP_m...
# 168                 23camp_c + h2o_c --> amp2p_c + h_c
# 169           s_3288 + s_3304 <=> 1agpc160_mm + s_3249
# 170           s_3270 + s_3307 <=> 1agpc181_mm + s_3252
# 171           s_3282 + s_3307 <=> 1agpc181_mm + s_3312
# 172   h2o_erm + s_3611 --> 2.0 h_erm + pi_erm + s_3587
# 173           s_3295 + s_3304 <=> 1agpc160_mm + s_3319
# 174  atp_m + gln__L_m + glutrna_gln_m + h2o_m --> a...
# 175        h2o_mm + s_3258 --> h_mm + hdca_mm + s_3278
# 176        h2o_mm + s_3238 --> h_mm + hdca_mm + s_3285
# 177                                  s_3114 <=> s_3157
# 178       h2o_mm + s_3266 --> h_mm + ocdca_mm + s_3294
# 179  focytc_m + 1.266 h_m + 0.25 o2_m --> ficytc_m ...
# 180           s_3292 + s_3305 <=> 1agpc161_mm + s_3261
# 181  4.0 fe2_m + 4.0 h_m + o2_m <=> 4.0 fe3_m + 2.0...
# 182           s_3295 + s_3307 <=> 1agpc181_mm + s_3319
# 183        h2o_mm + s_3250 --> h_mm + hdca_mm + s_3289
# 184           s_3270 + s_3296 <=> 1agpc160_mm + s_3240
# 185  atp_c + h2o_c + mn2_c <=> adp_c + h_c + mn2_er...
# 186           s_3272 + s_3306 <=> 1agpc180_mm + s_3253
# 187        h2o_lp + s_3050 --> h_lp + hdca_lp + s_3049
# 188         pc161_mm + s_3291 <=> 1agpc161_mm + s_3257
# 189              h2o_c + pser__L_c --> pi_c + ser__L_c
# 190         pc161_mm + s_3294 <=> 1agpc161_mm + s_3265
# 191     4mbzalc_c + nad_c <=> 4mbzald_c + h_c + nadh_c
# 192           dolmanp_er + s_3993 <=> dolp_er + s_3994
# 193         atp_gm + h_gm + s_3370 --> adp_gm + s_3371
# 194         pc161_mm + s_3273 <=> 1agpc161_mm + s_3242
# 195           s_3276 + s_3302 <=> 1agpc181_mm + s_3245
# 196        h2o_mm + s_3259 --> h_mm + hdca_mm + s_3279
# 197        h2o_mm + s_3261 --> h_mm + hdca_mm + s_3281
# 198         pc161_mm + s_3283 <=> 1agpc161_mm + s_3269
# 199           s_3275 + s_3305 <=> 1agpc161_mm + s_3256
# 200      h_lp + nadph_lp + s_2949 --> nadp_lp + s_2945
# 201     1agpe160_lp + ocdce9coa_lp --> coa_lp + s_3686
# 202  h2o_lp + tag1619Z1619Z1619Z_lp --> 12dgr161_lp...
# 203           s_3295 + s_3302 <=> 1agpc181_mm + s_3269
# 204        h2o_lp + s_3056 --> h_lp + hdca_lp + s_3055
# 205           s_3282 + s_3306 <=> 1agpc180_mm + s_3312
# 206           s_3280 + s_3302 <=> 1agpc181_mm + s_3266
# 207                              ile__L_v <=> ile__L_c
# 208      h2o_vm + s_3418 --> 2.0 h_vm + pi_vm + s_3394
# 209           h2o_c + s_0279 --> h_c + minohp_c + pi_c
# 210                                  s_3112 <=> s_3484
# 211           pe_hs_er + s_0338 <=> dag_hs_er + s_0332
# 212           s_3275 + s_3296 <=> 1agpc160_mm + s_3244
# 213   h2o_erm + s_3608 --> 2.0 h_erm + pi_erm + s_3584
# 214                  h2o_v + s_4290 <=> h_v + 2.0 pi_v
# 215           s_3274 + s_3304 <=> 1agpc160_mm + s_3255
# 216           s_3273 + s_3302 <=> 1agpc181_mm + s_3242
# 217          cl_v + k_v + na1_v <=> cl_c + k_c + na1_c
# 218           s_3287 + s_3304 <=> 1agpc160_mm + s_3315
# 219           s_3275 + s_3300 <=> 1agpc180_mm + s_3244
# 220     h2o_v + met_L_ala__L_v <=> ala__L_v + met__L_v
# 221           s_3273 + s_3305 <=> 1agpc161_mm + s_3254
# 222        h2o_mm + s_3262 --> h_mm + hdca_mm + s_3293
# 223         atp_gm + h_gm + s_3374 --> adp_gm + s_3375
# 224  h2o_lp + tag1619Z1619Z1819Z_lp --> 12dgr161_lp...
# 225   h2o_erm + s_3610 --> 2.0 h_erm + pi_erm + s_3586
# 226           s_3280 + s_3304 <=> 1agpc160_mm + s_3310
# 227   h2o_erm + s_3613 --> 2.0 h_erm + pi_erm + s_3589
# 228         pc161_mm + s_3280 <=> 1agpc161_mm + s_3266
# 229         pc161_mm + s_3279 <=> 1agpc161_mm + s_3265
# 230           s_3280 + s_3296 <=> 1agpc160_mm + s_3266
# 231           s_3289 + s_3302 <=> 1agpc181_mm + s_3251
# 232        h2o_mm + s_3264 --> h_mm + hdca_mm + s_3294
# 233                              lys__L_v <=> lys__L_c
# 234       h2o_mm + s_3249 --> h_mm + ocdca_mm + s_3274
# 235           s_3278 + s_3300 <=> 1agpc180_mm + s_3264
# 236           s_3273 + s_3296 <=> 1agpc160_mm + s_3242
# 237                h_c + lac__D_c <=> h2o_c + mthgxl_c
# 238         pc161_mm + s_3278 <=> 1agpc161_mm + s_3264
# 239  12dgr181_lp + h2o_lp --> h_lp + magole_hs_lp +...
# 240           s_3284 + s_3296 <=> 1agpc160_mm + s_3235
# 241           s_3270 + s_3304 <=> 1agpc160_mm + s_3252
# 242         pc161_mm + s_3290 <=> 1agpc161_mm + s_3253
# 243           s_3287 + s_3300 <=> 1agpc180_mm + s_3245
# 244        h2o_mm + s_3252 --> h_mm + hdca_mm + s_3290
# 245        h2o_mm + s_3244 --> h_mm + hdca_mm + s_3287
# 246           s_3279 + s_3296 <=> 1agpc160_mm + s_3265
# 247                                    mg2_c <=> mg2_m
# 248           s_3292 + s_3302 <=> 1agpc181_mm + s_3259
# 249           s_3274 + s_3305 <=> 1agpc161_mm + s_3255
# 250         pc161_mm + s_3285 <=> 1agpc161_mm + s_3239
# 251  3.0 h2o_c + s_0309 --> 3.0 h_c + inospp1_c + 3...
# 252           s_3293 + s_3305 <=> 1agpc161_mm + s_3318
# 253           s_3282 + s_3304 <=> 1agpc160_mm + s_3312
# 254           s_3284 + s_3300 <=> 1agpc180_mm + s_3235
# 255         atp_vm + h_vm + s_3354 --> adp_vm + s_3398
# 256           s_3291 + s_3305 <=> 1agpc161_mm + s_3317
# 257            s_3126 + stcoa_erm <=> coa_erm + s_3120
# ...
# 177                     Lipst1_1_49943 or Lipst1_1_984
# 178                                    Lipst1_1_102653
# 179  Lipst1_1_3895 or Lipst1_1_65274 or Lipst1_1_65...
# 180                                     Lipst1_1_68925
# 181                                     Lipst1_1_69822
# 182                                     Lipst1_1_68925
# 183                                    Lipst1_1_102653
# 184                                     Lipst1_1_68925
# 185                                     Lipst1_1_75754
# 186                                     Lipst1_1_68925
# 187  Lipst1_1_167596 or Lipst1_1_253586 or Lipst1_1...
# 188                                     Lipst1_1_68925
# 189                                      Lipst1_1_1740
# 190                                     Lipst1_1_68925
# 191  Lipst1_1_61079 or Lipst1_1_155238 or Lipst1_1_...
# 192                                     Lipst1_1_91236
# 193                   Lipst1_1_2990 or Lipst1_1_218588
# 194                                     Lipst1_1_68925
# 195                                     Lipst1_1_68925
# 196                                    Lipst1_1_102653
# 197                                    Lipst1_1_102653
# 198                                     Lipst1_1_68925
# 199                                     Lipst1_1_68925
# 200                                     Lipst1_1_71724
# 201                                    Lipst1_1_161356
# 202  Lipst1_1_167596 or Lipst1_1_253586 or Lipst1_1...
# 203                                     Lipst1_1_68925
# 204  Lipst1_1_167596 or Lipst1_1_253586 or Lipst1_1...
# 205                                     Lipst1_1_68925
# 206                                     Lipst1_1_68925
# 207                                    Lipst1_1_106989
# 208  Lipst1_1_71408 or Lipst1_1_78240 or Lipst1_1_3...
# 209                  Lipst1_1_57858 or Lipst1_1_105766
# 210                                     Lipst1_1_49943
# 211                  Lipst1_1_141087 or Lipst1_1_38480
# 212                                     Lipst1_1_68925
# 213                                    Lipst1_1_110448
# 214                                     Lipst1_1_72748
# 215                                     Lipst1_1_68925
# 216                                     Lipst1_1_68925
# 217                                    Lipst1_1_118138
# 218                                     Lipst1_1_68925
# 219                                     Lipst1_1_68925
# 220                    Lipst1_1_338327 or Lipst1_1_904
# 221                                     Lipst1_1_68925
# 222                                    Lipst1_1_102653
# 223                   Lipst1_1_2990 or Lipst1_1_218588
# 224  Lipst1_1_167596 or Lipst1_1_253586 or Lipst1_1...
# 225                                    Lipst1_1_110448
# 226                                     Lipst1_1_68925
# 227                                    Lipst1_1_110448
# 228                                     Lipst1_1_68925
# 229                                     Lipst1_1_68925
# 230                                     Lipst1_1_68925
# 231                                     Lipst1_1_68925
# 232                                    Lipst1_1_102653
# 233                  Lipst1_1_211414 or Lipst1_1_62919
# 234                                    Lipst1_1_102653
# 235                                     Lipst1_1_68925
# 236                                     Lipst1_1_68925
# 237                                      Lipst1_1_3208
# 238                                     Lipst1_1_68925
# 239                                    Lipst1_1_161356
# 240                                     Lipst1_1_68925
# 241                                     Lipst1_1_68925
# 242                                     Lipst1_1_68925
# 243                                     Lipst1_1_68925
# 244                                    Lipst1_1_102653
# 245                                    Lipst1_1_102653
# 246                                     Lipst1_1_68925
# 247                                      Lipst1_1_1637
# 248                                     Lipst1_1_68925
# 249                                     Lipst1_1_68925
# 250                                     Lipst1_1_68925
# 251                                    Lipst1_1_105766
# 252                                     Lipst1_1_68925
# 253                                     Lipst1_1_68925
# 254                                     Lipst1_1_68925
# 255   Lipst1_1_68143 or Lipst1_1_5996 or Lipst1_1_6287
# 256                                     Lipst1_1_68925
# 257                                     Lipst1_1_68496
# 258  Lipst1_1_61079 or Lipst1_1_155238 or Lipst1_1_...
# 259                                     Lipst1_1_67104
# 260                                     Lipst1_1_68925
# 261                                     Lipst1_1_71724
# 262                                    Lipst1_1_161356
# 263                                     Lipst1_1_72954
# 264                                      Lipst1_1_5945
# 265                                      Lipst1_1_6135
# 266  Lipst1_1_63052 or Lipst1_1_108075 or Lipst1_1_...
# 267                                     Lipst1_1_68925
# 268                                     Lipst1_1_68925
# 269                                    Lipst1_1_102653
# 270                                     Lipst1_1_68925
# 271                                     Lipst1_1_68925
# 272                   Lipst1_1_4043 or Lipst1_1_164418
# 273                                     Lipst1_1_68925
# 274                                     Lipst1_1_68925
# 275                                     Lipst1_1_68925
# 276                                    Lipst1_1_106087
# 277                                    Lipst1_1_102653
# 278                   Lipst1_1_2990 or Lipst1_1_218588
# 279                                    Lipst1_1_105766
# 280                                     Lipst1_1_68925
# 281                     Lipst1_1_49943 or Lipst1_1_984
# 282                                     Lipst1_1_71724
# 283                     Lipst1_1_49943 or Lipst1_1_984
# 284                                     Lipst1_1_68925
# 285                                     Lipst1_1_74168
# 286                                     Lipst1_1_68925
# 287                                     Lipst1_1_68925
# 288  Lipst1_1_63052 or Lipst1_1_108075 or Lipst1_1_...
# 289  Lipst1_1_167596 or Lipst1_1_253586 or Lipst1_1...
# 290                                     Lipst1_1_68925
# 291                                     Lipst1_1_68925
# 292  Lipst1_1_71408 or Lipst1_1_78240 or Lipst1_1_3...
# 293                                     Lipst1_1_68925
# 294  Lipst1_1_167596 or Lipst1_1_253586 or Lipst1_1...
# 295                                     Lipst1_1_68925
# 296                                    Lipst1_1_180684
# 297                                    Lipst1_1_102653
# 298  Lipst1_1_68023 or Lipst1_1_64448 or Lipst1_1_5...
# 299                                     Lipst1_1_67749
# 300                                    Lipst1_1_161356
# 301                                     Lipst1_1_68925
# 302                                     Lipst1_1_68925
# 303  Lipst1_1_61079 or Lipst1_1_155238 or Lipst1_1_...
# 304  Lipst1_1_167596 or Lipst1_1_253586 or Lipst1_1...
# 305                                     Lipst1_1_68925
# 306  Lipst1_1_167596 or Lipst1_1_253586 or Lipst1_1...
# 307                     Lipst1_1_49943 or Lipst1_1_984
# 308                                     Lipst1_1_68925
# 309                                     Lipst1_1_68925
# 310                                     Lipst1_1_68925
# 311                                     Lipst1_1_57858
# 312  Lipst1_1_167596 or Lipst1_1_253586 or Lipst1_1...
# 313                                    Lipst1_1_296629
# 314                                     Lipst1_1_68925
# 315                                     Lipst1_1_68925
# 316                                    Lipst1_1_161356
# 317                  Lipst1_1_67605 or Lipst1_1_103456
# 318                                    Lipst1_1_263735
# 319                                     Lipst1_1_68925
# 320                                     Lipst1_1_49943
# 321  Lipst1_1_63052 or Lipst1_1_108075 or Lipst1_1_...
# 322                                     Lipst1_1_70451
# 323                                     Lipst1_1_68925
# 324  Lipst1_1_167596 or Lipst1_1_253586 or Lipst1_1...
# 325                   Lipst1_1_2990 or Lipst1_1_218588
# 326                                     Lipst1_1_68925
# 327  Lipst1_1_167596 or Lipst1_1_253586 or Lipst1_1...
# 328                                    Lipst1_1_159073
# 329                                     Lipst1_1_68925
# 330                                    Lipst1_1_102653
# 331                                    Lipst1_1_102653
# 332                                     Lipst1_1_68925
# 333  Lipst1_1_2781 or Lipst1_1_102936 or Lipst1_1_6...
# 334                                     Lipst1_1_68925
# 335                                     Lipst1_1_68925
# 336                                      Lipst1_1_6611
# 337                                    Lipst1_1_110448
# 338                                     Lipst1_1_68925
# 339                                     Lipst1_1_68925
# 340  Lipst1_1_167596 or Lipst1_1_253586 or Lipst1_1...
# 341                                     Lipst1_1_49943
# 342   Lipst1_1_68143 or Lipst1_1_5996 or Lipst1_1_6287
# 343                                     Lipst1_1_68925
# 344                                     Lipst1_1_49943
# 345                                     Lipst1_1_68925
# 346                                     Lipst1_1_76260
# 347                                     Lipst1_1_68925
# 348                                     Lipst1_1_67749
# 349                     Lipst1_1_49943 or Lipst1_1_984
# 350                                     Lipst1_1_91236
# 351                                     Lipst1_1_68925
# 352                                    Lipst1_1_102653
# 353                                    Lipst1_1_296629
# 354                                     Lipst1_1_68925
# 355                                     Lipst1_1_68925
# 356                                      Lipst1_1_6611
# 357                                    Lipst1_1_211414
# 358                                    Lipst1_1_102653
# 359                                     Lipst1_1_49943
# 360                                     Lipst1_1_68925
# 361                                     Lipst1_1_71580
# 362                                     Lipst1_1_68925
# 363                                     Lipst1_1_68925
# 364                                    Lipst1_1_106989
# 365                                     Lipst1_1_68925
# 366                                     Lipst1_1_72954
# 367                                     Lipst1_1_68925
# 368                                     Lipst1_1_68925
# 369                                     Lipst1_1_68925
# 370                                     Lipst1_1_68925
# 371  Lipst1_1_56084 or Lipst1_1_6286 or Lipst1_1_13...
# 372                                    Lipst1_1_296629
# 373                                     Lipst1_1_68925
# 374                                     Lipst1_1_68925
# 375                                    Lipst1_1_170576
# 376  Lipst1_1_103455 or Lipst1_1_106915 or Lipst1_1...
# 377                                     Lipst1_1_68925
# 378                                      Lipst1_1_1096
# 379                                     Lipst1_1_68925
# 380  Lipst1_1_167596 or Lipst1_1_253586 or Lipst1_1...
# 381  Lipst1_1_71408 or Lipst1_1_78240 or Lipst1_1_3...
# 382                                     Lipst1_1_62314
# 383                                    Lipst1_1_102653
# 384                                     Lipst1_1_68925
# 385                                    Lipst1_1_161356
# 386                                     Lipst1_1_68925
# 387  Lipst1_1_61079 or Lipst1_1_155238 or Lipst1_1_...
# 388                                     Lipst1_1_50907
# 389                      Lipst1_1_92 or Lipst1_1_71475
# 390  Lipst1_1_71408 or Lipst1_1_78240 or Lipst1_1_3...
# 391   Lipst1_1_68143 or Lipst1_1_5996 or Lipst1_1_6287
# 392                                    Lipst1_1_318678
# 393  Lipst1_1_167596 or Lipst1_1_253586 or Lipst1_1...
# 394                                      Lipst1_1_1388
# 395                                     Lipst1_1_68925
# 396   Lipst1_1_68143 or Lipst1_1_5996 or Lipst1_1_6287
# 397                                     Lipst1_1_68925
# 398  Lipst1_1_167596 or Lipst1_1_253586 or Lipst1_1...
# 399                                     Lipst1_1_68925
# 400                     Lipst1_1_49943 or Lipst1_1_984
# 401                                     Lipst1_1_68925
# 402                                    Lipst1_1_222261
# 403                                     Lipst1_1_72748
# 404                                     Lipst1_1_72954
# 405                                     Lipst1_1_68925
# 406                                     Lipst1_1_68925
# 407                   Lipst1_1_2990 or Lipst1_1_218588
# 408                                     Lipst1_1_68925
# 409                                     Lipst1_1_68925
# 410  Lipst1_1_167596 or Lipst1_1_253586 or Lipst1_1...
# 411                     Lipst1_1_6803 or Lipst1_1_2352
# 412                                     Lipst1_1_47595
# 413                                     Lipst1_1_68925
# 414                                     Lipst1_1_68925
# 415                                     Lipst1_1_68925
# 416                                    Lipst1_1_106140
# 417                   Lipst1_1_2990 or Lipst1_1_218588
# 418                                     Lipst1_1_68925
# 419  Lipst1_1_2781 or Lipst1_1_102936 or Lipst1_1_6...
# 420                                     Lipst1_1_68496
# 421                                     Lipst1_1_68925
# 422                                     Lipst1_1_68925
# 423                                    Lipst1_1_102653
# 424                                    Lipst1_1_103747
# 425                  Lipst1_1_47671 or Lipst1_1_161356
# 426                                     Lipst1_1_68925
# 427                                     Lipst1_1_68925
# 428                                    Lipst1_1_106989
# 429                  Lipst1_1_57858 or Lipst1_1_105766
# 430                  Lipst1_1_159073 or Lipst1_1_71543
# 431                                    Lipst1_1_161356
# 432                                     Lipst1_1_72748
# 433                                     Lipst1_1_68925
# 434  Lipst1_1_167596 or Lipst1_1_253586 or Lipst1_1...
# 435                                    Lipst1_1_102653
# 436                                     Lipst1_1_68925
# 437                                     Lipst1_1_72748
# 438  Lipst1_1_167596 or Lipst1_1_253586 or Lipst1_1...
# 439                                    Lipst1_1_102653
# 440                                     Lipst1_1_42443
# 441                                     Lipst1_1_99002
# 442                                     Lipst1_1_76042
# 443  Lipst1_1_63052 or Lipst1_1_108075 or Lipst1_1_...
# 444  Lipst1_1_167596 or Lipst1_1_253586 or Lipst1_1...
# 445                                     Lipst1_1_68925
# 446                                    Lipst1_1_281312
# 447                                     Lipst1_1_68925
# 448                                     Lipst1_1_68925
# 449                                    Lipst1_1_296629
# 450  Lipst1_1_167596 or Lipst1_1_253586 or Lipst1_1...
# 451                                      Lipst1_1_3875
# 452                                    Lipst1_1_102653
# 453  Lipst1_1_71408 or Lipst1_1_78240 or Lipst1_1_3...
# 454                                      Lipst1_1_1895
# 455                                    Lipst1_1_102653
# 456  Lipst1_1_167596 or Lipst1_1_253586 or Lipst1_1...

# %%
# cobra.io.save_json_model(model,'Lst_v0.1_model_withOrthoMCLallAdded_noSCEtransporters.json')

# %% [markdown]
# ## try removing the reactions with only rto genes.

# %%
temp
# Out:
# {'ACRNtp',
#  'C30CPT1',
#  'CRNtp',
#  'DNTPPA',
#  'DRTPPD',
#  'FA160COAabcp',
#  'FA183COAabcp',
#  'FA240tp',
#  'GAPP',
#  'PMDPHT'}

# %%
temp = set(wrong_rx2)

print(model.optimize().objective_value,'default\n')

for x in temp:
    with model:
        r = model.reactions.get_by_id(x)
        print(r.id)
        print(r.name)
        print(r.gene_reaction_rule)
        model.remove_reactions([r])
        print(model.optimize().objective_value)
        print('\n')
# Out:
# 0.07800483549348808 default
#
# DNTPPA
# Dihydroneopterin triphosphate pyrophosphatase
# 15385
# 0.0
#
#
# ACRNtp
# Acetylcarnitine transport out of peroxisome
# 10149
# 0.0
#
#
# FA240tp
# Fatty acid peroxisomal transport
# 9912
# 0.07800483549348884
#
#
# PMDPHT
# Pyrimidine phosphatase
# 11513
# 0.0
#
#
# C30CPT1
# Production of propionylcarnitine
# 9315
# 0.0
#
#
# GAPP
# Glyceraldehyde-3-phosphate phosphatase
# 8460
# 0.07800318735919652
#
#
# FA160COAabcp
# Fatty acyl CoA peroxisomal transport via ABC system
# 13167 and 9637
# 0.07679940446092794
#
#
# DRTPPD
# 2 5 diamino 6 ribitylamino 4 3H  pyrimidinone 5  phosphate deaminase
# 15506
# 0.0
#
#
# CRNtp
# Carnitine transport into peroxsiome
# 10149
# 0.0
#
#
# FA183COAabcp
# Fatty acid peroxisomal transport via ABC system
# 13167 and 9637
# 0.07800483549348679

# %% [markdown]
# Fatty acid transporters can be removed. however will set the gene_reaction_rule to none.

# %%
model.reactions.FA183COAabcp.gene_reaction_rule = ''
model.reactions.FA240tp.gene_reaction_rule = ''
model.reactions.FA160COAabcp.gene_reaction_rule = ''


model.reactions.ACRNtp.gene_reaction_rule = ''
model.reactions.CRNtp.gene_reaction_rule = ''
# model.reactions.FA160COAabcp.gene_reaction_rule = ''

# %%
genes = model.genes
genes = [g.id for g in genes]
wrong = [g for g in genes if 'Lipst1' not in g]
len(set(wrong))
wrong_g2 = []
wrong_rx2 = []
for g in wrong:
    reac = model.genes.get_by_id(g).reactions
    if not reac:
        print(f'{g} has no associated reaction')
        
        cobra.manipulation.delete.remove_genes(model,[g])
    for rx in reac:
        if rx:
#             print(rx,g)
            wrong_g2.append(g)
            wrong_rx2.append(rx)
print(len(set(wrong_g2)))
print(len(set(wrong_rx2)))
# Out:
# 9912 has no associated reaction
# 13167 has no associated reaction
# 9637 has no associated reaction
# 10149 has no associated reaction
# 5
# 5

# %%
wrong_rx2 = [x.id for x in wrong_rx2]
set(wrong_rx2)
# Out:
# {'C30CPT1', 'DNTPPA', 'DRTPPD', 'GAPP', 'PMDPHT'}

# %%
for rx in wrong_rx2:
    r = model.reactions.get_by_id(rx)
    print(r,r.id,r.name)
    for metabolites in r.metabolites:
        try:
            ylip.metabolites.get_by_id(metabolites.id)
        except:
            print(f'{metabolites} not in ylip')
# Out:
# DRTPPD: 25dthpp_c + h2o_c + h_c --> 5aprbu_c + nh4_c DRTPPD 2 5 diamino 6 ribitylamino 4 3H  pyrimidinone 5  phosphate deaminase
# 25dthpp_c not in ylip
# DNTPPA: ahdt_c + h2o_c --> dhpmp_c + h_c + ppi_c DNTPPA Dihydroneopterin triphosphate pyrophosphatase
# PMDPHT: 5aprbu_c + h2o_c --> 4r5au_c + pi_c PMDPHT Pyrimidine phosphatase
# C30CPT1: crn_c + ppcoa_c <=> coa_c + pcrn_c C30CPT1 Production of propionylcarnitine
# pcrn_c not in ylip
# ppcoa_c not in ylip
# GAPP: g3p_c + h2o_c --> glyald_c + pi_c GAPP Glyceraldehyde-3-phosphate phosphatase

# %%
with model:
    model.remove_reactions(['GAPP'])
    gapfiller = cobra.flux_analysis.gapfilling.GapFiller(model, sce, demand_reactions=False, integer_threshold=1e-10)
    gapfiller.model.solver.configuration.tolerances.feasibility = 1e-9
    gapfiller.model.solver.configuration.tolerances.integrality = 1e-10
#     gapfiller.model.solver.configuration.tolerances.optimality = 1e-9
    solution = gapfiller.fill()

for reaction in solution[0]:
    print(reaction.id)

# %%
with model:
    model.remove_reactions(['GAPP'])
    gapfiller = cobra.flux_analysis.gapfilling.GapFiller(model, ylip, demand_reactions=False, integer_threshold=1e-10)
    gapfiller.model.solver.configuration.tolerances.feasibility = 1e-9
    gapfiller.model.solver.configuration.tolerances.integrality = 1e-10
#     gapfiller.model.solver.configuration.tolerances.optimality = 1e-9
    solution = gapfiller.fill()

for reaction in solution[0]:
    print(reaction.id)

# %%
sce.reactions.G3PT
# Out:
# <Reaction G3PT at 0x16a4f7dd0>

# %%
# neither sce gene is available. 
# lst_sce_dict['YER062C']
# lst_sce_dict['YIL053W']

# %%
ylip.reactions.GLYC3Ptm
# Out:
# <Reaction GLYC3Ptm at 0x15bb3d1d0>

# %%
# JGI shows the following gene as a glycerol-1-phosphatase.
model.genes.Lipst1_1_67195
# Out:
# <Gene Lipst1_1_67195 at 0x15b7a3490>

# %%
model.reactions.G6PP
# Out:
# <Reaction G6PP at 0x2a150b4d0>

# %%
for rx in wrong_rx2:
    print(rx,'sce')
    with model:
        model.remove_reactions([rx])
        gapfiller = cobra.flux_analysis.gapfilling.GapFiller(model, sce, demand_reactions=False, integer_threshold=1e-10)
        gapfiller.model.solver.configuration.tolerances.feasibility = 1e-9
        gapfiller.model.solver.configuration.tolerances.integrality = 1e-10
    #     gapfiller.model.solver.configuration.tolerances.optimality = 1e-9
        solution = gapfiller.fill()

    for reaction in solution[0]:
        print(reaction.id)

    print(rx,'ylip')
    
    if rx!='C30CPT1': # reaction fails in ylip. 
        with model:
            model.remove_reactions([rx])
            gapfiller = cobra.flux_analysis.gapfilling.GapFiller(model, ylip, demand_reactions=False, integer_threshold=1e-10)
            gapfiller.model.solver.configuration.tolerances.feasibility = 1e-9
            gapfiller.model.solver.configuration.tolerances.integrality = 1e-10
        #     gapfiller.model.solver.configuration.tolerances.optimality = 1e-9
            solution = gapfiller.fill()

        for reaction in solution[0]:
            print(reaction.id)
# Out:
# DRTPPD sce
# DRTPPD
# DRTPPD ylip
# APRAUR
# DHPPDA
# DNTPPA sce
# DNTPPA
# DNTPPA ylip
# AKP1
# PMDPHT sce
# PMDPHT
# PMDPHT ylip
# PMDPHT
# C30CPT1 sce
# r_4570
# r_4571
# C30CPT1 ylip
# GAPP sce
# GLYALDDr
# GAPP ylip
# GLYC3Ptm

# %%
with ylip, model:
    ylip.remove_reactions(['PMDPHT'])
    model.remove_reactions(['PMDPHT'])
    print("Ylip growth:", ylip.slim_optimize())
    print("Model growth:", model.slim_optimize())
# Out:
# /Users/czaj603/miniconda3/envs/lipGSM/lib/python3.11/site-packages/cobra/core/group.py:147: UserWarning: need to pass in a list
#   warn("need to pass in a list")
# Ylip growth: 1.1398166174414033
# Model growth: 0.0

# %%
# # becomes infeasible. 

#     with ylip,model:
#         ylip.remove_reactions(['PMDPHT'])
#         model.remove_reactions(['PMDPHT'])
        
#         gapfiller = cobra.flux_analysis.gapfilling.GapFiller(model, ylip, demand_reactions=False, integer_threshold=1e-10)
#         gapfiller.model.solver.configuration.tolerances.feasibility = 1e-9
#         gapfiller.model.solver.configuration.tolerances.integrality = 1e-10
#     #     gapfiller.model.solver.configuration.tolerances.optimality = 1e-9
#         solution = gapfiller.fill()
# Out:
# ---------------------------------------------------------------------------
# Infeasible                                Traceback (most recent call last)
# Cell In[336], line 9
#       7     gapfiller.model.solver.configuration.tolerances.integrality = 1e-10
#       8 #     gapfiller.model.solver.configuration.tolerances.optimality = 1e-9
# ----> 9     solution = gapfiller.fill()
#
# File ~/miniconda3/envs/lipGSM/lib/python3.11/site-packages/cobra/flux_analysis/gapfilling.py:296, in GapFiller.fill(self, iterations)
#     294 used_reactions = []
#     295 for _ in range(iterations):
# --> 296     self.model.slim_optimize(
#     297         error_value=None, message="gap filling optimization failed"
#     298     )
#     299     solution = [
#     300         self.model.reactions.get_by_id(ind.rxn_id)
#     301         for ind in self.indicators
#     302         if ind._get_primal() > self.integer_threshold
#     303     ]
#     304     if not self.validate(solution):
#
# File ~/miniconda3/envs/lipGSM/lib/python3.11/site-packages/cobra/core/model.py:1200, in Model.slim_optimize(self, error_value, message)
#    1198     return error_value
#    1199 else:
# -> 1200     assert_optimal(self, message)
#
# File ~/miniconda3/envs/lipGSM/lib/python3.11/site-packages/cobra/util/solver.py:590, in assert_optimal(model, message)
#     588 if status != OPTIMAL:
#     589     exception_cls = OPTLANG_TO_EXCEPTIONS_DICT.get(status, OptimizationError)
# --> 590     raise exception_cls(f"{message} ({status}).")
#
# Infeasible: gap filling optimization failed (infeasible).

# %% [markdown]
# the sce replacements seem simplier to implement overall.

# %%
model.reactions.DRTPPD
# Out:
# <Reaction DRTPPD at 0x2a1b92f90>

# %%
ylip.reactions.APRAUR
# Out:
# <Reaction APRAUR at 0x17fefe090>

# %%
lst_ylip_dict['YALI0D06501g']
# Out:
# 'Lipst1_1_74905'

# %%
model.genes.Lipst1_1_74905
# Out:
# <Gene Lipst1_1_74905 at 0x15b78ed10>

# %%
model.reactions.DROPPRx
# Out:
# <Reaction DROPPRx at 0x15b9efe90>

# %%
ylip.reactions.DHPPDA
# Out:
# <Reaction DHPPDA at 0x16a7ad410>

# %%
wrong_rx2
# Out:
# ['DRTPPD', 'DNTPPA', 'PMDPHT', 'C30CPT1', 'GAPP']

# %%
sce.reactions.AKP1
# Out:
# <Reaction AKP1 at 0x15b095a90>

# %%
lst_sce_dict['YDR481C']
# Out:
# 'Lipst1_1_2594'

# %%
model.genes.Lipst1_1_2594
# Out:
# <Gene Lipst1_1_2594 at 0x15b787910>

# %%
model.reactions.ALKP
# Out:
# <Reaction ALKP at 0x17ff19a50>

# %%
model.remove_reactions(['DRTPPD'])
r = sce.reactions.AKP1.copy()
r.gene_reaction_rule = 'Lipst1_1_2594'
model.add_reactions([r])
model.reactions.get_by_id(r.id).gene_reaction_rule
# Out:
# 'Lipst1_1_2594'

# %%
model.remove_reactions(['DNTPPA'])

# %%
wrong_rx2
# Out:
# ['DRTPPD', 'DNTPPA', 'PMDPHT', 'C30CPT1', 'GAPP']

# %% [markdown]
# PMDPHT seems to be an essential reaction with no associated gene.

# %%
sce.reactions.get_by_id('PMDPHT')
# Out:
# <Reaction PMDPHT at 0x16a641310>

# %%
ylip.reactions.get_by_id('PMDPHT')
# Out:
# <Reaction PMDPHT at 0x15bba2410>

# %%
model.reactions.get_by_id('PMDPHT')
# Out:
# <Reaction PMDPHT at 0x2a1bc2350>

# %%
model.reactions.get_by_id('PMDPHT').gene_reaction_rule = ''

# %%
wrong_rx2
# Out:
# ['DRTPPD', 'DNTPPA', 'PMDPHT', 'C30CPT1', 'GAPP']

# %% [markdown]
# C30CPT1 - r_4570
# r_4571

# %%
model.reactions.get_by_id('C30CPT1')
# Out:
# <Reaction C30CPT1 at 0x2a1bc32d0>

# %%
sce.reactions.r_4570
# Out:
# <Reaction r_4570 at 0x16aa73650>

# %%
sce.reactions.r_4571
# Out:
# <Reaction r_4571 at 0x16a71bc50>

# %% [markdown]
# gap filled sce solution has no gpr for second reaction. remove gpr for first reaction.

# %%
model.reactions.get_by_id('C30CPT1').gene_reaction_rule = ''

# %%
sce.reactions.get_by_id('GLYALDDr')
# Out:
# <Reaction GLYALDDr at 0x16aa1b990>

# %%
# not present in the ortholog dict. 
# lst_sce_dict['YMR110C']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[358], line 1
# ----> 1 lst_sce_dict['YMR110C']
#
# KeyError: 'YMR110C'

# %%
        rx = model.reactions.get_by_id('GAPP')
        with model:
            model.remove_reactions([rx])
            gapfiller = cobra.flux_analysis.gapfilling.GapFiller(model, ylip, demand_reactions=False, integer_threshold=1e-10)
            gapfiller.model.solver.configuration.tolerances.feasibility = 1e-9
            gapfiller.model.solver.configuration.tolerances.integrality = 1e-10
        #     gapfiller.model.solver.configuration.tolerances.optimality = 1e-9
            solution = gapfiller.fill()

        for reaction in solution[0]:
            print(reaction.id)
# Out:
# APRAUR
# DHPPDA

# %%
ylip.reactions.get_by_id('GLYC3Ptm')
# Out:
# <Reaction GLYC3Ptm at 0x15bb3d1d0>

# %%
ylip.reactions.get_by_id('DHPPDA')
# Out:
# <Reaction DHPPDA at 0x16a7ad410>

# %%
model.metabolites.get_by_id('5aprbu_c')
# Out:
# <Metabolite 5aprbu_c at 0x15b7227d0>

# %%
ylip.reactions.get_by_id('APRAUR')
# Out:
# <Reaction APRAUR at 0x17fefe090>

# %%
lst_ylip_dict['YALI0D06501g']
# Out:
# 'Lipst1_1_74905'

# %%
model.genes.Lipst1_1_74905
# Out:
# <Gene Lipst1_1_74905 at 0x15b78ed10>

# %%
model.reactions.DROPPRx
# Out:
# <Reaction DROPPRx at 0x15b9efe90>

# %%
r = model.reactions.get_by_id('GAPP')
model.remove_reactions([r])

# %%
y = ylip.reactions.get_by_id('GLYC3Ptm')

# %%
model.add_reactions([y])

# %%
y = ylip.reactions.get_by_id('DHPPDA')
model.add_reactions([y])

# %%
y = ylip.reactions.get_by_id('APRAUR').copy()
y.gene_reaction_rule = 'Lipst1_1_74905'
model.add_reactions([y])

# %%
model.optimize()
# Out:
# <Solution 0.078 at 0x2a903f410>

# %%
genes = model.genes
genes = [g.id for g in genes]
wrong = [g for g in genes if 'Lipst1' not in g]
len(set(wrong))
wrong_g2 = []
wrong_rx2 = []
for g in wrong:
    reac = model.genes.get_by_id(g).reactions
    if not reac:
        print(f'{g} has no associated reaction')
        
        cobra.manipulation.delete.remove_genes(model,[g])
    for rx in reac:
        if rx:
#             print(rx,g)
            wrong_g2.append(g)
            wrong_rx2.append(rx)
print(len(set(wrong_g2)))
print(len(set(wrong_rx2)))
wrong_rx2 = [x.id for x in wrong_rx2]
set(wrong_rx2)
# Out:
# 15506 has no associated reaction
# 15385 has no associated reaction
# 11513 has no associated reaction
# 9315 has no associated reaction
# 8460 has no associated reaction
# 0
# 0
# set()

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ls = 0.07800521206597387</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>6.49E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e</td>
#       <td>4.095E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe3_e</td>
#       <td>EX_fe3_e</td>
#       <td>0.0004812</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>1</td>
#       <td>6</td>
#       <td>98.56%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e</td>
#       <td>0.04569</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e</td>
#       <td>0.004814</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_e</td>
#       <td>EX_mn2_e</td>
#       <td>4.735E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>na1_e</td>
#       <td>EX_na1_e</td>
#       <td>0.002036</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>0.4596</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>2.356</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>0.02077</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e</td>
#       <td>0.007819</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e</td>
#       <td>3.978E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>8aonn_m</td>
#       <td>SRC_8aonn_m</td>
#       <td>0.0001886</td>
#       <td>9</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>lipoate_m</td>
#       <td>SRC_lipoate_m</td>
#       <td>0.0002424</td>
#       <td>8</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>trnaala_c</td>
#       <td>SRC_trnaala_c</td>
#       <td>0.04505</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaarg_c</td>
#       <td>SRC_trnaarg_c</td>
#       <td>0.01144</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaasn_c</td>
#       <td>SRC_trnaasn_c</td>
#       <td>0.008422</td>
#       <td>10</td>
#       <td>1.38%</td>
#     </tr>
#     <tr>
#       <td>trnaasp_c</td>
#       <td>SRC_trnaasp_c</td>
#       <td>0.01539</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnacys_c</td>
#       <td>SRC_trnacys_c</td>
#       <td>0.002673</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnagln_c</td>
#       <td>SRC_trnagln_c</td>
#       <td>0.009197</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaglu_c</td>
#       <td>SRC_trnaglu_c</td>
#       <td>0.01628</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnagly_c</td>
#       <td>SRC_trnagly_c</td>
#       <td>0.04003</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnahis_c</td>
#       <td>SRC_trnahis_c</td>
#       <td>0.004771</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaile_c</td>
#       <td>SRC_trnaile_c</td>
#       <td>0.01237</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaleu_c</td>
#       <td>SRC_trnaleu_c</td>
#       <td>0.02498</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnalys_c</td>
#       <td>SRC_trnalys_c</td>
#       <td>0.01344</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnamet_c</td>
#       <td>SRC_trnamet_c</td>
#       <td>0.00445</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaphe_c</td>
#       <td>SRC_trnaphe_c</td>
#       <td>0.007423</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnapro_c</td>
#       <td>SRC_trnapro_c</td>
#       <td>0.0184</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaser_c</td>
#       <td>SRC_trnaser_c</td>
#       <td>0.02628</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnathr_c</td>
#       <td>SRC_trnathr_c</td>
#       <td>0.01702</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnatrp_c</td>
#       <td>SRC_trnatrp_c</td>
#       <td>0.001819</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnatyr_c</td>
#       <td>SRC_trnatyr_c</td>
#       <td>0.004865</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trnaval_c</td>
#       <td>SRC_trnaval_c</td>
#       <td>0.02146</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>4oglu_c</td>
#       <td>DM_4oglu_c</td>
#       <td>-0.0001087</td>
#       <td>5</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>amob_m</td>
#       <td>DM_amob_m</td>
#       <td>-0.0001886</td>
#       <td>15</td>
#       <td>0.10%</td>
#     </tr>
#     <tr>
#       <td>dad_5_m</td>
#       <td>DM_dad_5_m</td>
#       <td>-0.0001886</td>
#       <td>10</td>
#       <td>0.06%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-2.619</td>
#       <td>1</td>
#       <td>89.99%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e</td>
#       <td>-0.0003342</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>-4.275</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>-0.1232</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>hco3_e</td>
#       <td>EX_hco3_e</td>
#       <td>-0.001955</td>
#       <td>1</td>
#       <td>0.07%</td>
#     </tr>
#     <tr>
#       <td>zymst_e</td>
#       <td>EX_zymst_e</td>
#       <td>-0.01053</td>
#       <td>27</td>
#       <td>9.76%</td>
#     </tr>
#   </tbody>
# </table>

# %%
model.optimize()
# Out:
# <Solution 0.078 at 0x2aa45fb50>

# %% [markdown]
# ## adjust model subsystems.

# %%
x = []
for r in model.reactions:
    if (r.subsystem == 'Cysteine and methionine Metabolism') | (r.subsystem == 'Cysteine and methionine metabolism'):
        r.subsystem = 'Cysteine and Methionine Metabolism'
    if (r.subsystem == 'Glycine, serine and threonine metabolism'):
        r.subsystem = 'Glycine, Serine, and Threonine Metabolism'
    if (r.subsystem == 'Histidine metabolism'):
        r.subsystem = 'Histidine Metabolism'
    if (r.subsystem == 'Purine metabolism'):
        r.subsystem = 'Purine Metabolism'
    if (r.subsystem == 'Pyruvate metabolism'):
        r.subsystem = 'Pyruvate Metabolism'
        
    if (r.subsystem == 'Transport, nucleus'):
        r.subsystem = 'Transport, Nuclear'
    if (r.subsystem == 'Transport, nuclear'):
        r.subsystem = 'Transport, Nuclear'
    if (r.subsystem == 'Transport, Glyoxysome'):
        r.subsystem = 'Transport, Peroxisomal'
        print(r)
    if (r.subsystem == 'Transport, Mitochondriall'):
        r.subsystem = 'Transport, Mitochondrial'
        print(r)
    if (r.subsystem == 'Glycine, Serine, Alanine, and threonine Metabolism'):
        r.subsystem = 'Glycine, Serine, Alanine, and Threonine Metabolism'
#     if (r.subsystem == 'Glyoxylate Metabolism'):
#         print(r)
#     if (r.subsystem == 'Glyoxylate and Dicarboxylate Metabolism'):
#         r.subsystem == 'Glyoxylate Metabolism'
        
#         r.subsystem = 'Histidine Metabolism'
    x.append(r.subsystem)
    
# 'Methionine Metabolism',
#  'Methionine and cysteine Metabolism',
# Out:
# THRtm: thr__L_c <=> thr__L_m
# GLYCLTtm: glyclt_c <=> glyclt_m
# GLXtm: glx_c <=> glx_m
# METtm: met__L_c <=> met__L_m
# CYStm: cys__L_c <=> cys__L_m
# ACACt2m: acac_c + h_c <=> acac_m + h_m
# BHBtm: bhb_c + h_c <=> bhb_m + h_m
# GHBtm: ghb_c + h_c <=> ghb_m + h_m
# 4ABUTtm: 4abut_c <=> 4abut_m
# AGMt_m: agm_c <=> agm_m
# NADtm: nad_c --> nad_m

# %%
set(x)
# Out:
# {'',
#  'Alanine and Aspartate Metabolism',
#  'Alternate Carbon Metabolism',
#  'Amino sugar and nucleotide sugar Metabolism',
#  'Aminosugar Metabolism',
#  'Anaplerotic Reactions',
#  'Arabinose Metabolism',
#  'Arginine and Proline Metabolism',
#  'Ascorbate Metabolism',
#  'B-Ketoadipate Pathway',
#  'Bile Acid Biosynthesis',
#  'Biomass and maintenance functions',
#  'Biosynthesis of steroids: Terpenoid backbone synthesis',
#  'Biosynthesis of steroids: Ubiquinone/Terpenoid-quinone Biosynthesis',
#  'Biosynthesis of unsaturated fatty acids',
#  'Biotin Metabolism',
#  'Butanoate Metabolism',
#  'Calvin cycle/Pentose Phosphate Pathway',
#  'Carbohydrates and related molecules',
#  'Carbon fixation;Glutamate Metabolism;Alanine and Aspartate Metabolism',
#  'Carnitine shuttle',
#  'Cell Envelope Biosynthesis',
#  'Cholesterol Metabolism',
#  'Citric Acid Cycle',
#  'Cofactor Biosynthesis: Carnitine Biosynthesis',
#  'Cofactor and Prosthetic Group Biosynthesis',
#  'Cofactor recycling',
#  'Complex Alcohol Metabolism',
#  'Cysteine Metabolism',
#  'Cysteine and Methionine Metabolism',
#  'Drug Metabolism - other enzymes',
#  'Extracellular exchange',
#  'Fatty Acid Degradation',
#  'Fatty Acid Metabolism',
#  'Fatty Acid, Biosynthesis',
#  'Fatty acid Metabolism',
#  'Fatty acid activation',
#  'Fatty acid elongation',
#  'Fatty acid elongation in mitochondria',
#  'Fatty acid oxidation',
#  'Fatty acid oxidation, peroxisome',
#  'Fatty acid synthesis',
#  'Folate Biosynthesis',
#  'Folate Metabolism',
#  'Folate biosynthesis',
#  'Fructose and Mannose Metabolism',
#  'Galactose Metabolism',
#  'Glutamate Metabolism',
#  'Glutamine Metabolism',
#  'Glutathione metabolism',
#  'Glycerolipid Metabolism',
#  'Glycerophospholipid Metabolism',
#  'Glycine and Serine Metabolism',
#  'Glycine, Serine, Alanine, and Threonine Metabolism',
#  'Glycine, Serine, and Threonine Metabolism',
#  'Glycolysis',
#  'Glycolysis/Gluconeogenesis',
#  'Glycoprotein Metabolism',
#  'Glyoxylate Metabolism',
#  'Glyoxylate and Dicarboxylate Metabolism',
#  'High-mannose type N-glycan Biosynthesis',
#  'Histidine Metabolism',
#  'Homogentisate Pathway',
#  'Inorganic Ion Transport and Metabolism',
#  'Inositol Phosphate Metabolism',
#  'Intracellular demand',
#  'Lipopolysaccharide Biosynthesis / Recycling',
#  'Lysine Biosynthesis',
#  'Lysine Metabolism',
#  'Membrane Lipid Metabolism',
#  'Metabolite Repair',
#  'Methane Metabolism',
#  'Methionine Metabolism',
#  'Methionine and cysteine Metabolism',
#  'Methylglyoxal Metabolism',
#  'N-Glycan Biosynthesis',
#  'N-Glycan Degradation',
#  'NAD Biosynthesis',
#  'NAD Metabolism',
#  'Nicotinate and nicotinamide Metabolism',
#  'Nitrogen Metabolism',
#  'Nucleotide Salvage Pathway',
#  'Nucleotide Sugar Metabolism',
#  'Nucleotides',
#  'One carbon pool by folate',
#  'Other',
#  'Other Amino Acid Metabolism',
#  'Oxidative Phosphorylation',
#  'Pantothenate and CoA Biosynthesis',
#  'Pentose Phosphate Pathway',
#  'Pentose and Glucuronate Interconversions',
#  'Phenylalanine Metabolism',
#  'Phospholipid Biosynthesis',
#  'Phospholipid Metabolism',
#  'Porphyrin and Chlorophyll Metabolism',
#  'Propanoate Metabolism',
#  'Purine Metabolism',
#  'Purine and Pyrimidine Biosynthesis',
#  'Pyridoxine Metabolism',
#  'Pyrimidine Catabolism',
#  'Pyrimidine Metabolism',
#  'Pyruvate Metabolism',
#  'Quinone Biosynthesis',
#  'ROS Detoxification',
#  'Riboflavin Metabolism',
#  'Selenoamino acid Metabolism',
#  'Sphingolipid Metabolism',
#  'Starch and Sucrose Metabolism',
#  'Sterol Metabolism',
#  'Sulfur Metabolism',
#  'TCA cycle;Carbon fixation;CO2 fixation',
#  'Taurine and hypotaurine Metabolism',
#  'Terpenoid backbone Biosynthesis',
#  'Tetrahydrobiopterin',
#  'Thiamine Metabolism',
#  'Threonine and Lysine Metabolism',
#  'Transport',
#  'Transport Extracellular',
#  'Transport Mitochondrial',
#  'Transport, Endoplasmic Reticular',
#  'Transport, Extracellular',
#  'Transport, Golgi Apparatus',
#  'Transport, Inner Membrane',
#  'Transport, Mitochondrial',
#  'Transport, Nuclear',
#  'Transport, Outer Membrane Porin',
#  'Transport, Peroxisomal',
#  'Transport, Vacuolar',
#  'Transport, glyoxysome',
#  'Tryptophan Metabolism',
#  'Tyrosine Metabolism',
#  'Tyrosine, Tryptophan, and Phenylalanine Metabolism',
#  'Ubiquinone synthesis',
#  'Unassigned',
#  'Urea cycle/amino group Metabolism',
#  'Valine, Leucine, and Isoleucine Degradation',
#  'Valine, Leucine, and Isoleucine Metabolism',
#  'Vitamin B2 Metabolism',
#  'Vitamin B6 Metabolism',
#  'Xylose Metabolism',
#  'beta-Alanine Metabolism',
#  'tRNA Charging'}

# %% [markdown]
# ## lets clean the model to remove orphan metabolites.

# %%
# Find orphan metabolites
orphan_metabolites = [m for m in model.metabolites if len(m.reactions) == 0]

# Remove orphan metabolites from the model
model.remove_metabolites(orphan_metabolites)

# %%
orphan_metabolites
# Out:
# []

# %%
cobra.io.save_json_model(model,'../models/Lst_v0.1_model_withOrthoMCLallAdded_forPUB.json')
# cobra.io.write_sbml_model(model, "Lst_v0.1_model_verify.xml")
cobra.io.save_json_model(model,'../modelsLst_v0.2_model_forPUB_copy.json')

# %% [markdown]
# ## finally, we will not add transporters here.

# %% [markdown]
# we can separate the above reactions that need to be added into a few categories:
#
# transport (vacuole to cytoplasm) 5 rxns:
# - r_4162: his__L_v <=> his__L_c
# - r_1220: tyr__L_v <=> tyr__L_c
# - r_4163: lys__L_v <=> lys__L_c
# - r_1208: leu__L_v <=> leu__L_c
# - r_1202: ile__L_v <=> ile__L_c
#
# transport (mitochondria to cytoplasm) 3 rxns:
# - r_1919: lys__L_c --> lys__L_m
# - ARGt2m: arg__L_c + h_c --> arg__L_m + h_m
# - r_1837: his__L_c --> his__L_m
#
# transport (extracellular to cytoplasm) 8 rxns:
# - r_4587: ca2_e + h_e <=> ca2_c + h_c
# - r2073_1: h_e + zn2_e <=> h_c + zn2_c
# - MNt2: h_e + mn2_e <=> h_c + mn2_c
# - Clt: cl_e <=> cl_c
# - CHOLtu: chol_c <=> chol_e
# - r_4589: cu2_e + h_e <=> cu2_c + h_c
# - r_4592: h_e + mg2_e <=> h_c + mg2_c
